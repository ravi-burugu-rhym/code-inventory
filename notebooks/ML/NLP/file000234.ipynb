# %%
import pandas as pd
df=pd.read_csv('groups_apt.csv')

# %%
df
# Out:
#     Unnamed: 0            Name  \
# 0            0       admin@338
# 1            1            APT1
# 2            2           APT12
# 3            3           APT16
# 4            4           APT17
# ..         ...             ...
# 89          89           Thrip
# 90          90  Tropic Trooper
# 91          91           Turla
# 92          92    Winnti Group
# 93          93           WIRTE
#
#                                                 Alias  \
# 0                                                 NaN
# 1          Comment Crew, Comment Group, Comment Panda
# 2            IXESHE, DynCalc, Numbered Panda, DNSCALC
# 3                                                 NaN
# 4                                          Deputy Dog
# ..                                                ...
# 89                                                NaN
# 90                                             KeyBoy
# 91  Waterbug, WhiteBear, VENOMOUS BEAR, Snake, Kry...
# 92                                           Blackfly
# 93                                                NaN
#
#                                           description
# 0   admin@338 is a China-based cyber threat group....
# 1   APT1 is a Chinese threat group that has been a...
# 2   APT12 is a threat group that has been attribut...
# 3   APT16 is a China-based threat group that has l...
# 4   APT17 is a China-based threat group that has c...
# ..                                                ...
# 89  Thrip is an espionage group that has targeted ...
# 90  Tropic Trooper is an unaffiliated threat group...
# 91  Turla is a Russian-based threat group that has...
# 92  Winnti Group is a threat group with Chinese or...
# 93  WIRTE is a threat group that has been active s...
#
# [94 rows x 4 columns]

# %%
apt=open(r"C:\Users\admin\Desktop\Threat_intel_services\NER\apt_group_names.txt",'r', encoding="utf8")
apt=apt.readlines()
apt=[i.replace('\n','').replace(' ','') for i in apt]

malware=open(r"C:\Users\admin\Desktop\Threat_intel_services\NER\malware.txt",'r', encoding="utf8")
malware=malware.readlines()
m=[]
for i in malware:
    if '.' in i:
        m.append(i.split('.')[1])
    else:
        m.append(i)
    

for desc in df['description']:
    tokens=desc.split(' ')
    for token in tokens:   
        if token in m:
            print('malware\n',token,':',desc)
        if token in apt:
            print('APT\n',token,':',desc)
# Out:
# APT
#  APT1 : APT1 is a Chinese threat group that has been attributed to the 2nd Bureau of the People’s Liberation Army (PLA) General Staff Department’s (GSD) 3rd Department, commonly known by its Military Unit Cover Designator (MUCD) as Unit 61398.
# APT
#  APT16 : APT16 is a China-based threat group that has launched spearphishing campaigns targeting Japanese and Taiwanese organizations.
# APT
#  APT17 : APT17 is a China-based threat group that has conducted network intrusions against U.S. government entities, the defense industry, law firms, information technology companies, mining companies, and non-government organizations.
# APT
#  APT19 : APT19 is a Chinese-based threat group that has targeted a variety of industries, including defense, finance, energy, pharmaceutical, telecommunications, high tech, education, manufacturing, and legal services. In 2017, a phishing campaign was used to target seven law and investment firms.  Some analysts track APT19 and Deep Panda as the same group, but it is unclear from open source information if the groups are the same.
# APT
#  APT19 : APT19 is a Chinese-based threat group that has targeted a variety of industries, including defense, finance, energy, pharmaceutical, telecommunications, high tech, education, manufacturing, and legal services. In 2017, a phishing campaign was used to target seven law and investment firms.  Some analysts track APT19 and Deep Panda as the same group, but it is unclear from open source information if the groups are the same.
# APT
#  APT28 : APT28 is a threat group that has been attributed to Russia's Main Intelligence Directorate of the Russian General Staff by a July 2018 U.S. Department of Justice indictment. This group reportedly compromised the Hillary Clinton campaign, the Democratic National Committee, and the Democratic Congressional Campaign Committee in 2016 in an attempt to interfere with the U.S. presidential election. APT28 has been active since at least 2004.
# APT
#  APT28 : APT28 is a threat group that has been attributed to Russia's Main Intelligence Directorate of the Russian General Staff by a July 2018 U.S. Department of Justice indictment. This group reportedly compromised the Hillary Clinton campaign, the Democratic National Committee, and the Democratic Congressional Campaign Committee in 2016 in an attempt to interfere with the U.S. presidential election. APT28 has been active since at least 2004.
# APT
#  APT29 : APT29 is threat group that has been attributed to the Russian government and has operated since at least 2008.   This group reportedly compromised the Democratic National Committee starting in the summer of 2015.
# APT
#  APT3 : APT3 is a China-based threat group that researchers have attributed to China's Ministry of State Security.   This group is responsible for the campaigns known as Operation Clandestine Fox, Operation Clandestine Wolf, and Operation Double Tap.   As of June 2015, the group appears to have shifted from targeting primarily US victims to primarily political organizations in Hong Kong.
# MITRE has also developed an APT3 Adversary Emulation Plan.
# APT
#  APT3 : APT3 is a China-based threat group that researchers have attributed to China's Ministry of State Security.   This group is responsible for the campaigns known as Operation Clandestine Fox, Operation Clandestine Wolf, and Operation Double Tap.   As of June 2015, the group appears to have shifted from targeting primarily US victims to primarily political organizations in Hong Kong.
# MITRE has also developed an APT3 Adversary Emulation Plan.
# malware
#  Adversary : APT3 is a China-based threat group that researchers have attributed to China's Ministry of State Security.   This group is responsible for the campaigns known as Operation Clandestine Fox, Operation Clandestine Wolf, and Operation Double Tap.   As of June 2015, the group appears to have shifted from targeting primarily US victims to primarily political organizations in Hong Kong.
# MITRE has also developed an APT3 Adversary Emulation Plan.
# APT
#  APT32 : APT32 is a threat group that has been active since at least 2014. The group has targeted multiple private sector industries as well as with foreign governments, dissidents, and journalists with a strong focus on Southeast Asian countries like Vietnam, the Philippines, Laos, and Cambodia. They have extensively used strategic web compromises to compromise victims. The group is believed to be Vietnam-based.
# APT
#  APT33 : APT33 is a suspected Iranian threat group that has carried out operations since at least 2013. The group has targeted organizations across multiple industries in the United States, Saudi Arabia, and South Korea, with a particular interest in the aviation and energy sectors.
# APT
#  APT37 : APT37 is a suspected North Korean cyber espionage group that has been active since at least 2012. The group has targeted victims primarily in South Korea, but also in Japan, Vietnam, Russia, Nepal, China, India, Romania, Kuwait, and other parts of the Middle East. APT37 has also been linked to following campaigns between 2016-2018: Operation Daybreak, Operation Erebus, Golden Time, Evil New Year, Are you Happy?, FreeMilk, Northern Korean Human Rights, and Evil New Year 2018.
# North Korean group definitions are known to have significant overlap, and the name Lazarus Group is known to encompass a broad range of activity. Some organizations use the name Lazarus Group to refer to any activity attributed to North Korea. Some organizations track North Korean clusters or groups such as Bluenoroff, APT37, and APT38 separately, while other organizations may track some activity associated with those group names by the name Lazarus Group.
# APT
#  APT37 : APT37 is a suspected North Korean cyber espionage group that has been active since at least 2012. The group has targeted victims primarily in South Korea, but also in Japan, Vietnam, Russia, Nepal, China, India, Romania, Kuwait, and other parts of the Middle East. APT37 has also been linked to following campaigns between 2016-2018: Operation Daybreak, Operation Erebus, Golden Time, Evil New Year, Are you Happy?, FreeMilk, Northern Korean Human Rights, and Evil New Year 2018.
# North Korean group definitions are known to have significant overlap, and the name Lazarus Group is known to encompass a broad range of activity. Some organizations use the name Lazarus Group to refer to any activity attributed to North Korea. Some organizations track North Korean clusters or groups such as Bluenoroff, APT37, and APT38 separately, while other organizations may track some activity associated with those group names by the name Lazarus Group.
# malware
#  Golden : APT37 is a suspected North Korean cyber espionage group that has been active since at least 2012. The group has targeted victims primarily in South Korea, but also in Japan, Vietnam, Russia, Nepal, China, India, Romania, Kuwait, and other parts of the Middle East. APT37 has also been linked to following campaigns between 2016-2018: Operation Daybreak, Operation Erebus, Golden Time, Evil New Year, Are you Happy?, FreeMilk, Northern Korean Human Rights, and Evil New Year 2018.
# North Korean group definitions are known to have significant overlap, and the name Lazarus Group is known to encompass a broad range of activity. Some organizations use the name Lazarus Group to refer to any activity attributed to North Korea. Some organizations track North Korean clusters or groups such as Bluenoroff, APT37, and APT38 separately, while other organizations may track some activity associated with those group names by the name Lazarus Group.
# malware
#  16 : APT38 is a financially-motivated threat group that is backed by the North Korean regime. The group mainly targets banks and financial institutions and has targeted more than 16 organizations in at least 13 countries since at least 2014.
# North Korean group definitions are known to have significant overlap, and the name Lazarus Group is known to encompass a broad range of activity. Some organizations use the name Lazarus Group to refer to any activity attributed to North Korea. Some organizations track North Korean clusters or groups such as Bluenoroff, APT37, and APT38 separately, while other organizations may track some activity associated with those group names by the name Lazarus Group.
# APT
#  APT39 : APT39 is an Iranian cyber espionage group that has been active since at least 2014. They have targeted the telecommunication and travel industries to collect personal information that aligns with Iran's national priorities.
# APT
#  APT41 : APT41 is a group that carries out Chinese state-sponsored espionage activity in addition to financially motivated activity. APT41 has been active since as early as 2012. The group has been observed targeting healthcare, telecom, technology, and video game industries in 14 countries.
# APT
#  APT41 : APT41 is a group that carries out Chinese state-sponsored espionage activity in addition to financially motivated activity. APT41 has been active since as early as 2012. The group has been observed targeting healthcare, telecom, technology, and video game industries in 14 countries.
# APT
#  Axiom : Axiom is a cyber espionage group suspected to be associated with the Chinese government. It is responsible for the Operation SMN campaign.  Though both this group and Winnti Group use the malware Winnti, the two groups appear to be distinct based on differences in reporting on the groups' TTPs and targeting.
# malware
#  Winnti : Axiom is a cyber espionage group suspected to be associated with the Chinese government. It is responsible for the Operation SMN campaign.  Though both this group and Winnti Group use the malware Winnti, the two groups appear to be distinct based on differences in reporting on the groups' TTPs and targeting.
# APT
#  BlackOasis : BlackOasis is a Middle Eastern threat group that is believed to be a customer of Gamma Group. The group has shown interest in prominent figures in the United Nations, as well as opposition bloggers, activists, regional news correspondents, and think tanks.   A group known by Microsoft as NEODYMIUM is reportedly associated closely with BlackOasis operations, but evidence that the group names are aliases has not been identified.
# APT
#  BlackOasis : BlackOasis is a Middle Eastern threat group that is believed to be a customer of Gamma Group. The group has shown interest in prominent figures in the United Nations, as well as opposition bloggers, activists, regional news correspondents, and think tanks.   A group known by Microsoft as NEODYMIUM is reportedly associated closely with BlackOasis operations, but evidence that the group names are aliases has not been identified.
# APT
#  Carbanak : Carbanak is a threat group that mainly targets banks. It also refers to malware of the same name (Carbanak). It is sometimes referred to as FIN7, but these appear to be two groups using the same Carbanak malware and are therefore tracked separately.
# APT
#  Carbanak : Carbanak is a threat group that mainly targets banks. It also refers to malware of the same name (Carbanak). It is sometimes referred to as FIN7, but these appear to be two groups using the same Carbanak malware and are therefore tracked separately.
# APT
#  Carbanak : Cobalt Group is a financially motivated threat group that has primarily targeted financial institutions. The group has conducted intrusions to steal money via targeting ATM systems, card processing, payment systems and SWIFT systems. Cobalt Group has mainly targeted banks in Eastern Europe, Central Asia, and Southeast Asia. One of the alleged leaders was arrested in Spain in early 2018, but the group still appears to be active. The group has been known to target organizations in order to use their access to then compromise additional victims.        Reporting indicates there may be links between Cobalt Group and both the malware Carbanak and the group Carbanak.
# APT
#  CopyKittens : CopyKittens is an Iranian cyber espionage group that has been operating since at least 2013. It has targeted countries including Israel, Saudi Arabia, Turkey, the U.S., Jordan, and Germany. The group is responsible for the campaign known as Operation Wilted Tulip.
# APT
#  Darkhotel : Darkhotel is a threat group that has been active since at least 2004. The group has conducted activity on hotel and business center Wi‑Fi and physical connections as well as peer-to-peer and file sharing networks. The actors have also conducted spearphishing.
# APT
#  DarkHydrus : DarkHydrus is a threat group that has targeted government agencies and educational institutions in the Middle East since at least 2016. The group heavily leverages open-source tools and custom payloads for carrying out attacks.
# malware
#  Black : Deep Panda is a suspected Chinese threat group known to target many industries, including government, defense, financial, and telecommunications.  The intrusion into healthcare company Anthem has been attributed to Deep Panda.  This group is also known as Shell Crew, WebMasters, KungFu Kittens, and PinkPanther.  Deep Panda also appears to be known as Black Vine based on the attribution of both group names to the Anthem intrusion.  Some analysts track Deep Panda and APT19 as the same group, but it is unclear from open source information if the groups are the same.
# APT
#  APT19 : Deep Panda is a suspected Chinese threat group known to target many industries, including government, defense, financial, and telecommunications.  The intrusion into healthcare company Anthem has been attributed to Deep Panda.  This group is also known as Shell Crew, WebMasters, KungFu Kittens, and PinkPanther.  Deep Panda also appears to be known as Black Vine based on the attribution of both group names to the Anthem intrusion.  Some analysts track Deep Panda and APT19 as the same group, but it is unclear from open source information if the groups are the same.
# malware
#  Storm : Dust Storm is a threat group that has targeted multiple industries in Japan, South Korea, the United States, Europe, and several Southeast Asian countries.
# APT
#  FIN6 : FIN6 is a cyber crime group that has stolen payment card data and sold it for profit on underground marketplaces. This group has aggressively targeted and compromised point of sale (PoS) systems in the hospitality and retail sectors.
# APT
#  FIN7 : FIN7 is a financially-motivated threat group that has primarily targeted the U.S. retail, restaurant, and hospitality sectors since mid-2015. They often use point-of-sale malware. A portion of FIN7 was run out of a front company called Combi Security. FIN7 is sometimes referred to as Carbanak Group, but these appear to be two groups using the same Carbanak malware and are therefore tracked separately.
# APT
#  FIN7 : FIN7 is a financially-motivated threat group that has primarily targeted the U.S. retail, restaurant, and hospitality sectors since mid-2015. They often use point-of-sale malware. A portion of FIN7 was run out of a front company called Combi Security. FIN7 is sometimes referred to as Carbanak Group, but these appear to be two groups using the same Carbanak malware and are therefore tracked separately.
# APT
#  FIN7 : FIN7 is a financially-motivated threat group that has primarily targeted the U.S. retail, restaurant, and hospitality sectors since mid-2015. They often use point-of-sale malware. A portion of FIN7 was run out of a front company called Combi Security. FIN7 is sometimes referred to as Carbanak Group, but these appear to be two groups using the same Carbanak malware and are therefore tracked separately.
# APT
#  Carbanak : FIN7 is a financially-motivated threat group that has primarily targeted the U.S. retail, restaurant, and hospitality sectors since mid-2015. They often use point-of-sale malware. A portion of FIN7 was run out of a front company called Combi Security. FIN7 is sometimes referred to as Carbanak Group, but these appear to be two groups using the same Carbanak malware and are therefore tracked separately.
# APT
#  Carbanak : FIN7 is a financially-motivated threat group that has primarily targeted the U.S. retail, restaurant, and hospitality sectors since mid-2015. They often use point-of-sale malware. A portion of FIN7 was run out of a front company called Combi Security. FIN7 is sometimes referred to as Carbanak Group, but these appear to be two groups using the same Carbanak malware and are therefore tracked separately.
# APT
#  Gallmaker : Gallmaker is a cyberespionage group that has targeted victims in the Middle East and has been active since at least December 2017. The group has mainly targeted victims in the defense, military, and government sectors.
# APT
#  Gorgon : Gorgon Group is a threat group consisting of members who are suspected to be Pakistan-based or have other connections to Pakistan. The group has performed a mix of criminal and targeted attacks, including campaigns against government organizations in the United Kingdom, Spain, Russia, and the United States.
# APT
#  Honeybee : Honeybee is a campaign led by an unknown actor that targets humanitarian aid organizations and has been active in Vietnam, Singapore, Argentina, Japans, Indonesia, and Canada. It has been an active operation since August of 2017 and as recently as February 2018.
# APT
#  Ke3chang : Ke3chang is a threat group attributed to actors operating out of China.
# Ke3chang has targeted several industries, including oil, government, military, and more.
# APT
#  Kimsuky : Kimsuky is a North Korean-based threat group that has been active since at least September 2013. The group focuses on targeting Korean think tank as well as DPRK/nuclear-related targets. The group was attributed as the actor behind the Korea Hydro & Nuclear Power Co. compromise.
# malware
#  Nuclear : Kimsuky is a North Korean-based threat group that has been active since at least September 2013. The group focuses on targeting Korean think tank as well as DPRK/nuclear-related targets. The group was attributed as the actor behind the Korea Hydro & Nuclear Power Co. compromise.
# malware
#  Malware : Lazarus Group is a threat group that has been attributed to the North Korean government. The group has been active since at least 2009 and was reportedly responsible for the November 2014 destructive wiper attack against Sony Pictures Entertainment as part of a campaign named Operation Blockbuster by Novetta. Malware used by Lazarus Group correlates to other reported campaigns, including Operation Flame, Operation 1Mission, Operation Troy, DarkSeoul, and Ten Days of Rain.  In late 2017, Lazarus Group used KillDisk, a disk-wiping tool, in an attack against an online casino based in Central America.
# North Korean group definitions are known to have significant overlap, and the name Lazarus Group is known to encompass a broad range of activity. Some organizations use the name Lazarus Group to refer to any activity attributed to North Korea. Some organizations track North Korean clusters or groups such as Bluenoroff, APT37, and APT38 separately, while other organizations may track some activity associated with those group names by the name Lazarus Group.
# APT
#  Leafminer : Leafminer is an Iranian threat group that has targeted government organizations and business entities in the Middle East since at least early 2017.
# APT
#  Leviathan : Leviathan is a cyber espionage group that has been active since at least 2013. The group generally targets defense and government organizations, but has also targeted a range of industries including engineering firms, shipping and transportation, manufacturing, defense, government offices, and research universities in the United States, Western Europe, and along the South China Sea.
# APT
#  Machete : Machete is a group that has been active since at least 2010, targeting high-profile government entities in Latin American countries.
# APT
#  menuPass : menuPass is a threat group that appears to originate from China and has been active since approximately 2009. The group has targeted healthcare, defense, aerospace, and government sectors, and has targeted Japanese victims since at least 2014. In 2016 and 2017, the group targeted managed IT service providers, manufacturing and mining companies, and a university.
# APT
#  Molerats : Molerats is a politically-motivated threat group that has been operating since 2012. The group's victims have primarily been in the Middle East, Europe, and the United States.
# APT
#  MuddyWater : MuddyWater is an Iranian threat group that has primarily targeted Middle Eastern nations, and has also targeted European and North American nations. The group's victims are mainly in the telecommunications, government (IT services), and oil sectors. Activity from this group was previously linked to FIN7, but the group is believed to be a distinct group possibly motivated by espionage.
# APT
#  PROMETHIUM : NEODYMIUM is an activity group that conducted a campaign in May 2016 and has heavily targeted Turkish victims. The group has demonstrated similarity to another activity group called PROMETHIUM due to overlapping victim and campaign characteristics.   NEODYMIUM is reportedly associated closely with BlackOasis operations, but evidence that the group names are aliases has not been identified.
# APT
#  BlackOasis : NEODYMIUM is an activity group that conducted a campaign in May 2016 and has heavily targeted Turkish victims. The group has demonstrated similarity to another activity group called PROMETHIUM due to overlapping victim and campaign characteristics.   NEODYMIUM is reportedly associated closely with BlackOasis operations, but evidence that the group names are aliases has not been identified.
# APT
#  OilRig : OilRig is a suspected Iranian threat group that has targeted Middle Eastern and international victims since at least 2014. The group has targeted a variety of industries, including financial, government, energy, chemical, and telecommunications, and has largely focused its operations within the Middle East. It appears the group carries out supply chain attacks, leveraging the trust relationship between organizations to attack their primary targets. FireEye assesses that the group works on behalf of the Iranian government based on infrastructure details that contain references to Iran, use of Iranian infrastructure, and targeting that aligns with nation-state interests.       This group was previously tracked under two distinct groups, APT34 and OilRig, but was combined due to additional reporting giving higher confidence about the overlap of the activity.
# APT
#  APT34 : OilRig is a suspected Iranian threat group that has targeted Middle Eastern and international victims since at least 2014. The group has targeted a variety of industries, including financial, government, energy, chemical, and telecommunications, and has largely focused its operations within the Middle East. It appears the group carries out supply chain attacks, leveraging the trust relationship between organizations to attack their primary targets. FireEye assesses that the group works on behalf of the Iranian government based on infrastructure details that contain references to Iran, use of Iranian infrastructure, and targeting that aligns with nation-state interests.       This group was previously tracked under two distinct groups, APT34 and OilRig, but was combined due to additional reporting giving higher confidence about the overlap of the activity.
# APT
#  Orangeworm : Orangeworm is a group that has targeted organizations in the healthcare sector in the United States, Europe, and Asia since at least 2015, likely for the purpose of corporate espionage.
# APT
#  PROMETHIUM : PROMETHIUM is an activity group that has been active since at least 2012. The group conducted a campaign in May 2016 and has heavily targeted Turkish victims. PROMETHIUM has demonstrated similarity to another activity group called NEODYMIUM due to overlapping victim and campaign characteristics.
# APT
#  PROMETHIUM : PROMETHIUM is an activity group that has been active since at least 2012. The group conducted a campaign in May 2016 and has heavily targeted Turkish victims. PROMETHIUM has demonstrated similarity to another activity group called NEODYMIUM due to overlapping victim and campaign characteristics.
# malware
#  Trojan : RTM is a cybercriminal group that has been active since at least 2015 and is primarily interested in users of remote banking systems in Russia and neighboring countries. The group uses a Trojan by the same name (RTM).
# APT
#  Sandworm : Sandworm Team is a Russian cyber espionage group that has operated since approximately 2009. The group likely consists of Russian pro-hacktivists. Sandworm Team targets mainly Ukrainian entities associated with energy, industrial control systems, SCADA, government, and media. Sandworm Team has been linked to the Ukrainian energy sector attack in late 2015.
# APT
#  Sandworm : Sandworm Team is a Russian cyber espionage group that has operated since approximately 2009. The group likely consists of Russian pro-hacktivists. Sandworm Team targets mainly Ukrainian entities associated with energy, industrial control systems, SCADA, government, and media. Sandworm Team has been linked to the Ukrainian energy sector attack in late 2015.
# APT
#  Sandworm : Sandworm Team is a Russian cyber espionage group that has operated since approximately 2009. The group likely consists of Russian pro-hacktivists. Sandworm Team targets mainly Ukrainian entities associated with energy, industrial control systems, SCADA, government, and media. Sandworm Team has been linked to the Ukrainian energy sector attack in late 2015.
# APT
#  Silence : Silence is a financially motivated threat actor targeting financial institutions in different countries. The group was first seen in June 2016. Their main targets reside in Russia, Ukraine, Belarus, Azerbaijan, Poland and Kazakhstan. They compromised various banking systems, including the Russian Central Bank's Automated Workstation Client, ATMs, and card processing.
# APT
#  Sowbug : Sowbug is a threat group that has conducted targeted attacks against organizations in South America and Southeast Asia, particularly government entities, since at least 2015.
# APT
#  Strider : Strider is a threat group that has been active since at least 2011 and has targeted victims in Russia, China, Sweden, Belgium, Iran, and Rwanda.
# APT
#  Suckfly : Suckfly is a China-based threat group that has been active since at least 2014.
# APT
#  TA505 : TA505 is a financially motivated threat group that has been active since at least 2014. The group is known for frequently changing malware and driving global trends in criminal malware distribution.
# APT
#  Taidoor : Taidoor is a threat group that has operated since at least 2009 and has primarily targeted the Taiwanese government.
# APT
#  TEMP.Veles : TEMP.Veles is a Russia-based threat group that has targeted critical infrastructure. The group has been observed utilizing TRITON, a malware framework designed to manipulate industrial safety systems.
# malware
#  White : The White Company is a likely state-sponsored threat actor with advanced capabilities. From 2017 through 2018, the group led an espionage campaign called Operation Shaheen targeting government and military organizations in Pakistan.
# APT
#  Thrip : Thrip is an espionage group that has targeted satellite communications, telecoms, and defense contractor companies in the U.S. and Southeast Asia. The group uses custom malware as well as "living off the land" techniques.
# malware
#  Turla : Turla is a Russian-based threat group that has infected victims in over 45 countries, spanning a range of industries including government, embassies, military, education, research and pharmaceutical companies since 2004. Heightened activity was seen in mid-2015. Turla is known for conducting watering hole and spearphishing campaigns and leveraging in-house tools and malware. Turla’s espionage platform is mainly used against Windows machines, but has also been seen used against macOS and Linux machines.
# APT
#  Turla : Turla is a Russian-based threat group that has infected victims in over 45 countries, spanning a range of industries including government, embassies, military, education, research and pharmaceutical companies since 2004. Heightened activity was seen in mid-2015. Turla is known for conducting watering hole and spearphishing campaigns and leveraging in-house tools and malware. Turla’s espionage platform is mainly used against Windows machines, but has also been seen used against macOS and Linux machines.
# malware
#  Turla : Turla is a Russian-based threat group that has infected victims in over 45 countries, spanning a range of industries including government, embassies, military, education, research and pharmaceutical companies since 2004. Heightened activity was seen in mid-2015. Turla is known for conducting watering hole and spearphishing campaigns and leveraging in-house tools and malware. Turla’s espionage platform is mainly used against Windows machines, but has also been seen used against macOS and Linux machines.
# APT
#  Turla : Turla is a Russian-based threat group that has infected victims in over 45 countries, spanning a range of industries including government, embassies, military, education, research and pharmaceutical companies since 2004. Heightened activity was seen in mid-2015. Turla is known for conducting watering hole and spearphishing campaigns and leveraging in-house tools and malware. Turla’s espionage platform is mainly used against Windows machines, but has also been seen used against macOS and Linux machines.
# malware
#  Linux : Turla is a Russian-based threat group that has infected victims in over 45 countries, spanning a range of industries including government, embassies, military, education, research and pharmaceutical companies since 2004. Heightened activity was seen in mid-2015. Turla is known for conducting watering hole and spearphishing campaigns and leveraging in-house tools and malware. Turla’s espionage platform is mainly used against Windows machines, but has also been seen used against macOS and Linux machines.
# malware
#  Winnti : Winnti Group is a threat group with Chinese origins that has been active since at least 2010. The group has heavily targeted the gaming industry, but it has also expanded the scope of its targeting.    Some reporting suggests a number of other groups, including Axiom, APT17, and Ke3chang, are closely linked to Winnti Group.
# malware
#  Winnti : Winnti Group is a threat group with Chinese origins that has been active since at least 2010. The group has heavily targeted the gaming industry, but it has also expanded the scope of its targeting.    Some reporting suggests a number of other groups, including Axiom, APT17, and Ke3chang, are closely linked to Winnti Group.
# APT
#  WIRTE : WIRTE is a threat group that has been active since at least August 2018. The group focuses on targeting Middle East defense and diplomats.

# %%
if 'at' in malware:
    print('t')
# Out:
# t

# %%
malware=[(i.replace('\n','').replace(' ','')).split('.')[1] for i in malware ]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-766c6d54450c> in <module>
# ----> 1 malware=[(i.replace('\n','').replace(' ','')).split('.')[1] for i in malware ]
#
# <ipython-input-13-766c6d54450c> in <listcomp>(.0)
# ----> 1 malware=[(i.replace('\n','').replace(' ','')).split('.')[1] for i in malware ]
#
# IndexError: list index out of range

# %%
malware=open(r"C:\Users\admin\Desktop\Threat_intel_services\NER\SPACY\malware.txt",'r', encoding="utf8")
malware=malware.readlines()
m=[]
for i in malware:
    if '.' in i:
        m.append(i.replace('\n','').split('.')[1])
    else:
        m.append(i.replace('\n','')
# Out:
#   File "<ipython-input-7-cd83a3cf738e>", line 9
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
m
# Out:
# ['Adware\n',
#  'Backdoor\n',
#  'Behavior\n',
#  'BrowserModifier\n',
#  'Constructor\n',
#  'DDoS\n',
#  'Exploit\n',
#  'Hacktool\n',
#  'Joke\n',
#  'Misleading\n',
#  'MonitoringTool\n',
#  'Program\n',
#  'PWS\n',
#  'Ransom\n',
#  'RemoteAccess\n',
#  'Rogue\n',
#  'SettingsModifier\n',
#  'SoftwareBundler\n',
#  'Spammer\n',
#  'Spoofer\n',
#  'Spyware\n',
#  'Tool\n',
#  'Trojan\n',
#  'TrojanClicker\n',
#  'TrojanDownloader\n',
#  'TrojanNotifier\n',
#  'TrojanProxy\n',
#  'TrojanSpy\n',
#  'VirTool\n',
#  'Virus\n',
#  'Worm\n',
#  'OpenSite',
#  'Dianjin',
#  'Yuupsearch',
#  'AdShooter',
#  'MXTarget',
#  'OMI',
#  'TMKSoft',
#  'Apkmore',
#  'Adpopup',
#  'Zwunzi!gen2',
#  'Rootnik',
#  '400',
#  'AlfaCleaner\n',
#  'InstallProvider',
#  'Webwise',
#  'Diandong',
#  'Catchtoken',
#  'Luckycat',
#  'Spyoo',
#  'ZestAdz',
#  'PastaLeads',
#  'Adfonic',
#  'Atlcontrol',
#  'JollyWallet',
#  'PassShow',
#  'Ariskkey\n',
#  'Rotator',
#  'FreeVideoConvtr',
#  'BetterSurf',
#  'Basedao',
#  'Momark',
#  'BrowserPal',
#  'Maltrec',
#  'Margoc',
#  'Opfake',
#  'WebRebates',
#  'Fakebank',
#  'Egyrank',
#  'Iwantsearch',
#  'ActiveSearch',
#  'Spytrack',
#  'Wooboo',
#  'Reputation',
#  'Raxums',
#  'Fakeyouwon',
#  'AntiVirus2010\n',
#  'EZToolbar',
#  'Emusic',
#  'MoPub',
#  'RunBooster',
#  'ABC\n',
#  'Funshion',
#  'Spedia',
#  'InMobi',
#  'HelpExpress',
#  '606',
#  'Fakeflash',
#  'DateManager',
#  'CtxPopup',
#  'Geinimi',
#  'ClickDLoader',
#  'SearchNew',
#  'Gonfu',
#  'Badaccents',
#  'TSAdbot',
#  'Greystripe',
#  'Smsblocker',
#  'CommonName',
#  'AntiSpywareExpert\n',
#  'Ballonpop',
#  'Superlogy',
#  'PLook',
#  'Gmaster',
#  'Utchi',
#  'Superbar',
#  'Qicsomos',
#  'Sandorat',
#  'Fakemrat',
#  'Fakevoice',
#  'SearchNet',
#  '506',
#  'PurityScan',
#  'Clickads',
#  'Kidda',
#  'iBanking',
#  'MediaPass',
#  'Adolph\n',
#  'HungryHands',
#  'Scartibro',
#  'WinTaskAd',
#  'MDSSearchboost',
#  'Adultbox',
#  'Searchlike',
#  'Uranico',
#  'Wqmobile',
#  'Crossid',
#  'AntiSpyPro\n',
#  'Beaglespy',
#  'DealHelper',
#  'Quiknowledge',
#  'Globalupdate',
#  'Teelog',
#  'Savenow',
#  'CPush',
#  'Wiyun',
#  'Roogoo',
#  'JustFindIt Removal Tool',
#  'GatorClone',
#  'Maltrec',
#  'Zwunzi!gen1',
#  'Dupvert',
#  'AmazonAds',
#  '385',
#  'Popuppers',
#  'Medload',
#  'Lockdroid',
#  'Fakeneflic',
#  'AntiSpyGuard\n',
#  'Coolpaperleak',
#  'PStrip',
#  'Fauxtocopy',
#  'IEHost',
#  'TidyNet',
#  'Satbo',
#  'LoadEWXD',
#  'AntiSpywareGuard\n',
#  'A',
#  'Uten',
#  'DashBar',
#  'Fastwebfinder',
#  '1151',
#  'OrbitExplorer',
#  'GreenIO',
#  'SeeqBar',
#  'SweetBar',
#  'Acnetdoor',
#  'ESDIexplorr',
#  'Batterydoctor',
#  'BlockChecker',
#  'Reputation',
#  'Oemji',
#  '814',
#  'Exactbar',
#  'Optserve',
#  'Pandbot',
#  'Waps',
#  'Clickpotato!gen',
#  'Mocore',
#  'Maltrec',
#  'Avispa\n',
#  'BestIdol',
#  'Fakescarav',
#  'Affilred',
#  'AntiVirusAndSpyware\n',
#  'ClickAlchemy',
#  'TopMoxie',
#  'Dealply!gen1',
#  '174',
#  'FakeMart',
#  'Wirex',
#  'Eziin',
#  'Ezula Removal Tool',
#  'IEPageHelper',
#  'Moghava',
#  'PrecisionTime',
#  'Upush',
#  'Bossefiv',
#  'Ebon',
#  'AntiSpywareSuite\n',
#  'ClickDLoader',
#  'FoncySMS',
#  'Gugespy',
#  'Monitorello',
#  'AOL4Free Virus Hoax\n',
#  'DealPly',
#  'IstartSurf!lnk',
#  'Fakealbums',
#  'Drusearch',
#  'Counterclank',
#  'Selfmite',
#  'AntiVirus2008\n',
#  'Mixxen',
#  'Adknowledge',
#  'P2PNetworking',
#  'Ventures',
#  'MoneyGainer',
#  'WinFavorites',
#  'Ro2cn',
#  'Backflash',
#  'AdsInContext',
#  'MBKWbar',
#  'Trogle',
#  'Gen',
#  'Horoscope',
#  'Bonzi',
#  'Clkpotato!gen2',
#  'Fresh',
#  'Ntsearch',
#  'Chuli',
#  'Gonfu',
#  'HyperBar',
#  'Qdplugin',
#  'A and A\n',
#  'SearchCounter',
#  'Anubisspy',
#  'AdwarePro2Sqr\n',
#  'TMAagent',
#  'EvidenceScan',
#  'Fapi',
#  'Ddpop',
#  'SearchAssist',
#  'LogiaAd',
#  'StartPage',
#  'Topicks',
#  'TopSearch',
#  'Dendoroid',
#  'Controlthis',
#  'Maltrec',
#  '7000n',
#  'Winpup',
#  'Mesploit',
#  'Adstation',
#  'Caishow',
#  'MxliveMedia',
#  'WebexpEnhanced',
#  'Airad',
#  'Kuaidian360',
#  'Qitmo',
#  'Steek',
#  'Centero',
#  'GeoFake',
#  'AdwareRemover\n',
#  'SideSearch',
#  'Antivirus360\n',
#  'Ewalls',
#  'Fakelicense',
#  'Bgserv',
#  'FastLook',
#  'Mobidisplay',
#  "AOL Flashing 'IM'\n",
#  'Saprilt',
#  'BocaiToolbar',
#  'Wnad',
#  'SMSReplicator',
#  'CrushSearch',
#  'Gomal',
#  'RevMob',
#  'SavingsHound',
#  'Handyclient',
#  'Poisoncake',
#  'Mobus',
#  'Nickispy',
#  'MainSearch',
#  'PennyBee',
#  'Enesoluty',
#  'Winshow',
#  'Ting',
#  'ByPush',
#  'FreeNew',
#  'YuMe',
#  'STIEBar',
#  'AOL and Intel Hoax\n',
#  'Webentrance',
#  'Uapush',
#  '575',
#  'SearchNugget',
#  'Andryushka\n',
#  'Gooboot',
#  'VDopia',
#  'StartPage',
#  'Windupdates',
#  'Links',
#  'PrecisionPop',
#  'Rufraud',
#  'Magicads',
#  'Infostealer',
#  'Fakebanco',
#  'Flyswat',
#  'AppLovin',
#  'AVSystemCare\n',
#  'IESearch',
#  'Boxore',
#  'AdGoblin',
#  'BargainBuddy',
#  'Hotbar',
#  'VirtuMonde',
#  'Adtomi',
#  'Jogotempo',
#  'Positmob',
#  'SocialReviewer',
#  'SpywareNuker',
#  'FavBarCash',
#  'Simplocker',
#  'AirInstaller',
#  'SyncroAd',
#  'Delta',
#  'Anthrax\n',
#  'Nuhaz',
#  'GonnaSearch',
#  'YinStart',
#  'Spywaller',
#  'Trojan',
#  'Netpal',
#  'Okcashbackmall',
#  'Accessiv',
#  'Dware',
#  'Iefeats',
#  'Zhong',
#  'Rabbhome',
#  'Igexin',
#  'Twaintec',
#  'Getup',
#  'RegiFast',
#  'NowFind',
#  'Jiwai',
#  'Riversoft',
#  'Fakejob',
#  'Shorty',
#  'Topantispyware',
#  'Moplus',
#  'MessStopper',
#  'MSView',
#  'SideBySide',
#  'Mobilespy',
#  'Simpliclean',
#  'Vidsquare',
#  'CashBackBuddy',
#  'Eorezo',
#  'CramToolbar',
#  'MediaInject',
#  'OfferAgent',
#  'ProfilinStylin',
#  'WebGuard',
#  'SellARing',
#  'Twikabot',
#  'Zeahache',
#  'Searchsquire',
#  'Vonteera',
#  'Aurecord',
#  'Pdaspy',
#  'AntiSpamBoy',
#  'DriverUpdater',
#  'Benews',
#  'Cosha',
#  '1101',
#  'Mesprank',
#  'AdwareSpy\n',
#  'AdServerNow',
#  'Windseeker',
#  'Hithopper',
#  'PandaAds',
#  'Pirator',
#  'Jumptap',
#  'WeirdOnTheWeb',
#  'Daosearch',
#  'Clkpotato!gen3',
#  'Mediafinder',
#  'Bursted',
#  'Stealthgenie',
#  'FakeLookout',
#  'Rootcager',
#  'Cafcon',
#  'Domob',
#  'SoftwareUpdater',
#  'LuckyTab',
#  'Apperhand',
#  'Downreceive',
#  'Searchexplorer',
#  'WPSOffice',
#  'Henbang',
#  'AntiSpyCheck\n',
#  'Reputation',
#  'ILookup',
#  'Borlan',
#  'Smszombie',
#  'Fakeguard',
#  'Uracto',
#  'Dropdialer',
#  'Kielog',
#  'CoolSavings',
#  'Antammi',
#  'Simplocker',
#  'Smaato',
#  'Adwhirl',
#  'Locator',
#  'Ipinsight',
#  'Ztoolbar',
#  'TrueAds',
#  'Lockdroid',
#  'IGetNet',
#  'Shazaa',
#  'Fakenotify',
#  'Buscape',
#  'Massfav',
#  'MediaTicket',
#  'WiFigx',
#  'Spydafon',
#  'QoolAid',
#  'AdwareRemover2007\n',
#  'MySafeSavings',
#  'AntispywareSoldier\n',
#  'Bookedspace',
#  'Clevernet',
#  'SQuery',
#  'Fakedefender',
#  'Roidsec',
#  'SearchScout',
#  'AdShortcuts\n',
#  'Tox',
#  'GoonSquad!gen1',
#  'Fakelemon',
#  'Lotoor',
#  'Golocker',
#  'NaughtyPops',
#  'Allayed\n',
#  'AntiEXE\n',
#  'Spitmo',
#  'Faketoken',
#  '429',
#  'Loaderpush',
#  'Conspy',
#  'SmartPops',
#  'SearchBarCash',
#  '3375',
#  'AgentSpyware\n',
#  'Malminer',
#  'WinAd',
#  'ClipGenie',
#  'Fastsearchweb',
#  'DailyToolbar',
#  'GravitySpace',
#  'Umeng',
#  'AdvParentalControl\n',
#  'Daoyoudao',
#  'Getup',
#  'EBoard',
#  'Pjapps',
#  'NewAds',
#  'Lovetrap',
#  'Maltrec',
#  'Lifemonspy',
#  'Fakedefender',
#  'FakePlayer',
#  'AntiToolbar\n',
#  'Awareness Virus Hoax\n',
#  'Obad',
#  'BestSearch',
#  'Maltrec',
#  'Aduru',
#  'ZangoSearch',
#  'Accessiv',
#  'BMCentral',
#  'SaveSense',
#  'Vdloader',
#  'Tonclank',
#  'eSyndicate',
#  'LSPP',
#  'SmartWeb',
#  'Backdexer',
#  'Pafloat',
#  'VCatch',
#  'MdotM',
#  'Repane',
#  'WinFavorites',
#  '2Search',
#  'AntiVirusDemoFraud\n',
#  'Yatoot',
#  'Browext!gen2',
#  'ZeroPopUp',
#  'Findwhatever',
#  'Stels',
#  'Adhelper',
#  'Smstibook',
#  '123Search',
#  'Sa',
#  'Onban',
#  'SeekSeek',
#  'Fakesucon',
#  'Kuguo',
#  'Elodu',
#  'Websteroids',
#  'Walkinwat',
#  'Ulubione',
#  'ZQuest',
#  'Moviedea',
#  'GoSave',
#  'Sheldor',
#  'Kuaiso',
#  'Meitu',
#  'AI\n',
#  'Basebridge',
#  'Rabio',
#  'Injekt',
#  'Ftad',
#  'Hippo',
#  'Milipnot',
#  'Sberick',
#  'Sockbot',
#  'Aornum',
#  'Arspam',
#  'Sosceo',
#  'Adsms',
#  'MWSearch',
#  'ZioCom',
#  'IEPlugin',
#  'Livechat',
#  'Antibody\n',
#  'SecurityUtilty',
#  'Kiswin',
#  'AntivirusDoktor2009\n',
#  'ADH',
#  'Mycashbag',
#  'Atomic\n',
#  'NaviSearch',
#  'Adpeak',
#  'Walla',
#  'WebSearcher',
#  'AntispyDeluxe\n',
#  'Akuku\n',
#  'StartPage',
#  'Annoyance',
#  'CWSIEFeats',
#  'Advertbar',
#  'DestinyHoros',
#  'DynamicUpdater',
#  'Mirar',
#  'ReferAd',
#  '818',
#  'Ju6',
#  'Kemoge',
#  'Lovespy',
#  'YahooAds',
#  'FlashEnhancer',
#  'CoolWebSearch',
#  'Dogowar',
#  'ImAdPush',
#  'Mezaa',
#  'Expand',
#  'FindNavi',
#  'Everbadge',
#  'Fakekakao',
#  'Farmbaby',
#  'Spyagent',
#  'MemoryMeter',
#  'AntivirusPlasma\n',
#  'FFToolBar',
#  'AdwarePro\n',
#  'PopAdStop',
#  'Keenval',
#  'WebBar',
#  'Awola\n',
#  'TrustInBar',
#  'Vtlbar',
#  'Webmisc',
#  'Hehe',
#  'Bankun',
#  'Spybubble',
#  'Buddylinks',
#  'Dealply!gen3',
#  'SuperFishRemove',
#  'Browext!lnk',
#  'Navihelper',
#  'VirtualBouncer',
#  'Cop',
#  'RapidMediaCon',
#  'Sumzand',
#  '180Search',
#  'Farfli',
#  'MobClix',
#  'AntiSpywareMaster\n',
#  'ABXToolbar',
#  'Memini',
#  'DisableKey',
#  'Laucassspy',
#  '1765',
#  'Anna\n',
#  'Ada\n',
#  'AOL4Free Trojan Horse\n',
#  'Vanish',
#  'Neurowise',
#  'Searchforit',
#  'AntispywareProXP\n',
#  'WeatherAlerts',
#  'Smslink',
#  'AFAEnhance',
#  'Snadapps',
#  'WannaLocker',
#  'Umaxsearch',
#  'Waren',
#  'Finfish',
#  'AntivirusSystemPro\n',
#  'EZSearch',
#  'CSearch',
#  'Hesperbot',
#  'AntispySpider\n',
#  'MyCentria',
#  'Malhome',
#  'WebDir',
#  'CDT',
#  'Beita',
#  'AdBlaster',
#  'Jraun',
#  'Citmo',
#  'Fitikser',
#  'Adtest',
#  '1344',
#  'Andromeda\n',
#  'Antivermins\n',
#  'Cydoor',
#  'Adlogix',
#  'InetAntispy',
#  'Maltrec',
#  'SeekSeek',
#  'Fakeplay',
#  'Medialets',
#  'Searchq',
#  'GoonSquad',
#  'WhenUSearchBar',
#  'Nafaoz',
#  'Cax',
#  'Aplog',
#  'Droidsheep',
#  'Faketaobao',
#  'CornerSunshine',
#  'AVCare\n',
#  'TickerBar',
#  'Qidion',
#  'Getprivate',
#  'Multidropper',
#  'Buzzcity',
#  'Hippo',
#  'FakeMessage',
#  'Kenilfe!inf',
#  'Rivpas',
#  'Thumbsnatcher',
#  'Vomba',
#  'Zwunzi!gen3',
#  'Pincer',
#  'Instdollars',
#  'BDE',
#  'Jollyserv',
#  'PigSearch',
#  'Vitruvian',
#  'AntispywareProtector\n',
#  'FreeScratchWin',
#  'VServ',
#  'EasyWWW',
#  'FCHelp',
#  'MediaLoad',
#  'WeatherScope',
#  'AdInfo',
#  'Trinity',
#  'AntiWorm2008\n',
#  'MatrixSearch',
#  'Redir',
#  'CasinoClient',
#  'SearchCentrix',
#  'AdvancedCleaner\n',
#  'Searchtool',
#  'Alienspy',
#  'Adware2\n',
#  'TargetSaver',
#  'Antichrist Hoax\n',
#  'Actech',
#  'Gonesixty',
#  'DiscoveryLive',
#  'Cauly',
#  'BlocknSurf',
#  'Sockrat',
#  'Uupay',
#  'MetaSearch',
#  'Accstealer',
#  'Tapjoy',
#  'Rockettab',
#  'Webext',
#  'Amoeba\n',
#  'Acnetsteal',
#  'Bmaster',
#  'Cnappbox',
#  'BubbleDock',
#  'PricePeep',
#  'DailyWinner',
#  'Iconosys',
#  'Simhosy',
#  'Fastfind',
#  'Vibleaker',
#  'Goodadpush',
#  'Geplook',
#  'OneStep',
#  'Maltrec',
#  'AdBlock',
#  'Singalng!g1',
#  'Weblookup',
#  'Appoli',
#  'Tbon',
#  'FOne',
#  'IstartSurf',
#  'Dengaru',
#  'Slagent',
#  'Dynamicit',
#  'Uxipp',
#  'Iebar',
#  'HighTraffic',
#  'AntiCMOS\n',
#  'Stiniter',
#  'AntiVirusAndTrojan\n',
#  'Machinleak',
#  'JustPlugIt',
#  'Gabpath',
#  'Maltrec',
#  'AdChannel19',
#  'Adwo',
#  'AntiVirus2009\n',
#  'BL',
#  'BBSee',
#  'Idocha',
#  'LookNSearch',
#  'Dynamic',
#  'Whazit',
#  'BarACE',
#  'WinProtect',
#  'Deathring',
#  'Istbar',
#  'Appleservice',
#  'BeSys',
#  'Broadcastpc',
#  'NewWeb',
#  'Clkpotato!gen4',
#  'Hmtoolbar',
#  'Dowgin',
#  'Perkel',
#  'GAIN',
#  'Sysecsms',
#  'Virusshield',
#  'Meswatcherbox',
#  'Rusms',
#  'Backscript',
#  'IEDriver',
#  'Dandro',
#  'Maistealer',
#  'Trusteddownload',
#  'Ggtracker',
#  'TrustInPopups',
#  'Bullseye',
#  'Morepaks',
#  'Tapsnake',
#  'FindSpyware',
#  'VBates',
#  'CinemaPlus!g1',
#  'SearchWords',
#  'Netisend',
#  'GoGoTools',
#  'MoeMoney',
#  'Peppi',
#  'Loaded',
#  'EZSearch',
#  'Ambulance\n',
#  'Faketaobao',
#  'Aurora',
#  'Doublehidden',
#  'Lightdd',
#  'Fakesecsuit',
#  'ScreenScenes',
#  'AUNPS',
#  'DelFin',
#  'Toolband',
#  'ZombieInvasion',
#  'Pontiflex',
#  'Updtbot',
#  'Appztoolbar',
#  'IEhlpr',
#  'Incredifind',
#  'AdvDriverUpd',
#  'Syslibie',
#  'Biigespy',
#  'Usbcleaver',
#  'AlibabaTB',
#  'Cashfiesta',
#  'Piddialer',
#  'PurityScan',
#  'Look2Me',
#  'Savepathdeals',
#  'WinLog',
#  'Iconosis',
#  'Cepsohord',
#  'Spitmo',
#  'WinFetch',
#  'Scipiex',
#  'Clearx',
#  'Temai',
#  'Crossid',
#  'AOL RIOT 2 Virus Hoax\n',
#  'Aureate',
#  'Cajino',
#  'Revealing',
#  'Topsearch',
#  'Fakegame',
#  'LinkMaker',
#  'Gazon',
#  'Lop',
#  'Netword',
#  'SecondThought',
#  'Wengs',
#  'Locaspy',
#  'Badpush',
#  'SuperFish',
#  'Genheur',
#  '180Solutions',
#  'AdMarvel',
#  'SendDroid',
#  'Pjapps',
#  'Smartsearch',
#  'FastSeek',
#  'Pris',
#  'SideBar',
#  'DomaIQ',
#  'AOL Gold Trojan\n',
#  'Quadro',
#  'Starware',
#  'WhileUSurf',
#  'ZenoSearch',
#  'Couponmarvel',
#  'Trojan',
#  'Malapp',
#  'Pikspam',
#  'Acecard',
#  '331',
#  'YourSiteBar',
#  'AIDS Virus Hoax\n',
#  'MobFox',
#  'Gonfu',
#  'AntiSpyBoss\n',
#  'WinBo',
#  'Mobinaspy',
#  'SmartAdware',
#  'Selfmite',
#  'EnhanceMSearch',
#  'Generisk',
#  'LoveFreeGames',
#  'Bursted',
#  'Fakemini',
#  'AntiCAD\n',
#  'Purityscan',
#  'TVWizard',
#  'Maltrec',
#  'Gugespy',
#  '819',
#  'Standard',
#  'Bankosy',
#  'AIDS_II\n',
#  'Dougalek',
#  'AntiSpyZone\n',
#  'StormAlerts',
#  'SideFind',
#  'Unico',
#  'X10',
#  'SmartBrowser',
#  'Bursted',
#  'ArcadeWeb!gen',
#  'Rotator!gen2',
#  'Cellshark',
#  'InstallPedia',
#  'Godwon',
#  'StopPopupAdsNow',
#  'Getadpush',
#  'Tetus',
#  'YellowPages',
#  '2293',
#  'SafeSearch',
#  'Fokonge',
#  'GallMe',
#  'Ecardgrabber',
#  'KuwoMusic',
#  'AdwareSheriff\n',
#  'Fakeupdate',
#  'Tamindir',
#  'Phimdropper',
#  'Genpush',
#  'Maltrec',
#  'CinemaPlus',
#  'CWSMSConfd',
#  'MyCustomIE',
#  'Spaceflash',
#  'CWSConyc',
#  'Maltrec',
#  'ShowBehind',
#  'TargetAd',
#  'WWWBar',
#  'Feiwo',
#  'Jifake',
#  'Angarsk\n',
#  'AppShake',
#  'Oneclickfraud',
#  'Miji',
#  'OverPro',
#  'AVSecuritySuite\n',
#  'TwkBtPCBooster',
#  'CrimeWatch',
#  'Deeveemap',
#  'Gamex',
#  'Meshidden',
#  'FakePlayer',
#  'Maltrec',
#  'Penetho',
#  'Roimoi',
#  'Ecobatry',
#  'InstaFinder',
#  'NetMedia',
#  'Flipora',
#  'AutoRefreshPlus',
#  'TicTa',
#  'ZioCom',
#  'Meplex',
#  'AdMob',
#  'AntiVirusGold\n',
#  'Youmi',
#  'SafeTerra',
#  'Mainpean',
#  'WorldSearch',
#  'Mobigapp',
#  'WebSecureAlert',
#  'Krysanec',
#  'Uplink',
#  'Nandrobox',
#  'Tgpush',
#  'Fizzle',
#  'FinanceAlert',
#  'AdDestroyer',
#  'AdvertMen',
#  'Zwunzi',
#  'Admass',
#  'AntivirusAgentPro\n',
#  'EasySearch',
#  'Maltrec',
#  'AdultLinks',
#  'Websearch',
#  'Begin2search',
#  'DollarRevenue',
#  'Director',
#  'Fakeapp',
#  'PSN',
#  'Blowsearch',
#  'CWSMSConfd',
#  'Appenda',
#  'Tanci',
#  'Ackposts',
#  'Lockdroid',
#  'Fastfind',
#  'LizardBar',
#  'Mobiletx',
#  'Ozotshielder',
#  'Social2Search',
#  'ArcadeWeb',
#  'Magoo',
#  'Crisis',
#  'AntivirusFraud\n',
#  'GeniusBox',
#  'Kidlogger',
#  'ContentExplorer',
#  'Spytekcell',
#  'Malebook',
#  'NetOptimizer',
#  'Ezula',
#  'AdBars',
#  'Answerbot',
#  'AutoStart 9805\n',
#  'Smspacem',
#  'JustFindIt',
#  'Diginum',
#  ...]

# %%
malware=open(r"C:\Users\admin\Desktop\Threat_intel_services\NER\malware.txt",'r', encoding="utf8")
malware=malware.readlines()
malware=[i.replace('\n','').replace(' ','') for i in malware]

# %%
malware[35].split('.')[1]
# Out:
# 'MXTarget'

# %%
for i in malware:
    print(i)
    if i== 'at':
        break
# Out:
# Adware.DisableKey
# Adware.SearchSeekFind
# Android.Uapush
# Adware.Quadro
# Adware.Maltrec.TS!g15
# Android.Fakescarav
# Android.Jumptap
# Adware.Maltrec.TS!g17
# Adware.Ntsearch
# Adware.GatorClone
# AntiSpywareMaster
# Adware.Maltrec.TS!g27
# Android.Spymple
# Adware.DealPly
# Adware.IstartSurf!lnk
# Adware.Drusearch
# Adware.TidyNet
# Adware.Clkpotato!gen4
# Adware.LSPP
# AwarenessVirusHoax
# Android.Spywaller
# Android.Aurecord
# AntiAVP.819
# Android.Greystripe
# Android.Tetus
# Arianna.3375
# Android.Smsblocker
# Adware.Funshion
# Adware.Admass
# Adware.Adstation
# Adware.EBoard
# Adware.ESDIexplorr
# Adware.Maltrec.TS!g22
# Adware.Singalng
# Adware.Unico
# Adware.AdBars
# Android.Medialets
# Android.Netisend
# Adware.Quiknowledge
# Adware.TrueAds
# Adware.DoubleD
# Android.AmazonAds
# Adware.TargetSaver
# Adware.Clearx
# Adware.Bonzi
# Adware.Ventures
# Android.Kuaidian360
# Android.Luckycat
# Android.Airpush
# Android.Dougalek
# Adware.FFToolBar
# Adware.MXTarget.B
# Adware.Iefeats
# Adware.OrbitExplorer
# Android.Malapp
# AOLGoldTrojan
# Android.Claco
# Adware.Searchforit
# Adware.Slagent
# Adware.CWSMSConfd.B
# Adware.X10
# Adware.Webbuy
# Adware.Webentrance
# Adware.Multidropper
# Adware.Rotator
# Android.Adwo
# Adware.BlazeFind
# Android.Godwon
# Android.Gupno
# Adware.IntDel
# Android.Phimdropper
# Adware.MWSearch
# Android.Lockdroid.E
# Adware.Twaintec
# Android.Fakebok
# Adware.ReferAd
# Adware.LoadEWXD
# Adware.Fapi
# Adware.ZeroPopUp
# Android.Habey
# Adware.Shazaa
# ACTS.Spaceflash
# Adware.Zhong
# Android.Deeveemap
# Adware.OpenShopper
# Android.Beita
# Adware.Okcashbackmall
# Adware.Elodu
# Adware.Lamhok
# Android.Bmaster
# ADT.1765
# Adware.Borlan
# Android.Obad
# Adware.Maltrec.TS!g19
# Android.Miji
# Adware.GoGoTools
# Adware.Getprivate
# Adware.Vtlbar
# Adware.EZToolbar
# Android.Anubisspy
# Adware.Cafcon
# AntiVirGear
# Android.Qitmo
# Android.Handyclient
# Anthrax
# AntiToolbar
# Antivirus360
# AntivirusdotNET
# Adware.MyCentria
# Adware.Exactbar
# Android.Vibleaker
# Android.Ecobatry
# Android.AdMob
# Adware.ABXToolbar
# Adware.BigTrafficNet
# Android.Adwhirl
# Adware.SafeTerra
# AdvancedXPFixer
# Android.Clickads
# Adware.BestIdol
# Adware.ILookup
# Adware.Starware
# Adware.Fresh
# Android.Geplook
# Adware.Look2Me
# AandA
# Android.Spytrack
# Adware.BrowserAid
# Adware.Peppi
# Adware.PortalScan
# Adware.WPSOffice
# Android.Fakealbums
# AI
# Android.Bossefiv
# Adware.Searchsquire
# Android.InMobi
# Ada
# Adware.Adhelper
# Android.Becuro
# Android.Kabstamper
# Adware.DealHelper
# Adware.BDE
# Adware.PStrip
# Adware.EZSearch
# Adware.InstaFinder
# Adware.Downreceive
# Adware.SearchAssist
# Adware.SearchMaid
# Android.Lotoor
# Adware.Topantispyware
# Adware.FreeAccessBar
# Adware.Keenval
# Adware.7000n
# Adware.DownloadMgrApp
# Adware.TMKSoft.XPlugin
# Android.Biigespy
# Adware.Raxums
# Adware.RegiFast
# Adware.Savepathdeals
# Android.Dupvert
# Android.Mobinaspy
# Android.Opfake.B
# Adware.GatorEWallet
# AntiVirusAndTrojan
# Android.Iconosys
# Adware.EasyWWW
# Adware.Getup
# Adware.Crossid
# Adware.Rotator!gen3
# Adware.Adpopup
# Adware.WhenUSearchBar
# Adware.ZenoSearch
# Adware.Ztoolbar
# Adware.TrustInBar
# Adware.Rotator!gen2
# Adware.Vidsquare
# A97M.Walla
# Adware.Latend
# Android.Crisis
# Android.Exprespam
# Android.Kielog
# AVSystemCare
# Android.Smsbomber
# Adware.SideBar
# Adware.SystemProcess
# Android.Buzzcity
# Android.Gonesixty
# Adware.AdDestroyer
# Adware.Vonteera
# Adware.SpywareNuker
# Android.Benews
# Android.Fakelemon
# Adware.MxliveMedia
# Adware.BBSee
# Android.Notcompatible
# Android.Tapsnake
# AOL.EXEHoax
# Alexander.1951
# Adware.180Search
# Android.VServ
# Adware.VCatch
# AntiSpywareShield
# Adware.DriverUpdater
# Adware.Begin2search
# Android.Dropdialer
# Android.Aduru
# Android.Airad
# Android.Sysecsms
# AdvParentalControl
# Adware.GreatArcadeHits
# Amanita.1151
# Android.Frogonal
# Adware.Ebon
# AM.Accessiv.B
# AndroidOS.FakePlayer.B
# AntivirusDoktor2009
# AVCare
# ABC
# Android.Rabbhome
# Android.Smspacem
# Adware.Instdollars
# Adware.Appztoolbar
# Android.Sandorat
# Android.Acnetdoor
# Android.ImAdPush
# Android.Gazon
# A2M.Accessiv.A
# Android.Meswatcherbox
# Adware.AUNPS
# AntiEXE
# AntispyDeluxe
# Adware.Ipinsight
# Android.Geinimi
# Android.Oneclickfraud
# Adware.MediaPass
# Android.Finfish
# Adware.Singalng!g1
# Alicino.331
# Adware.ArcadeTwist
# Adware.Winpup
# Adware.GoonSquad!gen1
# Android.Gamex
# Android.Golddream
# Android.Goldeneagle
# Adware.Maltrec.TS!g6
# Antivermins
# Android.WannaLocker
# Adware.Browext!gen2
# Adware.CashSaver
# Android.Twikabot
# Adware.DestinyHoros
# AntispywareSoldier
# Android.Yinhan
# Adware.Kiswin
# Adware.AdBlock
# Android.Fireleaker
# Adware.Sheldor
# Android.Enesoluty
# Android.Rootnik
# Adware.MemoryMeter
# Android.Sosceo
# Adware.LizardBar
# Adware.AdultLinks
# Android.Coolreaper
# Android.Waps
# Adware.StormAlerts
# Adware.PurityScan
# Adware.Incredifind
# Arriba.A
# Adware.FavBarCash
# Adware.InetAntispy
# Adware.Superlogy
# Adware.Weblookup
# Android.Teelog
# AntiSpyZone
# Adware.BetterInternet
# Android.Wooboo
# Adware.MDSSearchboost
# Adware.Hmtoolbar
# Android.Catchtoken
# Android.Clevernet
# Adware.NaughtyPops
# Adware.Umaxsearch
# AMIN
# Adware.MyCustomIE
# Adware.Replace
# Android.Gonfu
# Android.Fakeneflic
# Adware.ClickAlchemy
# Adware.ZioCom.C
# Android.Tanci
# Adware.TicTa
# Adware.UniversalTB
# Android.Machinleak
# Adware.Browext
# Adware.AdShooter
# Adware.CDT
# Adware.HalfLemon
# Adware.CasinoClient
# Antibody
# Adware.Rugo
# Android.Smszombie
# Adware.Jraun
# Adware.SearchNet
# Adware.SocialReviewer
# Android.Selfmite.B
# Adware.MediaInject
# AndromedaAV
# AplS.Saprilt.B
# Adware.Social2Search
# Android.Simplocker
# AntiSpyCheck
# AdvancedCleaner
# Adware.Searchtool
# Adware.ContentExplorer
# Adware2
# Adware.StartPage.C
# Android.FindAndCall
# Android.Lovetrap
# Android.Tascudap
# ARCV.330
# Adware.Netword
# Adware.FindSpyware
# Android.Lightdd
# Adware.Jogotempo
# Android.Selfmite
# Android.Spitmo.B
# Android.AppLovin
# A97M.Loaded
# Adware.MoneyGainer
# Android.Burstly
# Adware.WinFetch
# AOL.Infostealer.Trojan
# Android.ZestAdz
# Albania.506
# AlfaCleaner
# Adware.BrowserVillage
# Adware.Rotator!gen
# Android.Ecardgrabber
# Android.Jifake
# Adware.Crossid.B
# Android.Dandro
# Adware.ArcadeWeb
# Android.Basedao
# AntiSpyPro
# Adware.FreeNew
# Adware.Optserve
# Adware.IEHost
# Android.Lastacloud
# Android.Smsstealer
# AdwareRemover
# Adware.Spedia
# Adware.Maxdriver
# Adware.PSN
# Adware.HungryHands
# AntiPascal.1101
# Android.Morepaks
# Adware.Netpal
# Adware.RaxSearch
# Adware.Expand
# Adware.Adtest
# Android.Trogle
# Adware.DownloadPlus
# Adware.AdGoblin
# Adware.Littlehelper
# Android.Kituri
# Adware.BarACE
# Adware.SavingsHound
# Adware.Superbar
# Adware.WebGuard
# Adware.Sa
# Android.Fakedaum
# Android.Penetho
# Android.Iconosis
# Android.Lifemonspy
# Adware.HelpExpress
# Adware.GoSave
# Adware.FastSeek
# Adware.PrecisionPop
# Android.Smaato
# Adware.AutoRefreshPlus
# Adware.Toolband
# Android.Pletora
# Android.Qdplugin
# Adware.Bullseye
# Android.Bgserv
# Adware.BMCentral
# Android.Poisoncake
# Adware.Memini
# AntiVirus2010
# Adware.GeniusBox
# ALS.Bursted.C
# Android.Genheur
# Android.Farmbaby
# Android.Sberick
# Adware.SyncroAd
# AntispywareProtector
# Android.Gugespy.B
# Android.Pandbot
# Android.Malminer
# Adware.CoolSavings
# Android.MobFox
# Android.Wiyun
# Adware.DiscoveryLive
# Adware.Delta
# Android.Gonfu.B
# Adware.SlickSavings
# Android.Mobidisplay
# Adware.Maltrec.TS!g26
# Android.Smstibook
# Adware.WebexpEnhanced
# Android.Tigerbot
# Android.Umeng
# Android.Hippo.B
# Android.Loaderpush
# Adware.MainSearch
# Android.Diandong
# Android.Pjapps.B
# AOL4FreeTrojanHorse
# Adware.Superiorads
# Adware.MessStopper
# Adware.Tamindir
# AH.Farfli.0
# Adware.Mixxen
# Android.Bankosy
# Android.Fakedown
# Android.GeoFake
# Android.LogiaAd
# Adware.Dware
# Android.Backflash
# Android.Moplus
# Android.Pirator
# Android.Usbcleaver
# Adware.BetterSurf
# Android.Sockbot
# Adware.SuperFish
# Adware.EZSearch.B
# Adware.CoolWebSearch
# Adware.ZQuest
# Android.Tgpush
# Ariskkey
# Adware.DailyToolbar
# Android.Stealthgenie
# Android.iBanking
# Android.Pincer
# Adware.Atlcontrol
# Adware.Tbon
# Android.Fakeplay
# Adware.YinStart
# Android.Gugespy
# Android.Fakemrat
# Adware.Cashfiesta
# Adware.EZLife
# AT.140
# Adware.PPRich
# Adware.SearchCentrix
# Adware.MySafeSavings
# AntivirusAgentPro
# Android.MobileBackup
# Android.SMSReplicator
# Adware.Buscape
# Adware.Simpliclean
# AntichristHoax
# Android.Backapp
# Android.FakeLookout
# Android.Kuguo
# Adware.VBates
# Adware.Revealing
# Adware.WebSearcher
# Android.Malhome
# AntivirusSystemPro
# Adware.Controlthis
# Android.Sofacy
# Android.Hehe
# Albania.575
# Android.SendDroid
# Adware.InstallerSetup
# Adware.SearchScout
# Adware.Adsubscribe
# Adware.FreeVideoConvtr
# Android.Pikspam
# Adware.Kidda
# Adware.Medload
# Adware.WeirdOnTheWeb
# Adware.StatBlaster
# Adware.Maltrec.TS!g34
# Android.Monitorello
# Adware.UpSpiralBar
# ACTS.LFM.926
# Adware.Globalupdate
# Adware.PricePeep
# AdwarePro2Sqr
# Adware.CWSIEFeats
# Adware.OpenSite
# Adware.ZangoSearch
# Android.Bankun
# Android.PandaAds
# AutoStart9805
# AdvancedFix
# Adware.SideFind
# Adware.SuperFishRemove
# Adware.MatrixSearch
# Adware.Browext!lnk
# Adware.Searchdot
# Adware.SeekSeek
# Alfons.1344
# Android.Lockscreen
# Adware.Aornum
# Adware.TargetAd
# Adware.Popuppers
# Ana.174
# Android.Cellshark
# Android.Rusms
# Adware.AppShake
# Android.Spitmo
# Android.Coolpaperleak
# Adware.ClipGenie
# Adware.CPush
# Adware.BlockChecker
# Adware.2Search
# AdwarePro
# Android.Moghava
# AntiSpyBoss
# Android.Accstealer
# Adware.PigSearch
# Adware.MusicDowector
# AM.Accessiv.A
# Android.Mitcad
# Adware.Diginum
# AplS.Saprilt.A
# Adware.NewAds
# Android.Fakebank
# Android.Fitikser
# Adware.DesktopMedia
# Adware.Vanish
# Adware.Advision
# Adware.QuickBrowser
# Adware.Director
# Adware.Maltrec.TS!g24
# Adware.OverPro
# AntiVirusDemoFraud
# Adware.WebBar
# Adware.Caishow
# Adware.Searchq
# Adware.Henbang
# Android.Feiwo
# Alex.368
# Android.RevMob
# Android.Uracto
# Adware.Maltrec.TS!g12
# Adware.Maltrec.TS!g30
# Android.Badpush
# Adware.Sqwire
# Adware.Maltrec.TS!g5
# Android.Hippo
# Angarsk
# Adware.MXTarget
# Adware.SafeSearch
# Adware.IEPageHelper
# Adware.HyperBar
# Android.Pdaspy
# Adware.AdRoar
# Adware.InstantAccess
# Android.Uranico
# Adware.YeaDesktop
# Adware.Ulubione
# Adware.SearchCounter
# Android.Laucassspy
# Android.Smslink
# Adware.BubbleDock
# Android.Steek
# ABAP.Rivpas.A
# Adware.Clkpotato!gen3
# Adware.IstartSurf
# AntiVirus2008
# Adware.GreenIO
# Android.ZertSecurity
# Adware.Navihelper
# Android.Roidsec
# Adware.Webext
# Adware.Broadcastpc
# Adware.FastLook
# Adware.IEPlugin
# Adware.ClickDLoader
# Android.Stels
# Android.Sockrat
# Adware.Idocha
# AIDS_II
# Android.Scipiex
# Android.MillennialMedia
# Android.Wirex
# Android.MdotM
# Adware.Movittone
# Adware.SearchSpace
# Android.Krysanec
# Android.Maxit
# AntivirusFraud
# Adware.Shorty
# Adware.CtxPopup
# Anarchy
# Adware.PopAdStop
# Adware.AdBlaster
# Adware.FindemNow
# Adware.Horoscope
# Adware.Hotbar
# Adware.Purityscan.D
# Android.Batterydoctor
# AOLandIntelHoax
# Adware.Vomba
# Android.Goodadpush
# AOL4FreeVirusHoax
# Adware.Crossid!gen1
# Adware.Appoli
# Adware.ContextualToolbar
# Adware.Gabpath
# Adware.NetMedia
# Adware.WorldSearch
# Adware.Maltrec.TS!g4
# Adware.WeatherScope
# AM.Tox.A
# Adware.Trinity
# Android.Jsmshider
# Android.Gonfu.C
# Adware.Getup.B
# Android.Cajino
# Adware.StartPage.B
# Android.Malebook
# Adware.AlibabaTB
# Android.Zeusmitmo
# Adware.AdServerNow
# Adware.NaviSearch
# Android.Fakelogin
# Adware.GonnaSearch
# Adware.VirtuMonde
# Avkiller.Trojan
# Android.Deathring
# Android.Fakebank.B
# Android.Walkinwat
# Adware.Clkpotato!gen2
# Adware.SmartPops.B
# Adware.Adpeak
# Adware.ClearSearch
# Adware.Maltrec.TS!g13
# Android.FakeMart
# Android.Locaspy
# Adware.CWSAlfaSearch
# Android.ByPush
# Android.Simhosy
# Adware.Dealply!gen3
# ALS.Jiwai
# Adware.eSyndicate
# Adware.Ting
# Adware.Windupdates
# AOLFlashing'IM'
# AOL.Infostealer.32512
# Andromeda
# Android.Domob
# Adware.BL
# Adware.Zwunzi!gen1
# Adware.Eziin
# Adware.Annoyance
# Adware.Owlforce
# Adware.IEDriver
# Adware.SideSearch
# Adware.ScreenScenes
# Adware.Wengs
# Android.Virusshield
# Adware.Findwhatever
# Adware.Qwiklinx
# Adware.TrustInPopups
# Android.Badaccents
# Android.Perkel
# Adware.FCHelp
# Android.Getadpush
# Adware.WWWBar
# Android.Doublehidden
# AntiVirusAndSpyware
# Alad.2293
# Android.Pjapps
# Android.Antammi
# Awola
# Adware.Flipora
# Adware.CommonName
# Adware.Ro2cn
# Android.Mobilespy
# Android.Momark
# Adware.AdvDriverUpd
# Adware.Thumbsnatcher
# Adware.Moviedea
# Adware.SmartPops
# Android.Igexin
# Android.Fakedefender
# Android.Upush
# Adware.OMI
# Android.Gooboot
# Adware.Egyrank
# Android.Reputation.3
# AndroidOS.FakePlayer
# Adware.Smartsearch
# Adware.CornerSunshine
# Adware.SmartDove
# Android.Acecard
# Android.Fakesucon
# Android.Fakeangry
# AirCop.Standard
# Android.Fakeapp
# Android.Repane
# Android.361push
# Android.Scartibro
# Android.Faketaobao
# Adware.CrimeWatch
# Amoeba
# Android.Windseeker
# Adware.Cydoor
# Adware.Redir
# Adware.Fizzle
# AOD.385.B
# Adware.STIEBar
# Android.Ballonpop
# Android.AdMarvel
# Adware.IGetNet
# Android.Kidlogger
# Android.Adsms
# Adware.SP2Update
# Android.Utchi
# Adware.InstallProvider
# Albania.606
# Android.Pafloat
# Android.Hesperbot
# Adware.ADH
# Adware.Neurowise
# Adware.Bookedspace
# AntiVirusPro
# ALS.Kenilfe!inf
# Adware.SeekSeek.B
# Adware.YellowPages
# Adware.Mainpean
# Adware.InstallPedia
# Android.Ackposts
# AntiCAD
# Adware.GotSmiley
# Adware.TwkBtPCBooster
# Android.Acnetsteal
# Android.Apkmore
# Adware.CloudScout
# Android.Crusewind
# Android.Ozotshielder
# Adware.Mediafinder
# Adware.IAGold
# Adware.Istbar
# Android.Adwlauncher
# Adware.TMAagent
# Android.Aplog
# Android.Mesprank
# Android.Uxipp
# Adware.SeeqBar
# Android.Arspam
# Android.Casee
# Android.Centero
# Android.Cobblerone
# Android.Mocore
# Adware.ZioCom
# Anna
# Adware.DreamAd
# Adware.VirtualBouncer
# Adware.DNSUnlocker
# Android.Reputation.1
# Android.Fakeguard
# Adware.JustFindIt
# Android.Updtbot
# Adware.Meitu
# Adware.ActiveSearch
# Android.Beaglespy
# Adware.Injekt
# Adware.Riversoft
# Adware.Links
# Adware.IESearch
# Adware.Gen.3
# Adware.Livechat
# Adware.Surebar
# Android.Crazymedia
# Android.Daoyoudao
# Adware.AdsInContext
# Android.Fakeupdate
# Android.Dendoroid
# Android.Smbcheck
# Adware.CSearch
# Adware.Ezula
# Adware.Roogoo
# Adware.eFast
# Adware.Boxore
# Adware.NeededWare
# Adware.SecureServicePk
# Adware.Couponmarvel
# Android.Chuli
# Android.Fakejob
# Android.Wqmobile
# Akuku
# Android.Ewalls
# Adware.DailyWinner
# Android.Mesploit
# Adware.Webmisc
# Android.YahooAds
# Android.Yatoot
# Android.Youmi
# Android.Answerbot
# Android.Vdloader
# Android.Gmaster
# Android.Rootnik.B
# Adware.TSAdbot
# Android.MoPub
# Adware.IEhlpr
# Adware.QoolAid
# Android.Smssniffer
# Adware.Mycashbag
# Android.Fauxtocopy
# Adware.Fastfind
# Adware.BlitzMediaPlayr
# Adware.JustFindItRemovalTool
# Adware.Locator
# Adware.123Search
# Adware.Adultbox
# Adware.SoftwareUpdater
# Adware.WebSecureAlert
# Adware.Adtomi
# AntiVirus2009
# Adware.Magicads
# Android.Droidsheep
# Adware.KuwoMusic
# Adware.FindLyrics
# Adware.Getaclip
# Adware.Mirar
# Adware.RXToolbar
# Adware.StartPage
# Adware.Surfairy
# Android.Lockdroid.F
# Adware.DollarRevenue
# Adware.Gen.2
# Adware.Meplex
# Adware.Maltrec.TS!g16
# Adware.LookNSearch
# AntiSpywareSuite
# Adware.Maltrec.TS!g28
# AM.Tox.B
# Android.Lockdroid.G
# AntispywareProXP
# Adware.Daosearch
# Android.Jollyserv
# Adware.GAIN
# AOLRIOT2VirusHoax
# Adware.CramToolbar
# AntiWorm2008
# Adware.Clickpotato!gen
# Adware.Fastwebfinder
# Adware.AllSum
# Android.MobClix
# Android.Premiumtext
# Adware.PurityScan.C
# AntiSpyKit
# Android.Apperhand
# Adware.LoveFreeGames
# AntiSpywareExpert
# Adware.NowFind
# Android.Qicsomos
# Avalon.814
# AdsAlert
# Adware.Kuaiso
# Adware.PowerScan
# Adware.ProfilinStylin
# Adware.Maltrec.TS!g29
# AntiPascal.408
# Adware.Lop
# Adware.iPend
# Adware.Flyswat
# Android.Waren
# Adware.Zwunzi!gen2
# Android.Citmo
# Adware.SecondThought
# Android.Snadapps
# Adware.AntiSpamBoy
# Adware.Onban
# Adware.Wnad
# Android.Fakeflash
# Android.Switcher
# ALS.Bursted.B
# Android.Milipnot
# Adware.Searchlike
# Adware.MediaTicket
# Alabama
# Android.Backdexer
# Android.Genpush
# Adware.ContentDefend
# Akuku.Cop
# AOLYear2000UpdateHoax
# Adware.Iwantsearch
# Adware.SmartWeb
# AntivirusSystem2011
# Adware.ClickDLoader.B
# AgentSpyware
# Adware.Dealply!gen1
# AdShortcuts
# Android.Phospy
# AVSecuritySuite
# Adware.PennyBee
# Adware.EasySearch
# Adware.BuzzIt
# Android.Nuhaz
# Adware.Rabio
# Adware.WebRebates
# Adware.MoeMoney
# Adware.AdChannel19
# Adware.Rockettab
# AdwareSheriff
# Android.Meshidden
# Android.Nandrobox
# Adware.Eorezo
# Android.VDopia
# Android.Fakekakao
# AOL.Trojan
# Adware.EnhanceMSearch
# Android.Ggtracker
# Android.Everbadge
# Adware.Massfav
# Adware.MediaLoad
# Adware.WinFavorites.B
# Adware.FriendsBlog
# Android.Actech
# Adware.TickerBar
# Android.Generisk
# Avispa
# Android.Simplocker.B
# Android.Samsapo
# Adware.Websteroids
# Adware.Maltrec.TS!g32
# Adware.BestSearch
# AntiVirusGold
# Adware.Mezaa
# Android.Zeahache
# Adware.WhileUSurf
# Android.Mobigapp
# Android.Fakepatch
# Adware.Maltrec.TS!g23
# Adware.Hithopper
# Adware.Inetex
# Android.FoncySMS
# Adware.Whazit
# Adware.Clickpotato
# Adware.TopMoxie
# Android.Flexispy
# Adware.Oemji
# Adware.Iebar
# Adware.NDotNet
# Adware.AdSupport
# Adware.P2PNetworking
# Adware.Satbo
# Adware.WeatherAlerts
# Adware.Savenow
# Adware.JustPlugIt
# Adware.Fastfind.B
# Adware.SearchNew
# Adware.Yuupsearch
# Android.Fakebanco
# Android.Spyoo
# Adware.CrushSearch
# Adware.Webwise
# Adware.WinFavorites
# Android.Uten
# Adware.NetOptimizer
# AIDSVirusHoax
# Android.Pris
# Adware.Zwunzi
# Adware.WiFigx
# AntiVirProtect
# Adware.InstallMonster
# Android.Loicdos
# Adware.SaveSense
# Adware.MSView
# Android.Spydafon
# Adware.Blowsearch
# Adware.Fastsearchweb
# AntiCMOS
# Adware.AdvertMen
# Android.Cauly
# Adware.SQuery
# Alex.818
# A97M.Hamdam.A
# Adware.DateManager
# Android.Uupay
# Android.Opfake
# Adware.FakeMessage
# Android.Kranxpay
# Adware.WinProtect
# Android.Golocker
# Adware.RunBooster
# Adware.DelFin
# Adware.SweetBar
# Adware.CinemaPlus
# Adware.FOne
# Android.Spybubble
# Android.Maistealer
# Android.Jzmob
# Android.Pontiflex
# Adware.TopSearch.B
# Adware.MetaSearch
# Android.Gappusin
# Adware.180Solutions
# Adware.Buddylinks
# Adware.MaxSplit
# Adware.OfferAgent
# Android.AdChina
# Adware.FindNavi
# Adware.MBKWbar
# Android.Adknowledge
# Android.Cepsohord
# Adware.Affilred
# Android.Cosha
# Android.Fakevoice
# Android.Skullkey
# Android.Dogowar
# Adware.BargainBuddy
# Adware.BeSys
# Adware.Winshow
# Android.YuMe
# Adware.WinTaskAd
# Android.Nyearleaker
# AntispySpider
# Android.Faketoken
# Android.IadPush
# Adware.Roimoi
# A2K.Damcor
# Allayed
# Android.Appenda
# Android.AdInfo
# Android.Basebridge
# Android.Backscript
# Android.Stiniter
# Adware.IntelliDownload
# Adware.ShowBehind
# Adware.Dynamic
# Android.Lockdroid.H
# AdwareSpy
# Adware.EnergyPlugin
# Adware.BlocknSurf
# Adware.Margoc
# Adware.RCPrograms
# Adware.Qidion
# Adware.FinanceAlert
# Android.Dowgin
# Adware.FavoriteMan
# Adware.MixVideoPlay
# Adware.WinLog
# Android.MobWin
# Adware.PastaLeads
# Android.Adrd
# Adware.Maltrec.TS!g31
# Android.Sumzand
# Adware.Emusic
# Android.Gonfu.D
# Adware.DriverTuneup
# Android.Dianjin
# Adware.Websearch
# Android.Ghostpush
# Adware.SearchWords
# Adware.Topicks
# ANTI
# Android.Fakeyouwon
# Android.Fakegame
# Android.Mania
# Android.Cnappbox
# Adware.SmartAdware
# Adware.BrowserPal
# Adware.PrecisionTime
# Android.Boxpush
# Adware.WebDir
# Adware.SmartBrowser
# Adware.SearchNugget
# Adware.Adlogix
# Android.Moolah
# Adware.CWSMSConfd
# Android.Alienspy
# Adware.CinemaPlus!g1
# Adware.WinBo
# Adware.EzulaRemovalTool
# Adware.AirInstaller
# Adware.DashBar
# Adware.SideBySide
# Adolph
# Adware.Mpgcom
# Adware.Syslibie
# Android.Fakesecsuit
# Adware.JollyWallet
# Android.Loozfon
# AngryIPscanner
# Adware.ZipClix
# Adware.DynamicUpdater
# Adware.SurfSideKick
# AntivirusPlasma
# Android.Gomal
# Adware.Trusteddownload
# Android.Reputation.2
# Adware.YourSiteBar
# Adware.Ddpop
# Android.Appleservice
# Adware.Conspy
# Adware.NewWeb
# Android.Mobus
# Adware.MediaPlaceTV
# Adware.Advertbar
# Adware.Cax
# Adware.PLook
# Albania.429
# Android.Piddialer
# Android.Ftad
# Android.Kemoge
# Android.Spytekcell
# AntiVirusXP2008
# Adware.ArcadeWeb!gen
# Adware.EvidenceScan
# Adware.RapidMediaCon
# Atomic
# Android.GallMe
# Adware.SecurityUtilty
# Android.Fakelicense
# Adware.DomaIQ
# Adware.FlashEnhancer
# Adware.Vitruvian
# AntiSpywareGuard
# Android.Dynamicit
# Adware.CashBackBuddy
# Adware.Topsearch
# Accept.3773
# Adware.TopAV
# Adware.FreeScratchWin
# Adware.Zwunzi!gen3
# Android.Counterclank
# Android.Lovespy
# Adware.TVWizard
# Android.Tapjoy
# Adware.Nafaoz
# Android.Ju6
# Android.Faketaobao.B
# Adware.SurfAccuracy
# Adware.SearchBarCash
# ALS.Bursted.A
# Android.Fakedefender.B
# Android.Rootcager
# AntiSpyGuard
# Android.Rufraud
# Android.Spyagent
# ALS.Kenilfe
# Android.Dengaru
# Adware.LinkMaker
# Adware.GoonSquad
# Adware.Magoo
# Adware.ZombieInvasion
# Android.Fakenotify
# Adware.ZioCom.B
# Adware.Uplink
# Adware.Maltrec.TS!g25
# Android.Nickispy
# Android.Temai
# Andryushka
# Adware.Maltrec.TS!g14
# Anti-PascalII.400
# Adware.Linkgrabber
# Adware.MaxSearch
# Adware.Wurldmedia
# Android.Adfonic
# Android.Tonclank
# Android.Funtasy
# Android.Positmob
# Adware.AFAEnhance
# Adware.BocaiToolbar
# Adware.UCMore
# Adware.OneStep
# Adware.WinAd
# Adware.Webprefix
# Adware.CWSConyc
# Android.Fokonge
# Adware.Aurora
# Adware.Aureate
# Ambulance
# Android.Fakemini
# Adware.LuckyTab
# Adware.Searchexplorer
# AdwareRemover2007
# Adware.HighTraffic
# Adware.PassShow
# Adware.FreeComm
# Adware.GravitySpace
# Android.Mobiletx
# Adware.StopPopupAdsNow
# Android.SellARing
# Bloodhound.Exploit.20
# Bloodhound.Exploit.4
# Backdoor.Agent.BRemovalTool
# Backdoor.Avubot
# Bloodhound.Exploit.56
# Bloodhound.Exploit.477
# Bloodhound.Exploit.457
# Backdoor.Amitis.B
# Backdoor.Ghostnet
# Backdoor.RCServ
# Bloodhound.Exploit.166
# Backdoor.Rifelku
# Bloodhound.Flash.28
# Bloodhound.Exploit.263
# Bloodhound.Exploit.273
# Bloodhound.Exploit.33
# Backdoor.IRC.Whisper.B
# Backdoor.Dorshel
# Backdoor.Elpman
# Bloodhound.Exploit.55
# Backdoor.Ugy
# Bloodhound.Exploit.210
# Backdoor.Sadhound
# Bloodhound.Exploit.320
# Backdoor.Egobot
# Backdoor.IRC.Aladinz.D
# Backdoor.Beasty.B
# Backdoor.Sheedash!gen1
# Boot.Stookit
# BAT.Trojan.Tally
# Bloodhound.Exploit.338
# Bloodhound.Exploit.357
# Backdoor.Unifida
# Bloodhound.Exploit.35
# Backdoor.HackDefender
# Backdoor.Piltabe
# Backdoor.DarkSky.B
# Backdoor.Gapin
# Backdoor.Ryejet
# Backdoor.Darkirc
# Backdoor.R2D2
# Backdoor.Berbew.O
# Backdoor.Darkmoon.C
# Bloodhound.Flash.2
# Bloodhound.Exploit.269
# Backdoor.Haxdoor.I
# Backdoor.Sykipot!gen1
# Backdoor.Lala.B
# Backdoor.Spigot.B
# Bloodhound.Exploit.94
# Backdoor.Beasty.G
# BAT.Lala
# Backdoor.Shatekrat
# Backdoor.DeskProxy
# BAT.Randren
# Backdoor.Nflog
# Backdoor.Shroden
# Backdoor.Theef.C
# Bloodhound.Exploit.262
# Bloodhound.Exploit.202
# BAT.NetStop.Trojan
# Backdoor.Wold
# Backdoor.Bla.Trojan
# BAT.Sebak
# Bloodhound.Exploit.329
# Backdoor.Haxdoor.S/Trojan.Schoeberl.ERemovalTool
# Backdoor.Tela
# Backdoor.Ranky.Y
# Bloodhound.Exploit.158
# Backdoor.Laphex.Kit
# Backdoor.Toob.A
# Backdoor.Botex
# Backdoor.Optix.04
# Backdoor.Lax
# Backdoor.IRC.RPCBot.C
# Backdoor.Roopre
# Bloodhound.Exploit.183
# Backdoor.Haxdoor.H
# Bloodhound.Exploit.134
# Blender.exeandFish.exe
# Backdoor.Vertexbot
# Bloodhound.Exploit.474
# Bloodhound.PDF.24
# Backdoor.Jupdate
# Backdoor.Linfo
# Backdoor.Pahador
# Butterfly.302
# Backdoor.FTP_Ana.D
# Bloodhound.Exploit.374
# Backdoor.Korplug!gen7
# Bloodhound.ELAM.8
# Backdoor.Grexden
# Backdoor.Ratenjay
# Backdoor.Drator
# Backdoor.NetDevil
# BAT.Wimpey.dr
# Bloodhound.Exploit.281
# Bloodhound.Exploit.36
# Backdoor.Robofo.A
# Backdoor.Ohlotus
# Bloodhound.Exploit.40
# Bloodhound.Exploit.489
# Boot.Smitnyl
# Backdoor.Leniv
# Bloodhound.Exploit.24
# Bloodhound.Exploit.370
# Backdoor.Bifrose.K
# Backdoor.Ketch
# Backdoor.Lokidok
# Backdoor.Nibu.J
# Backdoor.Oliner
# Backdoor.Wiarp
# Bloodhound.Harakit
# Backdoor.Fimlis.B
# Bloodhound.Exploit.377
# Bloodhound.Exploit.552
# Backdoor.Migmaf
# Backdoor.Acidoor
# Backdoor.IRC.Client
# Backdoor.OptixPro.12.c
# Backdoor.Ohlotus!g1
# Backdoor.Straxbot!kmem
# Backdoor.Dvldr
# Backdoor.Cycbot!gen1
# Bat.SillyB.gen
# Backdoor.Naninf.A
# BAT.Without.C@mm
# Bloodhound.Exploit.325
# Backdoor.Stealer
# Backdoor.Sdbot.AA
# Backdoor.Evilbot.C
# Backdoor.Penrox
# Backdoor.Sdbot.I
# Backdoor.Pirpi!dr
# Backdoor.Wisti
# Backdoor.Kaziarb!gen1
# Bloodhound.Exploit.249
# Bloodhound.Exploit.442
# Bloodhound.Flash.19
# Bloodhound.PDF.22
# Bloodhound.Exploit.235
# Backdoor.Tidserv.K
# Bloodhound.Exploit.485
# Bloodhound.RTF.13
# Backdoor.DSNX
# Backdoor.Vexdoor
# Backdoor.Sdbot.AK
# Backdoor.Rarstone
# Backdoor.Singu.B
# Bloodhound.Exploit.365
# Bloodhound.Exploit.277
# Backdoor.Pirpi!gen2
# Backdoor.Bionet.404
# Bloodhound.Exploit.349
# Backdoor.Livehar
# Backdoor.Bosonha
# Backdoor.Lifefournow
# Backdoor.Misdat
# Backdoor.Cohhoc
# Bloodhound.Exploit.260
# Backdoor.Futh
# Backdoor.Darkmoon.D
# Bloodhound.Exploit.52
# Backdoor.Kaitex
# Backdoor.Singu.C
# Backdoor.OICQSer.165
# Backdoor.Grobodor
# Backdoor.Ranky
# Bloodhound.Exploit.71
# BosonGetPass
# Backdoor.Beasty.Cli
# Backdoor.Contopee!gen1
# Backdoor.Korplug!gm
# Backdoor.Specfix
# Backdoor.Spoofrand
# Backdoor.LittleWitch.B
# Backdoor.Baste
# Backdoor.Private
# Backdoor.OptixPro.13.C
# Backdoor.FunFactory
# Backdoor.FTP_Bmail
# Backdoor.Graybird.Cli
# Backdoor.AntiLam
# Backdoor.Coreflood!gen
# Backdoor.Darmenu
# Backdoor.Layork
# Backdoor.AntiLam.20.K
# Backdoor.Motnug
# Bloodhound.Exploit.43
# Backdoor.Papi
# Bloodhound.Exploit.531
# Backdoor.IRC.Whisper
# Bloodhound.Olexe.2
# Backdoor.Zekapab
# Bloodhound.Exploit.245
# Backdoor.Nota
# Backdoor.Typideg!gen1
# Backdoor.Wollf.16
# Backdoor.Khrat
# Bloodhound.Bancos.1
# Backdoor.Lassrv
# Backdoor.Dani
# Backdoor.StealthEye
# Backdoor.Kirihop
# Backdoor.Doksen
# Backdoor.Lithium
# Backdoor.Berbew.F
# Backdoor.Cycbot!gen11
# Bloodhound.Exploit.509
# Backdoor.Guzu
# Backdoor.Zegost
# Backdoor.Doublepulsar
# Backdoor.Tidserv.L
# Bloodhound.Exploit.324
# Backdoor.Specfix.B
# Boot.Chan
# Backdoor.Tricker
# Backdoor.Korplug!gen6
# Backdoor.Mudsy
# Bat.Delsys.Trojan
# Backdoor.Prioxer.C!inf
# Backdoor.Hesive.C
# Backdoor.Boksdrop
# Bloodhound.Exploit.99
# Backdoor.Berbew!g1
# Backdoor.Servsax
# Backdoor.Darkmoon.G
# Bloodhound.Exploit.294
# Backdoor.Tidserv.J
# Backdoor.Sheedash!inf
# Backdoor.Armageddon
# Backdoor.Redsip
# Backdoor.Pazus
# Bad.Sectors.3428
# Bloodhound.Exploit.279
# Backdoor.Korplug!gen3
# Backdoor.Homutex
# Bicho7Hoax
# Backdoor.Necurs!gen2
# Backdoor.Sacto!gen1
# Backdoor.Berbew.D
# Backdoor.Novacal
# Backdoor.Trojan.B
# Backdoor.Nitol!gen1
# Backdoor.XLog
# Backdoor.Uprootkit.cli
# Backdoor.Dewin
# Backdoor.Yat
# Backdoor.Assasin.B
# Backdoor.Netjoe
# Bloodhound.Exploit.132
# Bloodhound.Exploit.306
# Backdoor.Graybird.N
# Backdoor.Naninf.C
# Bloodhound.Exploit.153
# Backdoor.Krad!gm
# Backdoor.Blazgel
# Backdoor.UKS
# BeMyValentine
# Backdoor.Waketagat
# Backdoor.Barkiofork!g2
# Bloodhound.Flash.30
# Bloodhound.SMR.1
# Bloodhound.RTF.17
# Backdoor.Klankty
# Backdoor.Finfish!gen5
# Bloodhound.Exploit.191
# Bloodhound.Exploit.332
# Backdoor.Pihar
# Bloodhound.Exploit.239
# Backdoor.Checkesp
# Backdoor.Gholame
# Bloodhound.Exploit.27
# Backdoor.Miskip!gen1
# Backdoor.Plaintee
# Backdoor.Eminoc!inf
# Backdoor.Locobad
# Bloodhound.Morphine
# Backdoor.Netdevil.15
# Backdoor.Destiny
# Backdoor.Bifrose
# Bloodhound.Exploit.288
# Backdoor.IRC.Aladinz.O
# Backdoor.Mprox
# Backdoor.Alienspy
# Backdoor.Marotob
# Backdoor.Bofishy.C
# Backdoor.Niklaus
# Backdoor.Readomesa
# Bloodhound.Exploit.313
# Backdoor.Sdbot.AP
# Backdoor.Dumbot
# Backdoor.Zdemon
# BigBrotherHoax
# Bloodhound.Exploit.143
# Bloodhound.W32.1
# Bloodhound.PDF.18
# Backdoor.BladeRunner
# Backdoor.Ranky.B
# Backdoor.Eterok
# Backdoor.IRC.Ratsou
# Bloodhound.Exploit.29
# Backdoor.Hesive.D
# Backdoor.Ranky.Z
# Backdoor.Recerv
# Backdoor.Kodalo
# Bloodhound.PDF.15
# Bloodhound.Exploit.178
# Backdoor.Mite
# Bloodhound.Exploit.89
# Backdoor.Noknef
# Bloodhound.Exploit.51
# Bloodhound.Exploit.219
# Backdoor.Staprew
# Backdoor.Vasport
# Backdoor.CNK.A.Cli
# Backdoor.Lixy.B
# Backdoor.Roxy.C
# Backdoor.Slordu
# Bloodhound.Exploit.402
# Backdoor.Danrit
# Backdoor.Carufax.A
# Backdoor.Beasty
# Backdoor.Winnti!gen3
# Bat.Koo
# Backdoor.Delf.B
# Backdoor.Lastras
# Backdoor.Litmus.203
# Backdoor.Kerlisen
# Bloodhound.ST.1
# Backdoor.Cmjspy
# Backdoor.Hesive.E
# Backdoor.IRC.Lazz
# Backdoor.Rallovs.B
# Backdoor.Simali
# Bloodhound.RTF.18
# Backdoor.IRC.Spybuzz
# Backdoor.Sdbot.M
# Backdoor.GF.13
# Bloodhound.Flash.7
# Backdoor.Evilbot.B
# Backdoor.EZBot
# Backdoor.Korgapam
# Backdoor.Tinybaron!g1
# Backdoor.Flyoutburn
# Backdoor.Spedear
# Bat.RBM
# Backdoor.IRC.RPCBot.B
# Backdoor.Fakemrat
# Backdoor.Mxsender
# Bloodhound.Exploit.440
# Backdoor.Specfix.C!g1
# Backdoor.SubSeven.215
# Backdoor.Armageddon.B
# Backdoor.Barkiofork
# Backdoor.Mapafes
# Backdoor.Hacarmy.F
# Bloodhound.Exploit.274
# Backdoor.Cadelspy!g1
# Backdoor.Abebot
# Backdoor.Zyklobot
# Bloodhound.Exploit.91
# Backdoor.ZXShell
# Backdoor.IRC.PSK
# Bloodhound.Exploit.122
# Bloodhound.Exploit.271
# Bloodhound.ELAM.4
# Backdoor.Sadmind
# Backdoor.CrashCool
# Boot-437.A
# Backdoor.Darkmoon!gen5
# Bloodhound.Exploit.159
# Backdoor.Spymon
# Backdoor.Hesive.F
# Backdoor.Revrs
# Backdoor.Bifrose.N
# Backdoor.Fluxay
# Backdoor.Crazynet
# Backdoor.Darkmoon!gen3
# Backdoor.Kuyama
# Bloodhound.Exploit.77
# Bloodhound.RTF.5
# Backdoor.Uwarrat
# Backdoor.Whalfrost
# Backdoor.Haxdoor.O
# Backdoor.Mapsy
# Backdoor.Linopid
# Bloodhound.Exploit.165
# Backdoor.Nodelm
# Bloodhound.Exploit.103
# Backdoor.WinShell.50.b
# Backdoor.IISCrack.dll
# Backdoor.Remsec
# Backdoor.Spyboter.gen
# BAT.Ratty
# Backdoor.IRC.Bbot
# Backdoor.Oldrea!gen1
# Bloodhound.SONAR.2
# Bloodhound.Flash.10
# Backdoor.Voldat
# Backdoor.Bifrose.D
# Bloodhound.Exploit.295
# Backdoor.Korplug!gen9
# Bloodhound.Exploit.250
# Backdoor.Osirdoor
# Backdoor.Glasrats
# Backdoor.Litmus.203.c
# Backdoor.Volac.dr
# Backdoor.Miniduke!enc
# Backdoor.Acropolis
# Backdoor.Bionet.40a
# Backdoor.Emdivi!gm
# Backdoor.Remvio!gm
# Bloodhound.Exploit.101
# Bloodhound.Exploit.212
# Bloodhound.Overpacked
# Backdoor.Synrg
# Backdoor.Tuimer
# Backdoor.SmokeDown.B
# Backdoor.Kalasbot
# Bloodhound.Exploit.197
# Bloodhound.PDF.38
# Backdoor.Scanboot
# Backdoor.IRC.Yoink.A
# Backdoor.Darkmoon.E
# Backdoor.Pled
# Backdoor.Bandock.A
# Backdoor.Emdivi!gen2
# Backdoor.IRC.Zcrew
# Boot.Dididix.B
# BAT.Copykaz.Worm
# Bloodhound.PDF!gen
# Backdoor.Netbus.444051
# Backdoor.Trot.D
# Backdoor.Formador
# BAT.BWG@mm
# Bloodhound.Exploit.216
# Bloodhound.Exploit.233
# Bloodhound.PDF!gen2
# Backdoor.Outflare
# Backdoor.Mivast
# BBOS.Zeusmitmo
# Backdoor.Vinself
# Backdoor.Y3KRat.16
# Bloodhound.Exploit.38
# Backdoor.Darkmoon
# Bloodhound.Exploit.206
# Bloodhound.Exploit.397
# Backdoor.Regin
# Backdoor.Ratega
# Backdoor.IRC.Mutebot
# Bloodhound.Inflated
# Backdoor.Imiserv
# Backdoor.Wakeminap!g1
# Backdoor.Pcclient.B
# Backdoor.Femo
# Backdoor.Vinself.B
# Bloodhound.Exploit.199
# Backdoor.Ptakks.B
# BAT.Caya
# Backdoor.IRC.Aladinz.R
# Backdoor.Microkos
# Bloodhound.Exploit.330
# Bloodhound.Exploit.230
# Bat.Mumu.A.WormRemovalTool
# Bloodhound.Exploit.283
# Backdoor.Daer
# Backdoor.Kika.A
# Backdoor.Slackbot.B
# Backdoor.Tidserv!gen7
# Backdoor.EggHead
# Backdoor.Lusillon
# Backdoor.Conpee
# Bloodhound.Exploit.307
# Backdoor.MLink
# Backdoor.Rtkit
# Backdoor.Byerat
# Backdoor.Nemog.C
# Bloodhound.Exploit.293
# Backdoor.AutoupderRemovalTool
# Backdoor.Tabdim
# Backdoor.Gaucho
# Backdoor.HackTack
# Backdoor.Libnut
# Boot.Stonedbootkit
# Backdoor.Tjserv.B
# Backdoor.Coreflood!1
# Backdoor.Emdivi!gen5
# Bloodhound.Exploit.412
# Backdoor.Ranky.O
# Bloodhound.Exploit.54
# Bloodhound.Exploit.553
# Bloodhound.Packed.32
# Backdoor.IRC.Flood.H
# Backdoor.Renomb
# Backdoor.Sdbot.R
# Backdoor.Belmoo
# Bloodhound.PDF.29
# Backdoor.Botnachala
# Backdoor.Jolob
# Bloodhound.Exploit.254
# Backdoor.NTHack
# Backdoor.Darkmoon!gen9
# Backdoor.Klb
# Backdoor.Lastdoor
# Backdoor.Udps.10
# Backdoor.Augudor
# Backdoor.Robofo
# Backdoor.Sdbot.AE
# Backdoor.Proxyback
# Backdoor.DarkSky.Cli
# Bloodhound.Exploit.211
# Backdoor.Phoenix
# Backdoor.Memsyl
# Bloodhound.Exploit.113
# Backdoor.Conpee!inf
# Backdoor.Sdbot.AN
# Bloodhound.Exploit.82
# Backdoor.Redkod
# Backdoor.Litmus.203.b
# Backdoor.Theef.B
# Backdoor.IRC.Flood.E
# Backdoor.Alusins
# Backdoor.Graybird.L
# Bloodhound.SONAR.3
# Bloodhound.Exploit.161
# Backdoor.Graybird.J
# Backdoor.Smokodoor
# Backdoor.Hikit!gen1
# Backdoor.Sogu
# Backdoor.Ranky.Q
# Bloodhound.Exploit.454
# Bloodhound.Exploit.106
# Backdoor.Ranky.W
# Backdoor.Tankedoor
# Backdoor.Dckane
# Bloodhound.Exploit.112
# Backdoor.Cazno
# Backdoor.Trynoma
# Bloodhound.Exploit.470
# Backdoor.Quimera
# Bloodhound.Exploit.111
# Bloodhound.Exploit.557
# Backdoor.Perper
# Backdoor.Rocra
# Backdoor.Sagerunex
# Bloodhound.Exploit.49
# Backdoor.Tidserv!gen14
# Backdoor.Snowdoor.Cli
# Bloodhound.Exploit.118
# Bloodhound.W32.2
# Backdoor.Ultor
# Bloodhound.Exploit.135
# Bloodhound.CRC
# Bloodhound.Exploit.231
# Bloodhound.Exploit.73
# Bloodhound.HWP.1
# Backdoor.Crat
# Backdoor.Oliner!gm
# Backdoor.NetTrojan
# Backdoor.Baccamun
# Bloodhound.Exploit.181
# Bloodhound.Packed
# Backdoor.Nibu.K
# Bloodhound.Packed.29
# Backdoor.Gussdoor
# Backdoor.Assasin.E
# Backdoor.Cigivip
# Backdoor.G_Door.Client
# Bloodhound.Exploit.494
# Backdoor.Snowdoor
# Backdoor.Rockse
# Bloodhound.Exploit.354
# Bloodhound.Exploit.171
# Bloodhound.Exploit.243
# Backdoor.Securetalk
# Backdoor.Eterok.C
# Backdoor.Fxdoor
# Backdoor.Haiyangweng
# Boot.Mebroot
# Backdoor.Cycbot!gen5
# Backdoor.Nithsys
# BAT.Etimolod.A
# Bloodhound.RTF.8
# Backdoor.Tixanbot
# Backdoor.Hugly
# Backdoor.Verify
# Backdoor.Nibu.D
# Backdoor.Bandock.A!gm
# Bloodhound.Exploit.347
# Bloodhound.Exploit.44
# Backdoor.NetDevil.Dr
# Boot.Gapz
# Backdoor.Nuclear
# Backdoor.Bipfam!gen1
# Bloodhound.PDF!gen1
# Backdoor.Litmus
# Backdoor.Rocra!gen1
# Bloodhound.Exploit.244
# Backdoor.Finfish!gen4
# Backdoor.XTS.B
# Backdoor.Straxbot
# Boot.Mebromi.B
# Boot.Mebratix
# Backdoor.Protucs
# Bloodhound.Exploit.39
# Backdoor.Tidserv!kmem
# Backdoor.MiniCommander
# Backdoor.Elitem
# Bloodhound.Flash.31
# Bloodhound.Exploit.337
# Bloodhound.PDF.6
# Backdoor.Tranwos!gen1
# Backdoor.TidservRemovalTool
# Boot.Guntor
# Backdoor.Fakeslic
# Backdoor.Dsklite
# Backdoor.Rokrat
# Bloodhound.Packed.30
# Bombole.511
# Bloodhound.Exploit.84
# Backdoor.Badbee
# Backdoor.Mtron
# Backdoor.Darkmoon.F
# Backform
# Bloodhound.Exploit.465
# Backdoor.Berbew.T
# Backdoor.Vidgrab!gen1
# Backdoor.Misogow!g1
# Backdoor.Berbew.E
# Bloodhound.Exploit.92
# Backdoor.Sdbot.E
# Boot.Fispboot
# Backdoor.Agent.B
# Backdoor.Cobalt!gen2
# BAT.PDrome
# Bloodhound.Exploit.139
# Backdoor.Netduke
# Bloodhound.Exploit.85
# BAT.Betta.A
# Backdoor.Shangxing
# Boot.HDRoot
# Backdoor.Lateda
# Bloodhound.Flash.15
# Backdoor.Cycbot!gen7
# Backdoor.Urat.b
# Bloodhound.RTF.9
# Bloodhound.Exploit.403
# Bloodhound.Exploit.53
# Bloodhound.Exploit.829
# Backdoor.Zincite.A
# Backdoor.SDBot.Q
# Backdoor.Zegost!gm
# Backdoor.Berbew.I
# Backdoor.Evivinc
# Backdoor.Beasty.F
# Backdoor.Solidrat
# Backdoor.Finfish!gen3
# Bloodhound.Oleswf.2
# Backdoor.Naymard
# Backdoor.Sysbug
# Backdoor.Powerspider
# Backdoor.Rocra!gen2
# Backdoor.Kavar
# Backdoor.IRC.Aladinz.I
# Backdoor.IRC.Lampsy
# Backdoor.Assasin.F
# Bloodhound.Exploit.207
# Backdoor.Fatroj
# Backdoor.IRC.Flood
# Backdoor.Breut!gm
# Backdoor.Bifrose.G
# Backdoor.Nibu.H
# Backdoor.Sdbot.AR
# Bloodhound.Exploit.540
# Bloodhound.Exploit.59
# Backdoor.Lolok
# Backdoor.Tinybaron!g2
# Backdoor.Graybird.P
# Backdoor.NetThief
# Backdoor.Lixy
# Bloodhound.Packed.5
# Backdoor.VB.CH
# Backdoor.Fulamer.25
# Bloodhound.Exploit.504
# Backdoor.Industroyer
# Backdoor.Hormesu!gen2
# Bloodhound.Exploit.173
# Backdoor.Hacarmy.C
# Backdoor.Kaitex.D
# Backdoor.Korplug.C!gm
# Backdoor.Assasin.D
# Backdoor.Tervserv
# Backdoor.Haxdoor.M
# Bloodhound.Exploit.488
# Bloodhound.Exploit.174
# Bloodhound.Exploit.188
# Bloodhound.Exploit.192
# Backdoor.IRC.Aladinz.G
# Backdoor.Prosiak
# Backdoor.Volac
# Backdoor.Hornet
# Backdoor.Optix.04.d
# BAT.Snoital@mm
# BAT.Black
# Backdoor.Xebiz
# Backdoor.Dozillor
# BBproxy
# Backdoor.Tidserv!gen5
# Backdoor.WLF
# Bloodhound.Exploit.221
# Backdoor.Bipfam!gen2
# Backdoor.IRC.Bot.B
# Backdoor.Streamex
# Backdoor.Anyserv
# Backdoor.Gresim!gen1
# Bloodhound.Exploit.144
# Backdoor.Cuhmap
# BAT911.Worm
# Bloodhound.Exploit.74
# Backdoor.Anyserv.B
# Backdoor.Roxy
# Backdoor.Sparta
# Backdoor.Berbew.B
# Backdoor.Hacarmy.G
# Backdoor.Asylum
# Backdoor.Sincom
# Backdoor.Beasty.E
# Bloodhound.Flash.1
# Boot.Cidox
# Bloodhound.Exploit.550
# Backdoor.Barkiofork!g1
# Backdoor.Miranda
# Backdoor.FTP_Ana.B
# Backdoor.Pirpi!gen3
# Backdoor.Bmbot
# Backdoor.Fimlis
# Backdoor.Queen
# Backdoor.Pepperat
# BAT.Batix
# Bloodhound.Exploit.539
# Backdoor.Pirpi.C
# Backdoor.IRC.Loonbot
# Backdoor.Rustock
# Backdoor.Graybird.E
# Backdoor.Tidserv!gen15
# Bloodhound.Exploit.190
# Backdoor.Ducy
# Bloodhound.Exploit.138
# Backdoor.Bifrose.E
# Backdoor.Dindang
# Backdoor.Cazno.Kit
# Backdoor.Eparssa
# Backdoor.Haxdoor.Q
# Backdoor.Latinus.B
# BAT.Natay@mm
# BAT.Disom.Worm
# Bloodhound.Exploit.314
# BackDoor.G
# Backdoor.Doly.dr
# BAT.Nina.Trojan
# BadtimesHoax
# Backdoor.Steladok!g1
# Backdoor.Graybird.H
# Backdoor.Sdbot.AG
# Backdoor.VagrNocker
# Bloodhound.Exploit.507
# Backdoor.Winnti!inf
# Backdoor.Civcat
# Backdoor.Korplug
# Backdoor.Sdbot.N
# Bloodhound.Exploit.179
# Backdoor.IRC.Muiriled
# Backdoor.Mutny
# Backdoor.Neggpy
# Backdoor.Sedepex
# Backdoor.Hatckel
# Backdoor.Surge
# Backdoor.Berbew.Q
# Backdoor.IRC.RPCBot.D
# Bloodhound.MBR
# Backdoor.Jeetrat
# Bloodhound.Exploit.200
# Boza
# Backdoor.Sinflight.B
# Backdoor.Necurs!gen4
# Backdoor.Kargatroj
# Backdoor.Pioneer
# Backdoor.Tinybaron
# Backdoor.Cadelspy
# Backdoor.Graybird
# Backdoor.Alets.B
# BAT.Excessive.Worm
# Backdoor.Nibu.C
# Backdoor.Khaos
# Backdoor.Riblenc
# Backdoor.Finfish
# Bloodhound.MalVB
# Backdoor.Citrat
# Backdoor.Freeload
# Bloodhound.PDF.2
# Bloodhound.MalMacro!g3
# Backdoor.Shakydos
# Backdoor.Rocra!gen3
# Bneo.Trojan
# Bloodhound.Olexe
# Bloodhound.PDF.23
# Bloodhound.V.2
# Backdoor.IRC.Bot
# Backdoor.Pygeecat
# Bloodhound.Flash.23
# Backdoor.F3bot
# Backdoor.Freefors
# Backdoor.Preft!gm
# Backdoor.DarkSky
# Backdoor.Rozena
# Backdoor.Fivsec
# Backdoor.Quivoe
# Backdoor.Lanfilt.B
# Bloodhound.ELAM.5
# Backdoor.OptixPro.13
# Bloodhound.HWP.4
# Backdoor.Zvrop
# Backdoor.Meciv
# Backdoor.AIMVision
# Bloodhound.Exploit.366
# Backdoor.Thumbdoor
# Backdoor.Berbew.K
# Backdoor.Lancafdo
# Bloodhound.Exploit.416
# Backdoor.DKAngel
# Backdoor.Noppuca!gen
# Backdoor.Proxybox
# Bloodhound.Exploit.81
# Backdoor.Weevil.B
# Backdoor.Sdbot.G
# BetaBoys.Rattle
# Bloodhound.Exploit.501
# Backdoor.Ranky.F
# Bloodhound.Exploit.376
# BAT.Dfool
# Backdoor.Dsklite.cli
# Backdoor.Lateda.B
# Backdoor.SubSari.15
# Backdoor.Matsnu.B
# Backdoor.WinMap
# BAT.Cyseq.Worm
# Backdoor.Gapadaxi
# Backdoor.Cobalt!gen1
# Bloodhound.Exploit.496
# Backdoor.Fraggle
# Bloodhound.Exploit.503
# Backdoor.Wakeminap
# Backdoor.Contopee
# Bloodhound.Exploit.194
# Backdoor.Patpoopy!g1
# Backdoor.Bifrose.F
# Bloodhound.Exploit.512
# Bloodhound.Olemacho
# Backdoor.Graybird.F
# Backdoor.Sdbot.C
# Backdoor.Djump
# Bloodhound.Exploit.493
# Backdoor.Kol
# Backdoor.AntiLam.20
# Backdoor.Doster
# Backdoor.Remexi.B
# Backdoor.Ontarg
# Backdoor.Omega
# Backdoor.Brador.A
# Bloodhound.Malautoit
# Backdoor.Frigcase
# Backdoor.IrcContact
# Backdoor.Mosuc
# Backdoor.Objod
# Backdoor.Ripjac
# Backdoor.Ripinip
# Backdoor.CamKing
# Backdoor.Darksun
# Backdoor.Peers
# Backdoor.Kutex
# Backdoor.OptixPro.11.b
# Bloodhound.Exploit.286
# Backdoor.Matsnu
# Backdoor.Unpdoor
# Backdoor.Lukicsel
# Backdoor.Hacarmy.D
# Bloodhound.PDF.35
# Backdoor.IRC.Tastyred
# Backdoor.Graybird.O
# Backdoor.Winnti!gen4
# Bloodhound.Packed.4
# Backdoor.OptixDDoS
# Backdoor.Oblivion
# Backdoor.Slao
# Backdoor.Wincrash
# Backdoor.Badcodor
# Bloodhound.Exploit.369
# Backdoor.Sdbot.AF
# Bloodhound.Exploit.162
# Bloodhound.Exploit.41
# Backdoor.Minzen
# Backdoor.Apdoor
# Backdoor.Sparta.D
# Backdoor.Emcommander
# BBOS.Stealthgenie
# Bloodhound.PDF.12
# Bloodhound.Malautoit.6
# Backdoor.Netdex
# Bloodhound.ELAM.3
# Backdoor.Dalsk
# Backdoor.Paproxy
# Backdoor.Satancrew
# BAT.Trilissa@mm
# Backdoor.Pest.Cli
# Bloodhound.Exploit.223
# Bloodhound.Exploit.83
# Backdoor.Darkmoon.E1
# Backdoor.Forshare
# Bloodhound.Exploit.536
# Backdoor.GWGirl
# Bloodhound.Exploit.317
# Bloodhound.Exploit.195
# Backdoor.Mokes
# Backdoor.Dexbia
# Bloodhound.Exploit.346
# Backdoor.Glupzy
# Backdoor.R3C
# Backdoor.Juasek
# Bloodv1.1049
# Bloodhound.Exploit.265
# Backdoor.Pestic
# Backdoor.Muie
# Backdoor.Banechant
# Backdoor.Charge
# Bup.1234
# Backdoor.Haxdoor.E
# Backdoor.Balkart
# Backdoor.NetThief.Dr
# Bloodhound.RTF.3
# Bloodhound.Exploit.240
# Backdoor.SysXXX
# Backdoor.Dragodor
# Bloodhound.Exploit.128
# Backdoor.Banito
# Bloodhound.Exploit.383
# Bloodhound.Exploit.278
# Backdoor.Ranky.K
# Backdoor.Coreflood
# Backdoor.Smorph
# Backdoor.Zombam.B
# Backdoor.Talex
# Bloodhound.Exploit.66
# Bat.FAGE.1482
# Backdoor.Athenrat
# BeSpookedHoax
# Bloodhound.Exploit.126
# Boot.Kerlisen
# Backdoor.Hitcap
# Bloodhound.Exploit.439
# Backdoor.Lancafdo!gen2
# Backdoor.Spigot
# Backdoor.Coreflood.B
# BAT.Vir94
# Backdoor.NetControle
# Bloodhound.PDF.9
# Backdoor.Sadmind.Dr
# BAT.Boohoo.Worm
# Backdoor.Naninf.E
# Backdoor.Vinself.C
# Blink
# Backdoor.Lancafdo!gm
# Backdoor.Daserf.B
# Backdoor.Necurs!gen7
# Backdoor.Ghopapox
# Backdoor.Ndad
# Backdoor.Beasty.dr
# Bloodhound.Exploit.280
# Backdoor.Wespion
# Bloodhound.Exploit.533
# Backdoor.Polydrop
# Bloodhound.PDF.20
# Backdoor.Sdbot.AM
# Backdoor.Rsbot
# Backdoor.Korplug!gen1
# Backdoor.Salgorea
# Backdoor.Staprew.B
# Backdoor.Mydopam
# Bloodhound.RTF.15
# Bloodhound.Exploit.2
# Backdoor.Sdbot.H
# Backdoor.RPCBot.E
# Backdoor.Mulkerv
# Backdoor.Ghost
# Backdoor.IRC.Zcrew.B
# Bloodhound.Exploit.203
# Backdoor.Prorat
# Bloodhound.Flash.24
# Backdoor.Darkmoon!g11
# Bat.PG94.3964
# Backdoor.Softshell
# Backdoor.PSpider.310
# Backdoor.Beasty.I
# BlackIce
# Backdoor.CVM
# Backdoor.Duuzer.B
# BAT.BWG.gen
# Backdoor.Seamy
# Backdoor.Ginwui.C
# Bloodhound.Exploit.70
# Backdoor.Hesive
# Backdoor.Mulim
# Bloodhound.Exploit.209
# Backdoor.Nidiran!g1
# Bloodhound.Exploit.218
# Bloodhound.Exploit.287
# Backdoor.FTP.AFtp
# Backdoor.IRC.Zlulbot
# Backdoor.Fearles
# Backdoor.Klabcon
# Backdoor.Tidserv!gen19
# Backdoor.Roxrat
# Bloodhound.Exploit.105
# Backdoor.Pfinet
# Backdoor.Loknod
# Backdoor.Delf.D
# Bloodhound.Exploit.160
# Backdoor.Plexor
# Backdoor.Ripgof.C
# Backdoor.Mevade
# Backdoor.Roxy.B
# Bloodhound.Exploit.390
# Backdoor.Pharvest!inf
# Bloodhound.Exploit.151
# Backdoor.Fox
# Backdoor.Brakkeshell
# Backdoor.Ranky.E
# Backdoor.Berbew.N
# Backdoor.Asniffer
# Backdoor.Bipfam
# Backdoor.Ehdoor
# Backdoor.SubSeven22
# Backdoor.Korplug!gen10
# Backdoor.Netduke!g1
# Bloodhound.Exploit.367
# Backdoor.IRC.RPCBot.F
# Backdoor.Sosork
# Backdoor.Tidserv!gen4
# Backdoor.Necurs!gen5
# Bloodhound.Exploit.125
# Backdoor.Blizzard
# Backdoor.Graybird.B
# Bloodhound.Exploit.186
# Bloodhound.Exploit.104
# Backdoor.Omerta
# Bloodhound.ELAM.7
# Bloodhound.Exploit.150
# Backdoor.Tuckist
# Bloodhound.HLP.1
# Bloodhound.Exploit.46
# Backdoor.Korplug!gen8
# Backdoor.Lanfiltrator
# Backdoor.Mogefla
# Backdoor.Vmz
# Backdoor.Nibu.B
# Backdoor.Kaitex.B
# BAT.Rous.worm
# Backdoor.Eminoc
# Backdoor.Zdown
# Backdoor.Miffice
# Backdoor.Ploutus.B
# Bloodhound.Exploit.447
# Backdoor.Padmin
# Backdoor.Croxbow
# Backdoor.Cycbot!gen2
# Bloodhound.Flash.3
# Backdoor.Portless
# Backdoor.Actoin!gen1
# Backdoor.Linopid!gen1
# Bloodhound.Bancos.2
# Backdoor.Scuoter
# Backdoor.LittleWitch.C
# BAT.Dohman
# Backdoor.Wiween
# Backdoor.Specfix.C
# Backdoor.Mots
# Bloodhound.Exploit.205
# Backdoor.Delf.Cli
# Backdoor.IRC.Ratsou.B
# Backdoor.Dextenea
# Backdoor.Neodurk
# Bloodhound.Exploit.87
# Backdoor.Cartcapa
# Bloodhound.Exploit.222
# Backdoor.Makadocs
# Backdoor.Pointex
# Backdoor.Anakha
# Backdoor.Revrs.Client
# Backdoor.Sequel
# Backdoor.Zdemon.126
# Backdoor.Frango
# Backdoor.Litmus.2a
# Backdoor.Klovbot!gen1
# Backdoor.Antilam.g1
# Backdoor.Darkmoon!gen
# BAT.LCAM
# Bloodhound.Exploit.469
# Backdoor.Sdbot.dr
# Backdoor.Nibu
# Bloodhound.Exploit.225
# Backdoor.Prosti
# Backdoor.Gwapoors!gm
# Backdoor.DTR
# Backdoor.Graybird!gen
# Backdoor.Sdbot.Z
# Bloodhound.Exploit.252
# Backdoor.Singu
# Bloodhound.Exploit.169
# Backdoor.Solufina
# Backdoor.Beasty.J
# Backdoor.Autlad
# Backdoor.Poldat
# BUDDYLST.ZIP
# Bloodhound.Exploit.156
# Backdoor.Chafty
# Backdoor.Mirab
# Bloodhound.PDF.10
# Backdoor.Raid
# Backdoor.Chilurat
# Bloodhound.Exploit.554
# Backdoor.Raslup
# Backdoor.Danton
# Backdoor.IRC.Aladinz.L
# Backdoor.Notestuk
# Backdoor.Peerdoor
# Bloodhound.KillAV
# Bloodhound.Exploit.312
# Backdoor.Esion
# Backdoor.Stanex
# Bloodhound.SONAR.4
# Backdoor.Hackersdr!inf
# Backdoor.Spotcom
# Backdoor.Syzoor
# Backdoor.Roxe
# Bloodhound.Exploit.508
# Bloodhound.Exploit.76
# Backdoor.Darkmoon!gen2
# Bloodhound.Exploit.116
# Bloodhound.Exploit.542
# Bat.Hexvirus.1414
# Backdoor.Vinderuf!g1
# Backdoor.Destover
# Backdoor.Prioxer
# Backdoor.Sdbot.L
# Backdoor.Briba
# BackFont.905
# Backdoor.Ranky.V
# Backdoor.Ranky.U
# Backdoor.Odivy
# Backdoor.Enfourks
# Backdoor.Sheldor
# Backdoor.Ripiner
# Backdoor.Wofeksad
# Bloodhound.Exploit.3
# Backdoor.Comdinter
# BAT.Karal.A
# Backdoor.Snifula.D
# Bloodhound.ELAM.1
# Backdoor.Pigola
# Bloodhound.Exploit.137
# Backdoor.Dalbot
# Backdoor.Selka
# Backdoor.Apocalipto
# Bloodhound.Exploit.67
# Bloodhound.Exploit.114
# Backdoor.Beasty.C
# Backdoor.Weevil!gen1
# Backdoor.Herpybot
# Bloodhound.Exploit.1
# Bat.Mosquito.B.gen
# Backdoor.Hugly!gen1
# Bloodhound.ELAM.9
# Bloodhound.Exploit.422
# Backdoor.actx
# Boot.Ramnit
# Backdoor.Goster
# Backdoor.Switrex
# Backdoor.Duuzer
# Backdoor.Globe
# Backdoor.Mosuck
# Backdoor.Delf.Family
# BBOS.Lastacloud
# Backdoor.Haxdoor.P
# BAT.Deav.Worm
# Backdoor.IRC.Cirebot
# Backdoor.Ranky.J
# Backdoor.Korplug.C
# Bloodhound.PDF.26
# BAT.Antir
# Backdoor.Ratenjay!gen2
# Bloodhound.HWP.3
# Boot.Pitou.B
# Bloodhound.Exploit.505
# Backdoor.Trojan.Client
# Backdoor.Necurs!gen1
# Bloodhound.Exploit.170
# Backdoor.Rephlex
# Backdoor.Murcy
# Boot.Pihar
# Bloodhound.MalMacro!g1
# Backdoor.Necurs!gen3
# Backdoor.Spedear!gen2
# Backdoor.SchoolBus.B
# Backdoor.Beasty.Family
# Bloodhound.Exploit.267
# Bloodhound.Exploit.437
# Backdoor.Graybird.I
# Backdoor.Pirpi
# Bloodhound.Exploit.495
# Backdoor.Sdbot.AC
# Backdoor.Upfudoor
# Backdoor.Ciadoor.B
# Boot.Dididix
# Backdoor.Palukka
# Backdoor.Gresim
# Bloodhound.W32.3
# Backdoor.Xordoor
# Backdoor.Asoxy
# Backdoor.Adwind
# Backdoor.MSNCorrupt
# Backdoor.Dashikut
# Backdoor.Dideekong
# Backdoor.Pirpi.D
# Barrotes
# BAT.Bomb
# Bloodhound.Flash.29
# Boot.Basutra
# BAT.Enumiacs
# Bloodhound.Exploit.25
# Bloodhound.PDF.16
# Bloodhound.Flash.21
# Bloodhound.ELAM.6
# Backdoor.ConstructKit
# Backdoor.Jeem
# Bloodhound.Exploit.215
# Backdoor.Spyboter.A
# Backdoor.Miskip
# Backdoor.Skun
# Backdoor.Wualess
# Backdoor.Bofishy.B
# Backdoor.Coreflood.dr
# Backdoor.Nibu.F
# Burglar.1150.A
# Bloodhound.Exploit.226
# Backdoor.Pihar!gen1
# Backdoor.Arcomrat
# Backdoor.Fosor
# Backdoor.OptixPro.12
# Bloodhound.Exploit.13
# Backdoor.Backtor
# Backdoor.Cycbot!gen3
# Backdoor.Hale
# Backdoor.Ginwui
# Bloodhound.Beagle
# Backdoor.Cabro
# Bloodhound.Exploit.391
# Backdoor.Darksun.B
# Backdoor.Ryejet.B
# Bloodhound.Exploit.289
# Backdoor.Tjserv
# Bloodhound.Exploit.224
# Backdoor.Tubma
# Bloodhound.Exploit.117
# Bloodhound.Exploit.343
# Bloodhound.Exploit.176
# Backdoor.Ginwui.D
# Backdoor.Rabasheeta
# Backdoor.Dagonit
# Bloodhound.Exploit.7
# Bloodhound.Exploit.163
# Backdoor.Korplug.D
# Backdoor.OICQSer.17
# Backdoor.Gazer!gm
# Backdoor.Warbot
# Boot.Incodboot
# Backdoor.Jiripbot
# Bloodhound.PDF.27
# Backdoor.Mousey
# Backdoor.Wensal
# Backdoor.Tidserv!gen2
# Backdoor.Doly
# Bloodhound.PDF.13
# Backdoor.Typideg
# Bloodhound.Exploit.321
# Backdoor.GRM
# Backdoor.Boda!gen1
# Backdoor.Dister
# Backdoor.Lisdazz
# Backdoor.Alets
# Backdoor.IRC.Ratsou.D
# Backdoor.Nerte
# Boot.Cryptolocker.AU
# Backdoor.Bionet.318
# Backdoor.Nibu.L
# Backdoor.Rocra!gen4
# Backdoor.Subot
# Backdoor.Subwoofer
# Backdoor.Death.Cli
# Backdoor.Haxdoor.B
# Backdoor.Prysat
# Backdoor.Turkojan
# Backdoor.Delf.C
# Backdoor.Darkmoon!g10
# Bloodhound.Exploit.242
# Backdoor.IRC.Azbot
# Backdoor.Niovadoor
# Bloodhound.RTF.4
# Bloodhound.PDF.3
# Backdoor.IRC.Aladinz.E
# Backdoor.Tidserv!gen8
# Bloodhound.Exploit.Shs
# Backdoor.Cycbot!gen8
# Backdoor.Roodrig
# Backdoor.Hacarmy.E
# Backdoor.Ranky.M
# Backdoor.Optix.05
# Backdoor.Peeper
# Backdoor.Graybird.S
# Backdoor.Ranky.G
# Bloodhound.Unknown
# Bloodhound.Mallnk.1
# Backdoor.Graybird.Q
# Backdoor.Nibu.G
# Backdoor.Sdbot
# Bloodhound.Exploit.201
# Backdoor.SmokeDown
# Backdoor.Emdivi!gen1
# Backdoor.Adwind!g1
# Backdoor.Fxsvc
# Backdoor.Samkams!gen2
# Backdoor.Haxdoor.F
# Bloodhound.Exploit.75
# Backdoor.Joggver
# Backdoor.Sokeven
# Backdoor.Nemog.D
# Backdoor.Hormesu!gen1
# Backdoor.Pirpi!gen1
# Bloodhound.HLP.2
# Backdoor.Wecoym
# Backdoor.Lowtaper
# Backdoor.Bapkri
# Boot.Mebromi
# Backdoor.Lateda.C
# Bloodhound.Exploit.110
# Backdoor.Govrat
# Backdoor.RMFDoor.Cli
# Backdoor.Darkmoon!gen7
# Banan.Trojan
# Backdoor.WinJank
# Bloodhound.Exploit.102
# Backdoor.Maxload
# Backdoor.Sekorbdal
# Bloodhound.Exploit.155
# Bloodhound.Exploit.10
# Backdoor.Bigfoot
# Bloodhound.Exploit.455
# Backdoor.Theef
# Backdoor.DarkFtp
# Backdoor.IRC.Flood.G
# Backdoor.SofacyX
# Backdoor.Korplug.E
# Backdoor.Tidserv!gen21
# Bloodhound.Exploit.17
# Bloodhound.Exploit.411
# Backdoor.Sysdot
# Backdoor.Pirpi.B
# Backdoor.Tidserv!gen6
# Backdoor.Psiload
# Backdoor.Noppuca
# Backdoor.Cycbot!gen9
# Backdoor.Redsip.B
# Backdoor.Sokacaps
# Bloodhound.Exploit.270
# Backdoor.Graybird.M
# Backdoor.Lancafdo!gen
# Bloodhound.Exploit.193
# Bloodhound.Exploit.328
# BAT.Lati
# Backdoor.Korplug!gen2
# Backdoor.Bebsplug
# Bat.Comdrop
# Backdoor.Berpi
# Backdoor.Hipo
# Backdoor.Bifrose.J
# BAT.Snake
# Backdoor.Hydriis
# Backdoor.Spookdoor
# Backdoor.Picigail
# Bloodhound.Exploit.5
# Backdoor.IRC.RPCBot
# Bloodhound.PDF.34
# Backdoor.Regdor
# BabyNewYearVirusHoax
# Bloodhound.PDF.11
# Bloodhound.Exploit.37
# Backdoor.Denwp
# Backdoor.Cobrike
# Backdoor.Teawhy
# Backdoor.Longnu
# Backdoor.Samkams
# Backdoor.Malpayo
# Backdoor.Wualess.B
# Bloodhound.Exploit.534
# BAT.Junkboat.Worm
# Backdoor.Expjan
# Bloodhound.Exploit.168
# Backdoor.Cycbot!gen6
# Bloodhound.Pdexe
# Backdoor.Patpoopy!g2
# Backdoor.IRC.MyPoo.Kit
# Backdoor.Kilo
# Backdoor.Doroku
# Backdoor.Cmjspy.B
# Backdoor.Cimuz
# Backdoor.Sinpid
# Backdoor.Ciadoor
# Backdoor.Dragonqq
# BAT.Batwin.Worm
# Bloodhound.ELAM.2
# Backdoor.Betwem
# BAT.Ikol
# Backdoor.Winnti
# Bloodhound.RTF.14
# Bloodhound.Exploit.318
# Boot.Bootlock
# Backdoor.Autoupder
# Backdoor.Ginwui.B
# Backdoor.FTP_Ana.C
# Bloodhound.Exploit.316
# Bloodhound.Exploit.95
# Bloodhound.Exploit.418
# Bloodhound.Exploit.164
# Backdoor.Tidserv
# Bloodhound.RTF.16
# Bloodhound.Exploit.359
# Bloodhound.Exploit.142
# Backdoor.Remocy
# Backdoor.Leon
# Backdoor.Kikothac
# Backdoor.LittleWitch
# Backdoor.Bifrose!gen
# Bloodhound.Exploit.198
# Backdoor.OptixPro.13b
# Backdoor.Sacto
# Backdoor.Cruprox
# Backdoor.Fonamebot
# BuddyListRemovalTool
# Backdoor.Cycbot!gen10
# Backdoor.Rustock.B
# Backdoor.Breut
# Backdoor.Kihomchi
# BAT.Beckow.B@mm
# Bloodhound.Exploit.28
# Backdoor.Berbew
# Backdoor.IRC.Jemput
# Backdoor.Lala.C
# Backdoor.Yiha
# Backdoor.Guzu.B
# Backdoor.Runnet
# BAT.Migrate.A@mm
# Backdoor.Dropnak
# BAT.WCup@mm
# Backdoor.Tranwos
# Bloodhound.Exploit.451
# Backdoor.Y3KRat.14
# Bat.Tenej
# Backdoor.Layork.B
# Backdoor.Rurtar
# Backdoor.AntiLam.20.Q
# Backdoor.Uprootkit
# Backdoor.Evilbot
# Bloodhound.RLTrap
# Backdoor.Trojan
# Bloodhound.Exploit.86
# Backdoor.Sdbot.D
# Backdoor.Roxrat.10
# Backdoor.Sinflight
# Backdoor.Olourk
# Backdoor.Wualess.D
# Backdoor.IRC.Bifrut
# Bloodhound.Exploit.251
# Backdoor.Hogle
# Backdoor.Gwapoors
# Backdoor.Haxdoor.C
# Bloodhound.Exploit.147
# Bloodhound.Exploit.541
# Backdoor.Bitral
# Backdoor.Graybird.C
# Backdoor.Chafanty
# Backdoor.Cyn
# Backdoor.IRC.Bobbins
# Bloodhound.Exploit.48
# Backdoor.Kotilla
# Backdoor.Ratenjay.C
# Backdoor.Kaitex.E
# Backdoor.Himba
# Backdoor.Darkmoon!gen4
# Backdoor.Pigeon.AZUI
# Boot.Nawpers.A
# Backdoor.Spookdoor.Cli
# Backdoor.Ghostnet!gen1
# Backdoor.Prioxer.C
# Backdoor.GWGhost
# Backdoor.Eminoc!gen1
# Backdoor.Surdux
# Backdoor.ManMatite
# Backdoor.IRC.Yoink
# Backdoor.Mipsiv
# ...
# W32.Hauxi
# W32.Mydoom.A@mm
# W32.Mytob.AQ@mm
# W32.Neeris
# W32.Spotface.A
# W97M.Kritz
# WinaHoliday
# W32.HLLP.Lassa
# W32.Sober.B@mm
# W97M.Cane
# W32.Fourseman.B@mm
# W32.Sirhen.Worm
# W32.Shufa@mm
# W32.Cabanas
# W32.Emotet.B
# W32.SAPE.Cloud9.9
# W32.Beagle.DW@mm
# W95.Tenrobot.B
# W97M.Antiv.A
# W97M.Thus.E
# W32.Mediasups
# W32.Pilleuz!gen15
# W32.Magflag.B
# W32.HLLW.Primcol
# W32.Erkez.A@mm
# W32.Spamuzle.D
# W97M.SMDM.A
# W32.HLLW.Qaz.A
# W64.Cridex
# W32.Virut!html
# W32.Changeup!gen39
# W32.Pandem.B.Worm
# W32.Gaobot.AJE
# W32.Spybot.ACYRRemovalTool
# W32.Randex.UG
# W32.Sonic.Worm
# W32.Golem.A
# W32.Koobface!gen
# W32.SillyFDC.BBW
# W97M.Autch
# Worm.ExploreZip.B
# W32.Troresba
# W32.Korgo.R
# W32.Mimbot.B
# W32.Cabreck
# W32.Giwin.gen
# W32.Gammiy
# W32.HLLW.Kangur
# W32.Detnat.D
# W32.Mytob.E@mm
# W97M.MVCKA.kit
# W32.Fubalca.E
# W32.Feldor.A
# W32.Lamecada.B@mm
# W32.Mytob.R@mm
# W32.Opanki
# W97M.Sherlock
# W32.HLLW.Smelles
# W32.Ciosor
# W32.Dinoxi
# W32.Envid.O@mm
# W32.Lovit
# W32.Music.E.Worm
# W97M.Minceme
# W97M.Treoff.A
# W32.Almanahe.C
# W32.HLLW.Moega.D
# W32.Micharo
# W97M.Spatch
# W32.Mugly.E@mm
# W32.Fourseman.C@mm
# W32.HLLW.Lovgate.J@mm
# W32.Mytob.JH@mm
# W32.SillyFDC.BDL
# W32.Kelvir.BA
# W32.Figbox
# W32.Stration.B@mm
# W32.HLLW.Tufas
# W32.Sasser.gen
# WM.Johnny
# W32.HLLP.Arcer
# W32.Cherich@mm
# W32.Mydoom.AC@mm
# W32.Mydoom.AU@mm
# W97M.Twopey.C
# W32.Beagle.BJ@mm
# W32.Yarner.gen
# W32.Ircbrute.B
# W32.HLLP.Plea
# W32.HLLW.Anarch@mm
# W32.Meteit!inf
# W32.ElKern.3326
# W32.Stekct
# W97M.Nori.A
# W95.CIH.1049
# W97M.Marker
# W32.Pilleuz!gen19
# W32.Mytob.V@mm
# W32.SAPE.Cloud9.28
# W32.Tvido.B!inf
# W32.Duksten.D@mm
# W32.Mydoom@mmRemovalTool
# W95.MultiDJ.2012
# W32.Kedebe@mm
# W32.Autex.C
# W32.Opanki.D
# W32.Perenast.15773.int
# W32.Mytob.PP@mm
# W32.Rusty@m
# W32.Linkfars
# W32.ExploreZip.WormRemovalTool
# W32.Sober.N@mm
# W32.Sality!dam
# W32.SAPE.TrojanHorse.5
# W32.Mytob.BM@mm
# Word2000PasswdRecovery
# W32.Snaban
# W32.LastScene@mm
# W32.Pilleuz!gen6
# W32.Zori.A
# W32.SillyDC
# W32.Campurf@mm
# W32.Ircbot.NG!gen6
# W32.HLLO.Homer.C
# WS.Emerging.1
# W32.Areses.F@mm
# W32.Frethem.G@mm
# W32.Mytob.EJ@mm
# W32.SAPE.MegaSearch.10
# W32.Shiba.Worm
# W32.Spybot.NLX
# W32.Mytob.BE@mm
# W32.Vidon.A
# W97M.Stamp.A
# W97M.Stun
# W32.Looksky.A@mm
# W32.Ramnit.B!gen1
# W97M.Zeitung.A
# W32.SillyFDC.BCF
# W32.Mytob.EZ@mm
# W32.Bulehero
# W32.Lecna.H
# W32.Dafet.A
# W32.Sober.S@mm
# WM.Doggie
# W32.Wapomi.B
# W32.Erkez.D@mm
# W32.HLLP.Metrion
# W32.Erkez.C@mm
# W32.Alcarys@mm
# W32.Pulkfer
# W97M.Doeii
# W32.Gaobot.GW
# W97M.Phisher
# W97M.Suppl.A/W95.Suppl.16384.A
# W32.Brambul
# W32.HLLW.Asterz.intd
# W32.Tinit
# W32.Uporesc
# W32.HLLW.Shydy.B
# W97M.Lucia.A@mm
# W32.Munia!inf
# W32.Niucoft
# W97M.Downloader.J
# W97M.Rochitz.gen
# W97M.Tolu
# W32HybrisFFixTool
# W32.Guapim
# W97M.Gogaru.A
# W32.Nemim
# WM.InsideOut.A
# W32.Mimail.J@mm
# W32.Yimfoca!gen3
# W32.Beagle.AQ@mm
# W32.FBound.gen@mm
# W32.Mydoom.J@mm
# W32.STD.D
# W32.Yalat.Worm
# W32.Antiqfx.Worm
# W32.Dabora.A@mm
# W32.Basbot
# W32.Nimda.E@mmRemovalTool
# W97M.Bablas.BS
# W32.Randex.GEL
# W32.Zar.A@mm
# W32.Stayt.A
# WM.Ice.Intd
# W32.Kelvir.B
# WinSpyKiller
# W32.ThreeForOne
# W97M.AntiSocial.EVirus
# WinPerformance
# W32.Bratle.A
# W97M.Cloud.2
# W32.Werle!inf
# W32.Gaobot.AFC
# W32.HLLP.Julk.B@mm
# W32.Rinbot.AN
# W32.Changeup!gen10
# W32.HLLW.Lovgate.K@mm
# W95.Orez
# W32.Bropia.Q
# WM.Easy
# W32.SillyIRC
# W32.Mytob.KE@mm
# W32.Zoher@mm
# W2syncvirushoax
# W32.Mytob.GJ@mm
# W32.Mytob.HM@mm
# W95.LoveSong.998
# WS.Dialer.2
# W32.Redplut
# W97M.Strings.I
# W32.Allim.A
# W32.Abotus.Worm@m
# W32.Ahlem.A@mm
# W32.Inteter.Trojan
# W32.MyPower@mm
# W32.Daxijesh
# W97M.Obobrd.Int
# W32.Huayu
# W32.Sondia
# W32.Pilleuz
# W32.Fujacks.CA
# W32.Gammima.AG!gen3
# W32.Litar.Worm
# WM.Demon
# W32.Fubalca.B
# W32.SQLExp.WormRemovalTool
# W32.Waledac.D!gen5
# W32.Cridex!gen12
# W97M.Black.G
# W32.Mytob.CQ@mm
# W97M.Michael.Gen
# W32.Exploz.B!dam
# W32.Antiqfx.F.Worm
# W32.Heovin@mm
# W97M.Twopey.E
# W32.Queshare
# W32.Mydoom.BN@mm
# W32.SysId.Worm
# W32.Brid.A@mm/W32.Funlove.4099RemovalTool
# W95.MTX
# W32.Exploz.B
# W32.HLLW.Flopcopy
# W32.Kerim@mm
# W32.Changeup
# W32.Selfish
# W32.Esbot.E
# W32.Debanpass
# W97M.AntiCon
# W32.Fubalca.I!html
# W32.Niuniu!inf
# W32.Kitro.E.Worm
# W32.Pagipef.I!html
# W32.Asper
# W32.Mytob.AF@mm
# W32.Dexec
# W32.Dasher.A
# W32.Autorun.BMC
# W32.Bebar.B@mm
# W32.Kelvir.P
# W32.Waledac.C!gen1
# W32.Wapomi!gen1
# W32.HLLW.Reur.B
# W32.Styes
# WS.Spyware.2
# W32.Yarner.A@mm
# W32.HLLW.FizzerRemovalTool
# W32.SillyFDC.BBB
# W97M.Illegal.A
# W32.PasobirRemovalTool
# W32.Beagle.DV
# W32.Bolik!gm
# W97M.Salim.A
# W32.Banleed.B
# W32.Fubalca
# W32.Deletemusic
# W95.Padania
# W32.HLLW.Gaobot.AP
# W32.Randex.BTB
# W32.Enemany.A.int
# W32.HLLW.BenfGame.B
# W32.Beagle.AA@mm
# W32.Gaobot.SA
# W32.HLLW.Theug
# W32.Ixas@mm
# W32.Looksky.G@mm
# W32.Gink.Worm
# W32.Gubed.int
# W32.Sober@mm
# W32.Losabel
# W32.Zindos.A
# W32.Lovgate.AK@mm
# W32.Gaobot.UJRemovalTool
# W32.Wullik@mm
# W97M.Cerin.A
# W32.Mydoom.BI@mm
# W32.Kelvir.AC
# W32.SillyFDC.BBX
# WorldDominationHoax
# W95.SchoolGirl.910
# W32.Donk.S
# W32.Clunk.A
# W32.Kangero.A
# W32.Foamer.A
# W32.HLLW.Bare
# W32.Sixem.A@mm
# W32.Spyrat
# W32.IRCBot.G
# W32.HLLW.Slideshow
# W32.Tunk.A
# W32.Kelvir.DD
# W95.LoRez
# W32.Baki.C
# W97M.Alarm
# W32.Tofsee
# W32.Welchia.Worm
# W97M.Marfan.C
# W32.KrizRemovalTool
# W32.Joydotto
# W32.HLLW.Reckus
# W97M.Jelous
# W32.MyLife.E@mm
# W32.Voterai
# W32.Stikpid
# W32.Randex.ATS
# W32.Feebs.D@mm
# W32.Ahker.C@mm
# W32.Chod@mm
# W32.Denisbee
# W32.SillyFDC.BDK
# W98.Levi.3205
# W32.Randex.P
# W97M.Neurodo.A
# W97M.Shore.K
# W32.Kwbot.C.Worm
# W32.Mediakill.A@mm
# W32.Spybot.APEO
# W32.Looksky.H@mm
# W32.Popwin
# W95.Savior
# W32.Rixobot!gen1
# W32.Beagle.BI@mm
# W32.Linkbot
# W32.Manifest.Trojan
# W32.Music.A.Worm
# W32.Naplik!inf
# W32.Doggie.BX
# WM.Reflex
# W32.Benpao.Trojan
# W32.HLLW.Lovgate.E@mm
# W32.HLLW.Mantas
# W32.Moody.Worm
# W32.Zahaam
# W32.Yami.A
# W32.Gaobot.CPX
# W32.HLLW.Wangy@mm
# W32.Beagle.BO@mm
# W32.Jubon@mm
# W32.HLLW.Oror.C@mm
# W97M.Starsider
# W32.Chili
# W32.Hunch.H@mm
# W32.Xpaj
# W32.Alcarys.G@mm
# W32.HLLW.Rirc
# W97M.Thus.CP
# W32.Mabezat.B!inf
# W32.Mumawow.C
# W32.EsbotRemovalTool
# W32.Grenail.E!inf
# W32.Bacalid!inf
# W32.Ackantta!gen3
# W32.Haytap@mm
# W32.Passion.27648
# W32.Randex.AAS
# W32.SillyFDC.BDD
# W32.Stration.DH@mm
# W97M.Empstage
# WM.Colors.B
# Wm.Twno.C
# W32.Mytob.AD@mm
# W32.SAPE.Heur.3e
# W32.Blebla.B.Worm
# W32.Hobble.C@mm
# W32.HLLW.Togod
# W32.Gexin.A
# W32.Dexter
# W32.XTC.Worm
# W32.Blackmal.B@mm
# W32.Rinbot.F
# W32.Beagle.AB@mm
# WM.Cartman
# W32.Xpiro.F
# W32.Tupofse.B
# W32.Dotex
# W32.HLLP.YAI
# W32.HLLW.Gaobot.FL
# W32.Mytob.AA@mm
# W32.Rads@mm
# W32.HLLW.Lovgate.C@mm
# W32.Jumpred.A
# W32.Neroma@mm
# W97M.Prilissa.A
# W32.Mubla.B
# W32.Pimaf.Worm
# W32.SAPE.MegaSrch.10e
# W97M.Melissa.gen@mm
# W32.Changeup!gen31
# W97M.Cherrylove!int
# W32.Spybot.AGEN
# W32.Anpes@mm
# W97M.Jedan.A
# W97M.Rendra.D.Gen
# W32.Sand.11272
# W32.Spex.Worm
# W32.Yalove.D
# W32.Kergez.A@mm
# W32.Mytob.F@mm
# W97M.Invi
# W97M.Nomed.A
# W32.Changeup!gen40
# W32.Razect!inf
# W32.Mimail.G@mm
# W32.Dasher.G
# W32.Higuy@mm
# W32.Spybot!dr
# W32.Welchia.gen
# W32.Invictus.dll
# W32.Mytob.DD@mm
# W32.Antiman.A@mm
# W32.Mytob.MN@mm
# W32.Randex.AR
# W32.SAPE.DomaIQ.2
# W32.SillyFDC.BDH
# W97M.Smey
# W32.Antinny.Q
# W32.Serwab@mm
# W32.Sigougou
# W32.Vybab@mm
# W32.Changeup!gen7
# W32.Aimdes.C@mm
# W32.Bugsoft
# WM.NOP.A:De
# W97M.Downloader.H
# W32.HLLW.Shower.L
# W97M.Downloader!g16
# W32.Dumaru.AI
# W32.Mimail.Q@mm
# W32.Conycspa.G@mm
# W32.Gaga
# W32.Ifbo.A
# W32.Sory.A
# W32.SAPE.AdGazelle.1
# W32.Whybo
# W32.Kelvir.AP
# W32.Chod.S
# W32.Mytob.JN@mm
# W97M.HashiBirth
# W32.HLLW.Kazmor
# W32.Atak.B@mm
# W32.Naco.D@mm
# W32.IRCBot.Gen
# W32.SillyFDC.BBC
# W32.Anivip
# Wm.Outlaw
# Worm.ExploreZip(pack)
# W32.Garroch@mm
# W32.Waledac.C!gen2
# W32.Video.25600.Worm
# W32.Gaobot.ADV
# W32.Elitper.E@mm
# W32.Femot.WormRemovalTool
# W32.HLLW.Timese
# W32.Peerload.A
# W97M.Tips.gen
# W32.Bacros
# W32.Gauss!gen1
# WM.Boom:De
# WS.Hacktool.2
# W32.HLLW.Sodabot
# Wscript.KakwormRemovalTool
# WS.Joke.2
# W32.Mytob.AP@mm
# W32.Jacksuf.A
# W32.Sipem!inf
# W32.Gammima.AG!gen7
# W32.Bobax.C
# Winscanx
# W32.Netspree.Worm
# W32.SillyFDC.BDE
# W97M.Adenu.A
# W32.Gaobot.FO
# W32.Niumu
# W32.Changeup!gen3
# W32.Kibtos
# W32.Autorun.APR
# W32.Femot.Worm
# W32.HLLW.Qaz.C
# W64.Viknok.C!inf
# W32.Inzae.A@mm
# W32.IRCBot!gen3
# W32.Yaha.F@mm
# W32.Marjor
# W32.Gabloliz.A
# W32.Tupeg
# W32.HLLW.Taplak
# W97M.Iseng.Gen
# W97M.Opey.S
# W32.Mytob.DB@mm
# W32.Randsom.A
# W32.Kelvir.AI
# W32.HLLW.Chemsvy
# W32.Virut.U
# W97M.Sevensix.A
# W32.Morto
# W32.Cacogen
# W32.Stong.A
# WM.Colors.CA
# W32.Dizan.F
# W32.Chimerux
# W32.Redesi.B@mm
# W32.Mantibe
# W97M.Thus.BI
# W32.Adjunto.A@mm
# W32.Pykspa.E
# W32.Korgo.O
# W32.Mapson.D.Worm
# W32.Randex.T
# W32.Spybot.FCD
# W32.SillyFDC.BCC
# W32.Osapex
# W32.Madag.A
# W32.SAPE.Heur.1
# W32.Kakavex
# W97M.Mum.int
# W32.Duksten@mm
# W97M.Lanspy.A
# W32.Marol@mm
# W32.Feebs.DH@mm
# W32.Kodom
# W32.Pandem.C.Worm
# W32.Bancorkut@mm
# W32.Changeup!gen8
# W32.Koobface.D
# W32.Likasimal
# W32.Masavebe
# W32.Sober.Q@mm
# W32.HLLW.DW
# W32.Sejese
# WM.Bumble
# W32.Korgo.Y
# W32.Qdens.E
# W32.Odelud
# W97M.Camino.A@mm
# W32.Delalot.Trojan
# W32.HLLW.Gaobot.BV
# W32.Kelvir.J
# W32.Lovena.A@mm
# W32.HLLW.Gool
# W32.Zotob.L
# W32.Nujama
# W32.Imaut.U
# W32.Changeup!gen13
# W32.Ganda.A@mm.enc
# W32.Kibuv.D
# W32.Mytob.IM@mm
# W32.SillyFDC.BBI
# W32.Wergimog.B
# W97M.Thus.U
# W32.Dabyrev
# W32.Huhk.A
# W97M.Dotor.A@mm
# W32.Fujacks.CE!inf
# W32.HLLW.Epon@mm
# W32.Yaha.L@mm
# W97M.Astia.Gen
# W32.Netsky.U@mm
# W32.Rile
# W97M.Neuro.B
# W32.Kiman.B
# W32.Welchia.D.Worm
# W32.Appflet.A@mm
# W32.Lorsis.Worm
# W32.Randex.CST
# W32.Spybot.KHC
# W97M.Dranus
# W97M.Prece.A
# W32.Lanieca.A@mm
# W32.Ircbrute!gen
# W32.Junkcomp
# W32.Woospi!inf
# W32.SAPE.InstallRx.14e
# W32.Blaster.T.Worm
# W32.SAPE.InstallRx.1e
# W32.HLLW.Shower.J
# W32.HLLW.Leox.B
# W32.HLLW.Gaobot.BZ
# W32.Agnido.A@mm
# W32.Beaker.A@mm
# W32.Donk.Q
# W32.Mydoom.P@mm
# W32.Randex.CZZ
# W32.SAPE.Heur.8
# W32.Aizu
# W97M.Twopey.D
# W32.Lecna.E
# W32.Golroted!gen2
# W32.Naplik
# W32.HLLP.Flate.F
# W32.Pilleuz!gen29
# W32.Qakbot!gen5
# W32.Gibe.C@mm
# W32.Imalag.C
# W32.Mabezat.B
# W32.Ramnit
# W32.Wisfc
# W97M.Thus.W
# W32.Listas
# W32.Desperate@mm
# W32.Beagle.E@mm
# W32.Liamed@mm
# W32.Kifer
# W32.HLLW.Daboom@mm
# W32.Dolly.Mirc.gen
# W32.HLLW.Lovgate.I@mm
# W32.MyLife.B@mm
# W32.HLLP.Gosusub
# W32.Longbe@mm
# W32.Plagent
# W32.Darksnow!dam
# W32.Hunch@mm
# W32.Jonbarr.C@mm
# W32.Spybot.ALRD
# W32.Stration@mm
# W32.Glupzy.A
# W32.Mytob.EO@mm
# W32.Mytob.SA@mm
# W32.Mapson.C.Worm
# W32.SillyFDC.BCO
# W32.Mytob.IA@mm
# W32.Beagle.AZ@mm
# W97M.Nihilit
# W32.Enemany.B@mm
# W32.Yimper
# W32.BleBla.J.Worm
# W32.Spybot.ANDMRemovalTool
# W97M.Rats.B.gen
# W32.Frethem.Gen@mm
# W32.Induc.A!dcu
# W32.Amirecivel.H@mm
# W32.Spybot.ATEW
# W64.Flobal
# W32.Changeup!gen50
# W32.Fujacks.BZ
# W32.Lecna.A
# W32.Loxbot.F
# W32.Mydoom!gen
# W32.Mettemar.int
# W32.Kobot.L
# W32.Logitall.A@mm
# W32.SAPE.Heur.18
# W32.Changeup!gen26
# W32.SAPE.Heur.21
# W32.Xema.A
# WS.Malware.1
# W97M.Tanto
# W32.Zimuse.B
# W32.HLLW.Donk.L
# W32.Mytob.EA@mm
# W32.SAPE.Tarma.12e
# W32.Stealsmth!inf
# W97M.Aleja.N
# W32.Choke.Worm
# W97M.Myna
# W32.Atnas.A
# W32.Tofazzol
# W32.Derdero.A@mm
# W32.Wecorl
# W95.Smash
# W32.SillyFDC.BBV
# W32.Dbit
# W32.Nimda.I@mm
# W32.NewApt.Worm
# W32.Funlove.4099
# W32.Tufik.E!inf
# W32.HLLW.Walrain
# W97M.Maike
# W32.Gammima.AG!gen2
# W32.Pilleuz!gen5
# W32.Gaobot.BQJ
# W32.Killis
# W32.Skenkly.A@mm
# W32.Blebla.Worm
# W32.HLLW.Nettrash
# W32.Exvid.A@mm
# W32.Induc.A!pas
# W32.Nomvar
# W32.Zezer.Worm
# W32.Beagle.AP@mm
# W97M.Apoc.B
# Weather.B:Tw
# W32.Palevo!gen1
# W32.Molim@mm
# W32.HLLW.Kickin.A@mm
# W32.HLLW.Tofaced
# W32.Crypto
# W32.Beagle.BH@mm
# W32.Liberpy
# W32.Drivus.A
# W32.Bassyl!inf
# W32.Opaserv.WormRemovalTool
# W32.Dabora.B@mm
# W32.Lavehn.A@mm
# W32.Amca
# W97M.Downloader.F
# W32.Serot@mm
# W32.Changeup!gen2
# W32.Mytob.ME@mm
# W32.Waledac.D
# W32.HLLW.Doomjuice.B
# W97M.Tupca
# W32.Pilleuz!gen4
# W32.Fujacks.BH
# W32.Kaxela.A
# WM.Bandung
# W32.Allim
# W32.AntinnyRemovalTool
# W32.Takeobel
# W32.DSS.Trojan
# WS.RemoteAccess.2
# W97M.VMPCK1A.Gen
# W32.Dizan.C
# W32.Antinny.K
# W32.Downadup
# W32.HLLO.Videoinf
# W32.Qakbot!html
# W32.Nicehello@mm
# W32.Fubalca.N!html
# W32.Erah.A@mm
# W32.Mytob.KR@mm
# W32.SAPE.SoftPulse.3e
# W32.Tempedreve.A!inf
# W32.Imcontactspam@mm
# W32.Trats.B
# W32.Wotron.Worm
# W32.Feebs.B@mm
# W32.HLLW.Torvel@mm
# W32.Shoren
# WS.RemoteAccess.1
# W32.Phopifas!gen2
# W32.Gaobot.AZT
# W32.Memesa
# W32.Gaobot.ALV
# W32.Jeefo
# W32.Evaman.CRemovalTool
# W32.Mytob.JF@mm
# W32.Rinbot.L
# W32.Nujama.B
# W32.SillyFDC.BCS
# W32.BropiaRemovalTool
# W32.Ganbate.A
# W32.Amirecivel.F@mm
# W32.Mydoom.BU@mm
# W32.SAPE.Cloud9.4
# W32.Notech
# W32.Pilleuz!gen9
# WM.Wazzu
# W32.Beagle.B@mm
# W97M.Lafool
# W32.Stration.DB@mm
# W32.HLLC.Happylow
# W32.Mumo
# W32.Zomjoiner
# W32.Himu.A@mm
# W32.Dumaru.Y@mm!enc
# W32.Netsky.I@mm
# W32.Spybot.OFN
# W32.Mytob.ML@mm
# W32.Dotex.CA
# W32.Momib.A
# W97M.Rochitz.C
# W32.Auraax
# W32.Mytob.EU@mm
# W95.HybrisFFixTool
# W32.HLLP.Sharpei@mm
# W97M.Thus.S
# W97M.Adren
# WM.Ushasty.A
# WM.Wazzu.B
# W97M.Spectral.A
# W32.Lade
# W32.Beagle@mmRemovalTool
# W95.Bistro
# W97M.Rash.A
# W32.Frethem.L@mm
# W32.Funsoul@mm
# W32.Barten@mm
# W32.Mytob.GG@mm
# X97M.Divi.M
# XScan
# X97M.Squared.A
# X97M.Barisada.B
# X97M.BDoc2
# X97M.Sarsnan
# XLGuarder
# X97M.Laroux.gen
# X97M.Barisada.A
# X97M.Laroux.TY
# X97M.Codemas.B
# X97M.Laroux.WM
# XM.Erreic.Trojan
# X97M.Rawo
# Xeram.1664
# X97M.Booklet.A
# X97M.Goldendrop
# X97M.Millenmic
# X97M.Ellar.E
# X97M.Ainesey.B
# X97M.DIVI.Family
# X97M.Mauela
# X97M.Barisada.C
# X97M.Fress
# X97M.Romlax
# X97M.Bandi
# XM.Laroux.BP
# X97M.ROH.A
# X97M.Laroux.TZ
# X97M.Avone.A
# X97M.Barisada.K
# X97M.Jini.A1
# X97M.Ellar.F
# X97M.Seitty
# X97M.Pink.A.Gen
# XM.Joray
# XM.ZePast.A
# X97M.Yini
# X97M.Cian.C@mm
# X97M.Reten.B
# X97M.Teteon
# X97M.Trevir
# XF.Sic
# X97M.Laroux.KV
# X97M.Sugar.F
# XPCleaner
# XM.Laroux.ST
# X97M.BadBoy.C
# X97M.Phoneman
# XF.Padrepex
# X97M.Sufe.D
# XM.Laroux
# X97M.Laroux.NW
# X97M.Tang
# XF.Helpopy
# XMLid.Exploit
# X97M.Laroux.UA
# X97M.Barisada.D
# X97M.Kbase
# X97M.Rellik
# X97M.Esab
# X97M.Vcode.A
# X97M.Anis
# XPAntivirus
# X97M.Gene.A
# X97M.Adversary.A
# X97M.Fixen
# XF.Gydhex
# XF.Lugunay
# XM.VNN
# XM.Momac.A
# X97M.Dropo
# X97M.Grazz.A
# X97M.Laroux.FY
# X97M.Laroux.FO
# X97M.Sysbin
# X97M.Squared.B.Gen
# X97M.Ecmetsys
# X97M.Ellar.C
# X97M.Papa.B
# X97M.Barisada.E
# XM.Register
# XM.Sofa
# X97M.Domino
# X97M.Laroux.JO
# X97M.Manalo.M
# X97M.Momo
# X97M.Adn.C.Gen
# XM.Laroux.UB
# X97M.Brep
# X97M.Papa.A
# X97M.Reten.A
# X97M.Barisada.F
# XM.Mailcab@mm
# X97M.Hail.A
# X97M.Sops
# X97M.Barisada.P
# X97M.Chesu
# XF.Lugunay!dam
# X97M.Draco
# XM.Robocop.B
# X97M.Ellar.A
# Xuxa.1656
# XPShield
# X97M.Obvious.A
# X97M.Fontime.A
# X97M.Hihihoho
# X97M.Suhd@mm
# X97M.Gluas
# X97M.Rippet
# X97M.Frost
# X97M.Mspell
# X97M.Slacker.E
# X97M.Greedy
# XM.Delta
# X97M.Reten.C
# X97M.Adn.B
# XPdefender
# X97M.Metar
# X97M.Loz
# X97M.Barisada.O
# X97M.Poorboy.C
# X97M.Laroux.gen2
# X97M.Romnum
# X97M.Codemas.C
# X97M.Papercut
# X97M.Sugar
# X97M.Divi.D
# XF.Paix.A
# X97M.Laroux.KU
# X97M.Veltmar.Trojan
# X97M.Threekay.A
# X97M.Sufe
# XM.Laroux.HJ
# X97M.Divi.O
# X97M.Crex
# XPSecurityCenter
# X97M.Linik
# XM.Compat.A
# XpAntivirus!gen1
# XM.Slide
# X97M.Feng.A.Trojan
# Year1992(x)
# YourScreenNameHoax
# Ydaerla
# Y2K7VirusHoax
# YIMHarddrivekillerHoax
# YankeeDoodle
# YahooSpyMon
# Zelu
# Zinaps
# Zendown.Trojan
# Zlatko
# ZZ331VirusHoax
# Zag.1106
# ZUC
# Zeton.Mirc
# Octopus
# Flame
# JCry
# Proton
# GLOOXMAIL
# HARDRAIN
# Mosquito
# njRAT
# Miner-C
# TEXTMATE
# POWRUNER
# Chaos
# gh0stRAT
# RawPOS
# ChChes
# Remsec
# Psylo
# Winnti
# FlawedAmmyy
# SHIPSHAPE
# TURNEDUP
# esentutl
# PoshC2
# XAgentOSX
# BOOSTWRITE
# Net
# PUNCHBUGGY
# OlympicDestroyer
# POWERSTATS
# DOGCALL
# Impacket
# LockerGoga
# Wingbird
# Twitoor
# PowerDuke
# DownPaper
# pngdowner
# ExaramelforWindows
# TYPEFRAME
# OopsIE
# XLoader
# NotCompatible
# ROKRAT
# HiddenWasp
# zwShell
# StealthMango
# Pisloader
# HDoor
# NotPetya
# LaZagne
# Android/Chuli.A
# POWERSOURCE
# OBAD
# BravePrince
# PegasusforAndroid
# Astaroth
# Backdoor.Oldrea
# NetTraveler
# RIPTIDE
# hcdLoader
# netsh
# Crimson
# Bisonal
# Final1stspy
# Responder
# TINYTYPHON
# Azorult
# Shamoon
# PHOREAL
# LightNeuron
# HAMMERTOSS
# TDTESS
# Regin
# Dipsind
# Uroburos
# CORESHELL
# NavRAT
# USBStealer
# GreyEnergy
# NetCrawler
# Prikormka
# UPPERCUT
# VERMIN
# SEASHARPEE
# KeyRaider
# PegasusforiOS
# AgentTesla
# Hi-Zor
# Gazer
# NETEAGLE
# adbupd
# ipconfig
# NDiskMonitor
# POSHSPY
# Gustuff
# Machete
# UnknownLogger
# Sys10
# LOWBALL
# HOPLIGHT
# Truvasys
# Derusbi
# HAWKBALL
# CozyCar
# netstat
# PlugX
# ZxShell
# SHOTPUT
# WinMM
# Pupy
# Wiarp
# Agent.btz
# SslMM
# PinchDuke
# EvilBunny
# AndroRAT
# Denis
# ELMER
# Remexi
# Umbreon
# POWERTON
# KEYMARBLE
# Mis-Type
# HackingTeamUEFIRootkit
# Cachedump
# Riltok
# Bandook
# Elise
# Helminth
# BrainTest
# SLOWDRIFT
# nbtstat
# RogueRobin
# RevengeRAT
# BabyShark
# UBoatRAT
# yty
# Fysbis
# InnaputRAT
# Matroyshka
# jRAT
# Dyre
# MacSpy
# POORAIM
# BISCUIT
# Calisto
# NOKKI
# SpyNoteRAT
# CALENDAR
# XcodeGhost
# BADNEWS
# WINDSHIELD
# Pass-The-HashToolkit
# StoneDrill
# BLACKCOFFEE
# cmd
# ComRAT
# T9000
# Felismus
# Arp
# RedLeaves
# Linfo
# QUADAGENT
# gsecdump
# NanoCore
# OLDBAIT
# DualToy
# ShiftyBug
# Sakula
# Comnie
# Ursnif
# Emotet
# HIDEDRV
# Winexe
# BBSRAT
# Charger
# Dendroid
# DarkComet
# HummingWhale
# P2PZeuS
# WindowsCredentialEditor
# RemoteCMD
# CardinalRAT
# CoinTicker
# CallMe
# KeyBoy
# 4HRAT
# BlackEnergy
# Komplex
# Nerex
# Marcher
# FlawedGrace
# OceanSalt
# spwebmember
# NanHaiShu
# 3PARARAT
# PJApps
# Xbash
# OSX_OCEANLOTUS.D
# iKitten
# RawDisk
# httpclient
# Mimikatz
# MailSniper
# Pasam
# Ping
# Rotexy
# SeaDuke
# KARAE
# Misdat
# HTRAN
# MirageFox
# Trojan-SMS.AndroidOS.OpFake.a
# at

# %%
text=df['description'][22]
print(text)
# Out:
# Cleaver is a threat group that has been attributed to Iranian actors and is responsible for activity tracked as Operation Cleaver.  Strong circumstantial evidence suggests Cleaver is linked to Threat Group 2889 (TG-2889).

# %%
words=['Dust Storm','South Korea','Japan','United States','Asian ']
label=['group','target_country','target_country','target_country','target_country']

# %%
train=[]
entities=[]
if len(words)==len(label):
    for i in range(len(words)):
        word=text.find(words[i])
        print(word)
        if i==0:
            entities.append('[('+str(word)+','+str(word+len(words[i]))+','+'"'+label[i]+'"'+')')
        elif i==(len(words)-1):
            entities.append('('+str(word)+','+str(word+len(words[i]))+','+'"'+label[i]+'"'+')]}')
        else:
            entities.append('('+str(word)+','+str(word+len(words[i]))+','+'"'+label[i]+'"'+')')
        
    entities=','.join(entities)
    train.append('("'+text+'"'+','+'{"entities":'+entities+')')
else:
    print('once check')
    print("words:",len(words))
    print("labels:",len(label))
# Out:
# 0
# 77
# 70
# 94
# 139

# %%
train[0]
# Out:
# '("Dust Storm is a threat group that has targeted multiple industries in Japan, South Korea, the United States, Europe, and several Southeast Asian countries.",{"entities":[(0,10,"group"),(77,88,"target_country"),(70,75,"target_country"),(94,107,"target_country"),(139,145,"target_country")]})'

# %%
import plac
import random
from pathlib import Path
import spacy
from spacy.util import minibatch, compounding

# %%
TRAIN_DATA=[
    ("admin@338 is a China-based cyber threat group. It has previously used newsworthy events as lures to deliver malware and has primarily targeted organizations involved in financial, economic, and trade policy, typically using publicly available RATs such as PoisonIvy, as well as some non-public backdoors.",{"entities":[(0,9,"group"),(15,26,"threat_actor"),(169,178,"target"),(180,188,"target"),(194,206,"target"),(256,265,"path")]}),
    ("APT1 is a Chinese threat group that has been attributed to the 2nd Bureau of the People’s Liberation Army (PLA) General Staff Department’s (GSD) 3rd Department, commonly known by its Military Unit Cover Designator (MUCD) as Unit 61398.",{"entities":[(0,4,"group"),(10,18,"threat_actor"),(63,105,"target")]}),
    ("APT12 is a threat group that has been attributed to China. The group has targeted a variety of victims including but not limited to media outlets, high-tech companies, and multiple governments.",{"entities":[(0,5,"group"),(52,57,"threat_actor"),(132,145,"target"),(147,166,"target"),(172,192,"target")]}),
    ("APT16 is a China-based threat group that has launched spearphishing campaigns targeting Japanese and Taiwanese organizations.",{"entities":[(0,5,"group"),(11,23,"threat_actor"),(88,96,"target"),(101,110,"target")]}),
    ("APT17 is a China-based threat group that has conducted network intrusions against U.S. government entities, the defense industry, law firms, information technology companies, mining companies, and non-government organizations.",{"entities":[(0,5,"group"),(11,22,"threat_actor"),(55,73,"path"),(82,86,"target_country"),(112,128,"target"),(130,139,"target"),(141,163,"target"),(175,181,"target"),(197,211,"target")]}),
    ("APT18 is a threat group that has operated since at least 2009 and has targeted a range of industries, including technology, manufacturing, human rights groups, government, and medical.",{"entities":[(0,5,"group"),(57,61,"date"),(112,122,"target"),(124,137,"target"),(139,151,"target"),(160,170,"target"),(176,183,"target")]}),
    ("APT19 is a Chinese-based threat group that has targeted a variety of industries, including defense, finance, energy, pharmaceutical, telecommunications, high tech, education, manufacturing, and legal services. In 2017, a phishing campaign was used to target seven law and investment firms.  Some analysts track APT19 and Deep Panda as the same group, but it is unclear from open source information if the groups are the same.",{"entities":[(0,5,"group"),(11,24,"threat_group"),(321,331,"same_group"),(175,188,"target"),(91,98,"target"),(133,151,"target"),(117,131,"target")]}),
    ("APT28 is a threat group that has been attributed to Russia\'s Main Intelligence Directorate of the Russian General Staff by a July 2018 U.S. Department of Justice indictment. This group reportedly compromised the Hillary Clinton campaign, the Democratic National Committee, and the Democratic Congressional Campaign Committee in 2016 in an attempt to interfere with the U.S. presidential election. APT28 has been active since at least 2004.",{"entities":[(0,5,"group"),(52,58,"threat_group"),(434,438,"date"),(328,332,"date"),(212,236,"target"),(242,261,"target"),(281,305,"target")]}),
    ("APT29 is threat group that has been attributed to the Russian government and has operated since at least 2008.   This group reportedly compromised the Democratic National Committee starting in the summer of 2015.",{"entities":[(0,5,"group"),(54,61,"threat_group"),(105,109,"date"),(207,211,"date"),(151,170,"target")]}),
    ("APT3 is a China-based threat group that researchers have attributed to China\'s Ministry of State Security.   This group is responsible for the campaigns known as Operation Clandestine Fox, Operation Clandestine Wolf, and Operation Double Tap.   As of June 2015, the group appears to have shifted from targeting primarily US victims to primarily political organizations in Hong Kong. \nMITRE has also developed an APT3 Adversary Emulation Plan.",{"entities":[(0,4,"group"),(10,21,"threat_group"),(372,381,"target_country"),(256,260,"date"),(321,331,"target")]}),
    ("APT30 is a threat group suspected to be associated with the Chinese government.  While Naikon shares some characteristics with APT30, the two groups do not appear to be exact matches.",{"entities":[(0,5,"group"),(60,67,"threat_group")]}),
    ("Dragonfly 2.0 is a suspected Russian group that has targeted government entities and multiple U.S. critical infrastructure sectors since at least March 2016.   There is debate over the extent of overlap between Dragonfly 2.0 and Dragonfly, but there is sufficient evidence to lead to these being tracked as two separate groups.",{"entities":[(0,13,"group"),(29,37,"threat_group"),(94,98,"target_country"),(146,156,"date")]}),
    ("DragonOK is a threat group that has targeted Japanese organizations with phishing emails. Due to overlapping TTPs, including similar custom tools, DragonOK is thought to have a direct or indirect relationship with the threat group Moafee.  It is known to use a variety of malware, including Sysget/HelloBridge, PlugX, PoisonIvy, FormerFirstRat, NFlog, and NewCT.",{"entities":[(0,9,"group"),(45,54,"target_country"),(231,237,"same_group")]}),
    ("Dust Storm is a threat group that has targeted multiple industries in Japan, South Korea, the United States, Europe, and several Southeast Asian countries.",{"entities":[(0,10,"group"),(77,88,"target_country"),(70,75,"target_country"),(94,107,"target_country"),(139,145,"target_country")]}),]

# %%
model=None
if model is not None:
        nlp = spacy.load(model)  # load existing spaCy model
        print("Loaded model '%s'" % model)
else:
        nlp = spacy.blank("en")  # create blank Language class
        print("Created blank 'en' model")
if "ner" not in nlp.pipe_names:
        ner = nlp.create_pipe("ner")
        nlp.add_pipe(ner, last=True)
    # otherwise, get it so we can add labels
else:
    ner = nlp.get_pipe("ner")
    
for _, annotations in TRAIN_DATA:
        for ent in annotations.get("entities"):
            ner.add_label(ent[2])
# Out:
# Created blank 'en' model

# %%
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != "ner"]

# %%
with nlp.disable_pipes(*other_pipes):  # only train NER
        # reset and initialize the weights randomly – but only if we're
        # training a new model
        if model is None:
            nlp.begin_training()
        for itn in range(100):
            random.shuffle(TRAIN_DATA)
            losses = {}
            # batch up the examples using spaCy's minibatch
            batches = minibatch(TRAIN_DATA, size=compounding(4.0, 32.0, 1.001))
            for batch in batches:
                texts, annotations = zip(*batch)
                nlp.update(
                    texts,  # batch of texts
                    annotations,  # batch of annotations
                    drop=0.5,  # dropout - make it harder to memorise data
                    losses=losses,
                )
            print("Losses", losses)
# Out:
# Losses {'ner': 50.04646199790709}
# Losses {'ner': 46.9870311577273}
# Losses {'ner': 36.58805302936923}
# Losses {'ner': 67.7979691387506}
# Losses {'ner': 42.9267841148063}
# Losses {'ner': 31.154274665798575}
# Losses {'ner': 26.853744176002063}
# Losses {'ner': 32.86801939710722}
# Losses {'ner': 28.025471247285594}
# Losses {'ner': 36.31076856415828}
# Losses {'ner': 24.971844998096632}
# Losses {'ner': 25.633978552147212}
# Losses {'ner': 25.287065743270905}
# Losses {'ner': 18.883270231655914}
# Losses {'ner': 44.03638009799452}
# Losses {'ner': 44.393577775142255}
# Losses {'ner': 36.770851376199424}
# Losses {'ner': 27.13435382468843}
# Losses {'ner': 28.35231408366001}
# Losses {'ner': 31.041384184712996}
# Losses {'ner': 15.607410032112007}
# Losses {'ner': 22.47426059259185}
# Losses {'ner': 15.91419248589861}
# Losses {'ner': 16.310649256336887}
# Losses {'ner': 19.142589952654788}
# Losses {'ner': 16.98496905159933}
# Losses {'ner': 20.58677222927684}
# Losses {'ner': 50.91073337226517}
# Losses {'ner': 16.76425870989591}
# Losses {'ner': 25.29899119031993}
# Losses {'ner': 28.0371355092284}
# Losses {'ner': 21.89800374495727}
# Losses {'ner': 12.816340820184168}
# Losses {'ner': 12.340677701526372}
# Losses {'ner': 26.406512996370676}
# Losses {'ner': 23.02724080317602}
# Losses {'ner': 19.82882103621876}
# Losses {'ner': 12.933375738660184}
# Losses {'ner': 16.272134729900486}
# Losses {'ner': 12.678236681010976}
# Losses {'ner': 21.88882444571163}
# Losses {'ner': 11.9503756478922}
# Losses {'ner': 17.7596166395738}
# Losses {'ner': 14.068241171423056}
# Losses {'ner': 13.915616330673735}
# Losses {'ner': 13.958620939960422}
# Losses {'ner': 18.597229724302924}
# Losses {'ner': 8.212392640856175}
# Losses {'ner': 18.119499047524265}
# Losses {'ner': 12.677606563151494}
# Losses {'ner': 15.552949771630088}
# Losses {'ner': 6.091527002569025}
# Losses {'ner': 12.803091239622127}
# Losses {'ner': 23.5107632292631}
# Losses {'ner': 11.33714959150449}
# Losses {'ner': 15.482680105242178}
# Losses {'ner': 12.429161616236769}
# Losses {'ner': 11.516025287614374}
# Losses {'ner': 12.19363922856928}
# Losses {'ner': 12.157204240132454}
# Losses {'ner': 6.540169669726697}
# Losses {'ner': 15.201102754214993}
# Losses {'ner': 33.84274136206205}
# Losses {'ner': 24.08242131815265}
# Losses {'ner': 14.720359176292625}
# Losses {'ner': 19.393103253846387}
# Losses {'ner': 8.127146344810933}
# Losses {'ner': 21.83730250834818}
# Losses {'ner': 18.53250258077114}
# Losses {'ner': 19.374713670577542}
# Losses {'ner': 25.74618946676963}
# Losses {'ner': 18.513291462958488}
# Losses {'ner': 11.573681246636394}
# Losses {'ner': 6.664943955494798}
# Losses {'ner': 7.31350509876117}
# Losses {'ner': 9.196367394376354}
# Losses {'ner': 9.32256850385197}
# Losses {'ner': 9.516257162493257}
# Losses {'ner': 15.07505718968665}
# Losses {'ner': 10.376726429565704}
# Losses {'ner': 9.68265972283626}
# Losses {'ner': 6.1323433080630565}
# Losses {'ner': 8.747265773200398}
# Losses {'ner': 21.36195970069635}
# Losses {'ner': 10.335871842232322}
# Losses {'ner': 5.858323398133574}
# Losses {'ner': 5.306060113742239}
# Losses {'ner': 8.493838060903034}
# Losses {'ner': 2.8685197087303766}
# Losses {'ner': 6.175722004807685}
# Losses {'ner': 9.530211766963278}
# Losses {'ner': 38.25468949771591}
# Losses {'ner': 11.691616854749977}
# Losses {'ner': 14.859425009971696}
# Losses {'ner': 4.72278076947497}
# Losses {'ner': 8.450378845778948}
# Losses {'ner': 10.37408517033275}
# Losses {'ner': 13.577578922446756}
# Losses {'ner': 6.600837317343772}
# Losses {'ner': 21.168183743869506}

# %%
for text, _ in TRAIN_DATA:
        doc = nlp(text)
        #print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
        print("Tokens", [(t.text, t.ent_type_, t.ent_iob) for t in doc])
# Out:
# Tokens [('APT3', 'group', 3), ('is', '', 2), ('a', '', 2), ('China', 'threat_group', 3), ('-', 'threat_group', 1), ('based', 'threat_group', 1), ('threat', '', 2), ('group', '', 2), ('that', '', 2), ('researchers', '', 2), ('have', '', 2), ('attributed', '', 2), ('to', '', 2), ('China', '', 2), ("'s", '', 2), ('Ministry', '', 2), ('of', '', 2), ('State', '', 2), ('Security', '', 2), ('.', '', 2), ('  ', '', 2), ('This', '', 2), ('group', '', 2), ('is', '', 2), ('responsible', '', 2), ('for', '', 2), ('the', '', 2), ('campaigns', '', 2), ('known', '', 2), ('as', '', 2), ('Operation', '', 2), ('Clandestine', '', 2), ('Fox', '', 2), (',', '', 2), ('Operation', '', 2), ('Clandestine', '', 2), ('Wolf', '', 2), (',', '', 2), ('and', '', 2), ('Operation', '', 2), ('Double', '', 2), ('Tap', '', 2), ('.', '', 2), ('  ', '', 2), ('As', '', 2), ('of', '', 2), ('June', '', 2), ('2015', 'date', 3), (',', '', 2), ('the', '', 2), ('group', '', 2), ('appears', '', 2), ('to', '', 2), ('have', '', 2), ('shifted', '', 2), ('from', '', 2), ('targeting', '', 2), ('primarily', '', 2), ('US', 'target', 3), ('victims', 'target', 1), ('to', '', 2), ('primarily', '', 2), ('political', '', 2), ('organizations', '', 2), ('in', '', 2), ('Hong', 'target_country', 3), ('Kong', 'target_country', 1), ('.', '', 2), ('\n', '', 2), ('MITRE', '', 2), ('has', '', 2), ('also', '', 2), ('developed', '', 2), ('an', '', 2), ('APT3', '', 2), ('Adversary', '', 2), ('Emulation', '', 2), ('Plan', '', 2), ('.', '', 2)]
# Tokens [('DragonOK', 'group', 3), ('is', '', 2), ('a', '', 2), ('threat', '', 2), ('group', '', 2), ('that', '', 2), ('has', '', 2), ('targeted', '', 2), ('Japanese', '', 2), ('organizations', '', 2), ('with', '', 2), ('phishing', '', 2), ('emails', '', 2), ('.', '', 2), ('Due', '', 2), ('to', '', 2), ('overlapping', '', 2), ('TTPs', '', 2), (',', '', 2), ('including', '', 2), ('similar', '', 2), ('custom', '', 2), ('tools', '', 2), (',', '', 2), ('DragonOK', '', 2), ('is', '', 2), ('thought', '', 2), ('to', '', 2), ('have', '', 2), ('a', '', 2), ('direct', '', 2), ('or', '', 2), ('indirect', '', 2), ('relationship', '', 2), ('with', '', 2), ('the', '', 2), ('threat', '', 2), ('group', '', 2), ('Moafee', 'same_group', 3), ('.', '', 2), (' ', '', 2), ('It', '', 2), ('is', '', 2), ('known', '', 2), ('to', '', 2), ('use', '', 2), ('a', '', 2), ('variety', '', 2), ('of', '', 2), ('malware', '', 2), (',', '', 2), ('including', '', 2), ('Sysget', '', 2), ('/', '', 2), ('HelloBridge', '', 2), (',', '', 2), ('PlugX', '', 2), (',', '', 2), ('PoisonIvy', '', 2), (',', '', 2), ('FormerFirstRat', '', 2), (',', '', 2), ('NFlog', '', 2), (',', '', 2), ('and', '', 2), ('NewCT', '', 2), ('.', '', 2)]
# Tokens [('admin@338', 'group', 3), ('is', '', 2), ('a', '', 2), ('China', 'threat_actor', 3), ('-', 'threat_actor', 1), ('based', 'threat_actor', 1), ('cyber', '', 2), ('threat', '', 2), ('group', '', 2), ('.', '', 2), ('It', '', 2), ('has', '', 2), ('previously', '', 2), ('used', '', 2), ('newsworthy', '', 2), ('events', '', 2), ('as', '', 2), ('lures', '', 2), ('to', '', 2), ('deliver', '', 2), ('malware', '', 2), ('and', '', 2), ('has', '', 2), ('primarily', '', 2), ('targeted', '', 2), ('organizations', '', 2), ('involved', '', 2), ('in', '', 2), ('financial', 'target', 3), (',', '', 2), ('economic', 'target', 3), (',', '', 2), ('and', '', 2), ('trade', 'target', 3), ('policy', 'target', 1), (',', '', 2), ('typically', '', 2), ('using', '', 2), ('publicly', '', 2), ('available', '', 2), ('RATs', '', 2), ('such', '', 2), ('as', '', 2), ('PoisonIvy', 'path', 3), (',', '', 2), ('as', '', 2), ('well', '', 2), ('as', '', 2), ('some', '', 2), ('non', '', 2), ('-', '', 2), ('public', '', 2), ('backdoors', '', 2), ('.', '', 2)]
# Tokens [('APT30', 'group', 3), ('is', '', 2), ('a', '', 2), ('threat', '', 2), ('group', '', 2), ('suspected', '', 2), ('to', '', 2), ('be', '', 2), ('associated', '', 2), ('with', '', 2), ('the', '', 2), ('Chinese', 'threat_group', 3), ('government', '', 2), ('.', '', 2), (' ', '', 2), ('While', '', 2), ('Naikon', '', 2), ('shares', '', 2), ('some', '', 2), ('characteristics', '', 2), ('with', '', 2), ('APT30', '', 2), (',', '', 2), ('the', '', 2), ('two', '', 2), ('groups', '', 2), ('do', '', 2), ('not', '', 2), ('appear', '', 2), ('to', '', 2), ('be', '', 2), ('exact', '', 2), ('matches', '', 2), ('.', '', 2)]
# Tokens [('APT28', 'group', 3), ('is', '', 2), ('a', '', 2), ('threat', '', 2), ('group', '', 2), ('that', '', 2), ('has', '', 2), ('been', '', 2), ('attributed', '', 2), ('to', '', 2), ('Russia', 'threat_group', 3), ("'s", '', 2), ('Main', '', 2), ('Intelligence', '', 2), ('Directorate', '', 2), ('of', '', 2), ('the', '', 2), ('Russian', '', 2), ('General', '', 2), ('Staff', '', 2), ('by', '', 2), ('a', '', 2), ('July', '', 2), ('2018', '', 2), ('U.S.', '', 2), ('Department', '', 2), ('of', '', 2), ('Justice', '', 2), ('indictment', '', 2), ('.', '', 2), ('This', '', 2), ('group', '', 2), ('reportedly', '', 2), ('compromised', '', 2), ('the', '', 2), ('Hillary', 'target', 3), ('Clinton', 'target', 1), ('campaign', 'target', 1), (',', '', 2), ('the', '', 2), ('Democratic', 'target', 3), ('National', 'target', 1), ('Committee', '', 2), (',', '', 2), ('and', '', 2), ('the', '', 2), ('Democratic', 'target', 3), ('Congressional', 'target', 1), ('Campaign', '', 2), ('Committee', '', 2), ('in', '', 2), ('2016', 'date', 3), ('in', '', 2), ('an', '', 2), ('attempt', '', 2), ('to', '', 2), ('interfere', '', 2), ('with', '', 2), ('the', '', 2), ('U.S.', '', 2), ('presidential', '', 2), ('election', '', 2), ('.', '', 2), ('APT28', '', 2), ('has', '', 2), ('been', '', 2), ('active', '', 2), ('since', '', 2), ('at', '', 2), ('least', '', 2), ('2004', 'date', 3), ('.', '', 2)]
# Tokens [('APT18', 'group', 3), ('is', '', 2), ('a', '', 2), ('threat', '', 2), ('group', '', 2), ('that', '', 2), ('has', '', 2), ('operated', '', 2), ('since', '', 2), ('at', '', 2), ('least', '', 2), ('2009', 'date', 3), ('and', '', 2), ('has', '', 2), ('targeted', '', 2), ('a', '', 2), ('range', '', 2), ('of', '', 2), ('industries', '', 2), (',', '', 2), ('including', '', 2), ('technology', 'target', 3), (',', '', 2), ('manufacturing', 'target', 3), (',', '', 2), ('human', 'target', 3), ('rights', 'target', 1), ('groups', '', 2), (',', '', 2), ('government', 'target', 3), (',', '', 2), ('and', '', 2), ('medical', 'target', 3), ('.', '', 2)]
# Tokens [('APT1', 'group', 3), ('is', '', 2), ('a', '', 2), ('Chinese', 'threat_group', 3), ('threat', 'threat_group', 1), ('group', '', 2), ('that', '', 2), ('has', '', 2), ('been', '', 2), ('attributed', '', 2), ('to', '', 2), ('the', '', 2), ('2nd', 'target', 3), ('Bureau', 'target', 1), ('of', 'target', 1), ('the', 'target', 1), ('People', 'target', 1), ('’s', 'target', 1), ('Liberation', 'target', 1), ('Army', 'target', 1), ('(', '', 2), ('PLA', '', 2), (')', '', 2), ('General', '', 2), ('Staff', '', 2), ('Department', '', 2), ('’s', '', 2), ('(', '', 2), ('GSD', '', 2), (')', '', 2), ('3rd', '', 2), ('Department', '', 2), (',', '', 2), ('commonly', '', 2), ('known', '', 2), ('by', '', 2), ('its', '', 2), ('Military', '', 2), ('Unit', '', 2), ('Cover', '', 2), ('Designator', '', 2), ('(', '', 2), ('MUCD', '', 2), (')', '', 2), ('as', '', 2), ('Unit', '', 2), ('61398', '', 2), ('.', '', 2)]
# Tokens [('APT16', 'group', 3), ('is', '', 2), ('a', '', 2), ('China', 'threat_group', 3), ('-', 'threat_group', 1), ('based', 'threat_group', 1), ('threat', '', 2), ('group', '', 2), ('that', '', 2), ('has', '', 2), ('launched', '', 2), ('spearphishing', '', 2), ('campaigns', '', 2), ('targeting', '', 2), ('Japanese', 'target', 3), ('and', '', 2), ('Taiwanese', 'target', 3), ('organizations', '', 2), ('.', '', 2)]
# Tokens [('Dust', 'group', 3), ('Storm', 'group', 1), ('is', '', 2), ('a', '', 2), ('threat', '', 2), ('group', '', 2), ('that', '', 2), ('has', '', 2), ('targeted', '', 2), ('multiple', '', 2), ('industries', '', 2), ('in', '', 2), ('Japan', 'target_country', 3), (',', '', 2), ('South', 'target_country', 3), ('Korea', 'target_country', 1), (',', '', 2), ('the', '', 2), ('United', 'target_country', 3), ('States', 'target_country', 1), (',', '', 2), ('Europe', '', 2), (',', '', 2), ('and', '', 2), ('several', '', 2), ('Southeast', '', 2), ('Asian', '', 2), ('countries', '', 2), ('.', '', 2)]
# Tokens [('Dragonfly', 'group', 3), ('2.0', 'group', 1), ('is', '', 2), ('a', '', 2), ('suspected', '', 2), ('Russian', '', 2), ('group', '', 2), ('that', '', 2), ('has', '', 2), ('targeted', '', 2), ('government', '', 2), ('entities', '', 2), ('and', '', 2), ('multiple', '', 2), ('U.S.', 'target_country', 3), ('critical', '', 2), ('infrastructure', '', 2), ('sectors', '', 2), ('since', '', 2), ('at', '', 2), ('least', '', 2), ('March', 'date', 3), ('2016', 'date', 1), ('.', '', 2), ('  ', '', 2), ('There', '', 2), ('is', '', 2), ('debate', '', 2), ('over', '', 2), ('the', '', 2), ('extent', '', 2), ('of', '', 2), ('overlap', '', 2), ('between', '', 2), ('Dragonfly', '', 2), ('2.0', '', 2), ('and', '', 2), ('Dragonfly', '', 2), (',', '', 2), ('but', '', 2), ('there', '', 2), ('is', '', 2), ('sufficient', '', 2), ('evidence', '', 2), ('to', '', 2), ('lead', '', 2), ('to', '', 2), ('these', '', 2), ('being', '', 2), ('tracked', '', 2), ('as', '', 2), ('two', '', 2), ('separate', '', 2), ('groups', '', 2), ('.', '', 2)]
# Tokens [('APT12', 'group', 3), ('is', '', 2), ('a', '', 2), ('threat', '', 2), ('group', '', 2), ('that', '', 2), ('has', '', 2), ('been', '', 2), ('attributed', '', 2), ('to', '', 2), ('China', 'threat_actor', 3), ('.', '', 2), ('The', '', 2), ('group', '', 2), ('has', '', 2), ('targeted', '', 2), ('a', '', 2), ('variety', '', 2), ('of', '', 2), ('victims', '', 2), ('including', '', 2), ('but', '', 2), ('not', '', 2), ('limited', '', 2), ('to', '', 2), ('media', 'target', 3), ('outlets', 'target', 1), (',', '', 2), ('high', 'target', 3), ('-', 'target', 1), ('tech', 'target', 1), ('companies', 'target', 1), (',', '', 2), ('and', '', 2), ('multiple', 'target', 3), ('governments', 'target', 1), ('.', '', 2)]
# Tokens [('APT17', 'group', 3), ('is', '', 2), ('a', '', 2), ('China', 'threat_actor', 3), ('-', 'threat_actor', 1), ('based', 'threat_actor', 1), ('threat', '', 2), ('group', '', 2), ('that', '', 2), ('has', '', 2), ('conducted', '', 2), ('network', 'path', 3), ('intrusions', 'path', 1), ('against', '', 2), ('U.S.', 'target_country', 3), ('government', '', 2), ('entities', '', 2), (',', '', 2), ('the', '', 2), ('defense', 'target', 3), ('industry', 'target', 1), (',', '', 2), ('law', 'target', 3), ('firms', 'target', 1), (',', '', 2), ('information', 'target', 3), ('technology', 'target', 1), ('companies', '', 2), (',', '', 2), ('mining', 'target', 3), ('companies', '', 2), (',', '', 2), ('and', '', 2), ('non', 'target', 3), ('-', 'target', 1), ('government', 'target', 1), ('organizations', '', 2), ('.', '', 2)]
# Tokens [('APT29', 'group', 3), ('is', '', 2), ('threat', '', 2), ('group', '', 2), ('that', '', 2), ('has', '', 2), ('been', '', 2), ('attributed', '', 2), ('to', '', 2), ('the', '', 2), ('Russian', 'threat_group', 3), ('government', '', 2), ('and', '', 2), ('has', '', 2), ('operated', '', 2), ('since', '', 2), ('at', '', 2), ('least', '', 2), ('2008', 'date', 3), ('.', '', 2), ('  ', '', 2), ('This', '', 2), ('group', '', 2), ('reportedly', '', 2), ('compromised', '', 2), ('the', '', 2), ('Democratic', 'target', 3), ('National', 'target', 1), ('Committee', '', 2), ('starting', '', 2), ('in', '', 2), ('the', '', 2), ('summer', '', 2), ('of', '', 2), ('2015', 'date', 3), ('.', '', 2)]
# Tokens [('APT19', 'group', 3), ('is', '', 2), ('a', '', 2), ('Chinese', 'threat_group', 3), ('-', 'threat_group', 1), ('based', 'threat_group', 1), ('threat', '', 2), ('group', '', 2), ('that', '', 2), ('has', '', 2), ('targeted', '', 2), ('a', '', 2), ('variety', '', 2), ('of', '', 2), ('industries', '', 2), (',', '', 2), ('including', '', 2), ('defense', 'target', 3), (',', '', 2), ('finance', '', 2), (',', '', 2), ('energy', '', 2), (',', '', 2), ('pharmaceutical', 'target', 3), (',', '', 2), ('telecommunications', 'target', 3), (',', '', 2), ('high', '', 2), ('tech', '', 2), (',', '', 2), ('education', '', 2), (',', '', 2), ('manufacturing', 'target', 3), (',', '', 2), ('and', '', 2), ('legal', '', 2), ('services', '', 2), ('.', '', 2), ('In', '', 2), ('2017', '', 2), (',', '', 2), ('a', '', 2), ('phishing', '', 2), ('campaign', '', 2), ('was', '', 2), ('used', '', 2), ('to', '', 2), ('target', '', 2), ('seven', '', 2), ('law', '', 2), ('and', '', 2), ('investment', '', 2), ('firms', '', 2), ('.', '', 2), (' ', '', 2), ('Some', '', 2), ('analysts', '', 2), ('track', '', 2), ('APT19', '', 2), ('and', '', 2), ('Deep', 'same_group', 3), ('Panda', 'same_group', 1), ('as', '', 2), ('the', '', 2), ('same', '', 2), ('group', '', 2), (',', '', 2), ('but', '', 2), ('it', '', 2), ('is', '', 2), ('unclear', '', 2), ('from', '', 2), ('open', '', 2), ('source', '', 2), ('information', '', 2), ('if', '', 2), ('the', '', 2), ('groups', '', 2), ('are', '', 2), ('the', '', 2), ('same', '', 2), ('.', '', 2)]

# %%
doc=nlp('Cleaver is a threat group that has been attributed to Iranian actors and is responsible for activity tracked as Operation Cleaver.  Strong circumstantial evidence suggests Cleaver is linked to Threat Group 2889 (TG-2889)')
print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
#print("Tokens", [(t.text, t.ent_type_, t.ent_iob) for t in doc])
# Out:
# Entities [('Cleaver', 'group'), ('Strong', 'threat_group')]

# %%
from __future__ import unicode_literals, print_function

import plac
import random
from pathlib import Path
import spacy
from spacy.util import minibatch, compounding


# training data
TRAIN_DATA = [
    ("Who is Shaka Khan?", {"entities": [(7, 17, "PERSON")]}),
    ("I like London and Berlin.", {"entities": [(7, 13, "LOC"), (18, 24, "LOC")]}),
]


@plac.annotations(
    model=("Model name. Defaults to blank 'en' model.", "option", "m", str),
    output_dir=("Optional output directory", "option", "o", Path),
    n_iter=("Number of training iterations", "option", "n", int),
)
def main(model=None, output_dir=None, n_iter=100):
    """Load the model, set up the pipeline and train the entity recognizer."""
    if model is not None:
        nlp = spacy.load(model)  # load existing spaCy model
        print("Loaded model '%s'" % model)
    else:
        nlp = spacy.blank("en")  # create blank Language class
        print("Created blank 'en' model")

    # create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if "ner" not in nlp.pipe_names:
        ner = nlp.create_pipe("ner")
        nlp.add_pipe(ner, last=True)
    # otherwise, get it so we can add labels
    else:
        ner = nlp.get_pipe("ner")

    # add labels
    for _, annotations in TRAIN_DATA:
        for ent in annotations.get("entities"):
            ner.add_label(ent[2])

    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != "ner"]
    with nlp.disable_pipes(*other_pipes):  # only train NER
        # reset and initialize the weights randomly – but only if we're
        # training a new model
        if model is None:
            nlp.begin_training()
        for itn in range(n_iter):
            random.shuffle(TRAIN_DATA)
            losses = {}
            # batch up the examples using spaCy's minibatch
            batches = minibatch(TRAIN_DATA, size=compounding(4.0, 32.0, 1.001))
            for batch in batches:
                texts, annotations = zip(*batch)
                nlp.update(
                    texts,  # batch of texts
                    annotations,  # batch of annotations
                    drop=0.5,  # dropout - make it harder to memorise data
                    losses=losses,
                )
            print("Losses", losses)

    # test the trained model
    for text, _ in TRAIN_DATA:
        doc = nlp(text)
        print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
        print("Tokens", [(t.text, t.ent_type_, t.ent_iob) for t in doc])

# %%
if __name__ == "__main__":
    plac.call(main)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
TRAIN_DATA_1 = [
    ("Who is Shaka Khan?", {"entities": [(7, 17, "PERSON")]}),
    ("I like London and Berlin.", {"entities": [(7, 13, "LOC"), (18, 24, "LOC")]}),
]

# %%
for _,annotations in TRAIN_DATA:
    for ent in annotations.get("entities"):
            ner.add_label(ent[2])
