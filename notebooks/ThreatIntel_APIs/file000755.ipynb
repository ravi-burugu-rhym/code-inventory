# %%
import pandas as pd
import uuid
from datetime import datetime
import numpy as np
from grakn.client import GraknClient
from tqdm import tqdm
tqdm.pandas()

# %%
df=pd.read_excel(r"C:\Users\SRIKANTH\Desktop\OpenCTI_Data.xlsx",sheet_name='tool')

# %%
df.keys()
# Out:
# Index(['internal_id_key', 'stix_id_key', 'stix_label', 'entity_type',
#        'created', 'modified', 'revoked', 'object_status', 'created_at',
#        'created_at_day', 'created_at_month', 'created_at_year', 'updated_at',
#        'name', 'description', 'alias', 'graph_data', 'tool_version'],
#       dtype='object')

# %%
def  insert_general_info(df,ent_type,create):
    if create:
        for index,i in df.iterrows():
            df.internal_id_key[index]=str(uuid.uuid4())
            df.stix_id_key[index]=ent_type+'--'+str(uuid.uuid4())
            df.stix_label[index]='NA'
            df.entity_type[index]=ent_type
            df.created=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.created_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.created_at_day=(datetime.now()).strftime("%Y-%m-%d")
            df.created_at_month=(datetime.now()).strftime("%Y-%m")
            df.created_at_year=(datetime.now()).strftime("%Y")
            df.modified=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.updated_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.revoked=False
            df.object_status='NA'
    else:
            df.modified=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.updated_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
    return df

# %%
result=insert_general_info(df=df,ent_type='tools',create=True)
result.fillna('NA',inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
result
# Out:
#                          internal_id_key  \
# 0   2c30bc07-d5b7-48de-8c62-a3961829f1cb
# 1   d1fe707d-751a-4ec6-8c41-7b90b2f3e39b
# 2   5ca23abe-7a3b-4212-88dd-bd9ae37bdc0b
# 3   663db661-71ee-48c9-adbf-2ca5662985ee
# 4   480606f5-e4ab-4ade-8444-9aa192b5dced
# 5   5568671a-9b09-4a33-9053-2e22d10f3169
# 6   8f99353d-cfed-4351-bf72-21b3a8a576c7
# 7   ce556816-9a1c-46b7-92fe-15c92c00b6ba
# 8   84c8a923-540b-4ab2-b7e0-d687c376a2cc
# 9   95fe596f-14df-4e50-95c4-6db747fc19b9
# 10  d8e8a5c7-e44d-4a4f-8f38-f3f049a09cc8
#
#                                           stix_id_key stix_label  \
# 0   Intrusion-set--e16bfda8-b1aa-4b20-a98d-8a30fca...         NA
# 1   Intrusion-set--be1e60e4-fab3-4901-9976-216866c...         NA
# 2   Intrusion-set--54b68eff-1baf-4023-8286-d86076e...         NA
# 3   Intrusion-set--9e9dd0a6-ff13-41c1-8840-504e2dc...         NA
# 4   Intrusion-set--9b048315-89df-4951-ac8b-949a67f...         NA
# 5   Intrusion-set--bf6bb67e-a727-4e7e-bbae-44fbd03...         NA
# 6   Intrusion-set--d9b8568d-16c0-49cf-bc40-0969282...         NA
# 7   Intrusion-set--79461163-2a9e-451a-a644-85005e9...         NA
# 8   Intrusion-set--67fa18c3-cfe7-41aa-a8cb-605f24a...         NA
# 9   Intrusion-set--3283ef96-8b8f-4754-a106-fc999c8...         NA
# 10  Intrusion-set--bbd83452-dfab-4e7b-8cfb-48faaeb...         NA
#
#       entity_type              created             modified  revoked  \
# 0   Intrusion-set  2020-01-06T17:27:48  2020-01-06T17:27:48    False
# 1   Intrusion-set  2020-01-06T17:27:48  2020-01-06T17:27:48    False
# 2   Intrusion-set  2020-01-06T17:27:48  2020-01-06T17:27:48    False
# 3   Intrusion-set  2020-01-06T17:27:48  2020-01-06T17:27:48    False
# 4   Intrusion-set  2020-01-06T17:27:48  2020-01-06T17:27:48    False
# 5   Intrusion-set  2020-01-06T17:27:48  2020-01-06T17:27:48    False
# 6   Intrusion-set  2020-01-06T17:27:48  2020-01-06T17:27:48    False
# 7   Intrusion-set  2020-01-06T17:27:48  2020-01-06T17:27:48    False
# 8   Intrusion-set  2020-01-06T17:27:48  2020-01-06T17:27:48    False
# 9   Intrusion-set  2020-01-06T17:27:48  2020-01-06T17:27:48    False
# 10  Intrusion-set  2020-01-06T17:27:48  2020-01-06T17:27:48    False
#
#    object_status           created_at created_at_day created_at_month  \
# 0             NA  2020-01-06T17:27:48     2020-01-06          2020-01
# 1             NA  2020-01-06T17:27:48     2020-01-06          2020-01
# 2             NA  2020-01-06T17:27:48     2020-01-06          2020-01
# 3             NA  2020-01-06T17:27:48     2020-01-06          2020-01
# 4             NA  2020-01-06T17:27:48     2020-01-06          2020-01
# 5             NA  2020-01-06T17:27:48     2020-01-06          2020-01
# 6             NA  2020-01-06T17:27:48     2020-01-06          2020-01
# 7             NA  2020-01-06T17:27:48     2020-01-06          2020-01
# 8             NA  2020-01-06T17:27:48     2020-01-06          2020-01
# 9             NA  2020-01-06T17:27:48     2020-01-06          2020-01
# 10            NA  2020-01-06T17:27:48     2020-01-06          2020-01
#
#    created_at_year           updated_at           name  \
# 0             2020  2020-01-06T17:27:48         FinSpy
# 1             2020  2020-01-06T17:27:48       Certutil
# 2             2020  2020-01-06T17:27:48       Forfiles
# 3             2020  2020-01-06T17:27:48         Koadic
# 4             2020  2020-01-06T17:27:48       Mimikatz
# 5             2020  2020-01-06T17:27:48         Winexe
# 6             2020  2020-01-06T17:27:48          HTRAN
# 7             2020  2020-01-06T17:27:48  Cobalt Strike
# 8             2020  2020-01-06T17:27:48       Mimikatz
# 9             2020  2020-01-06T17:27:48         PsExec
# 10            2020  2020-01-06T17:27:48        SDelete
#
#                                           description alias graph_data  \
# 0   FinSpy is an extremely effective software tool...    NA         NA
# 1   certutil is a command-line utility that can be...    NA         NA
# 2   Forfiles is a Windows utility commonly used in...    NA         NA
# 3   Koadic is a Windows post-exploitation framewor...    NA         NA
# 4   Mimikatz is a credential dumper capable of obt...    NA         NA
# 5   Winexe is a lightweight, open source tool simi...    NA         NA
# 6   HTRAN is a tool that proxies connections throu...    NA         NA
# 7   Cobalt Strike is a commercial, full-featured, ...    NA         NA
# 8   Mimikatz is a credential dumper capable of obt...    NA         NA
# 9   PsExec is a free Microsoft tool that can be us...    NA         NA
# 10  SDelete is an application that securely delete...    NA         NA
#
#    tool_version
# 0           1.2
# 1            NA
# 2            NA
# 3            NA
# 4            NA
# 5            NA
# 6           1.1
# 7           1.2
# 8           1.1
# 9             1
# 10          1.1

# %%
result['tool_version']
# Out:
# 0     1.2
# 1      NA
# 2      NA
# 3      NA
# 4      NA
# 5      NA
# 6     1.1
# 7     1.2
# 8     1.1
# 9       1
# 10    1.1
# Name: tool_version, dtype: object

# %%
def insert_one_tool (df,session):
    #if df.first_seen != 'NA':
     #   f=df.first_seen.strftime("%Y-%m-%dT%H:%M:%S")
     #   f_m=df.first_seen.strftime("%Y-%m")
     #   f_d=df.first_seen.strftime("%Y-%m-%d")
    #elif df.first_seen_month != 'NA':
    #    f_m=df.first_seen_month
    #elif df.first_seen_day != 'NA':
    #    f_d=df.first_seen_day
    #else:
    #    f_d=None
    #    f_m=None
    #    f=None
    df['description']=df['description'].replace('\"','').strip()
    aliases = list()
    if df['alias'] != 'NA':            
        aliases=df.alias.split('\n')

    graql_match_query = f"match $i isa Tool , " \
                        f"has name \"{df['name']}__\"; " \
                        f"get;"
    # print(graql_match_query)
    with session.transaction().read() as read_transaction:
        # read_transaction.query(graql_match_query)
        answer_iterator = None
        answer_iterator = read_transaction.query(graql_match_query, infer=True)
        data = answer_iterator.collect_concepts()
                
        if len(data) > 0:
            # Update data.
            # Columns to be updated: object_status, revoked, updated_at, modified, description, alias
            # print("Update intrusion-set...")
            print("Update: " + df['name'])
            print(df.tool_version)
            if df['tool_version'] !='NA':
                graql_attribute_delete_query = f"match $i isa Tool , " \
                                           f"has name \"{df['name']}__\", "\
                                           f"has alias $a via $i1, "\
                                           f"has description $a via $i2, "\
                                           f"has tool_version $a via $i3; "\
                                           f"delete $i1, $i2 ,$i3;"
            elif df['tool_version'] =='NA':
                 graql_attribute_delete_query = f"match $i isa Tool , " \
                                           f"has name \"{df['name']}__\", "\
                                           f"has alias $a via $i1, "\
                                           f"has description $a via $i2; "\
                                           f"delete $i1, $i2;"
            print(graql_attribute_delete_query)
            update_flg = False
            first_attr_flg = True
            graql_attribute_update_query = f"match $i isa Vulnerability , " \
                                           f"has name \"{df['name']}__\"; insert $i"
            if df['description'] != 'NA':
                #via1='$i1'
                #graql_attribute_delete_query += f" has description $a via "+via1
                graql_attribute_update_query += f"  has description \"{df['description']}\" "
                if (first_attr_flg):
                    graql_attribute_update_query += ","
                update_flg = True
                first_attr_flg = False
            #print(len(aliases))
            if len(aliases) > 0:
                s = "|"
                #via2='$i2'
                #graql_attribute_delete_query += f" has description $a via "+via2
                graql_attribute_update_query += f" has alias \"{s.join(aliases).replace(' ','')}\" " 
                if first_attr_flg:
                     graql_attribute_update_query += ","
                update_flg = True
                first_attr_flg = False
            if df['tool_version'] != 'NA':
                # graql_attribute_delete_query += f" has description $a via $i2; "\
                graql_attribute_update_query += f"  has tool_version \"{df['tool_version']}\" "
                if (first_attr_flg) :
                    graql_attribute_update_query += ","
                update_flg = True
                first_attr_flg = False
            tokens=graql_attribute_update_query.split()
            if  tokens[-1]==',':
                tokens[-1]=''
            graql_attribute_update_query=' '.join(tokens)
            graql_attribute_update_query += ";"
           
            if update_flg:
                with session.transaction().write() as write_transaction:
                    # make a write transection with the query
                    write_transaction.query(graql_attribute_delete_query)
                    write_transaction.query(graql_attribute_update_query)
                    # remember to commit at the end
                    write_transaction.commit()           
        else:
            # print("Insert intrusion-set...")
            print("Insert: " + df['name'].strip())
            graql_insert_query = f"insert $x isa Tool, " \
                                 f"has internal_id_key \"{df['internal_id_key']}\", " \
                                 f"has stix_id_key \"{df['stix_id_key']}\", " \
                                 f"has stix_label \"{df['stix_label']}\", " \
                                 f"has entity_type \"{df['entity_type']}\", " \
                                 f"has created {df['created']}, " \
                                 f"has revoked \"{df['revoked']}\", "\
                                 f"has created_at {df['created_at']}, " \
                                 f"has created_at_day \"{df['created_at_day']}\", " \
                                 f"has created_at_month \"{df['created_at_month']}\", " \
                                 f"has created_at_year \"{df['created_at_year']}\", "\
                                 f"has updated_at {df['updated_at']}, "\
                                 f"has name \"{df['name'].strip()}__\" "
                                 
            if df['description'] != 'NA':
                graql_insert_query += f", has description \"{df['description']}\" "
            if len(aliases) > 0:
                s = "|"
                graql_insert_query += f", has alias \"{s.join(aliases)}\" "
            if  df['tool_version'] != 'NA':
                graql_insert_query += f", has tool_version \"{df['tool_version']}\" "
            #if f_d is not None:
            #    graql_insert_query += f", has first_seen_day \"{f_d}\" "
            #if f_m is not None:
             #   graql_insert_query += f", has first_seen_month \"{f_m}\" "
            #if f_m is not None:
            #    graql_insert_query += f", has first_seen_year \"{df['first_seen_year']}\""
            graql_insert_query += ";"
            print(graql_insert_query)
            with session.transaction().write() as write_transaction:
                # make a write transection with the query
                write_transaction.query(graql_insert_query)
                # remember to commit at the end
                write_transaction.commit()

# %%
def load_data_into_grakn(session,input_df):
    print("Inserting intrusion-set...")
    # using progress_apply instead of apply so we have a progress bar form tqdm
    # input_df.progress_apply(insert_one_intrusion_set, axis=1, session=session)
    print("Loading intrusion-set...")
    for index,row in input_df.iterrows():
        insert_one_tool(df=row,session=session)

# %%
def build_grakn_graph(input_df, keyspace_name):
    with GraknClient(uri="192.168.1.250:48555") as client:
        with client.session(keyspace = keyspace_name) as session:
            load_data_into_grakn(session,input_df)

# %%
build_grakn_graph(input_df=result,keyspace_name='grakn')
# Out:
# Inserting intrusion-set...
# Loading intrusion-set...
# Update: FinSpy
# 1.2
# match $i isa Tool , has name "FinSpy__", has alias $a via $i1, has description $a via $i2, has tool_version $a via $i3; delete $i1, $i2 ,$i3;
# Update: Certutil
# NA
# match $i isa Tool , has name "Certutil__", has alias $a via $i1, has description $a via $i2; delete $i1, $i2;
# Update: Forfiles
# NA
# match $i isa Tool , has name "Forfiles__", has alias $a via $i1, has description $a via $i2; delete $i1, $i2;
# Update: Koadic
# NA
# match $i isa Tool , has name "Koadic__", has alias $a via $i1, has description $a via $i2; delete $i1, $i2;
# Update: Mimikatz
# NA
# match $i isa Tool , has name "Mimikatz__", has alias $a via $i1, has description $a via $i2; delete $i1, $i2;
# Update: Winexe
# NA
# match $i isa Tool , has name "Winexe__", has alias $a via $i1, has description $a via $i2; delete $i1, $i2;
# Update: HTRAN
# 1.1
# match $i isa Tool , has name "HTRAN__", has alias $a via $i1, has description $a via $i2, has tool_version $a via $i3; delete $i1, $i2 ,$i3;
# Update: Cobalt Strike
# 1.2
# match $i isa Tool , has name "Cobalt Strike__", has alias $a via $i1, has description $a via $i2, has tool_version $a via $i3; delete $i1, $i2 ,$i3;
# Update: Mimikatz
# 1.1
# match $i isa Tool , has name "Mimikatz__", has alias $a via $i1, has description $a via $i2, has tool_version $a via $i3; delete $i1, $i2 ,$i3;
# Update: PsExec
# 1.0
# match $i isa Tool , has name "PsExec__", has alias $a via $i1, has description $a via $i2, has tool_version $a via $i3; delete $i1, $i2 ,$i3;
# Update: SDelete
# 1.1
# match $i isa Tool , has name "SDelete__", has alias $a via $i1, has description $a via $i2, has tool_version $a via $i3; delete $i1, $i2 ,$i3;
