# %%
import pandas as pd
import uuid
from datetime import datetime
import numpy as np
from grakn.client import GraknClient
from tqdm import tqdm
tqdm.pandas()

# %%
df=pd.read_excel(r"D:\Threat_intel_services\APT_collections\data\incidents\incidents_final.xlsx")

# %%
df
# Out:
#     internal_id_key  stix_id_key  stix_label  entity_type  created  modified  \
# 0               NaN          NaN         NaN          NaN      NaN       NaN
# 1               NaN          NaN         NaN          NaN      NaN       NaN
# 2               NaN          NaN         NaN          NaN      NaN       NaN
# 3               NaN          NaN         NaN          NaN      NaN       NaN
# 4               NaN          NaN         NaN          NaN      NaN       NaN
# 5               NaN          NaN         NaN          NaN      NaN       NaN
# 6               NaN          NaN         NaN          NaN      NaN       NaN
# 7               NaN          NaN         NaN          NaN      NaN       NaN
# 8               NaN          NaN         NaN          NaN      NaN       NaN
# 9               NaN          NaN         NaN          NaN      NaN       NaN
# 10              NaN          NaN         NaN          NaN      NaN       NaN
# 11              NaN          NaN         NaN          NaN      NaN       NaN
# 12              NaN          NaN         NaN          NaN      NaN       NaN
# 13              NaN          NaN         NaN          NaN      NaN       NaN
# 14              NaN          NaN         NaN          NaN      NaN       NaN
# 15              NaN          NaN         NaN          NaN      NaN       NaN
# 16              NaN          NaN         NaN          NaN      NaN       NaN
# 17              NaN          NaN         NaN          NaN      NaN       NaN
# 18              NaN          NaN         NaN          NaN      NaN       NaN
# 19              NaN          NaN         NaN          NaN      NaN       NaN
# 20              NaN          NaN         NaN          NaN      NaN       NaN
# 21              NaN          NaN         NaN          NaN      NaN       NaN
# 22              NaN          NaN         NaN          NaN      NaN       NaN
# 23              NaN          NaN         NaN          NaN      NaN       NaN
# 24              NaN          NaN         NaN          NaN      NaN       NaN
# 25              NaN          NaN         NaN          NaN      NaN       NaN
# 26              NaN          NaN         NaN          NaN      NaN       NaN
# 27              NaN          NaN         NaN          NaN      NaN       NaN
# 28              NaN          NaN         NaN          NaN      NaN       NaN
# 29              NaN          NaN         NaN          NaN      NaN       NaN
# 30              NaN          NaN         NaN          NaN      NaN       NaN
# 31              NaN          NaN         NaN          NaN      NaN       NaN
# 32              NaN          NaN         NaN          NaN      NaN       NaN
# 33              NaN          NaN         NaN          NaN      NaN       NaN
#
#     revoked  object_status  created_at  created_at_day  ...  updated_at  \
# 0       NaN            NaN         NaN             NaN  ...         NaN
# 1       NaN            NaN         NaN             NaN  ...         NaN
# 2       NaN            NaN         NaN             NaN  ...         NaN
# 3       NaN            NaN         NaN             NaN  ...         NaN
# 4       NaN            NaN         NaN             NaN  ...         NaN
# 5       NaN            NaN         NaN             NaN  ...         NaN
# 6       NaN            NaN         NaN             NaN  ...         NaN
# 7       NaN            NaN         NaN             NaN  ...         NaN
# 8       NaN            NaN         NaN             NaN  ...         NaN
# 9       NaN            NaN         NaN             NaN  ...         NaN
# 10      NaN            NaN         NaN             NaN  ...         NaN
# 11      NaN            NaN         NaN             NaN  ...         NaN
# 12      NaN            NaN         NaN             NaN  ...         NaN
# 13      NaN            NaN         NaN             NaN  ...         NaN
# 14      NaN            NaN         NaN             NaN  ...         NaN
# 15      NaN            NaN         NaN             NaN  ...         NaN
# 16      NaN            NaN         NaN             NaN  ...         NaN
# 17      NaN            NaN         NaN             NaN  ...         NaN
# 18      NaN            NaN         NaN             NaN  ...         NaN
# 19      NaN            NaN         NaN             NaN  ...         NaN
# 20      NaN            NaN         NaN             NaN  ...         NaN
# 21      NaN            NaN         NaN             NaN  ...         NaN
# 22      NaN            NaN         NaN             NaN  ...         NaN
# 23      NaN            NaN         NaN             NaN  ...         NaN
# 24      NaN            NaN         NaN             NaN  ...         NaN
# 25      NaN            NaN         NaN             NaN  ...         NaN
# 26      NaN            NaN         NaN             NaN  ...         NaN
# 27      NaN            NaN         NaN             NaN  ...         NaN
# 28      NaN            NaN         NaN             NaN  ...         NaN
# 29      NaN            NaN         NaN             NaN  ...         NaN
# 30      NaN            NaN         NaN             NaN  ...         NaN
# 31      NaN            NaN         NaN             NaN  ...         NaN
# 32      NaN            NaN         NaN             NaN  ...         NaN
# 33      NaN            NaN         NaN             NaN  ...         NaN
#
#                                             objective           first_seen  \
# 0    APT12 with suspected ties to the People’s Rep...  2013-01-01 00:00:00
# 1   APT12 since at least 2003, when Chinese hacker...  1905-07-06 00:00:00
# 2   The IXESHE attackers have been actively launch...  2009-07-01 00:00:00
# 3   Once the malicious file was downloaded and ext...  1905-07-03 00:00:00
# 4   Breach of The New York Times“For the last four...  2012-10-01 00:00:00
# 5   APT12 utilizing RIPTIDE, a proxy-aware backdoo...  2012-10-01 00:00:00
# 6   spear phish email sent to a Taiwanese governme...  2014-08-24 00:00:00
# 7   On Monday August 25, 2014 observed a different...  2014-08-25 00:00:00
# 8   blackOasis attack begins with the delivery of ...  2016-05-10 00:00:00
# 9   BlackOasis attack begins with the delivery of ...  2017-10-01 00:00:00
# 10  Leveraging data from Kaspersky Security Networ...  2015-06-01 00:00:00
# 11  FireEye recently detected a malicious Microsof...  2017-09-01 00:00:00
# 12  Kaspersky Lab’s advanced exploit prevention\ns...  2017-10-01 00:00:00
# 13   The first attack conducted by the Cobalt grou...  2016-06-01 00:00:00
# 14   ATM heist at the First Commercial Bank in Taiwan  2016-07-01 00:00:00
# 15  ATM heist at the Government Saving Bank in Tha...  2016-08-01 00:00:00
# 16  A massive spear-phishing campaign \nbegan targ...  2017-11-01 00:00:00
# 17  Spear-phishing attacks to Russian banks\nThe e...  2018-01-01 00:00:00
# 18  Cobalt cyberattack on the leading banks of Rus...  2018-05-23 00:00:00
# 19  Concerns over Russian espionage litter today’s...                 2016
# 20  \nThe BfV said a hacker group thought to work ...                 2014
# 21  cyber-attack which crippled a French televisio...  2015-04-01 00:00:00
# 22  Russian hackers backed by Moscow have been car...  2015-08-01 00:00:00
# 23  \nU.S. military wives’ death threats\nFive mil...  2015-02-10 00:00:00
# 24  Recently detected a limited APT campaign explo...  2015-04-13 00:00:00
# 25  \nEliot Higgins and other journalists associat...  2015-10-01 00:00:00
# 26  \nThe group targeted the Dutch Safety Board, t...  2015-10-01 00:00:00
# 27  Fancy Bear carried out spear-phishing attacks ...  2016-06-01 00:00:00
# 28  The Sofacy group, also known as APT28, is a we...  2016-05-28 00:00:00
# 29  Phishing emails sent to users of its database ...  2016-08-01 00:00:00
# 30  The global reach that coincided with this focu...  2016-10-01 00:00:00
# 31  GAMEFISH backdoor\nThey took advantage of the ...                 2017
# 32  In February 2017, the General Intelligence and...  2017-02-01 00:00:00
# 33  The officials of International Association of ...  2017-02-21 00:00:00
#
#    first_seen_day first_seen_month  first_seen_year            last_seen  \
# 0             NaN              NaN              NaN                  NaN
# 1             NaN              NaN              NaN                  NaN
# 2             NaN              NaN              NaN                  NaN
# 3             NaN              NaN              NaN                  NaN
# 4             NaN              NaN              NaN                  NaN
# 5             NaN              NaN              NaN  2014-05-01 00:00:00
# 6             NaN              NaN              NaN                  NaN
# 7             NaN              NaN              NaN                  NaN
# 8             NaN              NaN              NaN                  NaN
# 9             NaN              NaN              NaN                  NaN
# 10            NaN              NaN              NaN                  NaN
# 11            NaN              NaN              NaN                  NaN
# 12            NaN              NaN              NaN                  NaN
# 13            NaN              NaN              NaN                  NaN
# 14            NaN              NaN              NaN                  NaN
# 15            NaN              NaN              NaN                  NaN
# 16            NaN              NaN              NaN                  NaN
# 17            NaN              NaN              NaN                  NaN
# 18            NaN              NaN              NaN  2018-10-01 00:00:00
# 19            NaN              NaN              NaN                 2016
# 20            NaN              NaN              NaN                 2015
# 21            NaN              NaN              NaN  2015-04-01 00:00:00
# 22            NaN              NaN              NaN                  NaN
# 23            NaN              NaN              NaN  2015-02-10 00:00:00
# 24            NaN              NaN              NaN  2015-04-13 00:00:00
# 25            NaN              NaN              NaN                  NaN
# 26            NaN              NaN              NaN                  NaN
# 27            NaN              NaN              NaN                  NaN
# 28            NaN              NaN              NaN                  NaN
# 29            NaN              NaN              NaN                  NaN
# 30            NaN              NaN              NaN                  NaN
# 31            NaN              NaN              NaN                  NaN
# 32            NaN              NaN              NaN                  NaN
# 33            NaN              NaN              NaN                  NaN
#
#     last_seen_day last_seen_month  last_seen_year
# 0             NaN             NaN             NaN
# 1             NaN             NaN             NaN
# 2             NaN             NaN             NaN
# 3             NaN             NaN             NaN
# 4             NaN             NaN             NaN
# 5             NaN             NaN             NaN
# 6             NaN             NaN             NaN
# 7             NaN             NaN             NaN
# 8             NaN             NaN             NaN
# 9             NaN             NaN             NaN
# 10            NaN             NaN             NaN
# 11            NaN             NaN             NaN
# 12            NaN             NaN             NaN
# 13            NaN             NaN             NaN
# 14            NaN             NaN             NaN
# 15            NaN             NaN             NaN
# 16            NaN             NaN             NaN
# 17            NaN             NaN             NaN
# 18            NaN             NaN             NaN
# 19            NaN             NaN             NaN
# 20            NaN             NaN             NaN
# 21            NaN             NaN             NaN
# 22            NaN             NaN             NaN
# 23            NaN             NaN             NaN
# 24            NaN             NaN             NaN
# 25            NaN             NaN             NaN
# 26            NaN             NaN             NaN
# 27            NaN             NaN             NaN
# 28            NaN             NaN             NaN
# 29            NaN             NaN             NaN
# 30            NaN             NaN             NaN
# 31            NaN             NaN             NaN
# 32            NaN             NaN             NaN
# 33            NaN             NaN             NaN
#
# [34 rows x 22 columns]

# %%
def  insert_general_info(df,ent_type,create):
    if create:
        for index,i in df.iterrows():
            df.internal_id_key[index]=str(uuid.uuid4())
            df.stix_id_key[index]=ent_type+'--'+str(uuid.uuid4())
            df.stix_label[index]='NA'
            df.entity_type[index]=ent_type
            df.created=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.created_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.created_at_day=(datetime.now()).strftime("%Y-%m-%d")
            df.created_at_month=(datetime.now()).strftime("%Y-%m")
            df.created_at_year=(datetime.now()).strftime("%Y")
            df.modified=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.updated_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.revoked=False
            df.object_status='NA'
    else:
            df.modified=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.updated_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
    return df

# %%
result=insert_general_info(df=df,ent_type='Incident',create=True)
result.fillna('NA',inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
result
# Out:
#                          internal_id_key  \
# 0   e0e4b85d-f898-4390-93ac-ee282b7686d1
# 1   da9abab1-c54b-44ad-a58c-3238dba9cb34
# 2   a895e70d-22f8-45ba-b6e6-778c5dd9f876
# 3   dc368b01-1a28-4ab5-a9f8-f7513a61d945
# 4   06fa50bf-fad5-4bb2-9af1-be79abc6a832
# 5   1ec8e726-147a-4a15-aa3a-46e36eb8c04a
# 6   9a178636-1005-4af5-ae48-30812f8bfc30
# 7   4b2c02ce-be73-4f6b-a209-4cf5282828e1
# 8   befcf322-051a-4307-95dc-8ff8bed2b568
# 9   5902f8fb-e6d5-4124-bdf2-debbde68f637
# 10  840da94c-af54-47af-a264-49f5e1fdb815
# 11  bd0d1f5c-2799-419e-812e-3b140413a779
# 12  e36eaba0-a4d1-4131-bb5e-1e2dcaa4ba69
# 13  b3d44c7e-ad40-4ed9-bb33-ee7cdd66f073
# 14  16016785-681a-40cf-b97c-83038be8d9e6
# 15  7afd1579-668f-41c0-8aae-4ff6c149da63
# 16  53b6cd11-cc18-41c8-be18-5e14860f2f86
# 17  eefe0eb9-fe06-44f2-a3d7-2e7533e860b7
# 18  e80709b5-0a4d-40b4-a28f-8e3f6babc824
# 19  f2a4cfca-2887-4bfe-a94d-ba5c5a95c3e5
# 20  4faa22db-e296-433e-a532-b19020335815
# 21  d30f6820-dcf2-499b-af37-b779c930afcc
# 22  a53e1896-e248-44f5-a64f-d41cce61c23b
# 23  f9ad8f18-0ac8-4bff-b0f0-554605b5f987
# 24  2184be76-ee23-44ea-a64d-711039210781
# 25  7555e548-8dc0-40b0-bdca-c1ba5c04bb81
# 26  29a06f93-85b0-43df-8b73-90ea9c91075f
# 27  2cebdf10-3420-4987-acaa-e538d1e4af8f
# 28  e251d217-c2e8-4545-81de-b5e6dba43410
# 29  1d17b90f-c457-46cd-b39f-f42829ac0369
# 30  2cd36e42-ee32-489c-801b-95949c88bc22
# 31  f2476283-7470-4c03-b622-4f6e4f560c3c
# 32  b006a13d-9089-4994-8615-ed66ce9934db
# 33  d27a2d7d-ca0f-4ef2-8725-df17edc2d935
#
#                                        stix_id_key stix_label entity_type  \
# 0   Incident--60409953-e970-43c9-b327-21da931f2a1c         NA    Incident
# 1   Incident--11ddbed5-652b-4c5d-bc5f-4fc14590100d         NA    Incident
# 2   Incident--9fa39f27-3a7d-44d5-b506-5dab3a5160c5         NA    Incident
# 3   Incident--f765749b-07a5-4d21-b4dc-16786ca5823f         NA    Incident
# 4   Incident--b10ae161-27ea-4f0c-97af-ac6a6e5d0512         NA    Incident
# 5   Incident--292e1257-d73b-4ad3-8c75-da74a3722be4         NA    Incident
# 6   Incident--f35174da-25ac-47b8-929b-72c6f196d474         NA    Incident
# 7   Incident--66a728c0-8133-40ec-87ab-f517112fcce1         NA    Incident
# 8   Incident--9fa31b50-3047-4449-a835-8c444afd25c0         NA    Incident
# 9   Incident--81aef891-bb4e-436c-9bf4-6d1587ae6983         NA    Incident
# 10  Incident--ee9610de-2f25-4a3f-911c-713091ddf027         NA    Incident
# 11  Incident--7493d666-06e4-4c6d-9dbd-e9eb829e88ed         NA    Incident
# 12  Incident--d61b3029-14df-42e1-a6e8-515a1eeb7fec         NA    Incident
# 13  Incident--d935e668-2845-4598-b346-98e2f2f9784d         NA    Incident
# 14  Incident--c72c4c19-0094-4e26-b0a0-2f2fdc19780e         NA    Incident
# 15  Incident--961845a1-6193-4d81-8c25-478f6f23fe7e         NA    Incident
# 16  Incident--439bd918-033c-4482-ade9-d29f9810fe5d         NA    Incident
# 17  Incident--3cac1b4e-df73-4ba0-b66e-97bd6e72bf5d         NA    Incident
# 18  Incident--99d9149a-1307-4283-bba5-822b16d3dacd         NA    Incident
# 19  Incident--de82dabb-27ab-40c3-94fd-f1a4879c534a         NA    Incident
# 20  Incident--0138eac4-9490-45cd-bdb6-6b4a4c907b40         NA    Incident
# 21  Incident--14bbd5be-efba-4d36-99f5-eb4f219a2f55         NA    Incident
# 22  Incident--1f0147b0-3af2-46bf-9957-0bf869e1b35d         NA    Incident
# 23  Incident--603ea3fa-4bf6-4a62-81e8-c16c161d3087         NA    Incident
# 24  Incident--d017e407-8926-4ceb-b51b-a6d31a09126c         NA    Incident
# 25  Incident--4efb1c53-0a4d-4afe-9f76-6647ef5b5148         NA    Incident
# 26  Incident--0337e2eb-135b-470f-85a7-dda2f8373740         NA    Incident
# 27  Incident--9efb5ceb-4d6b-4e50-ae98-040d9e571c5b         NA    Incident
# 28  Incident--4001c2d4-f03c-4b6c-a5aa-d8a2bf1415ef         NA    Incident
# 29  Incident--ac45b3bb-c683-4f54-a52d-8f35a52011e2         NA    Incident
# 30  Incident--af7a0b21-429a-4ade-bd8b-0a8f54c29760         NA    Incident
# 31  Incident--a82a53fc-11cb-4285-85f4-e46d531ed817         NA    Incident
# 32  Incident--5882efc2-d086-4912-9840-fb237865cae8         NA    Incident
# 33  Incident--449f54cb-e7fd-4a09-9e8a-647b8d2e76de         NA    Incident
#
#                 created             modified  revoked object_status  \
# 0   2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 1   2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 2   2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 3   2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 4   2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 5   2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 6   2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 7   2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 8   2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 9   2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 10  2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 11  2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 12  2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 13  2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 14  2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 15  2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 16  2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 17  2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 18  2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 19  2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 20  2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 21  2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 22  2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 23  2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 24  2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 25  2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 26  2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 27  2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 28  2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 29  2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 30  2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 31  2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 32  2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
# 33  2020-01-10T14:12:14  2020-01-10T14:12:14    False            NA
#
#              created_at created_at_day  ...           updated_at  \
# 0   2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 1   2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 2   2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 3   2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 4   2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 5   2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 6   2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 7   2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 8   2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 9   2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 10  2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 11  2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 12  2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 13  2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 14  2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 15  2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 16  2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 17  2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 18  2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 19  2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 20  2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 21  2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 22  2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 23  2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 24  2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 25  2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 26  2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 27  2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 28  2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 29  2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 30  2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 31  2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 32  2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
# 33  2020-01-10T14:12:14     2020-01-10  ...  2020-01-10T14:12:14
#
#                                             objective           first_seen  \
# 0    APT12 with suspected ties to the People’s Rep...  2013-01-01 00:00:00
# 1   APT12 since at least 2003, when Chinese hacker...  1905-07-06 00:00:00
# 2   The IXESHE attackers have been actively launch...  2009-07-01 00:00:00
# 3   Once the malicious file was downloaded and ext...  1905-07-03 00:00:00
# 4   Breach of The New York Times“For the last four...  2012-10-01 00:00:00
# 5   APT12 utilizing RIPTIDE, a proxy-aware backdoo...  2012-10-01 00:00:00
# 6   spear phish email sent to a Taiwanese governme...  2014-08-24 00:00:00
# 7   On Monday August 25, 2014 observed a different...  2014-08-25 00:00:00
# 8   blackOasis attack begins with the delivery of ...  2016-05-10 00:00:00
# 9   BlackOasis attack begins with the delivery of ...  2017-10-01 00:00:00
# 10  Leveraging data from Kaspersky Security Networ...  2015-06-01 00:00:00
# 11  FireEye recently detected a malicious Microsof...  2017-09-01 00:00:00
# 12  Kaspersky Lab’s advanced exploit prevention\ns...  2017-10-01 00:00:00
# 13   The first attack conducted by the Cobalt grou...  2016-06-01 00:00:00
# 14   ATM heist at the First Commercial Bank in Taiwan  2016-07-01 00:00:00
# 15  ATM heist at the Government Saving Bank in Tha...  2016-08-01 00:00:00
# 16  A massive spear-phishing campaign \nbegan targ...  2017-11-01 00:00:00
# 17  Spear-phishing attacks to Russian banks\nThe e...  2018-01-01 00:00:00
# 18  Cobalt cyberattack on the leading banks of Rus...  2018-05-23 00:00:00
# 19  Concerns over Russian espionage litter today’s...                 2016
# 20  \nThe BfV said a hacker group thought to work ...                 2014
# 21  cyber-attack which crippled a French televisio...  2015-04-01 00:00:00
# 22  Russian hackers backed by Moscow have been car...  2015-08-01 00:00:00
# 23  \nU.S. military wives’ death threats\nFive mil...  2015-02-10 00:00:00
# 24  Recently detected a limited APT campaign explo...  2015-04-13 00:00:00
# 25  \nEliot Higgins and other journalists associat...  2015-10-01 00:00:00
# 26  \nThe group targeted the Dutch Safety Board, t...  2015-10-01 00:00:00
# 27  Fancy Bear carried out spear-phishing attacks ...  2016-06-01 00:00:00
# 28  The Sofacy group, also known as APT28, is a we...  2016-05-28 00:00:00
# 29  Phishing emails sent to users of its database ...  2016-08-01 00:00:00
# 30  The global reach that coincided with this focu...  2016-10-01 00:00:00
# 31  GAMEFISH backdoor\nThey took advantage of the ...                 2017
# 32  In February 2017, the General Intelligence and...  2017-02-01 00:00:00
# 33  The officials of International Association of ...  2017-02-21 00:00:00
#
#    first_seen_day first_seen_month first_seen_year            last_seen  \
# 0              NA               NA              NA                   NA
# 1              NA               NA              NA                   NA
# 2              NA               NA              NA                   NA
# 3              NA               NA              NA                   NA
# 4              NA               NA              NA                   NA
# 5              NA               NA              NA  2014-05-01 00:00:00
# 6              NA               NA              NA                   NA
# 7              NA               NA              NA                   NA
# 8              NA               NA              NA                   NA
# 9              NA               NA              NA                   NA
# 10             NA               NA              NA                   NA
# 11             NA               NA              NA                   NA
# 12             NA               NA              NA                   NA
# 13             NA               NA              NA                   NA
# 14             NA               NA              NA                   NA
# 15             NA               NA              NA                   NA
# 16             NA               NA              NA                   NA
# 17             NA               NA              NA                   NA
# 18             NA               NA              NA  2018-10-01 00:00:00
# 19             NA               NA              NA                 2016
# 20             NA               NA              NA                 2015
# 21             NA               NA              NA  2015-04-01 00:00:00
# 22             NA               NA              NA                   NA
# 23             NA               NA              NA  2015-02-10 00:00:00
# 24             NA               NA              NA  2015-04-13 00:00:00
# 25             NA               NA              NA                   NA
# 26             NA               NA              NA                   NA
# 27             NA               NA              NA                   NA
# 28             NA               NA              NA                   NA
# 29             NA               NA              NA                   NA
# 30             NA               NA              NA                   NA
# 31             NA               NA              NA                   NA
# 32             NA               NA              NA                   NA
# 33             NA               NA              NA                   NA
#
#    last_seen_day last_seen_month last_seen_year
# 0             NA              NA             NA
# 1             NA              NA             NA
# 2             NA              NA             NA
# 3             NA              NA             NA
# 4             NA              NA             NA
# 5             NA              NA             NA
# 6             NA              NA             NA
# 7             NA              NA             NA
# 8             NA              NA             NA
# 9             NA              NA             NA
# 10            NA              NA             NA
# 11            NA              NA             NA
# 12            NA              NA             NA
# 13            NA              NA             NA
# 14            NA              NA             NA
# 15            NA              NA             NA
# 16            NA              NA             NA
# 17            NA              NA             NA
# 18            NA              NA             NA
# 19            NA              NA             NA
# 20            NA              NA             NA
# 21            NA              NA             NA
# 22            NA              NA             NA
# 23            NA              NA             NA
# 24            NA              NA             NA
# 25            NA              NA             NA
# 26            NA              NA             NA
# 27            NA              NA             NA
# 28            NA              NA             NA
# 29            NA              NA             NA
# 30            NA              NA             NA
# 31            NA              NA             NA
# 32            NA              NA             NA
# 33            NA              NA             NA
#
# [34 rows x 22 columns]

# %%
def insert_one_malware(df,session):
    if df.first_seen != 'NA':
       f=df.first_seen.strftime("%Y-%m-%dT%H:%M:%S")
       f_m=df.first_seen.strftime("%Y-%m")
       f_d=df.first_seen.strftime("%Y-%m-%d")
       f_y=df.first_seen.strftime("%Y")
    elif df.first_seen_month != 'NA':
       f_m=df.first_seen_month
    elif df.first_seen_day != 'NA':
       f_d=df.first_seen_day
    else:
       f_d=None
       f_m=None
       f=None
    if df.last_seen != 'NA':
       l=df.last_seen.strftime("%Y-%m-%dT%H:%M:%S")
       l_m=df.last_seen.strftime("%Y-%m")
       l_d=df.last_seen.strftime("%Y-%m-%d")
       l_y=df.last_seen.strftime("%Y")
    elif df.last_seen_month != 'NA':
       l_m=df.last_seen_month
    elif df.last_seen_day != 'NA':
       l_d=df.last_seen_day
    else:
       l_d=None
       l_m=None
       l_y=None
       l=None
#     aliases = list()
#     if df['alias'] != 'NA':            
#         aliases=df.alias.split('\n')

    graql_match_query = f"match $i isa Incident, " \
                        f"has objective \"{df['objective']}\"; " \
                        f"get;"
    # print(graql_match_query)
    with session.transaction().read() as read_transaction:
        # read_transaction.query(graql_match_query)
        answer_iterator = None
        answer_iterator = read_transaction.query(graql_match_query, infer=True)
        data = answer_iterator.collect_concepts()
                
        if len(data) > 0:
            # Update data.
            # Columns to be updated: object_status, revoked, updated_at, modified, description, alias
            # print("Update intrusion-set...")
            print("Update: " + df['name'])
            graql_attribute_delete_query = f"match $i isa Incident, " \
                                           f"has objective \"{df['objective']}\", "\
                                           f"delete $i;"
            update_flg = False
            first_attr_flg = True
            graql_attribute_update_query = f"match $i isa Incident, " \
                                           f"has objective \"{df['objective']}\"; insert $i"
            
            graql_attribute_update_query += ";"
            print(graql_attribute_update_query)
            if update_flg:
                with session.transaction().write() as write_transaction:
                    # make a write transection with the query
                    write_transaction.query(graql_attribute_delete_query)
                    write_transaction.query(graql_attribute_update_query)
                    # remember to commit at the end
                    write_transaction.commit()           
        else:
            # print("Insert intrusion-set...")
            print("Insert: " + df['name'])
            graql_insert_query = f"insert $x isa Incident, " \
                                 f"has internal_id_key \"{df['internal_id_key']}\", " \
                                 f"has stix_id_key \"{df['stix_id_key']}\", " \
                                 f"has stix_label \"{df['stix_label']}\", " \
                                 f"has entity_type \"{df['entity_type']}\", " \
                                 f"has created {df['created']}, " \
                                 f"has revoked \"{df['revoked']}\", "\
                                 f"has created_at {df['created_at']}, " \
                                 f"has created_at_day \"{df['created_at_day']}\", " \
                                 f"has created_at_month \"{df['created_at_month']}\", " \
                                 f"has created_at_year \"{df['created_at_year']}\", "\
                                 f"has updated_at {df['updated_at']}, "\
                                 f"has objective \"{df['objective']}\" "
            
                          
    
            if f is not None:
                graql_insert_query += f", has first_seen {f} "
                first_attr_flg = False
            if f_d is not None:
                graql_insert_query += f", has first_seen_day \"{f_d}\" "
                first_attr_flg = False
            if f_m is not None:
                graql_insert_query += f", has first_seen_month \"{f_m}\" "
                first_attr_flg = False
            if f_y is not None:
                graql_insert_query += f", has first_seen_month \"{f_y}\" "
                first_attr_flg = False
            if f_y is not None:
                graql_insert_query += f", has first_seen_year \"{df['first_seen_year']}\""
                first_attr_flg = False
            if l is not None:
                graql_insert_query += f", has first_seen {l} "
                first_attr_flg = False
            if f_d is not None:
                graql_insert_query += f", has first_seen_day \"{l_d}\" "
                first_attr_flg = False
            if l_m is not None:
                graql_insert_query += f", has first_seen_month \"{l_m}\" "
                first_attr_flg = False
            if l_y is not None:
                graql_insert_query += f", has first_seen_month \"{l_y}\" "
                first_attr_flg = False
            if l is not None:
                graql_insert_query += f", has first_seen_year \"{df['last_seen_year']}\""
                first_attr_flg = False
                
            if  not first_attr_flg:
                first_attr_flg += ","
            graql_insert_query += ";"
            print(graql_insert_query)
#             with session.transaction().write() as write_transaction:
#                 # make a write transection with the query
#                 write_transaction.query(graql_insert_query)
#                 # remember to commit at the end
#                 write_transaction.commit()

# %%
def load_data_into_grakn(session,input_df):
    print("Malware...")
    # using progress_apply instead of apply so we have a progress bar form tqdm
    # input_df.progress_apply(insert_one_intrusion_set, axis=1, session=session)
    print("Malware...")
    for index,row in input_df.iterrows():
        insert_one_malware(df=row,session=session)

# %%
def build_grakn_graph(input_df, keyspace_name):
    with GraknClient(uri="192.168.83.128:48555") as client:
        with client.session(keyspace = keyspace_name) as session:
            load_data_into_grakn(session,input_df)

# %%
build_grakn_graph(input_df=result,keyspace_name='grakn_new')
# Out:
# Malware...
# Malware...
# Insert: Ixeshe
# Insert: Aumlib
# Insert: Threebyte
# Insert: Hightide
# Insert: Waterspout
# Insert: Coblnt
# Insert: More_eggs
# Insert: Carbanak
# Insert:  PetrWrap
# Insert: Finspy
# Insert: Finfisher
# Insert: wingbird
# Insert: ADVSTORESHELL
# Insert: Cannon
# Insert: CHOPSTICK
# Insert: CORESHELL
# Insert: Downdelph
# Insert: Fysbis
# Insert: JHUHUGIT
# Insert: HIDEDRV
# Insert: Komplex
# Insert: LoJax
# Insert: XAgentOSX
# Insert: XTunnel
# Insert: Zebrocy
# Insert: Backspace
# Insert: Flashflood
# Insert: spaceship
# Insert: Neteagle
# Insert: shipspace
