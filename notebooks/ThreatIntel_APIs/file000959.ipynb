# %%
import datetime
from pycti import OpenCTIApiClient
from dateutil.parser import parse
import pandas as pd
import os
import warnings

# %%
api_url = "https://demo.opencti.io"
api_token = "609caced-7610-4c84-80b4-f3a380d1939b"

# OpenCTI initialization
opencti_api_client = OpenCTIApiClient(api_url, api_token)
# Out:
# INFO:root:Listing Threat-Actors with filters null.

# %%
opencti_api_client.report.list(first=5)
# Out:
# INFO:root:Listing Reports with filters null.
# [{'id': '627715ba-e96f-436a-a367-07999f101e99',
#   'stix_id_key': 'report--044fa34f-5ee1-4837-bcf2-0f913c1bfb21',
#   'entity_type': 'report',
#   'stix_label': None,
#   'name': 'OSINT - Spam Warns about Boeing 737 Max Crashes While Pushing Malware',
#   'alias': [''],
#   'description': 'OSINT - Spam Warns about Boeing 737 Max Crashes While Pushing Malware',
#   'report_class': 'MISP event',
#   'published': '2019-03-16T00:00:00.000Z',
#   'object_status': 2,
#   'source_confidence_level': 1,
#   'graph_data': '',
#   'created': '2020-01-25T08:29:32.289Z',
#   'modified': '2020-01-25T08:29:32.289Z',
#   'created_at': '2020-01-27T04:18:17.804Z',
#   'updated_at': '2020-01-27T04:18:17.804Z',
#   'createdByRef': {'id': '2e0562f3-a790-4b18-9696-8a602d29d380',
#    'entity_type': 'organization',
#    'stix_id_key': 'identity--65a61e6d-d108-44b6-86cb-a60c585d1e5a',
#    'stix_label': None,
#    'name': 'CIRCL',
#    'alias': [''],
# ...

# %%
a=opencti_api_client.report.add_stix_entity(id='e2c8cca1-4fd0-4c71-a7af-5a8d5eb53759',entity_id = '2efae4f2-656c-4adc-8071-f5c487a44389')
# Out:
# INFO:root:Reading Report {e2c8cca1-4fd0-4c71-a7af-5a8d5eb53759}.

# %%
a
# Out:
# True

# %%
opencti_api_client.report.add_stix_entity(id='9d5466f1-6de1-4339-b2e6-2541b7942d72',entity_id = '73684dcd-d550-475b-bebd-e5330bdbc88e')
# Out:
# INFO:root:Reading Report {9d5466f1-6de1-4339-b2e6-2541b7942d72}.
# INFO:root:Adding Stix-Entity {73684dcd-d550-475b-bebd-e5330bdbc88e} to Report {9d5466f1-6de1-4339-b2e6-2541b7942d72}
# True
