# %%
import pandas as pd
import uuid
from datetime import datetime
import numpy as np
from grakn.client import GraknClient
from tqdm import tqdm
tqdm.pandas()

# %%
df=pd.read_excel(r"C:\Users\SRIKANTH\Desktop\OpentCti_data.xlsx",sheet_name='Course-Of-Action')

# %%
df.keys()
# Out:
# Index(['internal_id_key', 'stix_id_key', 'stix_label', 'entity_type',
#        'created', 'modified', 'revoked', 'object_status', 'created_at',
#        'created_at_day', 'created_at_month', 'created_at_year', 'updated_at',
#        'name', 'description', 'alias', 'graph_data', 'external_references ',
#        'object_marking_refs', 'granular_markings'],
#       dtype='object')

# %%
def  insert_general_info(df,ent_type,create):
    if create:
        for index,i in df.iterrows():
            df.internal_id_key[index]=str(uuid.uuid4())
            df.stix_id_key[index]=ent_type+'--'+str(uuid.uuid4())
            df.stix_label[index]='NA'
            df.entity_type[index]=ent_type
            df.created=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.created_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.created_at_day=(datetime.now()).strftime("%Y-%m-%d")
            df.created_at_month=(datetime.now()).strftime("%Y-%m")
            df.created_at_year=(datetime.now()).strftime("%Y")
            df.modified=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.updated_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.revoked=False
            df.object_status='NA'
    else:
            df.modified=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.updated_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
    return df

# %%
result=insert_general_info(df=df,ent_type='Malware',create=True)
result.fillna('NA',inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\SRIKANTH\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
result
# Out:
#                          internal_id_key  \
# 0   fe38026d-72f2-4dfa-8971-a52944e50bc0
# 1   e9f2806f-248f-4a1b-97f0-5372312129e2
# 2   814c057c-6acf-4d26-a363-14e2168a2005
# 3   2d4ff5a5-cbd3-4ded-8987-9223daf44c3a
# 4   92d4042f-fe02-4501-a635-1996f63d4a6d
# 5   2eec4be0-8d51-4965-929c-41170155bd25
# 6   855513fd-7ff7-442d-9456-c0796c144ad8
# 7   49a9961c-958e-4504-b32e-4eacf5c00b3e
# 8   84d56e9d-18be-424a-a417-0e59300e3954
# 9   d4ee70d5-a03b-4e9f-b644-30c632da5dc4
# 10  50611c3e-a9e3-401a-ab30-34a8458700c1
# 11  e28f168d-7737-41b5-9220-1e93350ddee8
# 12  563a53fe-6b0e-4931-8611-fd076b481df4
# 13  60c0e3b6-9a7c-4da0-95aa-c689123920e7
# 14  5cf9fcd8-e9b7-495f-b1d7-d2d5cd049116
# 15  1b0a14cf-7e4e-4d7d-a91f-1721c457b775
# 16  f865aeac-3669-458d-b2c8-6453c3c410e5
# 17  8c05a409-6c58-4489-9b93-8ce0eaa57faf
# 18  88847f61-f938-4028-bccb-a6cd03f97434
# 19  76b91d28-1ff4-4e81-bdcf-dfa7af6ac220
# 20  9d2e1b2f-b4a4-4198-91ff-834ec9d80318
# 21  d6f7177b-1ffa-415f-bf1e-13f440229b44
# 22  a1c9400f-d69a-441a-b629-e42ecaa304a2
# 23  71e0ef28-3412-4680-8051-d5b17d9a66d9
# 24  3f32b38d-1aac-4efc-aefd-9cba9d47cd54
# 25  e21b314b-01ed-41d3-8d52-acd404b8de54
# 26  5e5972cd-eeb7-4e1c-9793-b4f80a2a6d67
# 2           NA    NA         NA                   NA                  NA
# 3           NA    NA         NA                   NA                  NA
# 4           NA    NA         NA                   NA                  NA
# 5           NA    NA         NA                   NA                  NA
# 6           NA    NA         NA                   NA                  NA
# 7           NA    NA         NA                   NA                  NA
# 8           NA    NA         NA                   NA                  NA
# 9           NA    NA         NA                   NA                  NA
# 10          NA    NA         NA                   NA                  NA
# 11          NA    NA         NA                   NA                  NA
# 12          NA    NA         NA                   NA                  NA
# 13          NA    NA         NA                   NA                  NA
# 14          NA    NA         NA                   NA                  NA
# 15          NA    NA         NA                   NA                  NA
# 16          NA    NA         NA                   NA                  NA
# 17          NA    NA         NA                   NA                  NA
# 18          NA    NA         NA                   NA                  NA
# 19          NA    NA         NA                   NA                  NA
# 20          NA    NA         NA                   NA                  NA
# 21          NA    NA         NA                   NA                  NA
# 22          NA    NA         NA                   NA                  NA
# 23          NA    NA         NA                   NA                  NA
# 24          NA    NA         NA                   NA                  NA
# 25          NA    NA         NA                   NA                  NA
# 26          NA    NA         NA                   NA                  NA
# 27          NA    NA         NA                   NA                  NA
# 28          NA    NA         NA                   NA                  NA
# 29          NA    NA         NA                   NA                  NA
# ..         ...   ...        ...                  ...                 ...
# 45          NA    NA         NA                   NA                  NA
# 46          NA    NA         NA                   NA                  NA
# 47          NA    NA         NA                   NA                  NA
# 48          NA    NA         NA                   NA                  NA
# 49          NA    NA         NA                   NA                  NA
# 50          NA    NA         NA                   NA                  NA
# 51          NA    NA         NA                   NA                  NA
# 52          NA    NA         NA                   NA                  NA
# 53          NA    NA         NA                   NA                  NA
# 54          NA    NA         NA                   NA                  NA
# 55          NA    NA         NA                   NA                  NA
# 56          NA    NA         NA                   NA                  NA
# 57          NA    NA         NA                   NA                  NA
# 58          NA    NA         NA                   NA                  NA
# 59          NA    NA         NA                   NA                  NA
# 60          NA    NA         NA                   NA                  NA
# 61          NA    NA         NA                   NA                  NA
# 62          NA    NA         NA                   NA                  NA
# 63          NA    NA         NA                   NA                  NA
# 64          NA    NA         NA                   NA                  NA
# 65          NA    NA         NA                   NA                  NA
# 66          NA    NA         NA                   NA                  NA
# 67          NA    NA         NA                   NA                  NA
# 68          NA    NA         NA                   NA                  NA
# 69          NA    NA         NA                   NA                  NA
# 70          NA    NA         NA                   NA                  NA
# 71          NA    NA         NA                   NA                  NA
# 72          NA    NA         NA                   NA                  NA
# 73          NA    NA         NA                   NA                  NA
# 74          NA    NA         NA                   NA                  NA
#
#    granular_markings
# 0                 NA
# 1                 NA
# 2                 NA
# 3                 NA
# 4                 NA
# 5                 NA
# 6                 NA
# 7                 NA
# 8                 NA
# 9                 NA
# 10                NA
# 11                NA
# 12                NA
# 13                NA
# 14                NA
# 15                NA
# 16                NA
# 17                NA
# 18                NA
# 19                NA
# 20                NA
# 21                NA
# 22                NA
# 23                NA
# 24                NA
# 25                NA
# 26                NA
# 27                NA
# 28                NA
# 29                NA
# ..               ...
# 45                NA
# 46                NA
# 47                NA
# 48                NA
# 49                NA
# 50                NA
# 51                NA
# 52                NA
# 53                NA
# 54                NA
# 55                NA
# 56                NA
# 57                NA
# 58                NA
# 59                NA
# 60                NA
# 61                NA
# 62                NA
# 63                NA
# 64                NA
# 65                NA
# 66                NA
# 67                NA
# 68                NA
# 69                NA
# 70                NA
# 71                NA
# 72                NA
# 73                NA
# 74                NA
#
# [75 rows x 20 columns]

# %%
def insert_one_Course_Of_Action(df,session):
    #if df.first_seen != 'NA':
     #   f=df.first_seen.strftime("%Y-%m-%dT%H:%M:%S")
     #   f_m=df.first_seen.strftime("%Y-%m")
     #   f_d=df.first_seen.strftime("%Y-%m-%d")
    #elif df.first_seen_month != 'NA':
    #    f_m=df.first_seen_month
    #elif df.first_seen_day != 'NA':
    #    f_d=df.first_seen_day
    #else:
    #    f_d=None
    #    f_m=None
    #    f=None
    aliases = list()
    if df['alias'] != 'NA':            
        aliases=df.alias.split('\n')

    graql_match_query = f"match $i isa Course-Of-Action,"\
                        f"has name \"{df['name']}\"; " \
                        f"get;"
    # print(graql_match_query)
    with session.transaction().read() as read_transaction:
        # read_transaction.query(graql_match_query)
        answer_iterator = None
        answer_iterator = read_transaction.query(graql_match_query, infer=True)
        data = answer_iterator.collect_concepts()
                
        if len(data) > 0:
            # Update data.
            # Columns to be updated: object_status, revoked, updated_at, modified, description, alias
            # print("Update intrusion-set...")
            print("Update: " + df['name'])
            graql_attribute_delete_query = f"match $i isa Course-Of-Action,"\
                                           f"has name \"{df['name']}\", "\
                                           f"has alias $a via $i1, "\
                                           f"has description $a via $i2; "\
                                           f"delete $i1, $i2;"
            update_flg = False
            first_attr_flg = True
            graql_attribute_update_query = f"match $i isa Course-Of-Action, "\
                                           f"has name \"{df['name']}\"; insert $i,"
            if df['description'] != 'NA':
                # graql_attribute_delete_query += f" has description $a via $i2; "\
                graql_attribute_update_query += f" has description \"{df['description']}\" "
                if first_attr_flg:
                    graql_attribute_update_query += ","
                update_flg = True
                first_attr_flg = False
            if len(aliases) > 0:
                s = "|"
                graql_attribute_update_query += f" has alias \"{s.join(aliases).replace(' ','')}\" " 
#                 if first_attr_flg:
#                     graql_attribute_update_query += ","
                update_flg = True
                first_attr_flg = False
            graql_attribute_update_query += ";"
            print(graql_attribute_update_query)
            if update_flg:
                with session.transaction().write() as write_transaction:
                    # make a write transection with the query
                    write_transaction.query(graql_attribute_delete_query)
                    write_transaction.query(graql_attribute_update_query)
                    # remember to commit at the end
                    write_transaction.commit()           
        else:
            # print("Insert intrusion-set...")
            print("Insert: " + df['name'])
            graql_insert_query = f"insert $x isa Course-Of-Action, " \
                                 f"has internal_id_key \"{df['internal_id_key']}\", " \
                                 f"has stix_id_key \"{df['stix_id_key']}\", " \
                                 f"has stix_label \"{df['stix_label']}\", " \
                                 f"has entity_type \"{df['entity_type']}\", " \
                                 f"has created {df['created']}, " \
                                 f"has revoked \"{df['revoked']}\", "\
                                 f"has created_at {df['created_at']}, " \
                                 f"has created_at_day \"{df['created_at_day']}\", " \
                                 f"has created_at_month \"{df['created_at_month']}\", " \
                                 f"has created_at_year \"{df['created_at_year']}\", "\
                                 f"has updated_at {df['updated_at']}, "\
                                 f"has name \"{df['name'].strip()}\" "
                                 
            if df['description'] != 'NA':
                graql_insert_query += f", has description \"{df['description']}\" "
            if len(aliases) > 0:
                s = "|"
                graql_insert_query += f", has alias \"{s.join(aliases)}\" "
            #if f is not None:
            #    graql_insert_query += f", has first_seen {f} "
            #if f_d is not None:
            #    graql_insert_query += f", has first_seen_day \"{f_d}\" "
            #if f_m is not None:
             #   graql_insert_query += f", has first_seen_month \"{f_m}\" "
            #if f_m is not None:
            #    graql_insert_query += f", has first_seen_year \"{df['first_seen_year']}\""
            graql_insert_query += ";"
            print(graql_insert_query)
            with session.transaction().write() as write_transaction:
                # make a write transection with the query
                write_transaction.query(graql_insert_query)
                # remember to commit at the end
                write_transaction.commit()

# %%
def load_data_into_grakn(session,input_df):
    print("Mitigation...")
    # using progress_apply instead of apply so we have a progress bar form tqdm
    # input_df.progress_apply(insert_one_intrusion_set, axis=1, session=session)
    print("Mitigation...")
    for index,row in input_df.iterrows():
        insert_one_Course_Of_Action(df=row,session=session)

# %%
def build_grakn_graph(input_df, keyspace_name):
    with GraknClient(uri="192.168.83.128:48555") as client:
        with client.session(keyspace = keyspace_name) as session:
            load_data_into_grakn(session,input_df)

# %%
build_grakn_graph(input_df=result,keyspace_name='grakn')
# Out:
# Mitigation...
# Mitigation...
# Update: Privileged Account Management
# match $i isa Course-Of-Action, has name "Privileged Account Management"; insert $i,;
# Update: User Account Management
# match $i isa Course-Of-Action, has name "User Account Management"; insert $i,;
# Update: Audit
# match $i isa Course-Of-Action, has name "Audit"; insert $i,;
# Update: Encrypt Sensitive Information
# match $i isa Course-Of-Action, has name "Encrypt Sensitive Information"; insert $i,;
# Update: Restrict Web-Based Content
# match $i isa Course-Of-Action, has name "Restrict Web-Based Content"; insert $i,;
# Update: Remote Data Storage
# match $i isa Course-Of-Action, has name "Remote Data Storage"; insert $i,;
# Update: Boot Integrity
# match $i isa Course-Of-Action, has name "Boot Integrity"; insert $i,;
# Update: Execution Prevention
# match $i isa Course-Of-Action, has name "Execution Prevention"; insert $i,;
# Update: Network Intrusion Prevention
# match $i isa Course-Of-Action, has name "Network Intrusion Prevention"; insert $i,;
# Update: Network Segmentation
# match $i isa Course-Of-Action, has name "Network Segmentation"; insert $i,;
# Update: Disable or Remove Feature or Program
#
# match $i isa Course-Of-Action, has name "Disable or Remove Feature or Program
# "; insert $i,;
# Update: Operating System Configuration
# match $i isa Course-Of-Action, has name "Operating System Configuration"; insert $i,;
# Update: Active Directory Configuration
# match $i isa Course-Of-Action, has name "Active Directory Configuration"; insert $i,;
# Update: Credential Access Protection
# match $i isa Course-Of-Action, has name "Credential Access Protection"; insert $i,;
# Update: Password Policies
# match $i isa Course-Of-Action, has name "Password Policies"; insert $i,;
# Update: Privileged Process Integrity
# match $i isa Course-Of-Action, has name "Privileged Process Integrity"; insert $i,;
# Update: User Training
# match $i isa Course-Of-Action, has name "User Training"; insert $i,;
# Update: Application Isolation and Sandboxing
# match $i isa Course-Of-Action, has name "Application Isolation and Sandboxing"; insert $i,;
# Update: Behavior Prevention on Endpoint
# match $i isa Course-Of-Action, has name "Behavior Prevention on Endpoint"; insert $i,;
# Update: Software Configuration
# match $i isa Course-Of-Action, has name "Software Configuration"; insert $i,;
# Update: Multi-factor Authentication
# match $i isa Course-Of-Action, has name "Multi-factor Authentication"; insert $i,;
# Update: Exploit Protection
# match $i isa Course-Of-Action, has name "Exploit Protection"; insert $i,;
# Update: Threat Intelligence Program
# match $i isa Course-Of-Action, has name "Threat Intelligence Program"; insert $i,;
# Update: Update Software
# match $i isa Course-Of-Action, has name "Update Software"; insert $i,;
# Update: Vulnerability Scanning
# match $i isa Course-Of-Action, has name "Vulnerability Scanning"; insert $i,;
# Update: Restrict File and Directory Permissions
# match $i isa Course-Of-Action, has name "Restrict File and Directory Permissions"; insert $i,;
# Update: Antivirus/Antimalware
# match $i isa Course-Of-Action, has name "Antivirus/Antimalware"; insert $i,;
# Update: Privileged Account Management
#
# match $i isa Course-Of-Action, has name "Privileged Account Management
# "; insert $i,;
# Update: User Account Control
# match $i isa Course-Of-Action, has name "User Account Control"; insert $i,;
# Update: Code Signing
# match $i isa Course-Of-Action, has name "Code Signing"; insert $i,;
# Update: Limit Hardware Installation
# match $i isa Course-Of-Action, has name "Limit Hardware Installation"; insert $i,;
# Update: Disable or Remove Feature or Program
#
#
# match $i isa Course-Of-Action, has name "Disable or Remove Feature or Program
#
# "; insert $i,;
# Update: Restrict Web-Based Content
#
# match $i isa Course-Of-Action, has name "Restrict Web-Based Content
# "; insert $i,;
# Update: Network Segmentation
#
# match $i isa Course-Of-Action, has name "Network Segmentation
# "; insert $i,;
# Update: Application Developer Guidance
# match $i isa Course-Of-Action, has name "Application Developer Guidance"; insert $i,;
# Update: Filter Network Traffic
# match $i isa Course-Of-Action, has name "Filter Network Traffic"; insert $i,;
# Update: Restrict Registry Permissions
# match $i isa Course-Of-Action, has name "Restrict Registry Permissions"; insert $i,;
# Update: SSL/TLS Inspection
# match $i isa Course-Of-Action, has name "SSL/TLS Inspection"; insert $i,;
# Update: Disable or Remove Feature or Program
# match $i isa Course-Of-Action, has name "Disable or Remove Feature or Program"; insert $i,;
# Update: Restrict Library Loading
# match $i isa Course-Of-Action, has name "Restrict Library Loading"; insert $i,;
# Update: Limit Software Installation
# match $i isa Course-Of-Action, has name "Limit Software Installation"; insert $i,;
# Update: User Account Control
#
# match $i isa Course-Of-Action, has name "User Account Control
# "; insert $i,;
# Update: Limit Access to Resource Over Network
# match $i isa Course-Of-Action, has name "Limit Access to Resource Over Network"; insert $i,;
# Update: Active Directory Configuration
#
# match $i isa Course-Of-Action, has name "Active Directory Configuration
# "; insert $i,;
# Update: User Account Management
# match $i isa Course-Of-Action, has name "User Account Management "; insert $i,;
# Update: User Account Control
# match $i isa Course-Of-Action, has name "User Account Control	"; insert $i,;
# Update: Application Isolation and Sandboxing
# match $i isa Course-Of-Action, has name "Application Isolation and Sandboxing	"; insert $i,;
# Update:
# User Account Management
# match $i isa Course-Of-Action, has name "
# User Account Management	"; insert $i,;
# Update:
# Disable or Remove Feature or Program
# match $i isa Course-Of-Action, has name "
# Disable or Remove Feature or Program"; insert $i,;
# Update: Behavior Prevention on Endpoint
# match $i isa Course-Of-Action, has name "Behavior Prevention on Endpoint	"; insert $i,;
# Update: Privileged Account Management
# match $i isa Course-Of-Action, has name "Privileged Account Management	"; insert $i,;
# Update: Antivirus/Antimalware
# match $i isa Course-Of-Action, has name "Antivirus/Antimalware	"; insert $i,;
# Update: Network Intrusion Prevention
# match $i isa Course-Of-Action, has name "Network Intrusion Prevention	"; insert $i,;
# Update: Data Backup
# match $i isa Course-Of-Action, has name "Data Backup"; insert $i,;
# Update:
# User Account Management
# match $i isa Course-Of-Action, has name "
# User Account Management"; insert $i,;
# Update: Operating System Configuration
# match $i isa Course-Of-Action, has name "Operating System Configuration	"; insert $i,;
# Update:  Audit
# match $i isa Course-Of-Action, has name " Audit	"; insert $i,;
# Update: Execution Prevention
# match $i isa Course-Of-Action, has name "Execution Prevention	"; insert $i,;
# Update: Component Object Model and Distributed COM
# match $i isa Course-Of-Action, has name "Component Object Model and Distributed COM"; insert $i,;
# Update: Application Isolation and Sandboxing
# match $i isa Course-Of-Action, has name "Application Isolation and Sandboxing  "; insert $i,;
# Update:
# Password Policies
# match $i isa Course-Of-Action, has name "
# Password Policies"; insert $i,;
# Update: Filter Network Traffic
# match $i isa Course-Of-Action, has name "Filter Network Traffic	"; insert $i,;
# Update:  Execution Prevention
# match $i isa Course-Of-Action, has name " Execution Prevention"; insert $i,;
# Update: Update Software
# match $i isa Course-Of-Action, has name "Update Software	"; insert $i,;
# Update: User Training
# match $i isa Course-Of-Action, has name "User Training	"; insert $i,;
# Update:
# Privileged Account Management
# match $i isa Course-Of-Action, has name "
# Privileged Account Management	"; insert $i,;
# Update: User Account Management
# match $i isa Course-Of-Action, has name "User Account Management	"; insert $i,;
# Update: Disable or Remove Feature or Program
# match $i isa Course-Of-Action, has name "Disable or Remove Feature or Program	"; insert $i,;
# Update: Network Segmentation
# match $i isa Course-Of-Action, has name "Network Segmentation	"; insert $i,;
# Update:
# Active Directory Configuration
# match $i isa Course-Of-Action, has name "
# Active Directory Configuration	"; insert $i,;
# Update: Password Policies
# match $i isa Course-Of-Action, has name "Password Policies	"; insert $i,;
# Update: Data Backup
# match $i isa Course-Of-Action, has name "Data Backup	"; insert $i,;
# Update: Application Vetting
# match $i isa Course-Of-Action, has name "Application Vetting"; insert $i,;
# Update: Security Updates
# match $i isa Course-Of-Action, has name "Security Updates"; insert $i,;
# Update: Use Recent OS Version
# match $i isa Course-Of-Action, has name "Use Recent OS Version"; insert $i,;
