# %%
import pandas as pd
import uuid
from datetime import datetime
import numpy as np
from grakn.client import GraknClient
from tqdm import tqdm
tqdm.pandas()

# %%
#df=pd.read_excel(r"C:\Users\SRIKANTH\Desktop\OpenCTI_Data.xlsx",sheet_name='intrusion-set')
int_uses_mal=pd.read_excel(r"D:\Threat_intel_services\APT_collections\relation\intrusion\intrusion-malware.xlsx")
#int_targets_vul=pd.read_excel(r"D:\Threat_intel_services\APT_collections\relation\intrusion\intrusion-vulnerability.xlsx")

# %%
def  insert_general_info(df,ent_type,create):
    if create:
        for index,i in df.iterrows():
            df.internal_id_key[index]=str(uuid.uuid4())
            df.stix_id_key[index]=ent_type+'--'+str(uuid.uuid4())
            df.stix_label[index]='NA'
            df.entity_type[index]=ent_type
            df.created=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.created_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.created_at_day=(datetime.now()).strftime("%Y-%m-%d")
            df.created_at_month=(datetime.now()).strftime("%Y-%m")
            df.created_at_year=(datetime.now()).strftime("%Y")
            df.modified=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.updated_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.revoked=False
            df.object_status='NA'
    else:
            df.modified=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.updated_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
    return df

# %%
#result=insert_general_info(df=df,ent_type='Intrusion-set',create=True)
int_uses_mal_final=insert_general_info(df=int_uses_mal,ent_type='relationship',create=True)
#int_targets_vul_final=insert_general_info(df=int_targets_vul,ent_type='relationship',create=True)
#int_targets_vul_final.fillna('NA',inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\SRIKANTH\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
int_uses_mal_final
# Out:
#                          internal_id_key  \
# 0   cf70d34a-7ff3-4ffa-8364-7f22ce301a3e
# 1   6bd8f49e-1899-45cb-8368-a3da86f932dc
# 2   0b12b63b-66bf-4b9f-ac44-b484af734cdd
# 3   092d8767-c872-42b2-a1a8-39e0ac7a27f8
# 4   5d2fb2f9-aa37-4fc6-948c-bdfe95ec786c
# 5   6727de7a-1241-4b5e-9e51-2c96e93b5fab
# 6   8047e9af-8cbd-42c6-8e44-21cf20a0875a
# 7   2f2dd06c-2d82-40ff-bd4a-5e2e6c26468b
# 8   7ce47283-54f4-4bd6-9dc5-8a52f6b9ad53
# 9   0240cb4a-f101-401f-82f0-cbe1b9f0cad8
# 10  593a0ea3-11a4-484d-b800-5337fb7d655f
# 11  648bdcb5-c690-4b8b-90be-d5a697015674
# 12  f7bb3984-64d4-4446-b227-b0609735f7ec
# 13  1024c526-b0d0-4dbb-8cf1-c8a262ff0288
# 14  cfcddc5f-6143-46c3-8977-e49bd531c78a
# 15  62900622-9f09-4d79-b806-6b08a94c0fe8
# 16  e20afc54-4111-4b72-9b1c-4d7c949f4989
# 17  f3bf0287-3c23-4722-8203-6bff642707aa
# 18  26e63b86-0157-44b7-9663-cb79aaa56ae4
# 19  823a9ab9-fde2-4b56-98be-f7f2c85fb774
# 20  43f54d17-58c2-4475-8ef0-afc1d8c202ae
# 21  3ab3a0c7-a788-4184-95ac-b56b15e9e5f7
# 22  0ace6e54-8b10-46ba-8664-40639e9d2ae2
# 23  2ef17e05-dcf6-4b30-878f-0a066d8ec1df
# 24  87fee2f0-6065-4755-a3e7-73e5a1f569ec
# 25  d9e2b951-6f1a-4c40-950b-e252bde57d37
# 26  1d49bd88-8524-4aa8-9191-b8f5f06274be
# 27  f31dd2ce-d2a8-4526-b656-fb607bb7d04a
# 28  51e22846-5082-4e7d-bd1a-23296fe0f591
# 29  44af6a9c-20a6-4ac4-8d72-1d4a77da67c5
#
#                                           stix_id_key stix_label  \
# 0   relationship--2856b7d3-055a-4a3c-ba71-06a3dec3...         NA
# 1   relationship--1a033c13-58ba-45f0-b75c-7aacd735...         NA
# 2   relationship--293b4ea9-02c9-4a7c-a362-04a30a9e...         NA
# 3   relationship--fa8084d6-490c-4077-a70a-786f52e4...         NA
# 4   relationship--a1f4473c-18cd-45de-b730-87df595a...         NA
# 5   relationship--46489454-251a-4290-b5fa-7b3c68f3...         NA
# 6   relationship--564ca1d9-f789-4ab4-bd59-4dabfe2a...         NA
# 7   relationship--14bfc752-c7b8-436d-9e31-ad202c47...         NA
# 8   relationship--a143a537-63a8-4415-a655-826f6207...         NA
# 9   relationship--1aa88e36-5da2-4962-a609-35242580...         NA
# 10  relationship--43bf4494-938b-4faf-92c8-6f8227c1...         NA
# 11  relationship--0ed8bb2f-d404-4765-954b-654fa839...         NA
# 12  relationship--e23d1ff8-16a4-4bdf-bf07-8e440fc4...         NA
# 13  relationship--3e6f0934-f673-4270-95f6-7cb3c2ea...         NA
# 14  relationship--c0219ddf-eeff-49d3-abe8-9a11c78b...         NA
# 15  relationship--6d94fa23-08bd-4e63-a274-e2f7413e...         NA
# 16  relationship--f8735bd9-f607-4b2d-b641-fe223ba1...         NA
# 17  relationship--6893527e-f97f-4ce7-8b34-52b522f8...         NA
# 18  relationship--f1a692f7-adad-49a2-8cb4-a3e4706f...         NA
# 19  relationship--0e93e20a-ee24-43b4-9302-7a47af88...         NA
# 20  relationship--41469d9e-9544-4563-baf0-f7220e3e...         NA
# 21  relationship--b94bc4dd-0eba-40a5-80de-847f73af...         NA
# 22  relationship--ee12ff3a-0408-456c-a3c3-56aa80bd...         NA
# 23  relationship--87fe6e9b-06b1-41d2-bf20-b5c1c02f...         NA
# 24  relationship--0e6c9817-9007-4358-bd9d-b9345d5c...         NA
# 25  relationship--1b493190-a8f6-4acb-93d6-aa933fb9...         NA
# 26  relationship--47ca3d2d-9cce-4c3d-a177-fa311c59...         NA
# 27  relationship--5f0a3a51-89db-420a-83e4-45ed30d5...         NA
# 28  relationship--ba847fad-d4ab-47bc-a36a-d656305c...         NA
# 29  relationship--9d0d66aa-af04-4c3e-bf99-39c452e1...         NA
#
#      entity_type              created             modified  revoked  \
# 0   relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 1   relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 2   relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 3   relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 4   relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 5   relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 6   relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 7   relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 8   relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 9   relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 10  relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 11  relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 12  relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 13  relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 14  relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 15  relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 16  relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 17  relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 18  relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 19  relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 20  relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 21  relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 22  relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 23  relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 24  relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 25  relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 26  relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 27  relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 28  relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
# 29  relationship  2020-01-18T13:17:12  2020-01-18T13:17:12    False
#
#    object_status           created_at created_at_day created_at_month  \
# 0             NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 1             NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 2             NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 3             NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 4             NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 5             NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 6             NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 7             NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 8             NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 9             NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 10            NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 11            NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 12            NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 13            NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 14            NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 15            NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 16            NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 17            NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 18            NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 19            NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 20            NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 21            NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 22            NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 23            NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 24            NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 25            NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 26            NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 27            NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 28            NA  2020-01-18T13:17:12     2020-01-18          2020-01
# 29            NA  2020-01-18T13:17:12     2020-01-18          2020-01
#
#    created_at_year           updated_at  Group_name   malware_name
# 0             2020  2020-01-18T13:17:12       APT12         Ixeshe
# 1             2020  2020-01-18T13:17:12       APT12         Aumlib
# 2             2020  2020-01-18T13:17:12       APT12      Threebyte
# 3             2020  2020-01-18T13:17:12       APT12       Hightide
# 4             2020  2020-01-18T13:17:12       APT12     Waterspout
# 5             2020  2020-01-18T13:17:12      Cobalt         Coblnt
# 6             2020  2020-01-18T13:17:12      Cobalt      More_eggs
# 7             2020  2020-01-18T13:17:12      Cobalt       Carbanak
# 8             2020  2020-01-18T13:17:12      Cobalt       PetrWrap
# 9             2020  2020-01-18T13:17:12  blackOasis         Finspy
# 10            2020  2020-01-18T13:17:12  blackOasis      Finfisher
# 11            2020  2020-01-18T13:17:12  blackOasis       wingbird
# 12            2020  2020-01-18T13:17:12       APT28  ADVSTORESHELL
# 13            2020  2020-01-18T13:17:12       APT28         Cannon
# 14            2020  2020-01-18T13:17:12       APT28      CHOPSTICK
# 15            2020  2020-01-18T13:17:12       APT28      CORESHELL
# 16            2020  2020-01-18T13:17:12       APT28      Downdelph
# 17            2020  2020-01-18T13:17:12       APT28         Fysbis
# 18            2020  2020-01-18T13:17:12       APT28       JHUHUGIT
# 19            2020  2020-01-18T13:17:12       APT28        HIDEDRV
# 20            2020  2020-01-18T13:17:12       APT28        Komplex
# 21            2020  2020-01-18T13:17:12       APT28          LoJax
# 22            2020  2020-01-18T13:17:12       APT28      XAgentOSX
# 23            2020  2020-01-18T13:17:12       APT28        XTunnel
# 24            2020  2020-01-18T13:17:12       APT28        Zebrocy
# 25            2020  2020-01-18T13:17:12       APT30      Backspace
# 26            2020  2020-01-18T13:17:12       APT30     Flashflood
# 27            2020  2020-01-18T13:17:12       APT30      spaceship
# 28            2020  2020-01-18T13:17:12       APT30       Neteagle
# 29            2020  2020-01-18T13:17:12       APT30      shipspace

# %%
def insert_one_intrusion_set(df,session):
    f_d=None
    f_m=None
    f_y=None
    f=None
    if df.first_seen != 'NA':
        f=df.first_seen.strftime("%Y-%m-%dT%H:%M:%S")
        f_m=df.first_seen.strftime("%Y-%m")
        f_d=df.first_seen.strftime("%Y-%m-%d")
        f_y=df.first_seen.strftime("%Y")
    elif df.first_seen_month != 'NA':
        f_m=df.first_seen_month
    elif df.first_seen_day != 'NA':
        f_d=df.first_seen_day
    elif df.first_seen_year != 'NA':
        f_y=df.first_seen_year        
        
    if df.last_seen != 'NA':
        l=df.last_seen.strftime("%Y-%m-%dT%H:%M:%S")
        l_m=df.last_seen.strftime("%Y-%m")
        l_d=df.last_seen.strftime("%Y-%m-%d")
        l_y=df.last_seen.strftime("%Y")
    elif df.last_seen_month != 'NA':
        l_m=df.last_seen_month
    elif df.last_seen_day != 'NA':
        l_d=df.last_seen_day
    elif df.last_seen_year != 'NA':
        l_y=df.last_seen_year
    else:
        l_d=None
        l_m=None
        l_y=None
        l=None
               
    aliases=df.alias.split('\n')

    graql_match_query = f"match $i isa Intrusion-Set, " \
                        f"has name \"{df['name']}\"; " \
                        f"get;"
    print(graql_match_query)
    with session.transaction().read() as read_transaction:
        # read_transaction.query(graql_match_query)
        answer_iterator = None
        answer_iterator = read_transaction.query(graql_match_query, infer=True)
        data = answer_iterator.collect_concepts()
        print(len(data))     
        if len(data) > 0:
            # Update data.
            # Columns to be updated: object_status, revoked, updated_at, modified, description, alias
            # print("Update intrusion-set...")
            print("Update: " + df['name'])
            graql_attribute_delete_query = f"match $i isa Intrusion-Set, " \
                                           f"has name \"{df['name']}\", "\
                                           f"has alias $a via $i1, "\
                                           f"has description $a via $i2; "\
                                           f"delete $i1, $i2;"
            update_flg = False
            first_attr_flg = True
            graql_attribute_update_query = f"match $i isa Intrusion-Set, " \
                                           f"has name \"{df['name']}\"; insert $i"
            if df['description'] != 'NA':
                # graql_attribute_delete_query += f" has description $a via $i2; "\
                graql_attribute_update_query += f" has description \"{df['description']}\" "
                if first_attr_flg:
                    graql_attribute_update_query += ","
                update_flg = True
                first_attr_flg = False
            if len(aliases) > 0:
                s = "|"
                graql_attribute_update_query += f" has alias \"{s.join(aliases)}\" " 
                if first_attr_flg:
                    graql_attribute_update_query += ","
                update_flg = True
                first_attr_flg = False
            graql_attribute_update_query += ";"
            print(graql_attribute_update_query)
            if update_flg:
                with session.transaction().write() as write_transaction:
                    # make a write transection with the query
                    write_transaction.query(graql_attribute_delete_query)
                    write_transaction.query(graql_attribute_update_query)
                    # remember to commit at the end
                    write_transaction.commit()           
        else:
            print("Insert intrusion-set...")
            print("Insert: " + df['name'])
            graql_insert_query = f"insert $x isa Intrusion-Set, " \
                                 f"has internal_id_key \"{df['internal_id_key']}\", " \
                                 f"has stix_id_key \"{df['stix_id_key']}\", " \
                                 f"has stix_label \"{df['stix_label']}\", " \
                                 f"has entity_type \"{df['entity_type']}\", " \
                                 f"has created {df['created']}, " \
                                 f"has revoked \"{df['revoked']}\", "\
                                 f"has created_at {df['created_at']}, " \
                                 f"has created_at_day \"{df['created_at_day']}\", " \
                                 f"has created_at_month \"{df['created_at_month']}\", " \
                                 f"has created_at_year \"{df['created_at_year']}\", "\
                                 f"has updated_at {df['updated_at']}, "\
                                 f"has name \"{df['name']}\" "
                                 
            if df['description'] != 'NA':
                graql_insert_query += f", has description \"{df['description']}\" "
            if len(aliases) > 0:
                s = "|"
                graql_insert_query += f", has alias \"{s.join(aliases)}\" "
           
            if f is not None:
                graql_insert_query += f", has first_seen {f} "
            if f_d is not None:
                graql_insert_query += f", has first_seen_day \"{f_d}\" "
            if f_m is not None:
                graql_insert_query += f", has first_seen_month \"{f_m}\" "
            if f_y is not None:
                graql_insert_query += f", has first_seen_year \"{f_y}\""
            if l is not None:
                graql_insert_query += f", has last_seen {l} "
            if l_d is not None:
                graql_insert_query += f", has last_seen_day \"{l_d}\" "
            if l_m is not None:
                graql_insert_query += f", has last_seen_month \"{l_m}\" "
            if l_y is not None:
                graql_insert_query += f", has last_seen_year \"{l_y}\""
            if df['goal'] != 'NA':   
                graql_insert_query += f", has goal \"{df['goal']}\" "
            if df['sophistication'] != 'NA':   
                graql_insert_query += f", has sophistication \"{df['sophistication']}\" "
            if df['resource_level'] != 'NA':   
                graql_insert_query += f", has resource_level \"{df['resource_level']}\" "
            if df['primary_motivation'] != 'NA':   
                graql_insert_query += f", has primary_motivation \"{df['primary_motivation']}\" "
            if df['secondary_motivation'] != 'NA':   
                graql_insert_query += f", has primary_motivation \"{df['secondary_motivation']}\" "
           
            graql_insert_query += ";"
            # print(graql_insert_query)
            with session.transaction().write() as write_transaction:
                # make a write transection with the query
                write_transaction.query(graql_insert_query)
                # remember to commit at the end
                write_transaction.commit()

# %%
def load_data_into_grakn(session,input_df):
    print("Inserting intrusion-set...")
    # using progress_apply instead of apply so we have a progress bar form tqdm
    # input_df.progress_apply(insert_one_intrusion_set, axis=1, session=session)
    print("Loading intrusion-set...")
    for index,row in input_df.iterrows():
        insert_one_intrusion_set(df=row,session=session)

# %%
def build_grakn_graph(input_df, keyspace_name):
    with GraknClient(uri="192.168.83.128:48555") as client:
        with client.session(keyspace = keyspace_name) as session:
            load_data_into_grakn(session,input_df)

# %%
build_grakn_graph(input_df=result,keyspace_name='grakn_new')
# Out:
# Inserting intrusion-set...
# Loading intrusion-set...
# match $i isa Intrusion-Set, has name "APT12"; get;
# 1
# Update: APT12
# match $i isa Intrusion-Set, has name "APT12"; insert $i has description "APT12 is a threat group that has been attributed to China. The group has targeted a variety of victims including but not limited to media outlets, high-tech companies, and multiple governments" , has alias "APT 12 |Numbered Panda |TG-2754 |BeeBus |Calc Team|Group 22 |Crimson Iron " ;
# match $i isa Intrusion-Set, has name "APT28"; get;
# 1
# Update: APT28
# match $i isa Intrusion-Set, has name "APT28"; insert $i has description "APT28 is a threat group that has been attributed to Russia's Main Intelligence Directorate of the Russian General Staff by a July 2018 U.S. Department of Justice indictment. This group reportedly compromised the Hillary Clinton campaign, the Democratic National Committee, and the Democratic Congressional Campaign Committee in 2016 in an attempt to interfere with the U.S. presidential election. APT28 has been active since at least 2004" , has alias "SNAKEMACKEREL |Swallowtail|Group 74|Sednit|Sofacy|Pawn Storm|Fancy Bear|STRONTIUM |Tsar Team|Threat Group-4127|TG-4127 |" ;
# match $i isa Intrusion-Set, has name "BlackOasis"; get;
# 1
# Update: BlackOasis
# match $i isa Intrusion-Set, has name "BlackOasis"; insert $i has description "BlackOasis is a Middle Eastern threat group that is believed to be a customer of Gamma Group. The group has shown interest in prominent figures in the United Nations, as well as opposition bloggers, activists, regional news correspondents, and think tanks. [1] [2] A group known by Microsoft as NEODYMIUM is reportedly associated closely with BlackOasis operations, but evidence that the group names are aliases has not been identified" , has alias "Neodymium|Promethium" ;
# match $i isa Intrusion-Set, has name "Cobalt"; get;
# 1
# Update: Cobalt
# match $i isa Intrusion-Set, has name "Cobalt"; insert $i has description "Cobalt Group is a financially motivated threat group that has primarily targeted financial institutions. The group has conducted intrusions to steal money via targeting ATM systems, card processing, payment systems and SWIFT systems. Cobalt Group has mainly targeted banks in Eastern Europe, Central Asia, and Southeast Asia. One of the alleged leaders was arrested in Spain in early 2018, but the group still appears to be active. The group has been known to target organizations in order to use their access to then compromise additional victims.Reporting indicates there may be links between Cobalt Group and both the malware Carbanak and the group Carbanak." , has alias " Cobalt Gang,|Cobalt Spider|TEMP.Metastrike|" ;
# match $i isa Intrusion-Set, has name "APT30"; get;
# 1
# Update: APT30
# match $i isa Intrusion-Set, has name "APT30"; insert $i has description "APT30 is a threat group suspected to be associated with the Chinese government.  While Naikon shares some characteristics with APT30, the two groups do not appear to be exact matches" , has alias "APT30  PLA   78020  |Operation MsnMM   |Operation Camera Shy|Naikon | HellsingAPT|" ;

# %%
def intrusion_uses_malware(df,session):
    graql_insert_query= f'match $i isa Intrusion-Set,'\
                        f'has name \"'+df['Group_name']+'\";'\
                        f'$m isa Malware,'\
                        f'has name \"'+df['malware_name'].strip()+'\";'\
                        f'insert $uses (user:$i ,usage:$m) isa uses,'\
                        f"has name 'uses', " \
                        f"has internal_id_key \"{df['internal_id_key']}\", " \
                        f"has stix_id_key \"{df['stix_id_key']}\", " \
                        f"has entity_type \"{df['entity_type']}\", " \
                        f"has created {df['created']}, " \
                        f"has revoked \"{df['revoked']}\", "\
                        f"has created_at {df['created_at']}, " \
                        f"has created_at_day \"{df['created_at_day']}\", " \
                        f"has created_at_month \"{df['created_at_month']}\", " \
                        f"has created_at_year \"{df['created_at_year']}\", "\
                        f"has updated_at {df['updated_at']}; "
    print(graql_insert_query)
    with session.transaction().write() as write_transaction:
                # make a write transection with the query
                write_transaction.query(graql_insert_query)
                # remember to commit at the end
                write_transaction.commit()

# %%
def intrusion_targets_vulnerability(df,session):
    graql_insert_query= f'match $i isa Intrusion-Set,'\
                        f'has name \"'+df['Group_name']+'\";'\
                        f'$vul isa Vulnerability,'\
                        f'has name \"'+df['cve_id'].strip()+'__\";'\
                        f'insert $targets (source:$i ,target:$vul) isa targets,'\
                        f"has internal_id_key \"{df['internal_id_key']}\", " \
                        f"has stix_id_key \"{df['stix_id_key']}\", " \
                        f"has entity_type \"{df['entity_type']}\", " \
                        f"has created {df['created']}, " \
                        f"has revoked \"{df['revoked']}\", "\
                        f"has created_at {df['created_at']}, " \
                        f"has created_at_day \"{df['created_at_day']}\", " \
                        f"has created_at_month \"{df['created_at_month']}\", " \
                        f"has created_at_year \"{df['created_at_year']}\", "\
                        f"has updated_at {df['updated_at']}; "
    print(graql_insert_query)
    with session.transaction().write() as write_transaction:
                # make a write transection with the query
                write_transaction.query(graql_insert_query)
                # remember to commit at the end
                write_transaction.commit()

# %%
def load_data_into_grakn_relation(session,input_df):
    print("Inserting intrusion-set...")
    # using progress_apply instead of apply so we have a progress bar form tqdm
    # input_df.progress_apply(insert_one_intrusion_set, axis=1, session=session)
    print("Loading intrusion-set...")
    
    for index,row in input_df.iterrows():
        print(row['Group_name'])
        #intrusion_uses_malware(df=row,session=session)
        try:
            intrusion_uses_malware(df=row,session=session)
            #intrusion_targets_vulnerability(df=row,session=session)
        except:
            pass
            print('-----------------------------'+row['cve_id']+'has duplicates--------------------------------------')

# %%
def build_grakn_graph_relation(input_df, keyspace_name):
    with GraknClient(uri="192.168.83.128:48555") as client:
        with client.session(keyspace = keyspace_name) as session:
            load_data_into_grakn_relation(session,input_df)

# %%
build_grakn_graph_relation(input_df=int_uses_mal_final,keyspace_name='grakn_new')
# Out:
# Inserting intrusion-set...
# Loading intrusion-set...
# APT12
# match $i isa Intrusion-Set,has name "APT12";$m isa Malware,has name "Ixeshe";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "cf70d34a-7ff3-4ffa-8364-7f22ce301a3e", has stix_id_key "relationship--2856b7d3-055a-4a3c-ba71-06a3dec3ff1d", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# APT12
# match $i isa Intrusion-Set,has name "APT12";$m isa Malware,has name "Aumlib";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "6bd8f49e-1899-45cb-8368-a3da86f932dc", has stix_id_key "relationship--1a033c13-58ba-45f0-b75c-7aacd7353deb", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# APT12
# match $i isa Intrusion-Set,has name "APT12";$m isa Malware,has name "Threebyte";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "0b12b63b-66bf-4b9f-ac44-b484af734cdd", has stix_id_key "relationship--293b4ea9-02c9-4a7c-a362-04a30a9e074e", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# APT12
# match $i isa Intrusion-Set,has name "APT12";$m isa Malware,has name "Hightide";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "092d8767-c872-42b2-a1a8-39e0ac7a27f8", has stix_id_key "relationship--fa8084d6-490c-4077-a70a-786f52e43e58", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# APT12
# match $i isa Intrusion-Set,has name "APT12";$m isa Malware,has name "Waterspout";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "5d2fb2f9-aa37-4fc6-948c-bdfe95ec786c", has stix_id_key "relationship--a1f4473c-18cd-45de-b730-87df595a0715", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# Cobalt
# match $i isa Intrusion-Set,has name "Cobalt";$m isa Malware,has name "Coblnt";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "6727de7a-1241-4b5e-9e51-2c96e93b5fab", has stix_id_key "relationship--46489454-251a-4290-b5fa-7b3c68f3d48c", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# Cobalt
# match $i isa Intrusion-Set,has name "Cobalt";$m isa Malware,has name "More_eggs";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "8047e9af-8cbd-42c6-8e44-21cf20a0875a", has stix_id_key "relationship--564ca1d9-f789-4ab4-bd59-4dabfe2a5cf4", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# Cobalt
# match $i isa Intrusion-Set,has name "Cobalt";$m isa Malware,has name "Carbanak";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "2f2dd06c-2d82-40ff-bd4a-5e2e6c26468b", has stix_id_key "relationship--14bfc752-c7b8-436d-9e31-ad202c471a26", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# Cobalt
# match $i isa Intrusion-Set,has name "Cobalt";$m isa Malware,has name "PetrWrap";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "7ce47283-54f4-4bd6-9dc5-8a52f6b9ad53", has stix_id_key "relationship--a143a537-63a8-4415-a655-826f6207e76c", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# blackOasis
# match $i isa Intrusion-Set,has name "blackOasis";$m isa Malware,has name "Finspy";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "0240cb4a-f101-401f-82f0-cbe1b9f0cad8", has stix_id_key "relationship--1aa88e36-5da2-4962-a609-3524258006a9", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# blackOasis
# match $i isa Intrusion-Set,has name "blackOasis";$m isa Malware,has name "Finfisher";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "593a0ea3-11a4-484d-b800-5337fb7d655f", has stix_id_key "relationship--43bf4494-938b-4faf-92c8-6f8227c1c82a", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# blackOasis
# match $i isa Intrusion-Set,has name "blackOasis";$m isa Malware,has name "wingbird";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "648bdcb5-c690-4b8b-90be-d5a697015674", has stix_id_key "relationship--0ed8bb2f-d404-4765-954b-654fa839e5a3", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# APT28
# match $i isa Intrusion-Set,has name "APT28";$m isa Malware,has name "ADVSTORESHELL";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "f7bb3984-64d4-4446-b227-b0609735f7ec", has stix_id_key "relationship--e23d1ff8-16a4-4bdf-bf07-8e440fc4ff10", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# APT28
# match $i isa Intrusion-Set,has name "APT28";$m isa Malware,has name "Cannon";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "1024c526-b0d0-4dbb-8cf1-c8a262ff0288", has stix_id_key "relationship--3e6f0934-f673-4270-95f6-7cb3c2ea5aba", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# APT28
# match $i isa Intrusion-Set,has name "APT28";$m isa Malware,has name "CHOPSTICK";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "cfcddc5f-6143-46c3-8977-e49bd531c78a", has stix_id_key "relationship--c0219ddf-eeff-49d3-abe8-9a11c78b0856", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# APT28
# match $i isa Intrusion-Set,has name "APT28";$m isa Malware,has name "CORESHELL";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "62900622-9f09-4d79-b806-6b08a94c0fe8", has stix_id_key "relationship--6d94fa23-08bd-4e63-a274-e2f7413e1f24", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# APT28
# match $i isa Intrusion-Set,has name "APT28";$m isa Malware,has name "Downdelph";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "e20afc54-4111-4b72-9b1c-4d7c949f4989", has stix_id_key "relationship--f8735bd9-f607-4b2d-b641-fe223ba1368d", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# APT28
# match $i isa Intrusion-Set,has name "APT28";$m isa Malware,has name "Fysbis";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "f3bf0287-3c23-4722-8203-6bff642707aa", has stix_id_key "relationship--6893527e-f97f-4ce7-8b34-52b522f8b62e", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# APT28
# match $i isa Intrusion-Set,has name "APT28";$m isa Malware,has name "JHUHUGIT";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "26e63b86-0157-44b7-9663-cb79aaa56ae4", has stix_id_key "relationship--f1a692f7-adad-49a2-8cb4-a3e4706fc013", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# APT28
# match $i isa Intrusion-Set,has name "APT28";$m isa Malware,has name "HIDEDRV";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "823a9ab9-fde2-4b56-98be-f7f2c85fb774", has stix_id_key "relationship--0e93e20a-ee24-43b4-9302-7a47af88a17d", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# APT28
# match $i isa Intrusion-Set,has name "APT28";$m isa Malware,has name "Komplex";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "43f54d17-58c2-4475-8ef0-afc1d8c202ae", has stix_id_key "relationship--41469d9e-9544-4563-baf0-f7220e3ed8b5", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# APT28
# match $i isa Intrusion-Set,has name "APT28";$m isa Malware,has name "LoJax";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "3ab3a0c7-a788-4184-95ac-b56b15e9e5f7", has stix_id_key "relationship--b94bc4dd-0eba-40a5-80de-847f73af3c27", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# APT28
# match $i isa Intrusion-Set,has name "APT28";$m isa Malware,has name "XAgentOSX";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "0ace6e54-8b10-46ba-8664-40639e9d2ae2", has stix_id_key "relationship--ee12ff3a-0408-456c-a3c3-56aa80bdc3f6", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# APT28
# match $i isa Intrusion-Set,has name "APT28";$m isa Malware,has name "XTunnel";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "2ef17e05-dcf6-4b30-878f-0a066d8ec1df", has stix_id_key "relationship--87fe6e9b-06b1-41d2-bf20-b5c1c02f182d", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# APT28
# match $i isa Intrusion-Set,has name "APT28";$m isa Malware,has name "Zebrocy";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "87fee2f0-6065-4755-a3e7-73e5a1f569ec", has stix_id_key "relationship--0e6c9817-9007-4358-bd9d-b9345d5c91ae", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# APT30
# match $i isa Intrusion-Set,has name "APT30";$m isa Malware,has name "Backspace";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "d9e2b951-6f1a-4c40-950b-e252bde57d37", has stix_id_key "relationship--1b493190-a8f6-4acb-93d6-aa933fb90d71", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# APT30
# match $i isa Intrusion-Set,has name "APT30";$m isa Malware,has name "Flashflood";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "1d49bd88-8524-4aa8-9191-b8f5f06274be", has stix_id_key "relationship--47ca3d2d-9cce-4c3d-a177-fa311c596c37", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# APT30
# match $i isa Intrusion-Set,has name "APT30";$m isa Malware,has name "spaceship";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "f31dd2ce-d2a8-4526-b656-fb607bb7d04a", has stix_id_key "relationship--5f0a3a51-89db-420a-83e4-45ed30d5c6d2", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# APT30
# match $i isa Intrusion-Set,has name "APT30";$m isa Malware,has name "Neteagle";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "51e22846-5082-4e7d-bd1a-23296fe0f591", has stix_id_key "relationship--ba847fad-d4ab-47bc-a36a-d656305c4003", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;
# APT30
# match $i isa Intrusion-Set,has name "APT30";$m isa Malware,has name "shipspace";insert $uses (user:$i ,usage:$m) isa uses,has name 'uses', has internal_id_key "44af6a9c-20a6-4ac4-8d72-1d4a77da67c5", has stix_id_key "relationship--9d0d66aa-af04-4c3e-bf99-39c452e18fd5", has entity_type "relationship", has created 2020-01-18T13:17:12, has revoked "False", has created_at 2020-01-18T13:17:12, has created_at_day "2020-01-18", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-18T13:17:12;

# %%
 graql_match_query = f"match $i isa Intrusion-Set, " \
                        f"has name \"{df['name'][0]}_\"; " \
                        f"get;"
print(graql_match_query)
# Out:
# match $i isa Intrusion-Set, has name "APT12_"; get;

# %%
with GraknClient(uri="192.168.83.128:48555") as client:
        with client.session(keyspace = 'grakn') as session:
            with session.transaction().read() as read_transaction:
            # read_transaction.query(graql_match_query)
                answer_iterator = None
                answer_iterator = read_transaction.query(graql_match_query, infer=True)
                data = answer_iterator.collect_concepts()
                print(len(data))
# Out:
# 4

# %%
graql_insert_query='match $i isa Intrusion-Set,has name "APT30";$m isa Malware,has name "Ixeshe";insert $uses (user:$i ,usage:$m) isa uses,has stix_id_key "relationship--d7416de6-0060-4931-8696-99f58027f48f",has internal_id_key "360aab78-d201-4757-8ebb-6f50d82533e3";'
with GraknClient(uri="192.168.83.128:48555") as client:
        with client.session(keyspace = 'grakn_new') as session:
            print(graql_insert_query)
            with session.transaction().write() as write_transaction:
                # make a write transection with the query
                write_transaction.query(graql_insert_query)
                # remember to commit at the end
                write_transaction.commit()
# Out:
# match $i isa Intrusion-Set,has name "APT30";$m isa Malware,has name "Ixeshe";insert $uses (user:$i ,usage:$m) isa uses,has stix_id_key "relationship--d7416de6-0060-4931-8696-99f58027f48f",has internal_id_key "360aab78-d201-4757-8ebb-6f50d82533e3";
# ---------------------------------------------------------------------------
# _Rendezvous                               Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\grakn\service\Session\TransactionService.py in send(self, request)
#     155             self._add_request(request)
# --> 156             response = next(self._response_iterator)
#     157         except Exception as e: # specialize into different gRPC exceptions?
#
# ~\AppData\Roaming\Python\Python37\site-packages\grpc\_channel.py in __next__(self)
#     363     def __next__(self):
# --> 364         return self._next()
#     365
#
# ~\AppData\Roaming\Python\Python37\site-packages\grpc\_channel.py in _next(self)
#     357                     elif self._state.code is not None:
# --> 358                         raise self
#     359
#
# _Rendezvous: <_Rendezvous of RPC that terminated with:
# 	status = StatusCode.INVALID_ARGUMENT
# 	details = "InvalidKBException-A structural validation error has occurred. Please correct the [`1`] errors found.
# There is more than one thing of type [stix_relation] that owns the key [relationship--d7416de6-0060-4931-8696-99f58027f48f] of type [stix_id_key].
# . Please check server logs for the stack trace."
# 	debug_error_string = "{"created":"@1578488013.185000000","description":"Error received from peer","file":"src/core/lib/surface/call.cc","file_line":1017,"grpc_message":"InvalidKBException-A structural validation error has occurred. Please correct the [`1`] errors found. \nThere is more than one thing of type [stix_relation] that owns the key [relationship--d7416de6-0060-4931-8696-99f58027f48f] of type [stix_id_key]. \n. Please check server logs for the stack trace.","grpc_status":3}"
# >
#
# During handling of the above exception, another exception occurred:
#
# GraknError                                Traceback (most recent call last)
# <ipython-input-127-dba6c8274bb1> in <module>
#       7                 write_transaction.query(graql_insert_query)
#       8                 # remember to commit at the end
# ----> 9                 write_transaction.commit()
#
# C:\ProgramData\Anaconda3\lib\site-packages\grakn\client.py in commit(self)
#     134     def commit(self):
#     135         """ Commit and close this transaction, persisting changes to Grakn """
# --> 136         self._tx_service.commit()
#     137         self.close()
#     138
#
# C:\ProgramData\Anaconda3\lib\site-packages\grakn\service\Session\TransactionService.py in commit(self)
#      54     def commit(self):
#      55         request = RequestBuilder.commit()
# ---> 56         self._communicator.send(request)
#      57
#      58     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\grakn\service\Session\TransactionService.py in send(self, request)
#     158             # invalidate this communicator, functionally this occurs automatically on exception (iterator not usable anymore)
#     159             self._closed = True
# --> 160             raise GraknError("Server/network error: {0}\n\n generated from request: {1}".format(e, request))
#     161
#     162         if response is None:
#
# GraknError: Server/network error: <_Rendezvous of RPC that terminated with:
# 	status = StatusCode.INVALID_ARGUMENT
# 	details = "InvalidKBException-A structural validation error has occurred. Please correct the [`1`] errors found.
# There is more than one thing of type [stix_relation] that owns the key [relationship--d7416de6-0060-4931-8696-99f58027f48f] of type [stix_id_key].
# . Please check server logs for the stack trace."
# 	debug_error_string = "{"created":"@1578488013.185000000","description":"Error received from peer","file":"src/core/lib/surface/call.cc","file_line":1017,"grpc_message":"InvalidKBException-A structural validation error has occurred. Please correct the [`1`] errors found. \nThere is more than one thing of type [stix_relation] that owns the key [relationship--d7416de6-0060-4931-8696-99f58027f48f] of type [stix_id_key]. \n. Please check server logs for the stack trace.","grpc_status":3}"
# >
#
#  generated from request: commit_req {
# }
