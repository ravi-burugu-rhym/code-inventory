# %%
import pandas as pd
import uuid
from datetime import datetime
import numpy as np
from grakn.client import GraknClient
from tqdm import tqdm
tqdm.pandas()

# %%
df=pd.read_excel(r"D:\Threat_intel_services\APT_collections\data\attack_pattern\attackpattern-description.xlsx")

# %%
df.keys()
# Out:
# Index(['internal_id_key', 'stix_id_key', 'stix_label', 'entity_type',
#        'created', 'modified', 'revoked', 'object_status', 'created_at',
#        'created_at_day', 'created_at_month', 'created_at_year', 'updated_at',
#        'technique_name', 'technique_description'],
#       dtype='object')

# %%
def  insert_general_info(df,ent_type,create):
    if create:
        for index,i in df.iterrows():
            df.internal_id_key[index]=str(uuid.uuid4())
            df.stix_id_key[index]=ent_type+'--'+str(uuid.uuid4())
            df.stix_label[index]='NA'
            df.entity_type[index]=ent_type
            df.created=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.created_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.created_at_day=(datetime.now()).strftime("%Y-%m-%d")
            df.created_at_month=(datetime.now()).strftime("%Y-%m")
            df.created_at_year=(datetime.now()).strftime("%Y")
            df.modified=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.updated_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.revoked=False
            df.object_status='NA'
    else:
            df.modified=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.updated_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
    return df

# %%
result=insert_general_info(df=df,ent_type='Attack-Pattern',create=True)
result.fillna('NA',inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\SRIKANTH\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
result
# Out:
#                           internal_id_key  \
# 0    ee83f3a0-ff1d-45bd-ac9d-ee50f7d05f4e
# 1    f19f59da-2382-4dc5-bb6e-e5912c0c47b2
# 2    0b502970-6bfd-4358-9244-a3be32c645ea
# 3    abf3c556-4edc-4d35-bd15-a2ba041119ba
# 4    ef55b8d2-590d-464e-b6de-8058fbd0a970
# ..                                    ...
# 96   923e5f28-b7dd-4102-bdce-be669cf59976
# 97   bae1f17f-b5f1-4e48-9c06-721e2f72a638
# 98   f2eedc26-5f92-4ffb-8f3a-53e830b6b08b
# 99   19837d54-b907-497b-ab33-88e060b3bfb0
# 100  ee6c84cc-bca3-49ef-84f5-1066322a94e7
#
#                                            stix_id_key stix_label  \
# 0    Attack-Pattern--6166d006-7551-478e-9d68-274ce8...         NA
# 1    Attack-Pattern--20f0274e-109b-4f1d-8313-b9f4d3...         NA
# 2    Attack-Pattern--6b4e09c3-71d2-40d5-bd12-5c8033...         NA
# 3    Attack-Pattern--ab6f8d40-0429-453d-9389-b636e6...         NA
# 4    Attack-Pattern--5c1a39c3-14f1-468e-b7a3-92fc4c...         NA
# ..                                                 ...        ...
# 96   Attack-Pattern--45ab352e-3b18-4172-9520-75099e...         NA
# 97   Attack-Pattern--4ce78ccf-70e3-40f3-a344-54e970...         NA
# 98   Attack-Pattern--09d048cc-9f14-412a-80d8-016ac8...         NA
# 99   Attack-Pattern--befdf971-85f3-48ac-8b12-c9c6f3...         NA
# 100  Attack-Pattern--954418a3-e284-4ce0-bb04-187a91...         NA
#
#         entity_type              created             modified  revoked  \
# 0    Attack-Pattern  2020-01-06T17:21:22  2020-01-06T17:21:22    False
# 1    Attack-Pattern  2020-01-06T17:21:22  2020-01-06T17:21:22    False
# 2    Attack-Pattern  2020-01-06T17:21:22  2020-01-06T17:21:22    False
# 3    Attack-Pattern  2020-01-06T17:21:22  2020-01-06T17:21:22    False
# 4    Attack-Pattern  2020-01-06T17:21:22  2020-01-06T17:21:22    False
# ..              ...                  ...                  ...      ...
# 96   Attack-Pattern  2020-01-06T17:21:22  2020-01-06T17:21:22    False
# 97   Attack-Pattern  2020-01-06T17:21:22  2020-01-06T17:21:22    False
# 98   Attack-Pattern  2020-01-06T17:21:22  2020-01-06T17:21:22    False
# 99   Attack-Pattern  2020-01-06T17:21:22  2020-01-06T17:21:22    False
# 100  Attack-Pattern  2020-01-06T17:21:22  2020-01-06T17:21:22    False
#
#     object_status           created_at created_at_day  ... graph_data  \
# 0              NA  2020-01-06T17:21:22     2020-01-06  ...         NA
# 1              NA  2020-01-06T17:21:22     2020-01-06  ...         NA
# 2              NA  2020-01-06T17:21:22     2020-01-06  ...         NA
# 3              NA  2020-01-06T17:21:22     2020-01-06  ...         NA
# 4              NA  2020-01-06T17:21:22     2020-01-06  ...         NA
# ..            ...                  ...            ...  ...        ...
# 96             NA  2020-01-06T17:21:22     2020-01-06  ...         NA
# 97             NA  2020-01-06T17:21:22     2020-01-06  ...         NA
# 98             NA  2020-01-06T17:21:22     2020-01-06  ...         NA
# 99             NA  2020-01-06T17:21:22     2020-01-06  ...         NA
# 100            NA  2020-01-06T17:21:22     2020-01-06  ...         NA
#
#     platform required_permission external_id created_by_ref labels  \
# 0         NA                  NA          NA             NA     NA
# 1         NA                  NA          NA             NA     NA
# 2         NA                  NA          NA             NA     NA
# 3         NA                  NA          NA             NA     NA
# 4         NA                  NA          NA             NA     NA
# ..       ...                 ...         ...            ...    ...
# 96        NA                  NA          NA             NA     NA
# 97        NA                  NA          NA             NA     NA
# 98        NA                  NA          NA             NA     NA
# 99        NA                  NA          NA             NA     NA
# 100       NA                  NA          NA             NA     NA
#
#     kill_chain_phases external_references  object_marking_refs  \
# 0                  NA                   NA                  NA
# 1                  NA                   NA                  NA
# 2                  NA                   NA                  NA
# 3                  NA                   NA                  NA
# 4                  NA                   NA                  NA
# ..                ...                  ...                 ...
# 96                 NA                   NA                  NA
# 97                 NA                   NA                  NA
# 98                 NA                   NA                  NA
# 99                 NA                   NA                  NA
# 100                NA                   NA                  NA
#
#     granular_markings
# 0                  NA
# 1                  NA
# 2                  NA
# 3                  NA
# 4                  NA
# ..                ...
# 96                 NA
# 97                 NA
# 98                 NA
# 99                 NA
# 100                NA
#
# [101 rows x 26 columns]

# %%
def insert_one_attackpattern(df,session):
    #if df.first_seen != 'NA':
     #   f=df.first_seen.strftime("%Y-%m-%dT%H:%M:%S")
     #   f_m=df.first_seen.strftime("%Y-%m")
     #   f_d=df.first_seen.strftime("%Y-%m-%d")
    #elif df.first_seen_month != 'NA':
    #    f_m=df.first_seen_month
    #elif df.first_seen_day != 'NA':
    #    f_d=df.first_seen_day
    #else:
    #    f_d=None
    #    f_m=None
    #    f=None
    aliases = list()
    if df['alias'] != 'NA':            
        aliases=df.alias.split('\n')

    graql_match_query = f"match $i isa Attack-Pattern, " \
                        f"has name \"{df['name']}_\"; " \
                        f"get;"
    # print(graql_match_query)
    with session.transaction().read() as read_transaction:
        # read_transaction.query(graql_match_query)
        answer_iterator = None
        answer_iterator = read_transaction.query(graql_match_query, infer=True)
        data = answer_iterator.collect_concepts()
                
        if len(data) > 0:
            # Update data.
            # Columns to be updated: object_status, revoked, updated_at, modified, description, alias
            # print("Update intrusion-set...")
            print("Update: " + df['name'])
            graql_attribute_delete_query = f"match $i isa Attack-Pattern, " \
                                           f"has name \"{df['name']}_\", "\
                                           f"has alias $a via $i1, "\
                                           f"has description $a via $i2; "\
                                           f"delete $i1, $i2;"
            update_flg = False
            first_attr_flg = True
            graql_attribute_update_query = f"match $i isa Attack-Pattern, " \
                                           f"has name \"{df['name']}_\"; insert $i"
            if df['description'] != 'NA':
                # graql_attribute_delete_query += f" has description $a via $i2; "\
                graql_attribute_update_query += f" has description \"{df['description']}\" "
                if first_attr_flg:
                    graql_attribute_update_query += ","
                update_flg = True
                first_attr_flg = False
            if len(aliases) > 0:
                s = "|"
                graql_attribute_update_query += f" has alias \"{s.join(aliases).replace(' ','')}\" " 
#                 if first_attr_flg:
#                     graql_attribute_update_query += ","
                update_flg = True
                first_attr_flg = False
            graql_attribute_update_query += ";"
            print(graql_attribute_update_query)
            if update_flg:
                with session.transaction().write() as write_transaction:
                    # make a write transection with the query
                    write_transaction.query(graql_attribute_delete_query)
                    write_transaction.query(graql_attribute_update_query)
                    # remember to commit at the end
                    write_transaction.commit()           
        else:
            # print("Insert intrusion-set...")
            print("Insert: " + df['name'])
            graql_insert_query = f"insert $x isa Attack-Pattern, " \
                                 f"has internal_id_key \"{df['internal_id_key']}\", " \
                                 f"has stix_id_key \"{df['stix_id_key']}\", " \
                                 f"has stix_label \"{df['stix_label']}\", " \
                                 f"has entity_type \"{df['entity_type']}\", " \
                                 f"has created {df['created']}, " \
                                 f"has revoked \"{df['revoked']}\", "\
                                 f"has created_at {df['created_at']}, " \
                                 f"has created_at_day \"{df['created_at_day']}\", " \
                                 f"has created_at_month \"{df['created_at_month']}\", " \
                                 f"has created_at_year \"{df['created_at_year']}\", "\
                                 f"has updated_at {df['updated_at']}, "\
                                 f"has name \"{df['name']}_\" "
                                 
            if df['description'] != 'NA':
                graql_insert_query += f", has description \"{df['description']}\" "
            if len(aliases) > 0:
                s = "|"
                graql_insert_query += f", has alias \"{s.join(aliases)}\" "
            #if f is not None:
            #    graql_insert_query += f", has first_seen {f} "
            #if f_d is not None:
            #    graql_insert_query += f", has first_seen_day \"{f_d}\" "
            #if f_m is not None:
             #   graql_insert_query += f", has first_seen_month \"{f_m}\" "
            #if f_m is not None:
            #    graql_insert_query += f", has first_seen_year \"{df['first_seen_year']}\""
            graql_insert_query += ";"
            print(graql_insert_query)
            with session.transaction().write() as write_transaction:
                # make a write transection with the query
                write_transaction.query(graql_insert_query)
                # remember to commit at the end
                write_transaction.commit()

# %%
def load_data_into_grakn(session,input_df):
    print("Attack-Pattern...")
    # using progress_apply instead of apply so we have a progress bar form tqdm
    # input_df.progress_apply(insert_one_intrusion_set, axis=1, session=session)
    print("Attack-Pattern...")
    for index,row in input_df.iterrows():
        insert_one_attackpattern(df=row,session=session)

# %%
def build_grakn_graph(input_df, keyspace_name):
    with GraknClient(uri="192.168.1.250:48555") as client:
        with client.session(keyspace = keyspace_name) as session:
            load_data_into_grakn(session,input_df)

# %%
build_grakn_graph(input_df=result,keyspace_name='grakn')
# Out:
# Attack-Pattern...
# Attack-Pattern...
# Insert: Spear phishing-
# insert $x isa Attack-Pattern, has internal_id_key "ee83f3a0-ff1d-45bd-ac9d-ee50f7d05f4e", has stix_id_key "Attack-Pattern--6166d006-7551-478e-9d68-274ce8595404", has stix_label "NA", has entity_type "Attack-Pattern", has created 2020-01-06T17:21:22, has revoked "False", has created_at 2020-01-06T17:21:22, has created_at_day "2020-01-06", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-06T17:21:22, has name "Spear phishing-_" ;
# Insert: Exploitation for Client-
# insert $x isa Attack-Pattern, has internal_id_key "f19f59da-2382-4dc5-bb6e-e5912c0c47b2", has stix_id_key "Attack-Pattern--20f0274e-109b-4f1d-8313-b9f4d3a4e984", has stix_label "NA", has entity_type "Attack-Pattern", has created 2020-01-06T17:21:22, has revoked "False", has created_at 2020-01-06T17:21:22, has created_at_day "2020-01-06", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-06T17:21:22, has name "Exploitation for Client- _" ;
# Insert: Execution-
# insert $x isa Attack-Pattern, has internal_id_key "0b502970-6bfd-4358-9244-a3be32c645ea", has stix_id_key "Attack-Pattern--6b4e09c3-71d2-40d5-bd12-5c80337e3727", has stix_label "NA", has entity_type "Attack-Pattern", has created 2020-01-06T17:21:22, has revoked "False", has created_at 2020-01-06T17:21:22, has created_at_day "2020-01-06", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-06T17:21:22, has name "Execution-                                                                                              _" ;
# Update: Spearphishing Attachment
# match $i isa Attack-Pattern, has name "Spearphishing Attachment                                                                                                       _"; insert $i;
# Update: User Execution
# match $i isa Attack-Pattern, has name "User Execution                                                         _"; insert $i;
# Update: Web Service
# match $i isa Attack-Pattern, has name "Web Service_"; insert $i;
# Update: Spear Phishing
# match $i isa Attack-Pattern, has name "Spear Phishing_"; insert $i;
# Update: Credentials harvesting using spoofed websites
# match $i isa Attack-Pattern, has name "Credentials harvesting using spoofed websites_"; insert $i;
# Update: Zero days
# match $i isa Attack-Pattern, has name "Zero days_"; insert $i;
# Update: Malware
# match $i isa Attack-Pattern, has name "Malware_"; insert $i;
# Update: Buy domain name
# match $i isa Attack-Pattern, has name "Buy domain name _"; insert $i;
# Update: Obtain/re-use payloads
# match $i isa Attack-Pattern, has name "Obtain/re-use payloads _"; insert $i;
# Update: Access Token Manipulation
# match $i isa Attack-Pattern, has name "Access Token Manipulation _"; insert $i;
# Update: Application Access Token
# match $i isa Attack-Pattern, has name "Application Access Token_"; insert $i;
# Update: Automated Collection
# match $i isa Attack-Pattern, has name "Automated Collection _"; insert $i;
# Update: Bootkit
# match $i isa Attack-Pattern, has name "Bootkit_"; insert $i;
# Update: Command-Line Interface
# match $i isa Attack-Pattern, has name "Command-Line Interface _"; insert $i;
# Update: Commonly Used Port
# match $i isa Attack-Pattern, has name "Commonly Used Port _"; insert $i;
# Update: Communication Through Removable Media
# match $i isa Attack-Pattern, has name "Communication Through Removable Media _"; insert $i;
# Update: Component Object Model Hijacking
# match $i isa Attack-Pattern, has name "Component Object Model Hijacking _"; insert $i;
# Update: Connection Proxy
# match $i isa Attack-Pattern, has name "Connection Proxy _"; insert $i;
# Update: Credential Dumping
# match $i isa Attack-Pattern, has name "Credential Dumping _"; insert $i;
# Update: Custom Cryptographic Protocol
# match $i isa Attack-Pattern, has name "Custom Cryptographic Protocol _"; insert $i;
# Update: Data Compressed
# match $i isa Attack-Pattern, has name "Data Compressed _"; insert $i;
# Update: Data from Information Repositories
# match $i isa Attack-Pattern, has name "Data from Information Repositories _"; insert $i;
# Update: Data from Local System
# match $i isa Attack-Pattern, has name "Data from Local System _"; insert $i;
# Update: Data from Removable Media
# match $i isa Attack-Pattern, has name "Data from Removable Media _"; insert $i;
# Update: Data Obfuscation
# match $i isa Attack-Pattern, has name "Data Obfuscation _"; insert $i;
# Update: Data Staged
# match $i isa Attack-Pattern, has name "Data Staged _"; insert $i;
# Update: Deobfuscate/Decode Files or Information
# match $i isa Attack-Pattern, has name "Deobfuscate/Decode Files or Information _"; insert $i;
# Update: Dynamic Data Exchange
# match $i isa Attack-Pattern, has name "Dynamic Data Exchange _"; insert $i;
# Update: Email Collection
# match $i isa Attack-Pattern, has name "Email Collection _"; insert $i;
# Update: Exploitation for Client Execution
# match $i isa Attack-Pattern, has name "Exploitation for Client Execution _"; insert $i;
# Update: Exploitation for Defense Evasion
# match $i isa Attack-Pattern, has name "Exploitation for Defense Evasion _"; insert $i;
# Update: Exploitation for Privilege Escalation
# match $i isa Attack-Pattern, has name "Exploitation for Privilege Escalation _"; insert $i;
# Update: Exploitation of Remote Services
# match $i isa Attack-Pattern, has name "Exploitation of Remote Services _"; insert $i;
# Update: File and Directory Discovery
# match $i isa Attack-Pattern, has name "File and Directory Discovery _"; insert $i;
# Update: File Deletion
# match $i isa Attack-Pattern, has name "File Deletion _"; insert $i;
# Update: Hidden Files and Directories
# match $i isa Attack-Pattern, has name "Hidden Files and Directories _"; insert $i;
# Update: Hidden Window
# match $i isa Attack-Pattern, has name "Hidden Window _"; insert $i;
# Update: Indicator Removal on Host
# match $i isa Attack-Pattern, has name "Indicator Removal on Host _"; insert $i;
# Update: Input Capture
# match $i isa Attack-Pattern, has name "Input Capture _"; insert $i;
# Update: Logon Scripts
# match $i isa Attack-Pattern, has name "Logon Scripts _"; insert $i;
# Update: Network Sniffing
# match $i isa Attack-Pattern, has name "Network Sniffing _"; insert $i;
# Update: Obfuscated Files or Information
# match $i isa Attack-Pattern, has name "Obfuscated Files or Information _"; insert $i;
# Update: Office Application Startup
# match $i isa Attack-Pattern, has name "Office Application Startup _"; insert $i;
# Update: Pass the Hash
# match $i isa Attack-Pattern, has name "Pass the Hash _"; insert $i;
# Update: Peripheral Device Discovery
# match $i isa Attack-Pattern, has name "Peripheral Device Discovery  _"; insert $i;
# Update: PowerShell
# match $i isa Attack-Pattern, has name "PowerShell _"; insert $i;
# Update: Process Discovery
# match $i isa Attack-Pattern, has name "Process Discovery _"; insert $i;
# Update: Remote File Copy
# match $i isa Attack-Pattern, has name "Remote File Copy _"; insert $i;
# Update: Replication Through Removable Media
# match $i isa Attack-Pattern, has name "Replication Through Removable Media _"; insert $i;
# Update: Rootkit
# match $i isa Attack-Pattern, has name "Rootkit _"; insert $i;
# Update: Rundll32
# match $i isa Attack-Pattern, has name "Rundll32 _"; insert $i;
# Update: Screen Capture
# match $i isa Attack-Pattern, has name "Screen Capture _"; insert $i;
# Update: Scripting
# match $i isa Attack-Pattern, has name "Scripting _"; insert $i;
# Update: Spearphishing Attachment
# match $i isa Attack-Pattern, has name "Spearphishing Attachment _"; insert $i;
# Update: Spearphishing Link
# match $i isa Attack-Pattern, has name "Spearphishing Link_"; insert $i;
# Update: Standard Application Layer Protocol
# match $i isa Attack-Pattern, has name "Standard Application Layer Protocol _"; insert $i;
# Update: Steal Application Access Token
# match $i isa Attack-Pattern, has name "Steal Application Access Token _"; insert $i;
# Update: Template Injection
# match $i isa Attack-Pattern, has name "Template Injection _"; insert $i;
# Update: Timestomp
# match $i isa Attack-Pattern, has name "Timestomp _"; insert $i;
# Update: Trusted Relationship
# match $i isa Attack-Pattern, has name "Trusted Relationship _"; insert $i;
# Update: User Execution
# match $i isa Attack-Pattern, has name "User Execution _"; insert $i;
# Update: Valid Accounts
# match $i isa Attack-Pattern, has name "Valid Accounts_"; insert $i;
# Update: Spear Phishing with Word Attachments
# match $i isa Attack-Pattern, has name "Spear Phishing with Word Attachments_"; insert $i;
# Update: downloaders
# match $i isa Attack-Pattern, has name "downloaders _"; insert $i;
# Update: droppers
# match $i isa Attack-Pattern, has name "droppers   _"; insert $i;
# Update: backdoors
# match $i isa Attack-Pattern, has name "backdoors _"; insert $i;
# Update: central controller  and several components designed to infect removable drives and cross air-gapped networks to steal data
# match $i isa Attack-Pattern, has name "central controller  and several components designed to infect removable drives and cross air-gapped networks to steal data_"; insert $i;
# Update: Spearphishing
# match $i isa Attack-Pattern, has name "Spearphishing_"; insert $i;
# Update: obfuscated files or information
# match $i isa Attack-Pattern, has name "obfuscated files or information_"; insert $i;
# Update: Bypass User Account Control
# match $i isa Attack-Pattern, has name "Bypass User Account Control_"; insert $i;
# Update: CMSTP
# match $i isa Attack-Pattern, has name "CMSTP_"; insert $i;
# Update: Command-Line Interface
# match $i isa Attack-Pattern, has name "Command-Line Interface_"; insert $i;
# Update: Dynamic Data Exchange
# match $i isa Attack-Pattern, has name "Dynamic Data Exchange_"; insert $i;
# Update: Exploitation for Client Execution
# match $i isa Attack-Pattern, has name "Exploitation for Client Execution_"; insert $i;
# Update: Exploitation for Privilege Escalation
# match $i isa Attack-Pattern, has name "Exploitation for Privilege Escalation_"; insert $i;
# Update: File Deletion
# match $i isa Attack-Pattern, has name "File Deletion_"; insert $i;
# Update: Logon Scripts
# match $i isa Attack-Pattern, has name "Logon Scripts_"; insert $i;
# Update: Network Service Scanning
# match $i isa Attack-Pattern, has name "Network Service Scanning_"; insert $i;
# Update: New Service
# match $i isa Attack-Pattern, has name "New Service_"; insert $i;
# Update: Obfuscated Files or Information
# match $i isa Attack-Pattern, has name "Obfuscated Files or Information_"; insert $i;
# Update: PowerShell
# match $i isa Attack-Pattern, has name "PowerShell_"; insert $i;
# Update: Process Injection
# match $i isa Attack-Pattern, has name "Process Injection_"; insert $i;
# Update: Redundant Access
# match $i isa Attack-Pattern, has name "Redundant Access_"; insert $i;
# Update: Registry Run Keys / Startup Folder
# match $i isa Attack-Pattern, has name "Registry Run Keys / Startup Folder_"; insert $i;
# Update: Regsvr32
# match $i isa Attack-Pattern, has name "Regsvr32 _"; insert $i;
# Update: Remote Access Tools
# match $i isa Attack-Pattern, has name "Remote Access Tools_"; insert $i;
# Update: Remote Desktop Protocol
# match $i isa Attack-Pattern, has name "Remote Desktop Protocol_"; insert $i;
# Update: Remote File Copy
# match $i isa Attack-Pattern, has name "Remote File Copy_"; insert $i;
# Update: Scheduled Task
# match $i isa Attack-Pattern, has name "Scheduled Task_"; insert $i;
# Update: Scripting
# match $i isa Attack-Pattern, has name "Scripting_"; insert $i;
# Update: Security Software Discovery
# match $i isa Attack-Pattern, has name "Security Software Discovery_"; insert $i;
# Update: Signed Binary Proxy Execution
# match $i isa Attack-Pattern, has name "Signed Binary Proxy Execution_"; insert $i;
# Update: Spearphishing Attachment
# match $i isa Attack-Pattern, has name "Spearphishing Attachment _"; insert $i;
# Update: Spearphishing Link
# match $i isa Attack-Pattern, has name "Spearphishing Link_"; insert $i;
# Update: Standard Application Layer Protocol
# match $i isa Attack-Pattern, has name "Standard Application Layer Protocol_"; insert $i;
# Update: Standard Cryptographic Protocol
# match $i isa Attack-Pattern, has name "Standard Cryptographic Protocol_"; insert $i;
# Update: User Execution
# match $i isa Attack-Pattern, has name "User Execution_"; insert $i;
# Update: XSL Script Processing
# match $i isa Attack-Pattern, has name "XSL Script Processing_"; insert $i;
