# %%
import pandas as pd
import uuid
from datetime import datetime
import numpy as np
from grakn.client import GraknClient
from tqdm import tqdm
tqdm.pandas()

# %%
df=pd.read_excel(r"C:\Users\SRIKANTH\Desktop\OpenCTI_Data.xlsx",sheet_name='Course-of-action')

# %%
df.keys()
# Out:
# Index(['internal_id_key', 'stix_id_key', 'stix_label', 'entity_type',
#        'created', 'modified', 'revoked', 'object_status', 'created_at',
#        'created_at_day', 'created_at_month', 'created_at_year', 'updated_at',
#        'name', 'description', 'alias', 'graph_data', 'external_references ',
#        'object_marking_refs', 'granular_markings'],
#       dtype='object')

# %%
def  insert_general_info(df,ent_type,create):
    if create:
        for index,i in df.iterrows():
            df.internal_id_key[index]=str(uuid.uuid4())
            df.stix_id_key[index]=ent_type+'--'+str(uuid.uuid4())
            df.stix_label[index]='NA'
            df.entity_type[index]=ent_type
            df.created=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.created_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.created_at_day=(datetime.now()).strftime("%Y-%m-%d")
            df.created_at_month=(datetime.now()).strftime("%Y-%m")
            df.created_at_year=(datetime.now()).strftime("%Y")
            df.modified=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.updated_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.revoked=False
            df.object_status='NA'
    else:
            df.modified=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.updated_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
    return df

# %%
result=insert_general_info(df=df,ent_type='course-of-action',create=True)
result.fillna('NA',inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
result
# Out:
#                          internal_id_key  \
# 0   461006e5-6b51-4912-bb52-087372ca056c
# 1   05e8ac72-08ef-4abf-8acd-043ada6e47ca
# 2   e30fa603-142a-4ec0-bf51-62577737fcd2
# 3   dc6d2462-13a1-4dcc-a3a0-f87004b1693b
# 4   d92c2e28-44e5-4d40-9688-f9ec2fdf78b6
# 5   f24a5b05-ad35-4da1-a2bb-e2523e7befd3
# 6   a5639a47-16fa-4817-994a-9a1c6a52d8e4
# 7   b5e837a5-edfb-4cf7-a327-ec84fb1c9018
# 8   c92546a7-d105-4892-9dc2-01ff5bd654ac
# 9   9be24eb7-d6b1-4b3b-b80e-594f2329d1a9
# 10  195c0dce-3c43-4b6b-83c7-6f328b3bd4a0
# 11  5d42e9c8-867c-4ac8-8acd-02b3edee7db4
# 12  abcc9a8d-c4af-46cb-bf93-d4b39fc13c21
# 13  80494c44-c3db-4225-8e8e-5bf41619ea1d
# 14  513f4ab4-247f-41fb-b3d0-c7c2f1a5c6ba
# 15  4b06c330-6de1-4a6f-8b29-51f62499a0d7
# 16  b4b0519b-08df-4b5e-985d-ac5a724a12b1
#
#                                           stix_id_key stix_label  \
# 0   course-of-action--7eb36ef8-d15e-46b8-bc1b-0c33...         NA
# 1   course-of-action--93735a9e-6122-4e02-a5af-8371...         NA
# 2   course-of-action--6f40f7ab-ddb4-4fdf-8be1-3b21...         NA
# 3   course-of-action--b5b14ec1-fb28-4daf-9d56-9a06...         NA
# 4   course-of-action--16352a14-0ba8-4a83-9f49-c8bc...         NA
# 5   course-of-action--42883056-1e77-45c3-af11-8d59...         NA
# 6   course-of-action--740174b6-62f5-466d-a1e5-b749...         NA
# 7   course-of-action--c9f0aac4-7bfe-44df-83a0-0046...         NA
# 8   course-of-action--40b94a8e-f738-4545-98b8-d691...         NA
# 9   course-of-action--b2008ca2-9e66-49b6-a48e-ab95...         NA
# 10  course-of-action--30db898a-fab6-40e9-b95f-beef...         NA
# 11  course-of-action--93b6dbdd-235e-41c9-861d-9ea8...         NA
# 12  course-of-action--0a8c3ae2-40dd-40ed-af81-38d3...         NA
# 13  course-of-action--682c7853-6406-4e1c-9c26-3ebc...         NA
# 14  course-of-action--36f9b6e1-a925-453d-ace9-98d2...         NA
# 15  course-of-action--52489a57-3839-4166-beb4-2c6e...         NA
# 16  course-of-action--1b50ea10-6dc2-4f3e-b027-d637...         NA
#
#          entity_type              created             modified  revoked  \
# 0   course-of-action  2020-01-07T16:20:33  2020-01-07T16:20:33    False
# 1   course-of-action  2020-01-07T16:20:33  2020-01-07T16:20:33    False
# 2   course-of-action  2020-01-07T16:20:33  2020-01-07T16:20:33    False
# 3   course-of-action  2020-01-07T16:20:33  2020-01-07T16:20:33    False
# 4   course-of-action  2020-01-07T16:20:33  2020-01-07T16:20:33    False
# 5   course-of-action  2020-01-07T16:20:33  2020-01-07T16:20:33    False
# 6   course-of-action  2020-01-07T16:20:33  2020-01-07T16:20:33    False
# 7   course-of-action  2020-01-07T16:20:33  2020-01-07T16:20:33    False
# 8   course-of-action  2020-01-07T16:20:33  2020-01-07T16:20:33    False
# 9   course-of-action  2020-01-07T16:20:33  2020-01-07T16:20:33    False
# 10  course-of-action  2020-01-07T16:20:33  2020-01-07T16:20:33    False
# 11  course-of-action  2020-01-07T16:20:33  2020-01-07T16:20:33    False
# 12  course-of-action  2020-01-07T16:20:33  2020-01-07T16:20:33    False
# 13  course-of-action  2020-01-07T16:20:33  2020-01-07T16:20:33    False
# 14  course-of-action  2020-01-07T16:20:33  2020-01-07T16:20:33    False
# 15  course-of-action  2020-01-07T16:20:33  2020-01-07T16:20:33    False
# 16  course-of-action  2020-01-07T16:20:33  2020-01-07T16:20:33    False
#
#    object_status           created_at created_at_day created_at_month  \
# 0             NA  2020-01-07T16:20:33     2020-01-07          2020-01
# 1             NA  2020-01-07T16:20:33     2020-01-07          2020-01
# 2             NA  2020-01-07T16:20:33     2020-01-07          2020-01
# 3             NA  2020-01-07T16:20:33     2020-01-07          2020-01
# 4             NA  2020-01-07T16:20:33     2020-01-07          2020-01
# 5             NA  2020-01-07T16:20:33     2020-01-07          2020-01
# 6             NA  2020-01-07T16:20:33     2020-01-07          2020-01
# 7             NA  2020-01-07T16:20:33     2020-01-07          2020-01
# 8             NA  2020-01-07T16:20:33     2020-01-07          2020-01
# 9             NA  2020-01-07T16:20:33     2020-01-07          2020-01
# 10            NA  2020-01-07T16:20:33     2020-01-07          2020-01
# 11            NA  2020-01-07T16:20:33     2020-01-07          2020-01
# 12            NA  2020-01-07T16:20:33     2020-01-07          2020-01
# 13            NA  2020-01-07T16:20:33     2020-01-07          2020-01
# 14            NA  2020-01-07T16:20:33     2020-01-07          2020-01
# 15            NA  2020-01-07T16:20:33     2020-01-07          2020-01
# 16            NA  2020-01-07T16:20:33     2020-01-07          2020-01
#
#    created_at_year           updated_at  \
# 0             2020  2020-01-07T16:20:33
# 1             2020  2020-01-07T16:20:33
# 2             2020  2020-01-07T16:20:33
# 3             2020  2020-01-07T16:20:33
# 4             2020  2020-01-07T16:20:33
# 5             2020  2020-01-07T16:20:33
# 6             2020  2020-01-07T16:20:33
# 7             2020  2020-01-07T16:20:33
# 8             2020  2020-01-07T16:20:33
# 9             2020  2020-01-07T16:20:33
# 10            2020  2020-01-07T16:20:33
# 11            2020  2020-01-07T16:20:33
# 12            2020  2020-01-07T16:20:33
# 13            2020  2020-01-07T16:20:33
# 14            2020  2020-01-07T16:20:33
# 15            2020  2020-01-07T16:20:33
# 16            2020  2020-01-07T16:20:33
#
#                                         name  \
# 0                                Data Backup
# 1                     Filter Network Traffic
# 2                            Update Software
# 3                              User Training
# 4                     \nExecution Prevention
# 5              Privileged Account Management
# 6                 Restrict Web-Based Content
# 7                              User Training
# 8                        Protect credentials
# 9     Deploy good authentication practices\n
# 10         Protect high privilege accounts\n
# 11  Apply the principle of least privilege\n
# 12                       Lock down devices\n
# 13              Segregate networks as sets\n
# 14                        Monitor networks\n
# 15                  Consider using honeypots
# 16                     Antivirus/Antimalware
#
#                                           description alias graph_data  \
# 0   Take and store data backups from end user syst...    NA         NA
# 1   Use network appliances to filter ingress or eg...    NA         NA
# 2   Perform regular software updates to mitigate e...    NA         NA
# 3   Train users to to be aware of access or manipu...    NA         NA
# 4   Block execution of code on a system through ap...    NA         NA
# 5   Manage the creation, modification, use, and pe...    NA         NA
# 6   Determine if certain social media sites, perso...    NA         NA
# 7   Users can be trained to identify social engine...    NA         NA
# 8   All credentials on a network, especially those...    NA         NA
# 9   Authentication should be easy for the user, bu...    NA         NA
# 10  Local and domain administrative accounts - wit...    NA         NA
# 11  The principle of 'least privilege' (where acco...    NA         NA
# 12  Any device or system that is part of your netw...    NA         NA
# 13  Network segmentation (or segregation), involve...    NA         NA
# 14  It is vital to monitor your network for any se...    NA         NA
# 15  Honeypots are systems set up for the sole purp...    NA         NA
# 16  Anti-virus can also automatically quarantine s...    NA         NA
#
#    external_references  object_marking_refs granular_markings
# 0                    NA                  NA                NA
# 1                    NA                  NA                NA
# 2                    NA                  NA                NA
# 3                    NA                  NA                NA
# 4                    NA                  NA                NA
# 5                    NA                  NA                NA
# 6                    NA                  NA                NA
# 7                    NA                  NA                NA
# 8                    NA                  NA                NA
# 9                    NA                  NA                NA
# 10                   NA                  NA                NA
# 11                   NA                  NA                NA
# 12                   NA                  NA                NA
# 13                   NA                  NA                NA
# 14                   NA                  NA                NA
# 15                   NA                  NA                NA
# 16                   NA                  NA                NA

# %%
def insert_one_course_of_action(df,session):
    #if df.first_seen != 'NA':
     #   f=df.first_seen.strftime("%Y-%m-%dT%H:%M:%S")
     #   f_m=df.first_seen.strftime("%Y-%m")
     #   f_d=df.first_seen.strftime("%Y-%m-%d")
    #elif df.first_seen_month != 'NA':
    #    f_m=df.first_seen_month
    #elif df.first_seen_day != 'NA':
    #    f_d=df.first_seen_day
    #else:
    #    f_d=None
    #    f_m=None
    #    f=None
    aliases = list()
    if df['alias'] != 'NA':            
        aliases=df.alias.split('\n')

    graql_match_query = f"match $i isa Course-Of-Action, " \
                        f"has name \"{df['name']}__\"; " \
                        f"get;"
    # print(graql_match_query)
    with session.transaction().read() as read_transaction:
        # read_transaction.query(graql_match_query)
        answer_iterator = None
        answer_iterator = read_transaction.query(graql_match_query, infer=True)
        data = answer_iterator.collect_concepts()
                
        if len(data) > 0:
            # Update data.
            # Columns to be updated: object_status, revoked, updated_at, modified, description, alias
            # print("Update intrusion-set...")
            print("Update: " + df['name'])
            graql_attribute_delete_query = f"match $i isa Course-Of-Action, " \
                                           f"has name \"{df['name']}__\", "\
                                           f"has alias $a via $i1, "\
                                           f"has description $a via $i2; "\
                                           f"delete $i1, $i2;"
            update_flg = False
            first_attr_flg = True
            graql_attribute_update_query = f"match $i isa Course-Of-Action, " \
                                           f"has name \"{df['name']}__\"; insert $i"
            if df['description'] != 'NA':
                # graql_attribute_delete_query += f" has description $a via $i2; "\
                graql_attribute_update_query += f" has description \"{df['description']}\" "
                if (first_attr_flg) & (len(aliases)>0):
                    graql_attribute_update_query += ","
                update_flg = True
                first_attr_flg = False
            print(len(aliases))
            if len(aliases) > 0:
                s = "|"
                graql_attribute_update_query += f" has alias \"{s.join(aliases).replace(' ','')}\" " 
                if first_attr_flg:
                     graql_attribute_update_query += ","
                update_flg = True
                first_attr_flg = False
            graql_attribute_update_query += ";"
            print(graql_attribute_update_query)
            if update_flg:
                with session.transaction().write() as write_transaction:
                    # make a write transection with the query
                    write_transaction.query(graql_attribute_delete_query)
                    write_transaction.query(graql_attribute_update_query)
                    # remember to commit at the end
                    write_transaction.commit()           
        else:
            # print("Insert intrusion-set...")
            print("Insert: " + df['name'])
            graql_insert_query = f"insert $x isa Course-Of-Action, " \
                                 f"has internal_id_key \"{df['internal_id_key']}\", " \
                                 f"has stix_id_key \"{df['stix_id_key']}\", " \
                                 f"has stix_label \"{df['stix_label']}\", " \
                                 f"has entity_type \"{df['entity_type']}\", " \
                                 f"has created {df['created']}, " \
                                 f"has revoked \"{df['revoked']}\", "\
                                 f"has created_at {df['created_at']}, " \
                                 f"has created_at_day \"{df['created_at_day']}\", " \
                                 f"has created_at_month \"{df['created_at_month']}\", " \
                                 f"has created_at_year \"{df['created_at_year']}\", "\
                                 f"has updated_at {df['updated_at']}, "\
                                 f"has name \"{df['name']}__\" "
                                 
            if df['description'] != 'NA':
                graql_insert_query += f", has description \"{df['description']}\" "
            if len(aliases) > 0:
                s = "|"
                graql_insert_query += f", has alias \"{s.join(aliases)}\" "
            #if f is not None:
            #    graql_insert_query += f", has first_seen {f} "
            #if f_d is not None:
            #    graql_insert_query += f", has first_seen_day \"{f_d}\" "
            #if f_m is not None:
             #   graql_insert_query += f", has first_seen_month \"{f_m}\" "
            #if f_m is not None:
            #    graql_insert_query += f", has first_seen_year \"{df['first_seen_year']}\""
            graql_insert_query += ";"
            #print(graql_insert_query)
            with session.transaction().write() as write_transaction:
                # make a write transection with the query
                write_transaction.query(graql_insert_query)
                # remember to commit at the end
                write_transaction.commit()

# %%
def load_data_into_grakn(session,input_df):
    print("Inserting course_of_action...")
    # using progress_apply instead of apply so we have a progress bar form tqdm
    # input_df.progress_apply(insert_one_intrusion_set, axis=1, session=session)
    print("course_of_action...")
    for index,row in input_df.iterrows():
        insert_one_course_of_action(df=row,session=session)

# %%
def build_grakn_graph(input_df, keyspace_name):
    with GraknClient(uri="192.168.83.128:48555") as client:
        with client.session(keyspace = keyspace_name) as session:
            load_data_into_grakn(session,input_df)

# %%
build_grakn_graph(input_df=result,keyspace_name='grakn')
# Out:
# Inserting course_of_action...
# course_of_action...
# Update: Data Backup
# 0
# match $i isa Course-Of-Action, has name "Data Backup__"; insert $i has description "Take and store data backups from end user systems and critical servers. Ensure backup and storage systems are hardened and kept separate from the corporate network to prevent compromise." ;
# Update: Filter Network Traffic
# 0
# match $i isa Course-Of-Action, has name "Filter Network Traffic__"; insert $i has description "Use network appliances to filter ingress or egress traffic and perform protocol-based filtering. Configure software on endpoints to filter network traffic." ;
# Update: Update Software
# 0
# match $i isa Course-Of-Action, has name "Update Software__"; insert $i has description "Perform regular software updates to mitigate exploitation risk." ;
# Update: User Training
# 0
# match $i isa Course-Of-Action, has name "User Training__"; insert $i has description "Train users to to be aware of access or manipulation attempts by an adversary to reduce the risk of successful spearphishing, social engineering, and other techniques that involve user interaction.
# " ;
# Update:
# Execution Prevention
# 0
# match $i isa Course-Of-Action, has name "
# Execution Prevention__"; insert $i has description "Block execution of code on a system through application whitelisting, blacklisting, and/or script blocking." ;
# Update: Privileged Account Management
# 0
# match $i isa Course-Of-Action, has name "Privileged Account Management__"; insert $i has description "Manage the creation, modification, use, and permissions associated to privileged accounts, including SYSTEM and root." ;
# Update: Restrict Web-Based Content
# 0
# match $i isa Course-Of-Action, has name "Restrict Web-Based Content__"; insert $i has description "Determine if certain social media sites, personal webmail services, or other service that can be used for spearphishing is necessary for business operations and consider blocking access if activity cannot be monitored well or if it poses a significant risk." ;
# Update: User Training
# 0
# match $i isa Course-Of-Action, has name "User Training__"; insert $i has description "Users can be trained to identify social engineering techniques and spearphishing emails with malicious links." ;
# Update: Protect credentials
# 0
# match $i isa Course-Of-Action, has name "Protect credentials__"; insert $i has description "All credentials on a network, especially those of administrator accounts, should be adequately protected to prevent attackers using them to gain access to devices and systems.
#
# " ;
# Update: Deploy good authentication practices
#
# 0
# match $i isa Course-Of-Action, has name "Deploy good authentication practices
# __"; insert $i has description "Authentication should be easy for the user, but make it difficult for an attacker to gain access. Follow the NCSC password guidance to ensure your policy follows best practice. For example, do not re-use passwords for different systems, and consider the use of password managers in your organisation. This will limit the number of users storing credentials in plain text.
# " ;
# Update: Protect high privilege accounts
#
# 0
# match $i isa Course-Of-Action, has name "Protect high privilege accounts
# __"; insert $i has description "Local and domain administrative accounts - with access to most systems and data - are powerful tools in a network. Their use should be tightly controlled and locked down.
# " ;
# Update: Apply the principle of least privilege
#
# 0
# match $i isa Course-Of-Action, has name "Apply the principle of least privilege
# __"; insert $i has description "The principle of 'least privilege' (where accounts and users have the minimum amount of access needed to perform their role) should be implemented wherever possible. A tiering model for administrative accounts ensures they only have access to the specific administrative capabilities needed, rather than all of them.
# " ;
# Update: Lock down devices
#
# 0
# match $i isa Course-Of-Action, has name "Lock down devices
# __"; insert $i has description "Any device or system that is part of your network (even those not directly connected to the internet) can be targeted in the lateral movement stage of an attack. All devices should be kept up to date, with the latest patches deployed as soon as possible. Automated updates can also be used to simplify this process, although it is important to ensure that redundant pairs of devices update at different times to maintain redundancy.
# " ;
# Update:  Segregate networks as sets
#
# 0
# match $i isa Course-Of-Action, has name " Segregate networks as sets
# __"; insert $i has description "Network segmentation (or segregation), involves splitting up a network into various network segments. This greatly increases the difficulty for an attacker to reach their goal once in the network, as their point of entry may not have any means of reaching the target data or system.
#
# Systems and data that do not need to communicate or interact with each other should be separated into different network segments, and only allow users to access a segment where needed." ;
# Update: Monitor networks
#
# 0
# match $i isa Course-Of-Action, has name "Monitor networks
# __"; insert $i has description "It is vital to monitor your network for any security events that may be of interest. As new vulnerabilities are constantly discovered, determined attackers will eventually gain access, regardless of how well your network is protected. Once this happens, monitoring the network is the only way you can identify a breach, then react.
# " ;
# Update: Consider using honeypots
# 0
# match $i isa Course-Of-Action, has name "Consider using honeypots__"; insert $i has description "Honeypots are systems set up for the sole purpose of being attacked.
# Production honeypots, set up internally in a network as a decoy for real systems, can be valuable tools in detecting an intrusion into your network. As honeypots are not legitimate systems on the network (and contain no real data or services) unexpected connections can be assumed to be hostile activity (because genuine users have no need to access the honeypot)." ;
# Update: Antivirus/Antimalware
# 0
# match $i isa Course-Of-Action, has name "Antivirus/Antimalware__"; insert $i has description "Anti-virus can also automatically quarantine suspicious files." ;
