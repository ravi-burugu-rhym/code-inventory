# %%
import pandas as pd
import uuid
from datetime import datetime
import numpy as np
from grakn.client import GraknClient
from tqdm import tqdm
tqdm.pandas()

# %%
df=pd.read_excel(r"C:\Users\SRIKANTH\Desktop\OpenCTI_Data.xlsx",sheet_name='Course_of_action')

# %%
df.keys()
# Out:
# Index(['internal_id_key', 'stix_id_key', 'stix_label', 'entity_type',
#        'created', 'modified', 'revoked', 'object_status', 'created_at',
#        'created_at_day', 'created_at_month', 'created_at_year', 'updated_at',
#        'name', 'description', 'aliases', 'graph_data', 'external_references ',
#        'object_marking_refs', 'granular_markings'],
#       dtype='object')

# %%
def  insert_general_info(df,ent_type,create):
    if create:
        for index,i in df.iterrows():
            df.internal_id_key[index]=str(uuid.uuid4())
            df.stix_id_key[index]=ent_type+'--'+str(uuid.uuid4())
            df.stix_label[index]='NA'
            df.entity_type[index]=ent_type
            df.created=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.created_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.created_at_day=(datetime.now()).strftime("%Y-%m-%d")
            df.created_at_month=(datetime.now()).strftime("%Y-%m")
            df.created_at_year=(datetime.now()).strftime("%Y")
            df.modified=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.updated_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.revoked=False
            df.object_status='NA'
    else:
            df.modified=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.updated_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
    return df

# %%
result=insert_general_info(df=df,ent_type='Intrusion-set',create=True)
result.fillna('NA',inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\SRIKANTH\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
result
# Out:
#                          internal_id_key  \
# 0   bb188afe-6ba3-469c-a237-ef5b7dd6a2d8
# 1   2a9750c2-07e3-4de3-b683-b3d78e5ba4f8
# 2   5572d27e-61b5-406f-a04e-a822605c5446
# 3   9e5ae6fc-2159-4f33-85b1-9094e10327cf
# 4   f05f90fc-39f1-4595-89fa-79fbc9dd672f
# 5   b126003f-8c1f-42fc-9762-e7bf4515a6bd
# 6   1f549303-41cc-48a3-9eb0-6f643bb54c84
# 7   51392841-f84d-4b59-83e6-b54fc8bca4a2
# 8   fab75a9d-ea34-4219-b67d-14f810e7cb22
# 9   4d2114b9-3dbc-4722-844e-5f7e2b372e2f
# 10  5e1a2121-825b-4d15-bc23-2c6e6ce76124
# 11  bde2606f-c756-4bc4-8026-19c021a2ae92
# 12  5efa5179-a8da-455f-939b-c127c4ac143c
# 13  58742f63-b17e-425f-823f-49d438ac7421
# 14  5a2c6fc0-d601-4366-8c3f-5ef0eb1e9af8
# 15  5aa62533-58ff-438f-935d-2c6610131914
# 16  a8a69f2a-a707-4a8c-883c-da0aadbf532e
#
#                                           stix_id_key stix_label  \
# 0   Intrusion-set--4ee03e76-4071-4018-a714-15e57c0...         NA
# 1   Intrusion-set--196a06e8-ef75-4b9c-8071-fae31e0...         NA
# 2   Intrusion-set--112ac6e7-69fc-4ef7-a9ae-0f11c51...         NA
# 3   Intrusion-set--b26da308-b548-46cb-ad4e-85af065...         NA
# 4   Intrusion-set--11df7d36-10e4-4f77-969a-4f816df...         NA
# 5   Intrusion-set--0d69f376-a858-4a49-af7f-b96476d...         NA
# 6   Intrusion-set--7c103be3-ffbd-4df6-9961-1fe530c...         NA
# 7   Intrusion-set--ca115c11-2d6c-4adc-a129-bf0cfe4...         NA
# 8   Intrusion-set--abb2d2df-3fff-4f05-9578-29fd480...         NA
# 9   Intrusion-set--da7122f1-4c7d-429f-a4bd-05054c9...         NA
# 10  Intrusion-set--461ba933-ab9e-443e-ad6e-938ecc1...         NA
# 11  Intrusion-set--296c3a23-0c53-4ade-b40d-ba25bfa...         NA
# 12  Intrusion-set--9eea2d82-8e11-4e87-99dd-158c586...         NA
# 13  Intrusion-set--78ed64a5-798e-4d5f-9d89-de43fd9...         NA
# 14  Intrusion-set--391d1a77-8e17-408f-89f3-dd1136b...         NA
# 15  Intrusion-set--a6ead011-fb53-4e0f-969f-94282a0...         NA
# 16  Intrusion-set--b38ca85c-a134-451d-bf1d-bf18bfb...         NA
#
#       entity_type              created             modified  revoked  \
# 0   Intrusion-set  2020-01-07T16:15:13  2020-01-07T16:15:13    False
# 1   Intrusion-set  2020-01-07T16:15:13  2020-01-07T16:15:13    False
# 2   Intrusion-set  2020-01-07T16:15:13  2020-01-07T16:15:13    False
# 3   Intrusion-set  2020-01-07T16:15:13  2020-01-07T16:15:13    False
# 4   Intrusion-set  2020-01-07T16:15:13  2020-01-07T16:15:13    False
# 5   Intrusion-set  2020-01-07T16:15:13  2020-01-07T16:15:13    False
# 6   Intrusion-set  2020-01-07T16:15:13  2020-01-07T16:15:13    False
# 7   Intrusion-set  2020-01-07T16:15:13  2020-01-07T16:15:13    False
# 8   Intrusion-set  2020-01-07T16:15:13  2020-01-07T16:15:13    False
# 9   Intrusion-set  2020-01-07T16:15:13  2020-01-07T16:15:13    False
# 10  Intrusion-set  2020-01-07T16:15:13  2020-01-07T16:15:13    False
# 11  Intrusion-set  2020-01-07T16:15:13  2020-01-07T16:15:13    False
# 12  Intrusion-set  2020-01-07T16:15:13  2020-01-07T16:15:13    False
# 13  Intrusion-set  2020-01-07T16:15:13  2020-01-07T16:15:13    False
# 14  Intrusion-set  2020-01-07T16:15:13  2020-01-07T16:15:13    False
# 15  Intrusion-set  2020-01-07T16:15:13  2020-01-07T16:15:13    False
# 16  Intrusion-set  2020-01-07T16:15:13  2020-01-07T16:15:13    False
#
#    object_status           created_at created_at_day created_at_month  \
# 0             NA  2020-01-07T16:15:13     2020-01-07          2020-01
# 1             NA  2020-01-07T16:15:13     2020-01-07          2020-01
# 2             NA  2020-01-07T16:15:13     2020-01-07          2020-01
# 3             NA  2020-01-07T16:15:13     2020-01-07          2020-01
# 4             NA  2020-01-07T16:15:13     2020-01-07          2020-01
# 5             NA  2020-01-07T16:15:13     2020-01-07          2020-01
# 6             NA  2020-01-07T16:15:13     2020-01-07          2020-01
# 7             NA  2020-01-07T16:15:13     2020-01-07          2020-01
# 8             NA  2020-01-07T16:15:13     2020-01-07          2020-01
# 9             NA  2020-01-07T16:15:13     2020-01-07          2020-01
# 10            NA  2020-01-07T16:15:13     2020-01-07          2020-01
# 11            NA  2020-01-07T16:15:13     2020-01-07          2020-01
# 12            NA  2020-01-07T16:15:13     2020-01-07          2020-01
# 13            NA  2020-01-07T16:15:13     2020-01-07          2020-01
# 14            NA  2020-01-07T16:15:13     2020-01-07          2020-01
# 15            NA  2020-01-07T16:15:13     2020-01-07          2020-01
# 16            NA  2020-01-07T16:15:13     2020-01-07          2020-01
#
#    created_at_year           updated_at  \
# 0             2020  2020-01-07T16:15:13
# 1             2020  2020-01-07T16:15:13
# 2             2020  2020-01-07T16:15:13
# 3             2020  2020-01-07T16:15:13
# 4             2020  2020-01-07T16:15:13
# 5             2020  2020-01-07T16:15:13
# 6             2020  2020-01-07T16:15:13
# 7             2020  2020-01-07T16:15:13
# 8             2020  2020-01-07T16:15:13
# 9             2020  2020-01-07T16:15:13
# 10            2020  2020-01-07T16:15:13
# 11            2020  2020-01-07T16:15:13
# 12            2020  2020-01-07T16:15:13
# 13            2020  2020-01-07T16:15:13
# 14            2020  2020-01-07T16:15:13
# 15            2020  2020-01-07T16:15:13
# 16            2020  2020-01-07T16:15:13
#
#                                         name  \
# 0                                Data Backup
# 1                     Filter Network Traffic
# 2                            Update Software
# 3                              User Training
# 4                     \nExecution Prevention
# 5              Privileged Account Management
# 6                 Restrict Web-Based Content
# 7                              User Training
# 8                        Protect credentials
# 9     Deploy good authentication practices\n
# 10         Protect high privilege accounts\n
# 11  Apply the principle of least privilege\n
# 12                       Lock down devices\n
# 13              Segregate networks as sets\n
# 14                        Monitor networks\n
# 15                  Consider using honeypots
# 16                     Antivirus/Antimalware
#
#                                           description aliases graph_data  \
# 0   Take and store data backups from end user syst...      NA         NA
# 1   Use network appliances to filter ingress or eg...      NA         NA
# 2   Perform regular software updates to mitigate e...      NA         NA
# 3   Train users to to be aware of access or manipu...      NA         NA
# 4   Block execution of code on a system through ap...      NA         NA
# 5   Manage the creation, modification, use, and pe...      NA         NA
# 6   Determine if certain social media sites, perso...      NA         NA
# 7   Users can be trained to identify social engine...      NA         NA
# 8   All credentials on a network, especially those...      NA         NA
# 9   Authentication should be easy for the user, bu...      NA         NA
# 10  Local and domain administrative accounts - wit...      NA         NA
# 11  The principle of 'least privilege' (where acco...      NA         NA
# 12  Any device or system that is part of your netw...      NA         NA
# 13  Network segmentation (or segregation), involve...      NA         NA
# 14  It is vital to monitor your network for any se...      NA         NA
# 15  Honeypots are systems set up for the sole purp...      NA         NA
# 16  Anti-virus can also automatically quarantine s...      NA         NA
#
#    external_references  object_marking_refs granular_markings
# 0                    NA                  NA                NA
# 1                    NA                  NA                NA
# 2                    NA                  NA                NA
# 3                    NA                  NA                NA
# 4                    NA                  NA                NA
# 5                    NA                  NA                NA
# 6                    NA                  NA                NA
# 7                    NA                  NA                NA
# 8                    NA                  NA                NA
# 9                    NA                  NA                NA
# 10                   NA                  NA                NA
# 11                   NA                  NA                NA
# 12                   NA                  NA                NA
# 13                   NA                  NA                NA
# 14                   NA                  NA                NA
# 15                   NA                  NA                NA
# 16                   NA                  NA                NA

# %%
def insert_one_course_of_action(df,session):
    #if df.first_seen != 'NA':
     #   f=df.first_seen.strftime("%Y-%m-%dT%H:%M:%S")
     #   f_m=df.first_seen.strftime("%Y-%m")
     #   f_d=df.first_seen.strftime("%Y-%m-%d")
    #elif df.first_seen_month != 'NA':
    #    f_m=df.first_seen_month
    #elif df.first_seen_day != 'NA':
    #    f_d=df.first_seen_day
    #else:
    #    f_d=None
    #    f_m=None
    #    f=None
    aliases = list()
    if df['alias'] != 'NA':            
        aliases=df.alias.split('\n')

    graql_match_query = f"match $i isa , " \
                        f"has name \"{df['name']}__\"; " \
                        f"get;"
    # print(graql_match_query)
    with session.transaction().read() as read_transaction:
        # read_transaction.query(graql_match_query)
        answer_iterator = None
        answer_iterator = read_transaction.query(graql_match_query, infer=True)
        data = answer_iterator.collect_concepts()
                
        if len(data) > 0:
            # Update data.
            # Columns to be updated: object_status, revoked, updated_at, modified, description, alias
            # print("Update intrusion-set...")
            print("Update: " + df['name'])
            graql_attribute_delete_query = f"match $i isa Malware, " \
                                           f"has name \"{df['name']}__\", "\
                                           f"has alias $a via $i1, "\
                                           f"has description $a via $i2; "\
                                           f"delete $i1, $i2;"
            update_flg = False
            first_attr_flg = True
            graql_attribute_update_query = f"match $i isa Malware, " \
                                           f"has name \"{df['name']}__\"; insert $i"
            if df['description'] != 'NA':
                # graql_attribute_delete_query += f" has description $a via $i2; "\
                graql_attribute_update_query += f" has description \"{df['description']}\" "
                if (first_attr_flg) & (len(aliases)>0):
                    graql_attribute_update_query += ","
                update_flg = True
                first_attr_flg = False
            print(len(aliases))
            if len(aliases) > 0:
                s = "|"
                graql_attribute_update_query += f" has alias \"{s.join(aliases).replace(' ','')}\" " 
                if first_attr_flg:
                     graql_attribute_update_query += ","
                update_flg = True
                first_attr_flg = False
            graql_attribute_update_query += ";"
            print(graql_attribute_update_query)
            if update_flg:
                with session.transaction().write() as write_transaction:
                    # make a write transection with the query
                    write_transaction.query(graql_attribute_delete_query)
                    write_transaction.query(graql_attribute_update_query)
                    # remember to commit at the end
                    write_transaction.commit()           
        else:
            # print("Insert intrusion-set...")
            print("Insert: " + df['name'])
            graql_insert_query = f"insert $x isa Malware, " \
                                 f"has internal_id_key \"{df['internal_id_key']}\", " \
                                 f"has stix_id_key \"{df['stix_id_key']}\", " \
                                 f"has stix_label \"{df['stix_label']}\", " \
                                 f"has entity_type \"{df['entity_type']}\", " \
                                 f"has created {df['created']}, " \
                                 f"has revoked \"{df['revoked']}\", "\
                                 f"has created_at {df['created_at']}, " \
                                 f"has created_at_day \"{df['created_at_day']}\", " \
                                 f"has created_at_month \"{df['created_at_month']}\", " \
                                 f"has created_at_year \"{df['created_at_year']}\", "\
                                 f"has updated_at {df['updated_at']}, "\
                                 f"has name \"{df['name']}__\" "
                                 
            if df['description'] != 'NA':
                graql_insert_query += f", has description \"{df['description']}\" "
            if len(aliases) > 0:
                s = "|"
                graql_insert_query += f", has alias \"{s.join(aliases)}\" "
            #if f is not None:
            #    graql_insert_query += f", has first_seen {f} "
            #if f_d is not None:
            #    graql_insert_query += f", has first_seen_day \"{f_d}\" "
            #if f_m is not None:
             #   graql_insert_query += f", has first_seen_month \"{f_m}\" "
            #if f_m is not None:
            #    graql_insert_query += f", has first_seen_year \"{df['first_seen_year']}\""
            graql_insert_query += ";"
            #print(graql_insert_query)
            with session.transaction().write() as write_transaction:
                # make a write transection with the query
                write_transaction.query(graql_insert_query)
                # remember to commit at the end
                write_transaction.commit()

# %%
def load_data_into_grakn(session,input_df):
    print("Inserting intrusion-set...")
    # using progress_apply instead of apply so we have a progress bar form tqdm
    # input_df.progress_apply(insert_one_intrusion_set, axis=1, session=session)
    print("Loading intrusion-set...")
    for index,row in input_df.iterrows():
        insert_one_intrusion_set(df=row,session=session)

# %%
def build_grakn_graph(input_df, keyspace_name):
    with GraknClient(uri="192.168.83.128:48555") as client:
        with client.session(keyspace = keyspace_name) as session:
            load_data_into_grakn(session,input_df)

# %%
build_grakn_graph(input_df=result,keyspace_name='grakn')
# Out:
# Inserting intrusion-set...
# Loading intrusion-set...
# Insert: APT12x_
# Insert: APT28x_
# Insert: BlackOasis_
# Insert: Cobaltx_
# Insert: APT30x_
