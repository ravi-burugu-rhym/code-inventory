# %%
import pandas as pd
import uuid
from datetime import datetime
import numpy as np
from grakn.client import GraknClient
from tqdm import tqdm
tqdm.pandas()

# %%
df=pd.read_excel(r"C:\Users\SRIKANTH\Desktop\OpenCTI_Data.xlsx",sheet_name='Vulnerability')

# %%
def  insert_general_info(df,ent_type,create):
    if create:
        for index,i in df.iterrows():
            df.internal_id_key[index]=str(uuid.uuid4())
            df.stix_id_key[index]=ent_type+'--'+str(uuid.uuid4())
            df.stix_label[index]='NA'
            df.entity_type[index]=ent_type
            df.created=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.created_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.created_at_day=(datetime.now()).strftime("%Y-%m-%d")
            df.created_at_month=(datetime.now()).strftime("%Y-%m")
            df.created_at_year=(datetime.now()).strftime("%Y")
            df.modified=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.updated_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.revoked=False
            df.object_status='NA'
    else:
            df.modified=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.updated_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
    return df

# %%
result=insert_general_info(df=df,ent_type='Vulnerability',create=True)
result.fillna('NA',inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\SRIKANTH\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
result
# Out:
#                          internal_id_key  \
# 0   d35553a4-d597-42a8-bb51-eb70bc163a15
# 1   bbd3f81b-0f19-4246-9168-b485a48c9842
# 2   b2012f32-37eb-440e-a1ed-f7d23b9e87d4
# 3   6944c61e-cb2f-42a0-bb70-825c91d3f9b6
# 4   df072cc9-669a-4fdb-8a2c-c51689e936e7
# 5   ff7f3596-2fee-444e-9f41-77adde780cdb
# 6   c410d7bb-6b15-49cf-a9b7-f408796fa498
# 7   a42c331a-bf54-42d8-b79a-6f710f447c84
# 8   0c0c7409-77dd-454a-83d3-b3d7eefc825f
# 9   7f3213db-9106-442c-82d8-58ec578c7be1
# 10  e600df47-aed7-44fb-b07e-9e5d1d27a05c
# 11  61204712-1661-4a88-9b9a-c5d6f0e8a1e3
# 12  48fc249c-dc1c-4b2f-87e6-ea243414f58f
# 13  e884d2ea-4523-412c-9188-8d1c0e89397a
# 14  6b478a07-2936-45b7-8d44-889addba7b4a
# 15  1a955ca7-1017-406c-8997-1b779bd62359
# 16  c2227d4f-92a6-465b-ae50-e2fef0ea5cde
# 17  97267b01-a495-4c90-9bd4-242fa725770d
# 18  595ac97e-1286-4576-8fdc-78b366264601
# 19  2f5c6119-5049-4d71-8fda-65b1de7b3ff8
# 20  644ed7da-8dc3-4ba5-8e53-91e2bae9b4de
# 21  048622b2-e677-42b0-8ad3-2d1a31c5cae3
# 22  d9069b37-5ef7-45d2-8ff5-7f8ed11900b0
# 23  40948be2-7997-48dc-8420-c9e558c70d9b
# 24  811f3bc2-17fc-4836-b47d-eb0c5970fe06
# 25  fa578ee2-9f73-42b8-9e77-de2ca70e455d
# 26  e6462889-86ac-48f8-8a07-a649f95df124
# 27  5d85880e-fa0e-4c74-9b7b-e7df2753b9ab
# 28  5887209e-b3b6-4e9a-857e-93b1f2fb2944
# 29  24642abd-351b-439b-b3bc-9872f99008a8
# 30  4c897151-b111-40c9-838e-ae7ced5199ba
# 31  fc353062-0b3a-4428-94e6-3e3a672db869
#
#                                           stix_id_key stix_label  \
# 0   Vulnerability--5908d7fd-483a-411d-a98d-7304a4b...         NA
# 1   Vulnerability--a8933797-04b4-4c91-baf3-0c6f8b9...         NA
# 2   Vulnerability--b2d19edd-7dc7-4b1f-9c4b-3eeaafe...         NA
# 3   Vulnerability--94c1ee9d-6a02-44d7-9c7a-484ed0f...         NA
# 4   Vulnerability--7c52344a-c003-44bb-b1f0-8fa0ca2...         NA
# 5   Vulnerability--0c8edbf9-cc85-429e-ba4a-79d78b3...         NA
# 6   Vulnerability--9a23d7f7-2b5c-48e9-ae5a-e284b36...         NA
# 7   Vulnerability--d03b4bf1-6e61-4bf3-b333-5e72c68...         NA
# 8   Vulnerability--77d63b78-9d93-470b-ba9b-65e6bf1...         NA
# 9   Vulnerability--7ed31ca1-11e3-4958-9061-d6e14f7...         NA
# 10  Vulnerability--ac22c620-1285-4168-a232-0f12e51...         NA
# 11  Vulnerability--3c162c2f-aeaa-4a59-8f68-99b64b7...         NA
# 12  Vulnerability--84b74c29-a6b2-48b4-86da-24a41a5...         NA
# 13  Vulnerability--288e4e8d-85bb-4f91-9f8b-faa03b1...         NA
# 14  Vulnerability--4c9ee84f-1391-49a8-a928-268be8f...         NA
# 15  Vulnerability--a73b11d7-3f4a-4ea4-842c-2b672a4...         NA
# 16  Vulnerability--da3609b4-ab38-4cc8-a2c2-ea214e7...         NA
# 17  Vulnerability--aa305b36-3c52-486c-b9f7-f255a41...         NA
# 18  Vulnerability--130657b0-12e2-4a04-a952-5e7abfd...         NA
# 19  Vulnerability--d4a37940-4a83-465a-8bc3-d911f00...         NA
# 20  Vulnerability--942ac8b0-aaae-4403-a687-9b051e1...         NA
# 21  Vulnerability--2864057e-ac1e-44e3-a15f-d89fe70...         NA
# 22  Vulnerability--5a19f77f-6ebb-4ffe-a155-2d75242...         NA
# 23  Vulnerability--e8371b85-086c-4e47-9214-3ba5ca0...         NA
# 24  Vulnerability--8e3f7de0-6777-453e-ac68-2cb43aa...         NA
# 25  Vulnerability--bbd9e023-e30c-49cf-ab38-de49973...         NA
# 26  Vulnerability--bb284bbf-94f7-418e-8b2b-d6a2869...         NA
# 27  Vulnerability--2c820eac-6d56-4618-a423-d2d6d29...         NA
# 28  Vulnerability--f257327f-48e8-430a-a6f7-d929b93...         NA
# 29  Vulnerability--ab5cf8b3-d966-4b37-86b1-4c0a4ff...         NA
# 30  Vulnerability--d4ce6d67-ba33-4c9d-83f2-a183393...         NA
# 31  Vulnerability--8550707a-4d2d-47e3-8b2d-0bfba23...         NA
#
#       entity_type              created             modified  revoked  \
# 0   Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 1   Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 2   Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 3   Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 4   Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 5   Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 6   Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 7   Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 8   Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 9   Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 10  Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 11  Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 12  Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 13  Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 14  Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 15  Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 16  Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 17  Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 18  Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 19  Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 20  Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 21  Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 22  Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 23  Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 24  Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 25  Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 26  Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 27  Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 28  Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 29  Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 30  Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
# 31  Vulnerability  2020-01-22T10:27:59  2020-01-22T10:27:59    False
#
#    object_status           created_at created_at_day created_at_month  \
# 0             NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 1             NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 2             NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 3             NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 4             NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 5             NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 6             NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 7             NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 8             NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 9             NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 10            NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 11            NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 12            NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 13            NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 14            NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 15            NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 16            NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 17            NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 18            NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 19            NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 20            NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 21            NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 22            NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 23            NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 24            NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 25            NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 26            NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 27            NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 28            NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 29            NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 30            NA  2020-01-22T10:27:59     2020-01-22          2020-01
# 31            NA  2020-01-22T10:27:59     2020-01-22          2020-01
#
#    created_at_year           updated_at                               name  \
# 0             2020  2020-01-22T10:27:59                      CVE-2009-4324
# 1             2020  2020-01-22T10:27:59                  CVE-2011-0611
# 2             2020  2020-01-22T10:27:59                   CVE-2009-0927
# 3             2020  2020-01-22T10:27:59                      CVE-2011-0609
# 4             2020  2020-01-22T10:27:59                       CVE-209-3129
# 5             2020  2020-01-22T10:27:59                      CVE-2012-0158
# 6             2020  2020-01-22T10:27:59                      CVE-2013-1347
# 7             2020  2020-01-22T10:27:59                      CVE-2013-3897
# 8             2020  2020-01-22T10:27:59                      CVE-2014-1510
# 9             2020  2020-01-22T10:27:59                      CVE-2014-1511
# 10            2020  2020-01-22T10:27:59                      CVE-2014-1776
# 11            2020  2020-01-22T10:27:59                      CVE-2014-6332
# 12            2020  2020-01-22T10:27:59                    \nCVE-2015-2590
# 13            2020  2020-01-22T10:27:59                      CVE-2015-4902
# 14            2020  2020-01-22T10:27:59                      CVE-2015-3043
# 15            2020  2020-01-22T10:27:59                      CVE-2015-5119
# 16            2020  2020-01-22T10:27:59  \n\n\n\n\n\n\n\n\nCVE-2015-7645\n
# 17            2020  2020-01-22T10:27:59                      CVE-2015-5119
# 18            2020  2020-01-22T10:27:59                   \nCVE-2016-0984
# 19            2020  2020-01-22T10:27:59                      CVE-2016-4117
# 20            2020  2020-01-22T10:27:59                    \nCVE-2017-8759
# 21            2020  2020-01-22T10:27:59                \n \nCVE-2017-11292
# 22            2020  2020-01-22T10:27:59           CVE-2017-0199\n \n\n\n\n
# 23            2020  2020-01-22T10:27:59           CVE-2017-0199\n \n\n\n\n
# 24            2020  2020-01-22T10:27:59                    \nCVE-2017-8759
# 25            2020  2020-01-22T10:27:59                     CVE-2017-11882
# 26            2020  2020-01-22T10:27:59                      CVE-2018-8174
# 27            2020  2020-01-22T10:27:59                      CVE-2017-8570
# 28            2020  2020-01-22T10:27:59                      CVE-2018-0802
# 29            2020  2020-01-22T10:27:59                      CVE-2012-0158
# 30            2020  2020-01-22T10:27:59                      CVE-2013-3906
# 31            2020  2020-01-22T10:27:59                      CVE-2014-1761
#
#                                           description alias graph_data  \
# 0   Use-after-free vulnerability in the Doc.media....    NA         NA
# 1   Adobe Flash Player before 10.2.154.27 on Windo...    NA         NA
# 2   Stack-based buffer overflow in Adobe Reader an...    NA         NA
# 3   Unspecified vulnerability in Adobe Flash Playe...    NA         NA
# 4   Microsoft Office Excel 2002 SP3, 2003 SP3, and...    NA         NA
# 5   \n""The (1) ListView, (2) ListView2, (3) TreeV...    NA         NA
# 6   Microsoft Internet Explorer 8 does not properl...    NA         NA
# 7   Use-after-free vulnerability in the CDisplayPo...    NA         NA
# 8   The Web IDL implementation in Mozilla Firefox ...    NA         NA
# 9   Mozilla Firefox before 28.0, Firefox ESR 24.x ...    NA         NA
# 10  Use-after-free vulnerability in Microsoft Inte...    NA         NA
# 11  OleAut32.dll in OLE in Microsoft Windows Serve...    NA         NA
# 12  Unspecified vulnerability in Oracle Java SE 6u...    NA         NA
# 13  Unspecified vulnerability in Oracle Java SE 6u...    NA         NA
# 14  Adobe Flash Player before 13.0.0.281 and 14.x ...    NA         NA
# 15  Use-after-free vulnerability in the ByteArray ...    NA         NA
# 16  Adobe Flash Player 18.x through 18.0.0.252 and...    NA         NA
# 17  Use-after-free vulnerability in the ByteArray ...    NA         NA
# 18  Use-after-free vulnerability in Adobe Flash Pl...    NA         NA
# 19  Adobe Flash Player 21.0.0.226 and earlier allo...    NA         NA
# 20  Microsoft .NET Framework 2.0, 3.5, 3.5.1, 4.5....    NA         NA
# 21  Adobe Flash Player version 27.0.0.159 and earl...    NA         NA
# 22  Microsoft Office 2007 SP3, Microsoft Office 20...    NA         NA
# 23  Microsoft Office 2007 SP3, Microsoft Office 20...    NA         NA
# 24  Microsoft .NET Framework 2.0, 3.5, 3.5.1, 4.5....    NA         NA
# 25   Microsoft Office 2007 Service Pack 3, Microso...    NA         NA
# 26  A remote code execution vulnerability exists i...    NA         NA
# 27  Microsoft Office allows a remote code executio...    NA         NA
# 28  Equation Editor in Microsoft Office 2007, Micr...    NA         NA
# 29  \n""The (1) ListView, (2) ListView2, (3) TreeV...    NA         NA
# 30   GDI+ in Microsoft Windows Vista SP2 and Serve...    NA         NA
# 31   Microsoft Word 2003 SP3, 2007 SP3, 2010 SP1 a...    NA         NA
#
#    external_references  object_marking_refs granular_markings
# 0                    NA                  NA                NA
# 1                    NA                  NA                NA
# 2                    NA                  NA                NA
# 3                    NA                  NA                NA
# 4                    NA                  NA                NA
# 5                    NA                  NA                NA
# 6                    NA                  NA                NA
# 7                    NA                  NA                NA
# 8                    NA                  NA                NA
# 9                    NA                  NA                NA
# 10                   NA                  NA                NA
# 11                   NA                  NA                NA
# 12                   NA                  NA                NA
# 13                   NA                  NA                NA
# 14                   NA                  NA                NA
# 15                   NA                  NA                NA
# 16                   NA                  NA                NA
# 17                   NA                  NA                NA
# 18                   NA                  NA                NA
# 19                   NA                  NA                NA
# 20                   NA                  NA                NA
# 21                   NA                  NA                NA
# 22                   NA                  NA                NA
# 23                   NA                  NA                NA
# 24                   NA                  NA                NA
# 25                   NA                  NA                NA
# 26                   NA                  NA                NA
# 27                   NA                  NA                NA
# 28                   NA                  NA                NA
# 29                   NA                  NA                NA
# 30                   NA                  NA                NA
# 31                   NA                  NA                NA

# %%
def insert_one_vulnerability (df,session):
    #if df.first_seen != 'NA':
     #   f=df.first_seen.strftime("%Y-%m-%dT%H:%M:%S")
     #   f_m=df.first_seen.strftime("%Y-%m")
     #   f_d=df.first_seen.strftime("%Y-%m-%d")
    #elif df.first_seen_month != 'NA':
    #    f_m=df.first_seen_month
    #elif df.first_seen_day != 'NA':
    #    f_d=df.first_seen_day
    #else:
    #    f_d=None
    #    f_m=None
    #    f=None
    df['description']=df['description'].replace('\"','').strip()
    aliases = list()
    if df['alias'] != 'NA':            
        aliases=df.alias.split('\n')

    graql_match_query = f"match $i isa Vulnerability , " \
                        f"has name \"{df['name']}__\"; " \
                        f"get;"
    # print(graql_match_query)
    with session.transaction().read() as read_transaction:
        # read_transaction.query(graql_match_query)
        answer_iterator = None
        answer_iterator = read_transaction.query(graql_match_query, infer=True)
        data = answer_iterator.collect_concepts()
                
        if len(data) > 0:
            # Update data.
            # Columns to be updated: object_status, revoked, updated_at, modified, description, alias
            # print("Update intrusion-set...")
            print("Update: " + df['name'])
            graql_attribute_delete_query = f"match $i isa Vulnerability , " \
                                           f"has name \"{df['name']}__\", "\
                                           f"has alias $a via $i1, "\
                                           f"has description $a via $i2; "\
                                           f"delete $i1, $i2;"
            update_flg = False
            first_attr_flg = True
            graql_attribute_update_query = f"match $i isa Vulnerability , " \
                                           f"has name \"{df['name']}__\"; insert $i"
            if df['description'] != 'NA':
                # graql_attribute_delete_query += f" has description $a via $i2; "\
                graql_attribute_update_query += f"  has description \"{df['description']}\" "
                if (first_attr_flg) & (len(aliases)>0):
                    graql_attribute_update_query += ","
                update_flg = True
                first_attr_flg = False
            print(len(aliases))
            if len(aliases) > 0:
                s = "|"
                graql_attribute_update_query += f" has alias \"{s.join(aliases).replace(' ','')}\" " 
                if first_attr_flg:
                     graql_attribute_update_query += ","
                update_flg = True
                first_attr_flg = False
            graql_attribute_update_query += ";"
            print(graql_attribute_update_query)
            if update_flg:
                with session.transaction().write() as write_transaction:
                    # make a write transection with the query
                    write_transaction.query(graql_attribute_delete_query)
                    write_transaction.query(graql_attribute_update_query)
                    # remember to commit at the end
                    write_transaction.commit()           
        else:
            # print("Insert intrusion-set...")
            print("Insert: " + df['name'].strip())
            graql_insert_query = f"insert $x isa Vulnerability, " \
                                 f"has internal_id_key \"{df['internal_id_key']}\", " \
                                 f"has stix_id_key \"{df['stix_id_key']}\", " \
                                 f"has stix_label \"{df['stix_label']}\", " \
                                 f"has entity_type \"{df['entity_type']}\", " \
                                 f"has created {df['created']}, " \
                                 f"has revoked \"{df['revoked']}\", "\
                                 f"has created_at {df['created_at']}, " \
                                 f"has created_at_day \"{df['created_at_day']}\", " \
                                 f"has created_at_month \"{df['created_at_month']}\", " \
                                 f"has created_at_year \"{df['created_at_year']}\", "\
                                 f"has updated_at {df['updated_at']}, "\
                                 f"has name \"{df['name'].strip()}__\" "
                                 
            if df['description'] != 'NA':
                graql_insert_query += f", has description \"{df['description']}\" "
            if len(aliases) > 0:
                s = "|"
                graql_insert_query += f", has alias \"{s.join(aliases)}\" "
            #if f is not None:
            #    graql_insert_query += f", has first_seen {f} "
            #if f_d is not None:
            #    graql_insert_query += f", has first_seen_day \"{f_d}\" "
            #if f_m is not None:
             #   graql_insert_query += f", has first_seen_month \"{f_m}\" "
            #if f_m is not None:
            #    graql_insert_query += f", has first_seen_year \"{df['first_seen_year']}\""
            graql_insert_query += ";"
            print(graql_insert_query)
            
            with session.transaction().write() as write_transaction:
                # make a write transection with the query
                write_transaction.query(graql_insert_query)
                # remember to commit at the end
                write_transaction.commit()

# %%
def load_data_into_grakn(session,input_df):
    print("Vulnerability...")
    # using progress_apply instead of apply so we have a progress bar form tqdm
    # input_df.progress_apply(insert_one_intrusion_set, axis=1, session=session)
    print("Vulnerability...")
    for index,row in input_df.iterrows():
        insert_one_vulnerability(df=row,session=session)

# %%
def build_grakn_graph(input_df, keyspace_name):
    with GraknClient(uri="192.168.83.129:48555") as client:
        with client.session(keyspace = keyspace_name) as session:
            load_data_into_grakn(session,input_df)

# %%
build_grakn_graph(input_df=result,keyspace_name='grakn')
# Out:
# Vulnerability...
# Vulnerability...
# Insert: CVE-2009-4324
# insert $x isa Vulnerability, has internal_id_key "4aeba194-57c7-4a1d-8806-6410f4cd1cce", has stix_id_key "Vulnerability--866d8308-7632-4d06-983b-9fe456b79459", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2009-4324__" , has description "Use-after-free vulnerability in the Doc.media.newPlayer method in Multimedia.api in Adobe Reader and Acrobat 9.x before 9.3, and 8.x before 8.2 on Windows and Mac OS X, allows remote attackers to execute arbitrary code via a crafted PDF file using ZLib compressed streams, as exploited in the wild in December 2009." ;
# Insert: CVE-2011-0611
# insert $x isa Vulnerability, has internal_id_key "26ff718c-bda6-47d1-b127-4506f9e4d1e3", has stix_id_key "Vulnerability--4dffdaf0-b78e-487d-9db1-8d9b889f9383", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2011-0611__" , has description "Adobe Flash Player before 10.2.154.27 on Windows, Mac OS X, Linux, and Solaris and 10.2.156.12 and earlier on Android; Adobe AIR before 2.6.19140; and Authplay.dll (aka AuthPlayLib.bundle) in Adobe Reader 9.x before 9.4.4 and 10.x through 10.0.1 on Windows, Adobe Reader 9.x before 9.4.4 and 10.x before 10.0.3 on Mac OS X, and Adobe Acrobat 9.x before 9.4.4 and 10.x before 10.0.3 on Windows and Mac OS X allow remote attackers to execute arbitrary code or cause a denial of service (application crash) via crafted Flash content; as demonstrated by a Microsoft Office document with an embedded .swf file that has a size inconsistency in object type confusion,ActionScript that adds custom functions to prototypes, and Date objects; and as exploited in the wild in April 2011." ;
# Insert: CVE-2009-0927
# insert $x isa Vulnerability, has internal_id_key "8e742b28-5196-4915-bcec-edd267d4b6c5", has stix_id_key "Vulnerability--9c4a2476-04a9-473f-a0bf-a42049a5e752", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2009-0927__" , has description "Stack-based buffer overflow in Adobe Reader and Adobe Acrobat 9 before 9.1, 8 before 8.1.3 , and 7 before 7.1.1 allows remote attackers to execute arbitrary code via a crafted argument to the getIcon method of a Collab object, a different vulnerability than CVE-2009-0658." ;
# Insert: CVE-2011-0609
# insert $x isa Vulnerability, has internal_id_key "61e74718-bc6b-4a34-b956-5fc7a7d0ca00", has stix_id_key "Vulnerability--be461d23-ea7d-4907-8ab9-e32aef94b336", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2011-0609__" , has description "Unspecified vulnerability in Adobe Flash Player 10.2.154.13 and earlier on Windows, Mac OS X, Linux, and Solaris; 10.1.106.16 and earlier on Android; Adobe AIR 2.5.1 and earlier; and Authplay.dll (aka AuthPlayLib.bundle) in Adobe Reader and Acrobat 9.x through 9.4.2 and 10.x through 10.0.1 on Windows and Mac OS X, allows remote attackers to execute arbitrary code or cause a denial of service (application crash) via crafted Flash content, as demonstrated by a .swf file embedded in an Excel spreadsheet, and as exploited in the wild in March 2011." ;
# Insert: CVE-209-3129
# insert $x isa Vulnerability, has internal_id_key "65633de8-b5aa-4873-a422-338a111bb524", has stix_id_key "Vulnerability--cdbd879a-c94d-4d31-8d3c-c6686a95e502", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-209-3129__" , has description "Microsoft Office Excel 2002 SP3, 2003 SP3, and 2007 SP1 and SP2; Office 2004 and 2008 for Mac; Open XML File Format Converter for Mac; Office Excel Viewer 2003 SP3; Office Excel Viewer SP1 and SP2; and Office Compatibility Pack for Word, Excel, and PowerPoint 2007 File Formats SP1 and SP2 allows remote attackers to execute arbitrary code via a spreadsheet with a FEATHEADER record containing an invalid cbHdrData size element that affects a pointer offset, aka Excel Featheader Record Memory Corruption Vulnerability." ;
# Insert: CVE-2012-0158
# insert $x isa Vulnerability, has internal_id_key "494621b3-a254-4609-849a-1b84f9eb9018", has stix_id_key "Vulnerability--67bfa565-da76-4477-8735-fdb97f54eff3", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2012-0158__" , has description "The (1) ListView, (2) ListView2, (3) TreeView, and (4) TreeView2 ActiveX controls in MSCOMCTL.OCX in the Common Controls in Microsoft Office 2003 SP3, 2007 SP2 and SP3, and 2010 Gold and SP1; Office 2003 Web Components SP3; SQL Server 2000 SP4, 2005 SP4, and 2008 SP2, SP3, and R2; BizTalk Server 2002 SP1; Commerce Server 2002 SP4, 2007 SP2, and 2009 Gold and R2; Visual FoxPro 8.0 SP1 and 9.0 SP2; and Visual Basic 6.0 Runtime allow remote attackers to execute arbitrary code via a crafted (a) web site, (b) Office document, or (c) .rtf file that triggers system state corruption, as exploited in the wild in April 2012, aka MSCOMCTL.OCX RCE Vulnerability." ;
# Insert: CVE-2013-1347
# insert $x isa Vulnerability, has internal_id_key "2f4afa2d-bda2-4a98-a9bd-e2e4e7aae343", has stix_id_key "Vulnerability--d3da4589-72d9-4739-9dff-410698bea252", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2013-1347__" , has description "Microsoft Internet Explorer 8 does not properly handle objects in memory, which allows remote attackers to execute arbitrary code by accessing an object that
# (1) was not properly allocated or (2) is deleted, as exploited in the wild in May 2013." ;
# Insert: CVE-2013-3897
# insert $x isa Vulnerability, has internal_id_key "929c581a-59af-4eb8-a184-f4d27fffcaac", has stix_id_key "Vulnerability--754dc97a-4aff-47ce-a6e6-692d2501fc70", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2013-3897__" , has description "Use-after-free vulnerability in the CDisplayPointer class in mshtml.dll in Microsoft Internet Explorer 6 through 11 allows remote attackers to execute arbitrary code or cause a denial of service (memory corruption) via crafted JavaScript code that uses the onpropertychange event handler, as exploited in the wild in September and October 2013, aka Internet Explorer Memory Corruption Vulnerability." ;
# Insert: CVE-2014-1510
# insert $x isa Vulnerability, has internal_id_key "3f01c09a-5dbb-4d2d-9ca7-11a6dbbe53af", has stix_id_key "Vulnerability--979d7ad2-ae60-41c6-a1e8-c46e87c553f6", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2014-1510__" , has description "The Web IDL implementation in Mozilla Firefox before 28.0, Firefox ESR 24.x before 24.4, Thunderbird before 24.4, and SeaMonkey before 2.25 allows remote attackers to execute arbitrary JavaScript code with chrome privileges by using an IDL fragment to trigger a window.open call." ;
# Insert: CVE-2014-1511
# insert $x isa Vulnerability, has internal_id_key "47313237-2d4b-4f50-ac46-c6559fdf2a58", has stix_id_key "Vulnerability--0b2524ed-f39c-469e-8c04-10f356739395", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2014-1511__" , has description "Mozilla Firefox before 28.0, Firefox ESR 24.x before 24.4, Thunderbird before 24.4, and SeaMonkey before 2.25 allow remote attackers to bypass the popup blocker via unspecified vectors." ;
# Insert: CVE-2014-1776
# insert $x isa Vulnerability, has internal_id_key "f9acc145-84c3-486e-974e-942bd4700e69", has stix_id_key "Vulnerability--5e81c165-e244-41bd-9819-886f5f6bfbf0", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2014-1776__" , has description "Use-after-free vulnerability in Microsoft Internet Explorer 6 through 11 allows remote attackers to execute arbitrary code or cause a denial of service (memory corruption) via vectors related to the CMarkup::IsConnectedToPrimaryMarkup function, as exploited in the wild in April 2014. NOTE: this issue originally emphasized VGX.DLL, but Microsoft clarified that VGX.DLL does not contain the vulnerable code leveraged in this exploit. Disabling VGX.DLL is an exploit-specific workaround that provides an immediate,
# effective workaround to help block known attacks." ;
# Insert: CVE-2014-6332
# insert $x isa Vulnerability, has internal_id_key "c0c0c691-382b-4aca-829c-10e937262b6a", has stix_id_key "Vulnerability--7a368426-8010-4b5b-b076-a08f6b31eed8", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2014-6332__" , has description "OleAut32.dll in OLE in Microsoft Windows Server 2003 SP2, Windows Vista SP2, Windows Server 2008 SP2 and R2 SP1, Windows 7 SP1, Windows 8, Windows 8.1, Windows Server 2012 Gold and R2, and Windows RT Gold and 8.1 allows remote attackers to execute arbitrary code via a crafted web site, as demonstrated by an array-redimensioning attempt that triggers improper handling of a size value in the SafeArrayDimen function, aka Windows OLE Automation Array Remote Code Execution Vulnerability." ;
# Insert: CVE-2015-2590
# insert $x isa Vulnerability, has internal_id_key "cb9b295e-3c29-469f-86e7-1c9513957b89", has stix_id_key "Vulnerability--e369ce6d-d098-47c4-9845-e7951fa1edee", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2015-2590__" , has description "Unspecified vulnerability in Oracle Java SE 6u95, 7u80, and 8u45, and Java SE Embedded 7u75 and 8u33 allows remote attackers to affect confidentiality, integrity, and availability via unknown vectors related to Libraries, a different vulnerability than CVE-2015-4732." ;
# Insert: CVE-2015-4902
# insert $x isa Vulnerability, has internal_id_key "4def8231-fecf-43fc-bc53-252af0411fd2", has stix_id_key "Vulnerability--4cb1b6ce-e9c2-4577-b33a-abb0af4114c6", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2015-4902__" , has description "Unspecified vulnerability in Oracle Java SE 6u101, 7u85, and 8u60 allows remote attackers to affect integrity via unknown vectors related to Deployment." ;
# Insert: CVE-2015-3043
# insert $x isa Vulnerability, has internal_id_key "d6c202af-e995-47bb-8f86-a6c716067ba7", has stix_id_key "Vulnerability--e991ee7e-63b2-43b7-a263-e75075bd10da", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2015-3043__" , has description "Adobe Flash Player before 13.0.0.281 and 14.x through 17.x before 17.0.0.169 on Windows and OS X and before 11.2.202.457 on Linux allows attackers to execute arbitrary code
# or cause a denial of service (memory corruption) via unspecified vectors, as exploited in the wild in April 2015, a different vulnerability thanCVE-2015-0347, CVE-2015-0350, CVE-2015-0352, CVE-2015-0353, CVE-2015-0354, CVE-2015-0355, CVE-2015-0360, CVE-2015-3038, CVE-2015-3041, and CVE-2015-3042." ;
# Insert: CVE-2015-5119
# insert $x isa Vulnerability, has internal_id_key "658d2212-e8fc-4727-9bee-dd623247dfdd", has stix_id_key "Vulnerability--07cd23c1-493b-49d3-a779-479cdf4f644c", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2015-5119__" , has description "Use-after-free vulnerability in the ByteArray class in the ActionScript 3 (AS3) implementation in Adobe Flash Player 13.x through 13.0.0.296 and 14.x through 18.0.0.194 on Windows and OS X and 11.x through 11.2.202.468 on Linux allows remote attackers to execute arbitrary code or cause a denial of service (memory corruption) via crafted Flash content that overrides a valueOf function, as exploited in the wild in July 2015." ;
# Insert: CVE-2015-7645
# insert $x isa Vulnerability, has internal_id_key "443bc65e-7a80-49ff-b6ba-8cd78ba45e9c", has stix_id_key "Vulnerability--3ba55fd3-4a9a-4388-8cc3-dc305ff07696", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2015-7645__" , has description "Adobe Flash Player 18.x through 18.0.0.252 and 19.x through 19.0.0.207 on Windows and OS X and 11.x through 11.2.202.535 on Linux allows remote attackers to execute arbitrary code via a crafted SWF file, as exploited in the wild in October 2015." ;
# Insert: CVE-2015-5119
# insert $x isa Vulnerability, has internal_id_key "6ba11a1a-6b29-4831-958c-49573ff6e1f1", has stix_id_key "Vulnerability--0fb7deb5-05fa-4cd5-8fd5-2087c4509e79", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2015-5119__" , has description "Use-after-free vulnerability in the ByteArray class in the ActionScript 3 (AS3) implementation in Adobe Flash Player 13.x through 13.0.0.296 and 14.x through 18.0.0.194 on Windows and OS X and 11.x through 11.2.202.468 on Linux allows remote attackers to execute arbitrary code or cause a denial of service (memory corruption) via crafted Flash content that overrides a valueOf function, as exploited in the wild in July 2015." ;
# Insert: CVE-2016-0984
# insert $x isa Vulnerability, has internal_id_key "faff2c1a-a434-4dcd-afcc-63840187d83a", has stix_id_key "Vulnerability--223f2f21-0054-4ef1-841c-ecda8de4da14", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2016-0984__" , has description "Use-after-free vulnerability in Adobe Flash Player before 18.0.0.329 and 19.x and 20.x before 20.0.0.306 on Windows and OS X and before 11.2.202.569 on Linux, Adobe AIR before 20.0.0.260, Adobe AIR SDK before 20.0.0.260, and Adobe AIR SDK & Compiler before 20.0.0.260 allows attackers to execute arbitrary code via unspecified vectors, a different vulnerability than CVE-2016-0973, CVE-2016-0974, CVE-2016-0975, CVE-2016-0982, and CVE-2016-0983." ;
# Insert: CVE-2016-4117
# insert $x isa Vulnerability, has internal_id_key "93f344fe-cb2c-4fe1-a1f2-1fc9dde56040", has stix_id_key "Vulnerability--78f48b86-74f7-4416-91ec-7c93cd00f571", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2016-4117__" , has description "Adobe Flash Player 21.0.0.226 and earlier allows remote attackers to execute arbitrary code via unspecified vectors, as exploited in the wild in May 2016." ;
# Insert: CVE-2017-8759
# insert $x isa Vulnerability, has internal_id_key "128036fb-1474-4518-ba0c-8713654722d1", has stix_id_key "Vulnerability--5eed6bef-9727-49f9-8645-75a11d31d103", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2017-8759__" , has description "Microsoft .NET Framework 2.0, 3.5, 3.5.1, 4.5.2, 4.6, 4.6.1, 4.6.2 and 4.7 allow an attacker to execute code remotely via a malicious document or application, aka .NET Framework Remote Code Execution Vulnerability." ;
# Insert: CVE-2017-11292
# insert $x isa Vulnerability, has internal_id_key "049bd6d1-9ce0-4966-84ac-b6ca21fc23aa", has stix_id_key "Vulnerability--e3c95479-c264-43a3-b521-24e2015fdb90", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2017-11292__" , has description "Adobe Flash Player version 27.0.0.159 and earlier has a flawed bytecode verification procedure, which allows for an untrusted value to be used in the calculation of an array index. This can lead to type confusion, and successful exploitation could lead to arbitrary code execution." ;
# Insert: CVE-2017-0199
# insert $x isa Vulnerability, has internal_id_key "031cadb8-4e5d-428e-b30d-857c027682af", has stix_id_key "Vulnerability--7222a2c1-a449-4592-a07a-403a03bb376c", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2017-0199__" , has description "Microsoft Office 2007 SP3, Microsoft Office 2010 SP2, Microsoft Office 2013 SP1, Microsoft Office 2016,
#  Microsoft Windows Vista SP2, Windows Server 2008 SP2, Windows 7 SP1, Windows 8.1 allow remote attackers to execute arbitrary code via a crafted document, aka Microsoft Office/WordPad Remote Code Execution Vulnerability w/Windows API." ;
# Insert: CVE-2017-0199
# insert $x isa Vulnerability, has internal_id_key "11ad1ca5-361e-4d8e-8120-6dd2e741d297", has stix_id_key "Vulnerability--d540ed9b-97be-43ea-a131-e5a387610b27", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2017-0199__" , has description "Microsoft Office 2007 SP3, Microsoft Office 2010 SP2, Microsoft Office 2013 SP1, Microsoft Office 2016,
#  Microsoft Windows Vista SP2, Windows Server 2008 SP2, Windows 7 SP1, Windows 8.1 allow remote attackers to execute arbitrary code via a crafted document, aka Microsoft Office/WordPad Remote Code Execution Vulnerability w/Windows API." ;
# Insert: CVE-2017-8759
# insert $x isa Vulnerability, has internal_id_key "c9e25c11-8718-4e77-aba2-590fb0a61019", has stix_id_key "Vulnerability--ecb18051-711d-4ee2-a92c-0f42ea1e8f7c", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2017-8759__" , has description "Microsoft .NET Framework 2.0, 3.5, 3.5.1, 4.5.2, 4.6, 4.6.1, 4.6.2 and 4.7 allow an attacker to execute code remotely via a malicious document or application, aka .NET Framework Remote Code Execution Vulnerability." ;
# Insert: CVE-2017-11882
# insert $x isa Vulnerability, has internal_id_key "b2607082-9185-4755-acdf-a9819e57290d", has stix_id_key "Vulnerability--a94eee29-20fe-41f7-aa3a-72dbdb94fb29", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2017-11882__" , has description "Microsoft Office 2007 Service Pack 3, Microsoft Office 2010 Service Pack 2, Microsoft Office 2013 Service Pack 1, and Microsoft Office 2016 allow an attacker to run arbitrary code in the context of the current user by failing to properly handle objects in memory, aka Microsoft Office Memory Corruption Vulnerability.
#  This CVE ID is unique from CVE-2017-11884" ;
# Insert: CVE-2018-8174
# insert $x isa Vulnerability, has internal_id_key "84904432-6a75-49d4-b1e0-59d1a0c717a5", has stix_id_key "Vulnerability--c2add0a9-4968-429f-8c2c-be0a49af164b", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2018-8174__" , has description "A remote code execution vulnerability exists in the way that the VBScript engine handles objects in memory, aka Windows VBScript Engine Remote Code Execution Vulnerability.
#  This affects Windows 7, Windows Server 2012 R2, Windows RT 8.1, Windows Server 2008, Windows Server 2012, Windows 8.1, Windows Server 2016, Windows Server 2008 R2, Windows 10, Windows 10 Servers." ;
# Insert: CVE-2017-8570
# insert $x isa Vulnerability, has internal_id_key "c2a7886e-fbef-4e83-804d-05de662fa747", has stix_id_key "Vulnerability--7e781c6c-a907-48f2-93c4-7368bcd099ba", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2017-8570__" , has description "Microsoft Office allows a remote code execution vulnerability due to the way that it handles objects in memory, aka Microsoft Office Remote Code Execution Vulnerability." ;
# Insert: CVE-2018-0802
# insert $x isa Vulnerability, has internal_id_key "1155e3a2-21c6-48f1-b31e-200310a328b3", has stix_id_key "Vulnerability--4139dc7e-96fd-44b5-bafb-26dc3e841a15", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2018-0802__" , has description "Equation Editor in Microsoft Office 2007, Microsoft Office 2010, Microsoft Office 2013, and Microsoft Office 2016 allow a remote code execution vulnerability due to the way objects are handled in memory, aka Microsoft Office Memory Corruption Vulnerability." ;
# Insert: CVE-2012-0158
# insert $x isa Vulnerability, has internal_id_key "0b6d6254-a8b6-473e-b50d-8fc8078735d0", has stix_id_key "Vulnerability--34055ea4-941b-46ff-8806-37becd065792", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2012-0158__" , has description "The (1) ListView, (2) ListView2, (3) TreeView, and (4) TreeView2 ActiveX controls in MSCOMCTL.OCX in the Common Controls in Microsoft Office 2003 SP3, 2007 SP2 and SP3, and 2010 Gold and SP1; Office 2003 Web Components SP3; SQL Server 2000 SP4, 2005 SP4, and 2008 SP2, SP3, and R2; BizTalk Server 2002 SP1; Commerce Server 2002 SP4, 2007 SP2, and 2009 Gold and R2; Visual FoxPro 8.0 SP1 and 9.0 SP2; and Visual Basic 6.0 Runtime allow remote attackers to execute arbitrary code via a crafted (a) web site, (b) Office document, or (c) .rtf file that triggers system state corruption, as exploited in the wild in April 2012, aka MSCOMCTL.OCX RCE Vulnerability." ;
# Insert: CVE-2013-3906
# insert $x isa Vulnerability, has internal_id_key "161b2f5c-da97-4835-b807-a3eed5d0ff1d", has stix_id_key "Vulnerability--e4d1867f-e43f-4641-9493-5956b3659f07", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2013-3906__" , has description "GDI+ in Microsoft Windows Vista SP2 and Server 2008 SP2; Office 2003 SP3, 2007 SP3, and 2010 SP1 and SP2; Office Compatibility Pack SP3; and Lync 2010,2010 Attendee, 2013, and Basic 2013 allows remote attackers to execute arbitrary code via a crafted TIFF image, as demonstrated by an image in a Word document, and exploited in the wild in October and November 2013." ;
# Insert: CVE-2014-1761
# insert $x isa Vulnerability, has internal_id_key "3c7754e4-8910-4e13-9ff6-affd12271f26", has stix_id_key "Vulnerability--91b975de-e15c-4ee5-bd95-1c5b65cccf98", has stix_label "NA", has entity_type "Vulnerability", has created 2020-01-21T15:22:58, has revoked "False", has created_at 2020-01-21T15:22:58, has created_at_day "2020-01-21", has created_at_month "2020-01", has created_at_year "2020", has updated_at 2020-01-21T15:22:58, has name "CVE-2014-1761__" , has description "Microsoft Word 2003 SP3, 2007 SP3, 2010 SP1 and SP2, 2013, and 2013 RT; Word Viewer; Office Compatibility Pack SP3; Office for Mac 2011; Word Automation Services on SharePoint Server 2010 SP1 and SP2 and 2013; Office Web Apps 2010 SP1 and SP2; and Office Web Apps Server 2013 allow remote attackers to execute arbitrary code or cause a denial of service (memory corruption) via crafted RTF data, as exploited in the wild in March 2014." ;

# %%
result['description'][5].replace('\"','')
# Out:
# '\nThe (1) ListView, (2) ListView2, (3) TreeView, and (4) TreeView2 ActiveX controls in MSCOMCTL.OCX in the Common Controls in Microsoft Office 2003 SP3, 2007 SP2 and SP3, and 2010 Gold and SP1; Office 2003 Web Components SP3; SQL Server 2000 SP4, 2005 SP4, and 2008 SP2, SP3, and R2; BizTalk Server 2002 SP1; Commerce Server 2002 SP4, 2007 SP2, and 2009 Gold and R2; Visual FoxPro 8.0 SP1 and 9.0 SP2; and Visual Basic 6.0 Runtime allow remote attackers to execute arbitrary code via a crafted (a) web site, (b) Office document, or (c) .rtf file that triggers system state corruption, as exploited in the wild in April 2012, aka MSCOMCTL.OCX RCE Vulnerability.'
