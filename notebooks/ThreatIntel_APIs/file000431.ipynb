# %%
from pycti import OpenCTIApiClient

# %%
api_url = "https://demo.opencti.io"
api_token = "2b4f29e3-5ea8-4890-8cf5-a76f61f1e2b2"

# OpenCTI initialization
opencti_api_client = OpenCTIApiClient(api_url, api_token)
# Out:
# INFO:root:Listing Threat-Actors with filters null.

# %%
indicators = opencti_api_client.indicator.list(getAll=True)
# Out:
# INFO:root:Listing Indicators with filters null.
# INFO:root:Listing Indicators after YXJyYXljb25uZWN0aW9uOjUwMA==
# INFO:root:Listing Indicators after YXJyYXljb25uZWN0aW9uOjEwMDA=
# INFO:root:Listing Indicators after YXJyYXljb25uZWN0aW9uOjE1MDA=
# INFO:root:Listing Indicators after YXJyYXljb25uZWN0aW9uOjIwMDA=
# INFO:root:Listing Indicators after YXJyYXljb25uZWN0aW9uOjI1MDA=
# INFO:root:Listing Indicators after YXJyYXljb25uZWN0aW9uOjMwMDA=
# INFO:root:Listing Indicators after YXJyYXljb25uZWN0aW9uOjM1MDA=
# INFO:root:Listing Indicators after YXJyYXljb25uZWN0aW9uOjQwMDA=
# INFO:root:Listing Indicators after YXJyYXljb25uZWN0aW9uOjQ1MDA=

# %%
indicators = opencti_api_client.stix_observable.list(first=5)
# Out:
# INFO:root:Listing StixObservables with filters null.

# %%
indicators
# Out:
# [{'id': 'ba8d42d9-e101-4972-ab76-2587a692bf56',
#   'stix_id_key': 'observable--db310aa1-f47c-4b7a-b0b2-b24e81cc6bc9',
#   'entity_type': 'domain',
#   'name': 'document-out.hopto.org',
#   'description': '',
#   'observable_value': 'document-out.hopto.org',
#   'created_at': '2020-04-03T06:22:04.032Z',
#   'updated_at': '2020-04-03T06:22:04.032Z',
#   'createdByRef': {'id': '03551e1a-ac3f-4a5b-8ba5-a0dfe8b1fb19',
#    'entity_type': 'organization',
#    'stix_id_key': 'identity--071e2dfa-f96b-4552-85eb-87f62d9bb73e',
#    'stix_label': None,
#    'name': 'AlienVault',
#    'alias': [],
#    'description': '',
#    'created': '2020-04-02T08:52:40.983Z',
#    'modified': '2020-04-02T08:52:40.983Z',
#    'organization_class': None,
#    'remote_relation_id': 'c551a580-180f-5160-b624-1daacc68a326'},
#   'tags': [],
#   'markingDefinitions': [{'id': 'c4ae0c3a-3535-44e2-b206-bb451c25c749',
#     'entity_type': 'marking-definition',
#     'stix_id_key': 'marking-definition--613f2e26-407d-48c7-9eca-b8e91df99dc9',
#     'definition_type': 'TLP',
#     'definition': 'TLP:WHITE',
#     'level': 1,
#     'color': '#ffffff',
#     'created': '2020-04-01T13:30:18.349Z',
#     'modified': '2020-04-01T13:30:18.349Z',
#     'remote_relation_id': '45126eb3-71aa-5d18-8b36-b01b17dab161',
#     'createdByRef': None}],
#   'externalReferences': [],
#   'indicators': [{'id': '6a0c4479-40a6-43d6-84ec-8922f52740f5',
#     'entity_type': 'indicator',
#     'stix_id_key': 'indicator--60f51a8a-a1b3-4860-abf4-ba305e639c09',
#     'valid_from': '2019-12-30T17:10:43.000Z',
#     'valid_until': '2020-12-29T17:10:43.000Z',
#     'score': 50,
#     'pattern_type': 'stix',
#     'indicator_pattern': "[domain-name:value = 'document-out.hopto.org']",
#     'created': '2020-04-02T08:53:17.256Z',
#     'modified': '2020-04-02T08:53:17.256Z',
#     'remote_relation_id': 'd4115ab1-9216-56da-99af-bb0569812db2',
#     'createdByRef': None}],
#   'markingDefinitionsIds': ['c4ae0c3a-3535-44e2-b206-bb451c25c749'],
#   'tagsIds': [],
#   'externalReferencesIds': [],
#   'indicatorsIds': ['6a0c4479-40a6-43d6-84ec-8922f52740f5']},
#  {'id': '2ead8435-c9ac-43dd-8092-64af299a7d86',
#   'stix_id_key': 'observable--59b6d858-5980-4c09-93cf-02a0f27d6142',
#   'entity_type': 'domain',
#   'name': 'libcrash.ddns.net',
#   'description': '',
#   'observable_value': 'libcrash.ddns.net',
#   'created_at': '2020-04-03T06:22:00.674Z',
#   'updated_at': '2020-04-03T06:22:00.674Z',
#   'createdByRef': {'id': '03551e1a-ac3f-4a5b-8ba5-a0dfe8b1fb19',
#    'entity_type': 'organization',
#    'stix_id_key': 'identity--071e2dfa-f96b-4552-85eb-87f62d9bb73e',
#    'stix_label': None,
#    'name': 'AlienVault',
#    'alias': [],
#    'description': '',
#    'created': '2020-04-02T08:52:40.983Z',
#    'modified': '2020-04-02T08:52:40.983Z',
#    'organization_class': None,
#    'remote_relation_id': 'd3e31d84-60da-5a27-afd4-91384fcecffe'},
#   'tags': [],
#   'markingDefinitions': [{'id': 'c4ae0c3a-3535-44e2-b206-bb451c25c749',
#     'entity_type': 'marking-definition',
#     'stix_id_key': 'marking-definition--613f2e26-407d-48c7-9eca-b8e91df99dc9',
#     'definition_type': 'TLP',
#     'definition': 'TLP:WHITE',
#     'level': 1,
#     'color': '#ffffff',
#     'created': '2020-04-01T13:30:18.349Z',
#     'modified': '2020-04-01T13:30:18.349Z',
#     'remote_relation_id': '0f66845e-7b48-5f90-b2d3-554480b290b4',
#     'createdByRef': None}],
#   'externalReferences': [],
#   'indicators': [{'id': '69492682-ecf5-4f88-b3d8-7de39770d670',
#     'entity_type': 'indicator',
#     'stix_id_key': 'indicator--d864d35c-7900-4fc3-a9e2-2ea3d283c3d4',
#     'valid_from': '2019-12-30T17:10:43.000Z',
#     'valid_until': '2020-12-29T17:10:43.000Z',
#     'score': 50,
#     'pattern_type': 'stix',
#     'indicator_pattern': "[domain-name:value = 'libcrash.ddns.net']",
#     'created': '2020-04-02T08:53:17.255Z',
#     'modified': '2020-04-02T08:53:17.255Z',
#     'remote_relation_id': 'c4f255d8-223c-5c5d-81aa-55aec728b264',
#     'createdByRef': None}],
#   'markingDefinitionsIds': ['c4ae0c3a-3535-44e2-b206-bb451c25c749'],
#   'tagsIds': [],
#   'externalReferencesIds': [],
#   'indicatorsIds': ['69492682-ecf5-4f88-b3d8-7de39770d670']},
#  {'id': 'b962f8c4-6d97-4466-adfb-ff49b5b9a2ac',
#   'stix_id_key': 'observable--822b2fe6-0ced-42d5-b408-a2b759a88880',
#   'entity_type': 'domain',
#   'name': 'pasive.ddns.net',
#   'description': '',
#   'observable_value': 'pasive.ddns.net',
#   'created_at': '2020-04-03T06:22:13.784Z',
#   'updated_at': '2020-04-03T06:22:13.784Z',
#   'createdByRef': {'id': '03551e1a-ac3f-4a5b-8ba5-a0dfe8b1fb19',
#    'entity_type': 'organization',
#    'stix_id_key': 'identity--071e2dfa-f96b-4552-85eb-87f62d9bb73e',
#    'stix_label': None,
#    'name': 'AlienVault',
#    'alias': [],
#    'description': '',
#    'created': '2020-04-02T08:52:40.983Z',
#    'modified': '2020-04-02T08:52:40.983Z',
#    'organization_class': None,
#    'remote_relation_id': 'b4de7767-c78c-5bc0-a822-616899248523'},
#   'tags': [],
#   'markingDefinitions': [{'id': 'c4ae0c3a-3535-44e2-b206-bb451c25c749',
#     'entity_type': 'marking-definition',
#     'stix_id_key': 'marking-definition--613f2e26-407d-48c7-9eca-b8e91df99dc9',
#     'definition_type': 'TLP',
#     'definition': 'TLP:WHITE',
#     'level': 1,
#     'color': '#ffffff',
#     'created': '2020-04-01T13:30:18.349Z',
#     'modified': '2020-04-01T13:30:18.349Z',
#     'remote_relation_id': 'd582c231-1fa8-5a15-8cf0-ef7941711692',
#     'createdByRef': None}],
#   'externalReferences': [],
#   'indicators': [{'id': 'bdd9bf84-053a-4842-b257-46745ce7bbee',
#     'entity_type': 'indicator',
#     'stix_id_key': 'indicator--206efeb1-ff8b-446d-a8e5-f4172557a616',
#     'valid_from': '2020-01-09T17:12:13.000Z',
#     'valid_until': '2021-01-08T17:12:13.000Z',
#     'score': 50,
#     'pattern_type': 'stix',
#     'indicator_pattern': "[domain-name:value = 'pasive.ddns.net']",
#     'created': '2020-04-02T08:53:17.259Z',
#     'modified': '2020-04-02T08:53:17.259Z',
#     'remote_relation_id': 'de44784e-0572-51ad-bb0c-2d4157e59f5d',
#     'createdByRef': None}],
#   'markingDefinitionsIds': ['c4ae0c3a-3535-44e2-b206-bb451c25c749'],
#   'tagsIds': [],
#   'externalReferencesIds': [],
#   'indicatorsIds': ['bdd9bf84-053a-4842-b257-46745ce7bbee']},
#  {'id': 'cd2807b2-037c-456e-b466-efb84f81a628',
#   'stix_id_key': 'observable--1f752361-0851-48a9-a9f6-cde2bcc39036',
#   'entity_type': 'url',
#   'name': 'http://nicoledotson.icu/debby/weatherford/',
#   'description': '',
#   'observable_value': 'http://nicoledotson.icu/debby/weatherford/',
#   'created_at': '2020-04-03T06:24:26.837Z',
#   'updated_at': '2020-04-03T06:24:26.837Z',
#   'createdByRef': {'id': '03551e1a-ac3f-4a5b-8ba5-a0dfe8b1fb19',
#    'entity_type': 'organization',
#    'stix_id_key': 'identity--071e2dfa-f96b-4552-85eb-87f62d9bb73e',
#    'stix_label': None,
#    'name': 'AlienVault',
#    'alias': [],
#    'description': '',
#    'created': '2020-04-02T08:52:40.983Z',
#    'modified': '2020-04-02T08:52:40.983Z',
#    'organization_class': None,
#    'remote_relation_id': '20a93b02-a890-51e9-90b6-5943d0a9f2de'},
#   'tags': [],
#   'markingDefinitions': [{'id': 'c4ae0c3a-3535-44e2-b206-bb451c25c749',
#     'entity_type': 'marking-definition',
#     'stix_id_key': 'marking-definition--613f2e26-407d-48c7-9eca-b8e91df99dc9',
#     'definition_type': 'TLP',
#     'definition': 'TLP:WHITE',
#     'level': 1,
#     'color': '#ffffff',
#     'created': '2020-04-01T13:30:18.349Z',
#     'modified': '2020-04-01T13:30:18.349Z',
#     'remote_relation_id': 'c9f39b3c-c7aa-5a0b-a557-767f2abfae14',
#     'createdByRef': None}],
#   'externalReferences': [],
#   'indicators': [{'id': 'fe98a316-47c5-44b3-a7e4-04747457747d',
#     'entity_type': 'indicator',
#     'stix_id_key': 'indicator--2c91eddd-2d99-46c1-82d9-ccb0a257fed0',
#     'valid_from': '2020-02-13T09:52:53.000Z',
#     'valid_until': '2021-02-12T09:52:53.000Z',
#     'score': 50,
#     'pattern_type': 'stix',
#     'indicator_pattern': "[url:value = 'http://nicoledotson.icu/debby/weatherford/']",
#     'created': '2020-04-02T08:53:17.456Z',
#     'modified': '2020-04-02T08:53:17.456Z',
#     'remote_relation_id': 'ee9813be-0802-5db9-898d-8093a6dc24e1',
#     'createdByRef': None}],
#   'markingDefinitionsIds': ['c4ae0c3a-3535-44e2-b206-bb451c25c749'],
#   'tagsIds': [],
#   'externalReferencesIds': [],
#   'indicatorsIds': ['fe98a316-47c5-44b3-a7e4-04747457747d']},
#  {'id': '476e0c26-691c-41df-952a-515b39d0c745',
#   'stix_id_key': 'observable--1a82f774-ed5a-43f2-b2d3-a1c6603db691',
#   'entity_type': 'domain',
#   'name': 'nicoledotson.icu',
#   'description': '',
#   'observable_value': 'nicoledotson.icu',
#   'created_at': '2020-04-03T06:24:50.025Z',
#   'updated_at': '2020-04-03T06:24:50.025Z',
#   'createdByRef': {'id': '03551e1a-ac3f-4a5b-8ba5-a0dfe8b1fb19',
#    'entity_type': 'organization',
#    'stix_id_key': 'identity--071e2dfa-f96b-4552-85eb-87f62d9bb73e',
#    'stix_label': None,
#    'name': 'AlienVault',
#    'alias': [],
#    'description': '',
#    'created': '2020-04-02T08:52:40.983Z',
#    'modified': '2020-04-02T08:52:40.983Z',
#    'organization_class': None,
#    'remote_relation_id': 'fed93ae8-a442-5ca6-aebe-a09bb44cbb63'},
#   'tags': [],
#   'markingDefinitions': [{'id': 'c4ae0c3a-3535-44e2-b206-bb451c25c749',
#     'entity_type': 'marking-definition',
#     'stix_id_key': 'marking-definition--613f2e26-407d-48c7-9eca-b8e91df99dc9',
#     'definition_type': 'TLP',
#     'definition': 'TLP:WHITE',
#     'level': 1,
#     'color': '#ffffff',
#     'created': '2020-04-01T13:30:18.349Z',
#     'modified': '2020-04-01T13:30:18.349Z',
#     'remote_relation_id': 'c2a81220-aa16-50f8-86c4-ed7aa2896383',
#     'createdByRef': None}],
#   'externalReferences': [],
#   'indicators': [{'id': '18e2b164-64f7-4192-9a48-913c19c1b289',
#     'entity_type': 'indicator',
#     'stix_id_key': 'indicator--5ec0dbb2-1b62-4c82-8bf9-d276c494130e',
#     'valid_from': '2020-02-13T09:52:53.000Z',
#     'valid_until': '2021-02-12T09:52:53.000Z',
#     'score': 50,
#     'pattern_type': 'stix',
#     'indicator_pattern': "[domain-name:value = 'nicoledotson.icu']",
#     'created': '2020-04-02T08:53:17.470Z',
#     'modified': '2020-04-02T08:53:17.470Z',
#     'remote_relation_id': 'a930f614-016a-5478-92ff-5939a2ae7b0b',
#     'createdByRef': None}],
#   'markingDefinitionsIds': ['c4ae0c3a-3535-44e2-b206-bb451c25c749'],
#   'tagsIds': [],
#   'externalReferencesIds': [],
#   'indicatorsIds': ['18e2b164-64f7-4192-9a48-913c19c1b289']}]

# %%
opencti_api_client.
# Out:
# [{'id': 'ba8d42d9-e101-4972-ab76-2587a692bf56',
#   'stix_id_key': 'observable--db310aa1-f47c-4b7a-b0b2-b24e81cc6bc9',
#   'entity_type': 'domain',
#   'name': 'document-out.hopto.org',
#   'description': '',
#   'observable_value': 'document-out.hopto.org',
#   'created_at': '2020-04-03T06:22:04.032Z',
#   'updated_at': '2020-04-03T06:22:04.032Z',
#   'createdByRef': {'id': '03551e1a-ac3f-4a5b-8ba5-a0dfe8b1fb19',
#    'entity_type': 'organization',
#    'stix_id_key': 'identity--071e2dfa-f96b-4552-85eb-87f62d9bb73e',
#    'stix_label': None,
#    'name': 'AlienVault',
#    'alias': [],
#    'description': '',
#    'created': '2020-04-02T08:52:40.983Z',
#    'modified': '2020-04-02T08:52:40.983Z',
#    'organization_class': None,
#    'remote_relation_id': 'c551a580-180f-5160-b624-1daacc68a326'},
#   'tags': [],
#   'markingDefinitions': [{'id': 'c4ae0c3a-3535-44e2-b206-bb451c25c749',
#     'entity_type': 'marking-definition',
#     'stix_id_key': 'marking-definition--613f2e26-407d-48c7-9eca-b8e91df99dc9',
#     'definition_type': 'TLP',
#     'definition': 'TLP:WHITE',
#     'level': 1,
#     'color': '#ffffff',
#     'created': '2020-04-01T13:30:18.349Z',
#     'modified': '2020-04-01T13:30:18.349Z',
#     'remote_relation_id': '45126eb3-71aa-5d18-8b36-b01b17dab161',
#     'createdByRef': None}],
#   'externalReferences': [],
#   'indicators': [{'id': '6a0c4479-40a6-43d6-84ec-8922f52740f5',
#     'entity_type': 'indicator',
#     'stix_id_key': 'indicator--60f51a8a-a1b3-4860-abf4-ba305e639c09',
#     'valid_from': '2019-12-30T17:10:43.000Z',
#     'valid_until': '2020-12-29T17:10:43.000Z',
#     'score': 50,
#     'pattern_type': 'stix',
#     'indicator_pattern': "[domain-name:value = 'document-out.hopto.org']",
#     'created': '2020-04-02T08:53:17.256Z',
#     'modified': '2020-04-02T08:53:17.256Z',
#     'remote_relation_id': 'd4115ab1-9216-56da-99af-bb0569812db2',
#     'createdByRef': None}],
#   'markingDefinitionsIds': ['c4ae0c3a-3535-44e2-b206-bb451c25c749'],
#   'tagsIds': [],
#   'externalReferencesIds': [],
#   'indicatorsIds': ['6a0c4479-40a6-43d6-84ec-8922f52740f5']},
#  {'id': '2ead8435-c9ac-43dd-8092-64af299a7d86',
#   'stix_id_key': 'observable--59b6d858-5980-4c09-93cf-02a0f27d6142',
#   'entity_type': 'domain',
#   'name': 'libcrash.ddns.net',
#   'description': '',
#   'observable_value': 'libcrash.ddns.net',
#   'created_at': '2020-04-03T06:22:00.674Z',
#   'updated_at': '2020-04-03T06:22:00.674Z',
#   'createdByRef': {'id': '03551e1a-ac3f-4a5b-8ba5-a0dfe8b1fb19',
#    'entity_type': 'organization',
#    'stix_id_key': 'identity--071e2dfa-f96b-4552-85eb-87f62d9bb73e',
#    'stix_label': None,
#    'name': 'AlienVault',
#    'alias': [],
#    'description': '',
#    'created': '2020-04-02T08:52:40.983Z',
#    'modified': '2020-04-02T08:52:40.983Z',
#    'organization_class': None,
#    'remote_relation_id': 'd3e31d84-60da-5a27-afd4-91384fcecffe'},
#   'tags': [],
#   'markingDefinitions': [{'id': 'c4ae0c3a-3535-44e2-b206-bb451c25c749',
#     'entity_type': 'marking-definition',
#     'stix_id_key': 'marking-definition--613f2e26-407d-48c7-9eca-b8e91df99dc9',
#     'definition_type': 'TLP',
#     'definition': 'TLP:WHITE',
#     'level': 1,
#     'color': '#ffffff',
#     'created': '2020-04-01T13:30:18.349Z',
#     'modified': '2020-04-01T13:30:18.349Z',
#     'remote_relation_id': '0f66845e-7b48-5f90-b2d3-554480b290b4',
#     'createdByRef': None}],
#   'externalReferences': [],
#   'indicators': [{'id': '69492682-ecf5-4f88-b3d8-7de39770d670',
#     'entity_type': 'indicator',
#     'stix_id_key': 'indicator--d864d35c-7900-4fc3-a9e2-2ea3d283c3d4',
#     'valid_from': '2019-12-30T17:10:43.000Z',
#     'valid_until': '2020-12-29T17:10:43.000Z',
#     'score': 50,
#     'pattern_type': 'stix',
#     'indicator_pattern': "[domain-name:value = 'libcrash.ddns.net']",
#     'created': '2020-04-02T08:53:17.255Z',
#     'modified': '2020-04-02T08:53:17.255Z',
#     'remote_relation_id': 'c4f255d8-223c-5c5d-81aa-55aec728b264',
#     'createdByRef': None}],
#   'markingDefinitionsIds': ['c4ae0c3a-3535-44e2-b206-bb451c25c749'],
#   'tagsIds': [],
#   'externalReferencesIds': [],
#   'indicatorsIds': ['69492682-ecf5-4f88-b3d8-7de39770d670']},
#  {'id': 'b962f8c4-6d97-4466-adfb-ff49b5b9a2ac',
#   'stix_id_key': 'observable--822b2fe6-0ced-42d5-b408-a2b759a88880',
#   'entity_type': 'domain',
#   'name': 'pasive.ddns.net',
#   'description': '',
#   'observable_value': 'pasive.ddns.net',
#   'created_at': '2020-04-03T06:22:13.784Z',
#   'updated_at': '2020-04-03T06:22:13.784Z',
#   'createdByRef': {'id': '03551e1a-ac3f-4a5b-8ba5-a0dfe8b1fb19',
#    'entity_type': 'organization',
#    'stix_id_key': 'identity--071e2dfa-f96b-4552-85eb-87f62d9bb73e',
#    'stix_label': None,
#    'name': 'AlienVault',
#    'alias': [],
#    'description': '',
#    'created': '2020-04-02T08:52:40.983Z',
#    'modified': '2020-04-02T08:52:40.983Z',
#    'organization_class': None,
#    'remote_relation_id': 'b4de7767-c78c-5bc0-a822-616899248523'},
#   'tags': [],
#   'markingDefinitions': [{'id': 'c4ae0c3a-3535-44e2-b206-bb451c25c749',
#     'entity_type': 'marking-definition',
#     'stix_id_key': 'marking-definition--613f2e26-407d-48c7-9eca-b8e91df99dc9',
#     'definition_type': 'TLP',
#     'definition': 'TLP:WHITE',
#     'level': 1,
#     'color': '#ffffff',
#     'created': '2020-04-01T13:30:18.349Z',
#     'modified': '2020-04-01T13:30:18.349Z',
#     'remote_relation_id': 'd582c231-1fa8-5a15-8cf0-ef7941711692',
#     'createdByRef': None}],
#   'externalReferences': [],
#   'indicators': [{'id': 'bdd9bf84-053a-4842-b257-46745ce7bbee',
#     'entity_type': 'indicator',
#     'stix_id_key': 'indicator--206efeb1-ff8b-446d-a8e5-f4172557a616',
#     'valid_from': '2020-01-09T17:12:13.000Z',
#     'valid_until': '2021-01-08T17:12:13.000Z',
#     'score': 50,
#     'pattern_type': 'stix',
#     'indicator_pattern': "[domain-name:value = 'pasive.ddns.net']",
#     'created': '2020-04-02T08:53:17.259Z',
#     'modified': '2020-04-02T08:53:17.259Z',
#     'remote_relation_id': 'de44784e-0572-51ad-bb0c-2d4157e59f5d',
#     'createdByRef': None}],
#   'markingDefinitionsIds': ['c4ae0c3a-3535-44e2-b206-bb451c25c749'],
#   'tagsIds': [],
#   'externalReferencesIds': [],
#   'indicatorsIds': ['bdd9bf84-053a-4842-b257-46745ce7bbee']},
#  {'id': 'cd2807b2-037c-456e-b466-efb84f81a628',
#   'stix_id_key': 'observable--1f752361-0851-48a9-a9f6-cde2bcc39036',
#   'entity_type': 'url',
#   'name': 'http://nicoledotson.icu/debby/weatherford/',
#   'description': '',
#   'observable_value': 'http://nicoledotson.icu/debby/weatherford/',
#   'created_at': '2020-04-03T06:24:26.837Z',
#   'updated_at': '2020-04-03T06:24:26.837Z',
#   'createdByRef': {'id': '03551e1a-ac3f-4a5b-8ba5-a0dfe8b1fb19',
#    'entity_type': 'organization',
#    'stix_id_key': 'identity--071e2dfa-f96b-4552-85eb-87f62d9bb73e',
#    'stix_label': None,
#    'name': 'AlienVault',
#    'alias': [],
#    'description': '',
#    'created': '2020-04-02T08:52:40.983Z',
#    'modified': '2020-04-02T08:52:40.983Z',
#    'organization_class': None,
#    'remote_relation_id': '20a93b02-a890-51e9-90b6-5943d0a9f2de'},
#   'tags': [],
#   'markingDefinitions': [{'id': 'c4ae0c3a-3535-44e2-b206-bb451c25c749',
#     'entity_type': 'marking-definition',
#     'stix_id_key': 'marking-definition--613f2e26-407d-48c7-9eca-b8e91df99dc9',
#     'definition_type': 'TLP',
#     'definition': 'TLP:WHITE',
#     'level': 1,
#     'color': '#ffffff',
#     'created': '2020-04-01T13:30:18.349Z',
#     'modified': '2020-04-01T13:30:18.349Z',
#     'remote_relation_id': 'c9f39b3c-c7aa-5a0b-a557-767f2abfae14',
#     'createdByRef': None}],
#   'externalReferences': [],
#   'indicators': [{'id': 'fe98a316-47c5-44b3-a7e4-04747457747d',
#     'entity_type': 'indicator',
#     'stix_id_key': 'indicator--2c91eddd-2d99-46c1-82d9-ccb0a257fed0',
#     'valid_from': '2020-02-13T09:52:53.000Z',
#     'valid_until': '2021-02-12T09:52:53.000Z',
#     'score': 50,
#     'pattern_type': 'stix',
#     'indicator_pattern': "[url:value = 'http://nicoledotson.icu/debby/weatherford/']",
#     'created': '2020-04-02T08:53:17.456Z',
#     'modified': '2020-04-02T08:53:17.456Z',
#     'remote_relation_id': 'ee9813be-0802-5db9-898d-8093a6dc24e1',
#     'createdByRef': None}],
#   'markingDefinitionsIds': ['c4ae0c3a-3535-44e2-b206-bb451c25c749'],
#   'tagsIds': [],
#   'externalReferencesIds': [],
#   'indicatorsIds': ['fe98a316-47c5-44b3-a7e4-04747457747d']},
#  {'id': '476e0c26-691c-41df-952a-515b39d0c745',
#   'stix_id_key': 'observable--1a82f774-ed5a-43f2-b2d3-a1c6603db691',
#   'entity_type': 'domain',
#   'name': 'nicoledotson.icu',
#   'description': '',
#   'observable_value': 'nicoledotson.icu',
#   'created_at': '2020-04-03T06:24:50.025Z',
#   'updated_at': '2020-04-03T06:24:50.025Z',
#   'createdByRef': {'id': '03551e1a-ac3f-4a5b-8ba5-a0dfe8b1fb19',
#    'entity_type': 'organization',
#    'stix_id_key': 'identity--071e2dfa-f96b-4552-85eb-87f62d9bb73e',
#    'stix_label': None,
#    'name': 'AlienVault',
#    'alias': [],
#    'description': '',
#    'created': '2020-04-02T08:52:40.983Z',
#    'modified': '2020-04-02T08:52:40.983Z',
#    'organization_class': None,
#    'remote_relation_id': 'fed93ae8-a442-5ca6-aebe-a09bb44cbb63'},
#   'tags': [],
#   'markingDefinitions': [{'id': 'c4ae0c3a-3535-44e2-b206-bb451c25c749',
#     'entity_type': 'marking-definition',
#     'stix_id_key': 'marking-definition--613f2e26-407d-48c7-9eca-b8e91df99dc9',
#     'definition_type': 'TLP',
#     'definition': 'TLP:WHITE',
#     'level': 1,
#     'color': '#ffffff',
#     'created': '2020-04-01T13:30:18.349Z',
#     'modified': '2020-04-01T13:30:18.349Z',
#     'remote_relation_id': 'c2a81220-aa16-50f8-86c4-ed7aa2896383',
#     'createdByRef': None}],
#   'externalReferences': [],
#   'indicators': [{'id': '18e2b164-64f7-4192-9a48-913c19c1b289',
#     'entity_type': 'indicator',
#     'stix_id_key': 'indicator--5ec0dbb2-1b62-4c82-8bf9-d276c494130e',
#     'valid_from': '2020-02-13T09:52:53.000Z',
#     'valid_until': '2021-02-12T09:52:53.000Z',
#     'score': 50,
#     'pattern_type': 'stix',
#     'indicator_pattern': "[domain-name:value = 'nicoledotson.icu']",
#     'created': '2020-04-02T08:53:17.470Z',
#     'modified': '2020-04-02T08:53:17.470Z',
#     'remote_relation_id': 'a930f614-016a-5478-92ff-5939a2ae7b0b',
#     'createdByRef': None}],
#   'markingDefinitionsIds': ['c4ae0c3a-3535-44e2-b206-bb451c25c749'],
#   'tagsIds': [],
#   'externalReferencesIds': [],
#   'indicatorsIds': ['18e2b164-64f7-4192-9a48-913c19c1b289']}]
