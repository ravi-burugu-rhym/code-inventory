# %%
import pandas as pd
import uuid
from datetime import datetime
import numpy as np
from grakn.client import GraknClient
from tqdm import tqdm
tqdm.pandas()

# %%
df=pd.read_excel(r"C:\Users\SRIKANTH\Desktop\OpenCTI_Data.xlsx",sheet_name='malware')

# %%
df.keys()
# Out:
# Index(['internal_id_key', 'stix_id_key', 'stix_label', 'entity_type',
#        'created', 'modified', 'revoked', 'object_status', 'created_at',
#        'created_at_day', 'created_at_month', 'created_at_year', 'updated_at',
#        'name', 'description', 'alias', 'graph_data', 'external_references ',
#        'object_marking_refs', 'granular_markings'],
#       dtype='object')

# %%
def  insert_general_info(df,ent_type,create):
    if create:
        for index,i in df.iterrows():
            df.internal_id_key[index]=str(uuid.uuid4())
            df.stix_id_key[index]=ent_type+'--'+str(uuid.uuid4())
            df.stix_label[index]='NA'
            df.entity_type[index]=ent_type
            df.created=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.created_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.created_at_day=(datetime.now()).strftime("%Y-%m-%d")
            df.created_at_month=(datetime.now()).strftime("%Y-%m")
            df.created_at_year=(datetime.now()).strftime("%Y")
            df.modified=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.updated_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.revoked=False
            df.object_status='NA'
    else:
            df.modified=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.updated_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
    return df

# %%
result=insert_general_info(df=df,ent_type='Malware',create=True)
result.fillna('NA',inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\SRIKANTH\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
result
# Out:
#                          internal_id_key  \
# 0   548f1d80-fbca-4264-a024-f0998560aa98
# 1   0ad0b5bd-9cee-4667-ae39-695ee78e8f29
# 2   273e402b-a775-4419-9d47-b3046ff99318
# 3   e5275edd-a2cd-4298-802e-8afebfa3e94c
# 4   52e09dfc-8dca-4954-83bc-89ee59ea9372
# 5   55646394-bea3-48bb-b8df-f47e97db0db9
# 6   c2d11642-d161-4cf6-8417-477228018750
# 7   5a58c586-b587-46c9-a962-47966c430b96
# 8   aebbd09a-6dc2-4cbe-acc5-07c3fa560366
# 9   ac9291f2-cc8d-4a98-a7c2-cd7a9544c21a
# 10  8c0081dd-74fa-411c-af83-4e0522b2e8ad
# 11  9c5bed93-4d95-4a5c-ad43-87b4a1916892
# 12  132909d3-7534-4ab4-8c7d-2ef9260d538c
# 13  22aa4baf-5fa6-45f1-9dbc-d4646c14f6ed
# 14  d902c8f0-debc-407b-889a-ca692ec80f7f
# 15  2bdc3c1f-a20b-4d8f-a374-e200cf031699
# 16  f6dd0509-a8e4-43d1-96fd-ffa385c29c0d
# 17  4b6c9de0-71f1-4fed-9d39-dd830db34b13
# 18  b038a00b-9eaa-47ab-9ffe-aa3801508a39
# 19  84d413c3-f4ee-4917-821a-865a9b7c4b3e
# 20  5675bcc5-107a-4027-b92b-61645c51edde
# 21  79aba98d-615d-4b21-9db0-2dd11f79b6b9
# 22  e3a049de-cf19-4a38-8a6b-e861061b9545
# 23  3f289f40-2339-44a2-994c-96221dddb478
# 24  86495ac0-eebc-45a9-a6de-ad03830310f4
# 25  b99b44a5-48fb-45ed-8bc1-1765ac2b2e87
# 26  a5d399a9-f040-418e-8847-d59cfe3768f8
# 27  fd7f92ca-5f54-4e7d-a97d-6e328cf1e59c
# 28  3b18eb83-a631-46a4-88df-58e6bb6b0e16
# 29  43fbbfe4-54fb-4cd0-bf9d-36da42e7751c
# 30  704972b6-0625-4554-b275-1ba0944ea0b3
# 31  84f49f87-466c-4d2f-bc39-97e868708377
#
#                                       stix_id_key stix_label entity_type  \
# 0   Malware--6eb63f2b-ae8c-4bae-b843-e6079c5d7dfa         NA     Malware
# 1   Malware--f4ea09d4-acfa-448f-b233-cf54422d2158         NA     Malware
# 2   Malware--f70731dd-3690-493f-8978-c25aba819b61         NA     Malware
# 3   Malware--22085de0-730c-4a8a-8125-20fbf75c696f         NA     Malware
# 4   Malware--5b8f66b1-c2aa-46af-97fb-f700a2445130         NA     Malware
# 5   Malware--23b9c7df-67bc-43bb-8eda-951f22976712         NA     Malware
# 6   Malware--42612ebc-97a9-4d70-9476-57045c3a43d7         NA     Malware
# 7   Malware--168fc7b9-9f4b-43d4-8b93-c414935045ca         NA     Malware
# 8   Malware--b3e0ce6b-8990-4878-8e94-e9c4876d7e96         NA     Malware
# 9   Malware--ffa94a9e-76b0-4b97-a8b5-ee24af5a63c7         NA     Malware
# 10  Malware--e1bbca9c-eb55-4cbc-8b0b-aa62e94626e7         NA     Malware
# 11  Malware--e77929d3-f0d3-4218-8a28-ac4477bccac0         NA     Malware
# 12  Malware--39bab856-9e73-457a-8302-dda546f2380a         NA     Malware
# 13  Malware--ac0d4ce6-53ad-46bb-9e0f-3641faf07a2e         NA     Malware
# 14  Malware--13de2ece-7d4d-4259-999c-c8823602305c         NA     Malware
# 15  Malware--eb160ebc-1362-4f02-a987-18b01685648f         NA     Malware
# 16  Malware--0b701847-d53c-49a7-b2bf-643b6e2ce934         NA     Malware
# 17  Malware--167585ff-bb98-4cb7-bf33-649d00e6b9c0         NA     Malware
# 18  Malware--99e86c2e-de87-4758-9b89-3d235b0b66ea         NA     Malware
# 19  Malware--afa8380a-65c2-42c0-9d4c-0078038aee05         NA     Malware
# 20  Malware--185ff4bd-5b1a-4045-b93d-5e21632ab90e         NA     Malware
# 21  Malware--b411d1b1-5cf5-46ed-922e-b18a1eeddf48         NA     Malware
# 22  Malware--662d369c-2429-448c-9faf-f06da27f8a45         NA     Malware
# 23  Malware--c54a88d8-f7d7-401a-a4d7-e630c9323214         NA     Malware
# 24  Malware--b2980139-9ec8-44a4-a942-bc9c86b0b84f         NA     Malware
# 25  Malware--fc75eaa6-d5eb-44fb-a3f8-2cd2e7fbf2e7         NA     Malware
# 26  Malware--fc7b944e-6072-4363-8b40-6de539c8123b         NA     Malware
# 27  Malware--3f9f2ac5-3def-4532-9fd2-8acf782506e4         NA     Malware
# 28  Malware--1828d55c-c2df-41f2-b56f-8202a51473fd         NA     Malware
# 29  Malware--5f8b4fa0-6e98-4269-aeda-4811de124871         NA     Malware
# 30  Malware--843ec5d2-3d88-4ce5-aaeb-4df6142d9946         NA     Malware
# 31  Malware--d004950a-9252-4b6a-a375-eff1dc0d959c         NA     Malware
#
#                 created             modified  revoked object_status  \
# 0   2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 1   2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 2   2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 3   2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 4   2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 5   2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 6   2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 7   2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 8   2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 9   2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 10  2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 11  2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 12  2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 13  2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 14  2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 15  2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 16  2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 17  2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 18  2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 19  2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 20  2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 21  2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 22  2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 23  2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 24  2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 25  2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 26  2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 27  2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 28  2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 29  2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 30  2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
# 31  2020-01-06T13:20:07  2020-01-06T13:20:07    False            NA
#
#              created_at created_at_day created_at_month created_at_year  \
# 0   2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 1   2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 2   2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 3   2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 4   2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 5   2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 6   2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 7   2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 8   2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 9   2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 10  2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 11  2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 12  2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 13  2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 14  2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 15  2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 16  2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 17  2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 18  2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 19  2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 20  2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 21  2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 22  2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 23  2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 24  2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 25  2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 26  2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 27  2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 28  2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 29  2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 30  2020-01-06T13:20:07     2020-01-06          2020-01            2020
# 31  2020-01-06T13:20:07     2020-01-06          2020-01            2020
#
#              updated_at           name  \
# 0   2020-01-06T13:20:07         Ixeshe
# 1   2020-01-06T13:20:07         Aumlib
# 2   2020-01-06T13:20:07      Threebyte
# 3   2020-01-06T13:20:07       Hightide
# 4   2020-01-06T13:20:07     Waterspout
# 5   2020-01-06T13:20:07         Coblnt
# 6   2020-01-06T13:20:07      More_eggs
# 7   2020-01-06T13:20:07       Carbanak
# 8   2020-01-06T13:20:07       PetrWrap
# 9   2020-01-06T13:20:07             NA
# 10  2020-01-06T13:20:07         Finspy
# 11  2020-01-06T13:20:07      Finfisher
# 12  2020-01-06T13:20:07       wingbird
# 13  2020-01-06T13:20:07             NA
# 14  2020-01-06T13:20:07  ADVSTORESHELL
# 15  2020-01-06T13:20:07         Cannon
# 16  2020-01-06T13:20:07      CHOPSTICK
# 17  2020-01-06T13:20:07      CORESHELL
# 18  2020-01-06T13:20:07      Downdelph
# 19  2020-01-06T13:20:07         Fysbis
# 20  2020-01-06T13:20:07       JHUHUGIT
# 21  2020-01-06T13:20:07        HIDEDRV
# 22  2020-01-06T13:20:07        Komplex
# 23  2020-01-06T13:20:07          LoJax
# 24  2020-01-06T13:20:07      XAgentOSX
# 25  2020-01-06T13:20:07        XTunnel
# 26  2020-01-06T13:20:07        Zebrocy
# 27  2020-01-06T13:20:07      Backspace
# 28  2020-01-06T13:20:07     Flashflood
# 29  2020-01-06T13:20:07      spaceship
# 30  2020-01-06T13:20:07       Neteagle
# 31  2020-01-06T13:20:07      shipspace
#
#                                           description  \
# 0   Advanced persistent threat that uses stealthy ...
# 1   Aumlib have been enhanced to encode HTTP commu...
# 2   Threebyte is a Backdoor that targets the Windo...
# 3   On Sunday August 24, 2014 we observed a spear ...
# 4   spear phishing emails targeting a high-technol...
# 5   CobInt, is a self-developed backdoor of the Co...
# 6   More_eggs is a JavaScript backdoor used by the...
# 7   Carbanak is a full-featured, remote backdoor u...
# 8   The PetrWrap Trojan is written in C and compil...
# 9                                                  NA
# 10  Trojan-Spy:W32/FinSpy.A is a component of a co...
# 11  FinFisher can be covertly installed on targets...
# 12  Wingbird is a backdoor that appears to be a ve...
# 13                                                 NA
# 14  ADVSTORESHELL is a spying backdoor that has be...
# 15  Cannon is a Trojan with variants written in C#...
# 16  CHOPSTICK is a malware family of modular backd...
# 17  CORESHELL is a downloader used by APT28. The o...
# 18  Downdelph is a first-stage downloader written ...
# 19           Linux-based TROJAN/backdoo at least 2014
# 20  JHUHUGIT is malware used by APT28. It is based...
# 21                                            Rootkit
# 22  Komplex is a backdoor/Trojan that has been use...
# 23  LoJax is a UEFI rootkit used by APT28 to persi...
# 24  XAgentOSX is a trojan that has been used by AP...
# 25  XTunnel a VPN-like network proxy tool that can...
# 26  Zebrocy is a Trojan that has been used by APT2...
# 27  ‘Backspace’, a professionally developed and ma...
# 28  FLASHFLOOD is malware developed by APT30 that ...
# 29  SPACESHIP is malware developed by APT30 that a...
# 30  NETEAGLE is a backdoor developed by APT30 with...
# 31  SHIPSHAPE is malware developed by APT30 that a...
#
#                                                 alias graph_data  \
# 0   Numbered Panda      TG-2754             BeeBus...         NA
# 1                                  bbsinfo     aumlib         NA
# 2                                                  NA         NA
# 3                                             Etumbot         NA
# 4                                                  NA         NA
# 5                                                  NA         NA
# 6                                       SpicyOmelette         NA
# 7                                              Anunak         NA
# 8                                                  NA         NA
# 9                                                  NA         NA
# 10                                                 NA         NA
# 11                                                 NA         NA
# 12                                                 NA         NA
# 13                                                 NA         NA
# 14  Trojan.Win32.Sofacy.al\nTrojan.Win32.Sofacy.be...         NA
# 15                                                 NA         NA
# 16                                                 NA         NA
# 17                                                 NA         NA
# 18  apivscd.dll\ninstall_com_x32_LL_full.dll\nshco...         NA
# 19                                                 NA         NA
# 20                                                 NA         NA
# 21                                                 NA         NA
# 22                                                 NA         NA
# 23                                                 NA         NA
# 24                                                 NA         NA
# 25                                                 NA         NA
# 26                                                 NA         NA
# 27                                                 NA         NA
# 28                                                 NA         NA
# 29                                                 NA         NA
# 30                                                 NA         NA
# 31                                                 NA         NA
#
#    external_references  object_marking_refs granular_markings
# 0                    NA                  NA                NA
# 1                    NA                  NA                NA
# 2                    NA                  NA                NA
# 3                    NA                  NA                NA
# 4                    NA                  NA                NA
# 5                    NA                  NA                NA
# 6                    NA                  NA                NA
# 7                    NA                  NA                NA
# 8                    NA                  NA                NA
# 9                    NA                  NA                NA
# 10                   NA                  NA                NA
# 11                   NA                  NA                NA
# 12                   NA                  NA                NA
# 13                   NA                  NA                NA
# 14                   NA                  NA                NA
# 15                   NA                  NA                NA
# 16                   NA                  NA                NA
# 17                   NA                  NA                NA
# 18                   NA                  NA                NA
# 19                   NA                  NA                NA
# 20                   NA                  NA                NA
# 21                   NA                  NA                NA
# 22                   NA                  NA                NA
# 23                   NA                  NA                NA
# 24                   NA                  NA                NA
# 25                   NA                  NA                NA
# 26                   NA                  NA                NA
# 27                   NA                  NA                NA
# 28                   NA                  NA                NA
# 29                   NA                  NA                NA
# 30                   NA                  NA                NA
# 31                   NA                  NA                NA

# %%
def insert_one_malware(df,session):
    #if df.first_seen != 'NA':
     #   f=df.first_seen.strftime("%Y-%m-%dT%H:%M:%S")
     #   f_m=df.first_seen.strftime("%Y-%m")
     #   f_d=df.first_seen.strftime("%Y-%m-%d")
    #elif df.first_seen_month != 'NA':
    #    f_m=df.first_seen_month
    #elif df.first_seen_day != 'NA':
    #    f_d=df.first_seen_day
    #else:
    #    f_d=None
    #    f_m=None
    #    f=None
    aliases = list()
    if df['alias'] != 'NA':            
        aliases=df.alias.split('\n')

    graql_match_query = f"match $i isa Malware, " \
                        f"has name \"{df['name']}_\"; " \
                        f"get;"
    # print(graql_match_query)
    with session.transaction().read() as read_transaction:
        # read_transaction.query(graql_match_query)
        answer_iterator = None
        answer_iterator = read_transaction.query(graql_match_query, infer=True)
        data = answer_iterator.collect_concepts()
                
        if len(data) > 0:
            # Update data.
            # Columns to be updated: object_status, revoked, updated_at, modified, description, alias
            # print("Update intrusion-set...")
            print("Update: " + df['name'])
            graql_attribute_delete_query = f"match $i isa Malware, " \
                                           f"has name \"{df['name']}_\", "\
                                           f"has alias $a via $i1, "\
                                           f"has description $a via $i2; "\
                                           f"delete $i1, $i2;"
            update_flg = False
            first_attr_flg = True
            graql_attribute_update_query = f"match $i isa Malware, " \
                                           f"has name \"{df['name']}_\"; insert $i"
            if df['description'] != 'NA':
                # graql_attribute_delete_query += f" has description $a via $i2; "\
                graql_attribute_update_query += f" has description \"{df['description']}\" "
                if first_attr_flg:
                    graql_attribute_update_query += ","
                update_flg = True
                first_attr_flg = False
            print(len(aliases))
            if len(aliases) > 0:
                s = "|"
                graql_attribute_update_query += f" has alias \"{s.join(aliases).replace(' ','')}\" " 
                if first_attr_flg:
                     graql_attribute_update_query += ","
                update_flg = True
                first_attr_flg = False
            graql_attribute_update_query += ";"
            print(graql_attribute_update_query)
            if update_flg:
                with session.transaction().write() as write_transaction:
                    # make a write transection with the query
                    write_transaction.query(graql_attribute_delete_query)
                    write_transaction.query(graql_attribute_update_query)
                    # remember to commit at the end
                    write_transaction.commit()           
        else:
            # print("Insert intrusion-set...")
            print("Insert: " + df['name'])
            graql_insert_query = f"insert $x isa Malware, " \
                                 f"has internal_id_key \"{df['internal_id_key']}\", " \
                                 f"has stix_id_key \"{df['stix_id_key']}\", " \
                                 f"has stix_label \"{df['stix_label']}\", " \
                                 f"has entity_type \"{df['entity_type']}\", " \
                                 f"has created {df['created']}, " \
                                 f"has revoked \"{df['revoked']}\", "\
                                 f"has created_at {df['created_at']}, " \
                                 f"has created_at_day \"{df['created_at_day']}\", " \
                                 f"has created_at_month \"{df['created_at_month']}\", " \
                                 f"has created_at_year \"{df['created_at_year']}\", "\
                                 f"has updated_at {df['updated_at']}, "\
                                 f"has name \"{df['name']}_\" "
                                 
            if df['description'] != 'NA':
                graql_insert_query += f", has description \"{df['description']}\" "
            if len(aliases) > 0:
                s = "|"
                graql_insert_query += f", has alias \"{s.join(aliases)}\" "
            #if f is not None:
            #    graql_insert_query += f", has first_seen {f} "
            #if f_d is not None:
            #    graql_insert_query += f", has first_seen_day \"{f_d}\" "
            #if f_m is not None:
             #   graql_insert_query += f", has first_seen_month \"{f_m}\" "
            #if f_m is not None:
            #    graql_insert_query += f", has first_seen_year \"{df['first_seen_year']}\""
            graql_insert_query += ";"
            #print(graql_insert_query)
            with session.transaction().write() as write_transaction:
                # make a write transection with the query
                write_transaction.query(graql_insert_query)
                # remember to commit at the end
                write_transaction.commit()

# %%
def load_data_into_grakn(session,input_df):
    print("Malware...")
    # using progress_apply instead of apply so we have a progress bar form tqdm
    # input_df.progress_apply(insert_one_intrusion_set, axis=1, session=session)
    print("Malware...")
    for index,row in input_df.iterrows():
        insert_one_malware(df=row,session=session)

# %%
def build_grakn_graph(input_df, keyspace_name):
    with GraknClient(uri="192.168.83.128:48555") as client:
        with client.session(keyspace = keyspace_name) as session:
            load_data_into_grakn(session,input_df)

# %%
build_grakn_graph(input_df=result,keyspace_name='grakn')
# Out:
# Malware...
# Malware...
# Update: Ixeshe
# 1
# match $i isa Malware, has name "Ixeshe_"; insert $i has description "Advanced persistent threat that uses stealthy data-stealing malware called IXESHE (“i-sushi”) to infect machines. So far it’s hit East Asian governments, Taiwanese electronics manufacturers and German telecommunications firms operating across Asia.  " , has alias "NumberedPandaTG-2754BeeBusGroup22DynCalc/CalcTeamDNSCalcCrimsonIronAPT12" ;
# Update: Aumlib
# 1
# match $i isa Malware, has name "Aumlib_"; insert $i has description "Aumlib have been enhanced to encode HTTP communication and use new network traffic patterns respectively.
# The researchers speculate this is an attempt to avoid detection by security systems." , has alias "bbsinfoaumlib" ;
# Update: Threebyte
# 0
# match $i isa Malware, has name "Threebyte_"; insert $i has description "Threebyte is a Backdoor that targets the Windows platform. This malware contacts a remote server to receive commands to execute on the infected system. It sends out information about the targeted system. Furthermore, it has been reportedly delivered to a victim's machine via exploitation of a Microsoft Word Document vulnerability (CVE-2012-0158). In order to survive system reboots, it adds a value to the Run key in the Registry." ,;
# ---------------------------------------------------------------------------
# _Rendezvous                               Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\grakn\service\Session\TransactionService.py in send(self, request)
#     155             self._add_request(request)
# --> 156             response = next(self._response_iterator)
#     157         except Exception as e: # specialize into different gRPC exceptions?
#
# ~\AppData\Roaming\Python\Python37\site-packages\grpc\_channel.py in __next__(self)
#     363     def __next__(self):
# --> 364         return self._next()
#     365
#
# ~\AppData\Roaming\Python\Python37\site-packages\grpc\_channel.py in _next(self)
#     357                     elif self._state.code is not None:
# --> 358                         raise self
#     359
#
# _Rendezvous: <_Rendezvous of RPC that terminated with:
# 	status = StatusCode.UNKNOWN
# 	details = "syntax error at line 1:
# match $i isa Malware, has name "Threebyte_"; insert $i has description "Threebyte is a Backdoor that targets the Windows platform. This malware contacts a remote server to receive commands to execute on the infected system. It sends out information about the targeted system. Furthermore, it has been reportedly delivered to a victim's machine via exploitation of a Microsoft Word Document vulnerability (CVE-2012-0158). In order to survive system reboots, it adds a value to the Run key in the Registry." ,;
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ^
# mismatched input ';' expecting {'match', 'define', 'undefine', 'insert', 'compute'}. Please check server logs for the stack trace."
# 	debug_error_string = "{"created":"@1578297232.259000000","description":"Error received from peer","file":"src/core/lib/surface/call.cc","file_line":1017,"grpc_message":"syntax error at line 1: \nmatch $i isa Malware, has name "Threebyte_"; insert $i has description "Threebyte is a Backdoor that targets the Windows platform. This malware contacts a remote server to receive commands to execute on the infected system. It sends out information about the targeted system. Furthermore, it has been reportedly delivered to a victim's machine via exploitation of a Microsoft Word Document vulnerability (CVE-2012-0158). In order to survive system reboots, it adds a value to the Run key in the Registry." ,;\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ^\nmismatched input ';' expecting {'match', 'define', 'undefine', 'insert', 'compute'}. Please check server logs for the stack trace.","grpc_status":2}"
# >
#
# During handling of the above exception, another exception occurred:
#
# GraknError                                Traceback (most recent call last)
# <ipython-input-14-5e7a2e31729c> in <module>
# ----> 1 build_grakn_graph(input_df=result,keyspace_name='grakn')
#
# <ipython-input-13-f8a11a8230ca> in build_grakn_graph(input_df, keyspace_name)
#       2     with GraknClient(uri="192.168.83.128:48555") as client:
#       3         with client.session(keyspace = keyspace_name) as session:
# ----> 4             load_data_into_grakn(session,input_df)
#
# <ipython-input-12-5648aae2886d> in load_data_into_grakn(session, input_df)
#       5     print("Malware...")
#       6     for index,row in input_df.iterrows():
# ----> 7         insert_one_malware(df=row,session=session)
#
# <ipython-input-11-1da81f246578> in insert_one_malware(df, session)
#      61                     # make a write transection with the query
#      62                     write_transaction.query(graql_attribute_delete_query)
# ---> 63                     write_transaction.query(graql_attribute_update_query)
#      64                     # remember to commit at the end
#      65                     write_transaction.commit()
#
# C:\ProgramData\Anaconda3\lib\site-packages\grakn\client.py in query(self, query, infer)
#     129     def query(self, query, infer=True):
#     130         """ Execute a Graql query, inference is optionally enabled """
# --> 131         return self._tx_service.query(query, infer)
#     132     query.__annotations__ = {'query': str}
#     133
#
# C:\ProgramData\Anaconda3\lib\site-packages\grakn\service\Session\TransactionService.py in query(self, query, infer)
#      47         request = RequestBuilder.query(query, infer=infer)
#      48         # print("Query request: {0}".format(request))
# ---> 49         response = self._communicator.send(request)
#      50         # convert `response` into a python iterator
#      51         return ResponseReader.ResponseReader.query(self, response.query_iter)
#
# C:\ProgramData\Anaconda3\lib\site-packages\grakn\service\Session\TransactionService.py in send(self, request)
#     158             # invalidate this communicator, functionally this occurs automatically on exception (iterator not usable anymore)
#     159             self._closed = True
# --> 160             raise GraknError("Server/network error: {0}\n\n generated from request: {1}".format(e, request))
#     161
#     162         if response is None:
#
# GraknError: Server/network error: <_Rendezvous of RPC that terminated with:
# 	status = StatusCode.UNKNOWN
# 	details = "syntax error at line 1:
# match $i isa Malware, has name "Threebyte_"; insert $i has description "Threebyte is a Backdoor that targets the Windows platform. This malware contacts a remote server to receive commands to execute on the infected system. It sends out information about the targeted system. Furthermore, it has been reportedly delivered to a victim's machine via exploitation of a Microsoft Word Document vulnerability (CVE-2012-0158). In order to survive system reboots, it adds a value to the Run key in the Registry." ,;
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ^
# mismatched input ';' expecting {'match', 'define', 'undefine', 'insert', 'compute'}. Please check server logs for the stack trace."
# 	debug_error_string = "{"created":"@1578297232.259000000","description":"Error received from peer","file":"src/core/lib/surface/call.cc","file_line":1017,"grpc_message":"syntax error at line 1: \nmatch $i isa Malware, has name "Threebyte_"; insert $i has description "Threebyte is a Backdoor that targets the Windows platform. This malware contacts a remote server to receive commands to execute on the infected system. It sends out information about the targeted system. Furthermore, it has been reportedly delivered to a victim's machine via exploitation of a Microsoft Word Document vulnerability (CVE-2012-0158). In order to survive system reboots, it adds a value to the Run key in the Registry." ,;\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ^\nmismatched input ';' expecting {'match', 'define', 'undefine', 'insert', 'compute'}. Please check server logs for the stack trace.","grpc_status":2}"
# >
#
#  generated from request: query_req {
#   query: "match $i isa Malware, has name \"Threebyte_\"; insert $i has description \"Threebyte is a Backdoor that targets the Windows platform. This malware contacts a remote server to receive commands to execute on the infected system. It sends out information about the targeted system. Furthermore, it has been reportedly delivered to a victim\'s machine via exploitation of a Microsoft Word Document vulnerability (CVE-2012-0158). In order to survive system reboots, it adds a value to the Run key in the Registry.\" ,;"
# }
