# %%
import pandas as pd
import uuid
from datetime import datetime
import numpy as np
from grakn.client import GraknClient
from tqdm import tqdm
tqdm.pandas()

# %%
df=pd.read_excel(r"C:\Users\SRIKANTH\Desktop\OpenCTI_Data.xlsx",sheet_name='malware')

# %%
df.keys()
# Out:
# Index(['internal_id_key', 'stix_id_key', 'stix_label', 'entity_type',
#        'created', 'modified', 'revoked', 'object_status', 'created_at',
#        'created_at_day', 'created_at_month', 'created_at_year', 'updated_at',
#        'name', 'description', 'alias', 'graph_data', 'external_references ',
#        'object_marking_refs', 'granular_markings'],
#       dtype='object')

# %%
def  insert_general_info(df,ent_type,create):
    if create:
        for index,i in df.iterrows():
            df.internal_id_key[index]=str(uuid.uuid4())
            df.stix_id_key[index]=ent_type+'--'+str(uuid.uuid4())
            df.stix_label[index]='NA'
            df.entity_type[index]=ent_type
            df.created=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.created_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.created_at_day=(datetime.now()).strftime("%Y-%m-%d")
            df.created_at_month=(datetime.now()).strftime("%Y-%m")
            df.created_at_year=(datetime.now()).strftime("%Y")
            df.modified=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.updated_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.revoked=False
            df.object_status='NA'
    else:
            df.modified=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
            df.updated_at=(datetime.now()).strftime("%Y-%m-%dT%H:%M:%S")
    return df

# %%
result=insert_general_info(df=df,ent_type='Malware',create=True)
result.fillna('NA',inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\SRIKANTH\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
result
# Out:
#                          internal_id_key  \
# 0   e33c0977-5293-44e4-a389-da077b504627
# 1   017913c9-ffea-448f-bb19-001a32973c32
# 2   5ece9df5-015f-4311-b55c-df84db035f23
# 3   757cec1f-53e9-46e5-9776-31e2de3c6f23
# 4   cef86581-8df6-4670-9bc6-24bb4e94c3c3
# 5   52c0b5d5-b398-4923-9efd-5d26c38cb65f
# 6   294f42c9-e682-4766-a466-0b7748f79f28
# 7   0d72485c-4437-4df1-b682-7a0123089f97
# 8   44289369-d639-4be9-9b95-0f287e1f1a6d
# 9   44d9c248-2293-4ae8-91b0-c90432efdef8
# 10  24a53f3b-2da7-4ba6-af6a-9d5d80e834b6
# 11  1f664f77-c061-4af3-ba3d-7c7f657985e9
# 12  f3a6a43b-5d26-475a-bac3-33a199e07549
# 13  21dc788a-ecbd-4970-9b82-e163ce68d07e
# 14  773f9c87-215e-4893-b175-066379786d6b
# 15  d1be2f7b-591a-4961-b08c-d05cd2d9a311
# 16  b864f3fd-33dd-4618-bde2-17c549035cc0
# 17  5afb7102-5179-4fa2-86bc-fc41f5ccf1a6
# 18  450dcbc8-cc6e-454c-8113-22533458be42
# 19  af0c1706-a4b8-4afb-ad49-06e4439756bb
# 20  ca4287ae-e41d-4cf1-ac19-81f472ce1b96
# 21  ed697540-67cc-4538-a428-1f42db93d5fc
# 22  bf829f04-f03e-4214-9eca-2a982d775ed6
# 23  801e6880-ec0e-4264-92d0-04eef60841bc
# 24  55c00511-4154-4cc4-9704-8c6574eb8c1d
# 25  268b836a-d56e-4a4a-92e0-956609e9b799
# 26  f225ed6d-b7e2-41f3-b444-371e5ab4e5b4
# 27  22f46fcb-9265-49e4-a694-c66fb0900d50
# 28  dd6c7e85-4c97-434c-b288-15a4d76d31f7
# 29  af5937b8-e525-4908-9f59-37b21e6d15af
#
#                                       stix_id_key stix_label entity_type  \
# 0   Malware--1309ce77-d5ee-405c-bf65-8f7b0774f1f3         NA     Malware
# 1   Malware--d51c9082-13d9-4ff4-b85b-f6c695d8521e         NA     Malware
# 2   Malware--bd8e5ebd-5e90-4bb2-9ba8-67c0055cb5d1         NA     Malware
# 3   Malware--c0696fc0-6c45-4a4e-9108-66d494444e4c         NA     Malware
# 4   Malware--755062df-f587-42af-a73f-83aa61f719cc         NA     Malware
# 5   Malware--9f7bcefe-b6eb-4e8e-ae5f-0d38480dc8dd         NA     Malware
# 6   Malware--6dcc3d46-9b06-4164-8924-4478fcc085b1         NA     Malware
# 7   Malware--ddcacd3a-2dfc-4c0d-bc69-5808d1d727f7         NA     Malware
# 8   Malware--73cc9aa5-a62e-4599-b32e-beb82c47098c         NA     Malware
# 9   Malware--93545c9a-6db3-4d7d-9420-483cd69ed965         NA     Malware
# 10  Malware--5e56ee5b-ee06-4d44-ab93-da9fe8e6305d         NA     Malware
# 11  Malware--a230d105-a72a-455b-bb3b-f7808bdfd120         NA     Malware
# 12  Malware--5680044e-1fd5-4ffb-b2d1-eaa4a423808f         NA     Malware
# 13  Malware--24f08081-58e5-4921-9432-5a98cceb0e0f         NA     Malware
# 14  Malware--f0243a5e-99d6-402a-a9e4-7ef3efa8af94         NA     Malware
# 15  Malware--68430ce4-71ae-4b27-9123-c8e20bf826d8         NA     Malware
# 16  Malware--a69dae54-6c72-4b44-9054-62309bd8c6d4         NA     Malware
# 17  Malware--6600969c-a7fc-4b1d-baff-052212f8e17a         NA     Malware
# 18  Malware--0b4f13f4-5ada-4eee-97a7-20ef48a16dc5         NA     Malware
# 19  Malware--a3921ac9-906e-43a3-b0b3-e303ab8b7707         NA     Malware
# 20  Malware--87a6024c-6c57-4918-8719-db69727f0cac         NA     Malware
# 21  Malware--18c45230-257d-4fd1-88f8-e2938b70b214         NA     Malware
# 22  Malware--a1f1a3f6-4e88-490c-871d-d2861be1945e         NA     Malware
# 23  Malware--6d5a1e38-bc99-4431-acd8-4e94fbe22c3f         NA     Malware
# 24  Malware--ba2e453c-892c-4dc0-b234-cde6b2a7d685         NA     Malware
# 25  Malware--13d36a52-0282-42cb-ab61-19bf46e199ff         NA     Malware
# 26  Malware--f897a2c4-7657-4c5a-abd8-61e38ca71e8f         NA     Malware
# 27  Malware--8b359594-6127-4dba-8774-ee90b9e204c4         NA     Malware
# 28  Malware--9b0223ce-a3a0-41d7-85df-cb2ed6390df6         NA     Malware
# 29  Malware--9f25c5a5-7a45-4c36-8bdc-f5049fbbb18a         NA     Malware
#
#                 created             modified  revoked object_status  \
# 0   2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 1   2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 2   2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 3   2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 4   2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 5   2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 6   2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 7   2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 8   2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 9   2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 10  2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 11  2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 12  2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 13  2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 14  2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 15  2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 16  2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 17  2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 18  2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 19  2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 20  2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 21  2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 22  2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 23  2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 24  2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 25  2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 26  2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 27  2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 28  2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
# 29  2020-01-08T14:25:31  2020-01-08T14:25:31    False            NA
#
#              created_at created_at_day created_at_month created_at_year  \
# 0   2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 1   2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 2   2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 3   2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 4   2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 5   2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 6   2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 7   2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 8   2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 9   2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 10  2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 11  2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 12  2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 13  2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 14  2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 15  2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 16  2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 17  2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 18  2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 19  2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 20  2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 21  2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 22  2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 23  2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 24  2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 25  2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 26  2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 27  2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 28  2020-01-08T14:25:31     2020-01-08          2020-01            2020
# 29  2020-01-08T14:25:31     2020-01-08          2020-01            2020
#
#              updated_at           name  \
# 0   2020-01-08T14:25:31         Ixeshe
# 1   2020-01-08T14:25:31         Aumlib
# 2   2020-01-08T14:25:31      Threebyte
# 3   2020-01-08T14:25:31       Hightide
# 4   2020-01-08T14:25:31     Waterspout
# 5   2020-01-08T14:25:31         Coblnt
# 6   2020-01-08T14:25:31      More_eggs
# 7   2020-01-08T14:25:31       Carbanak
# 8   2020-01-08T14:25:31       PetrWrap
# 9   2020-01-08T14:25:31         Finspy
# 10  2020-01-08T14:25:31      Finfisher
# 11  2020-01-08T14:25:31       wingbird
# 12  2020-01-08T14:25:31  ADVSTORESHELL
# 13  2020-01-08T14:25:31         Cannon
# 14  2020-01-08T14:25:31      CHOPSTICK
# 15  2020-01-08T14:25:31      CORESHELL
# 16  2020-01-08T14:25:31      Downdelph
# 17  2020-01-08T14:25:31         Fysbis
# 18  2020-01-08T14:25:31       JHUHUGIT
# 19  2020-01-08T14:25:31        HIDEDRV
# 20  2020-01-08T14:25:31        Komplex
# 21  2020-01-08T14:25:31          LoJax
# 22  2020-01-08T14:25:31      XAgentOSX
# 23  2020-01-08T14:25:31        XTunnel
# 24  2020-01-08T14:25:31        Zebrocy
# 25  2020-01-08T14:25:31      Backspace
# 26  2020-01-08T14:25:31     Flashflood
# 27  2020-01-08T14:25:31      spaceship
# 28  2020-01-08T14:25:31       Neteagle
# 29  2020-01-08T14:25:31      shipspace
#
#                                           description  \
# 0   Advanced persistent threat that uses stealthy ...
# 1   Aumlib have been enhanced to encode HTTP commu...
# 2   Threebyte is a Backdoor that targets the Windo...
# 3   On Sunday August 24, 2014 we observed a spear ...
# 4   spear phishing emails targeting a high-technol...
# 5   CobInt, is a self-developed backdoor of the Co...
# 6   More_eggs is a JavaScript backdoor used by the...
# 7   Carbanak is a full-featured, remote backdoor u...
# 8   The PetrWrap Trojan is written in C and compil...
# 9   Trojan-Spy:W32/FinSpy.A is a component of a co...
# 10  FinFisher can be covertly installed on targets...
# 11  Wingbird is a backdoor that appears to be a ve...
# 12  ADVSTORESHELL is a spying backdoor that has be...
# 13  Cannon is a Trojan with variants written in C#...
# 14  CHOPSTICK is a malware family of modular backd...
# 15  CORESHELL is a downloader used by APT28. The o...
# 16  Downdelph is a first-stage downloader written ...
# 17           Linux-based TROJAN/backdoo at least 2014
# 18  JHUHUGIT is malware used by APT28. It is based...
# 19                                            Rootkit
# 20  Komplex is a backdoor/Trojan that has been use...
# 21  LoJax is a UEFI rootkit used by APT28 to persi...
# 22  XAgentOSX is a trojan that has been used by AP...
# 23  XTunnel a VPN-like network proxy tool that can...
# 24  Zebrocy is a Trojan that has been used by APT2...
# 25  ‘Backspace’, a professionally developed and ma...
# 26  FLASHFLOOD is malware developed by APT30 that ...
# 27  SPACESHIP is malware developed by APT30 that a...
# 28  NETEAGLE is a backdoor developed by APT30 with...
# 29  SHIPSHAPE is malware developed by APT30 that a...
#
#                                                 alias graph_data  \
# 0   Numbered Panda      \nTG-2754             \nBe...         NA
# 1                              \nbbsinfo     \naumlib         NA
# 2                                                  NA         NA
# 3                                             Etumbot         NA
# 4                                                  NA         NA
# 5                                                  NA         NA
# 6                                       SpicyOmelette         NA
# 7                                              Anunak         NA
# 8                                                  NA         NA
# 9                                                  NA         NA
# 10                                                 NA         NA
# 11                                                 NA         NA
# 12  Trojan.Win32.Sofacy.al\nTrojan.Win32.Sofacy.be...         NA
# 13                                                 NA         NA
# 14                                                 NA         NA
# 15                                                 NA         NA
# 16  apivscd.dll\ninstall_com_x32_LL_full.dll\nshco...         NA
# 17                                                 NA         NA
# 18                                                 NA         NA
# 19                                                 NA         NA
# 20                                                 NA         NA
# 21                                                 NA         NA
# 22                                                 NA         NA
# 23                                                 NA         NA
# 24                                                 NA         NA
# 25                                                 NA         NA
# 26                                                 NA         NA
# 27                                                 NA         NA
# 28                                                 NA         NA
# 29                                                 NA         NA
#
#    external_references  object_marking_refs granular_markings
# 0                    NA                  NA                NA
# 1                    NA                  NA                NA
# 2                    NA                  NA                NA
# 3                    NA                  NA                NA
# 4                    NA                  NA                NA
# 5                    NA                  NA                NA
# 6                    NA                  NA                NA
# 7                    NA                  NA                NA
# 8                    NA                  NA                NA
# 9                    NA                  NA                NA
# 10                   NA                  NA                NA
# 11                   NA                  NA                NA
# 12                   NA                  NA                NA
# 13                   NA                  NA                NA
# 14                   NA                  NA                NA
# 15                   NA                  NA                NA
# 16                   NA                  NA                NA
# 17                   NA                  NA                NA
# 18                   NA                  NA                NA
# 19                   NA                  NA                NA
# 20                   NA                  NA                NA
# 21                   NA                  NA                NA
# 22                   NA                  NA                NA
# 23                   NA                  NA                NA
# 24                   NA                  NA                NA
# 25                   NA                  NA                NA
# 26                   NA                  NA                NA
# 27                   NA                  NA                NA
# 28                   NA                  NA                NA
# 29                   NA                  NA                NA

# %%
def insert_one_malware(df,session):
    #if df.first_seen != 'NA':
     #   f=df.first_seen.strftime("%Y-%m-%dT%H:%M:%S")
     #   f_m=df.first_seen.strftime("%Y-%m")
     #   f_d=df.first_seen.strftime("%Y-%m-%d")
    #elif df.first_seen_month != 'NA':
    #    f_m=df.first_seen_month
    #elif df.first_seen_day != 'NA':
    #    f_d=df.first_seen_day
    #else:
    #    f_d=None
    #    f_m=None
    #    f=None
    aliases = list()
    if df['alias'] != 'NA':            
        aliases=df.alias.split('\n')

    graql_match_query = f"match $i isa Malware, " \
                        f"has name \"{df['name']}\"; " \
                        f"get;"
    # print(graql_match_query)
    with session.transaction().read() as read_transaction:
        # read_transaction.query(graql_match_query)
        answer_iterator = None
        answer_iterator = read_transaction.query(graql_match_query, infer=True)
        data = answer_iterator.collect_concepts()
                
        if len(data) > 0:
            # Update data.
            # Columns to be updated: object_status, revoked, updated_at, modified, description, alias
            # print("Update intrusion-set...")
            print("Update: " + df['name'])
            graql_attribute_delete_query = f"match $i isa Malware, " \
                                           f"has name \"{df['name']}\", "\
                                           f"has alias $a via $i1, "\
                                           f"has description $a via $i2; "\
                                           f"delete $i1, $i2;"
            update_flg = False
            first_attr_flg = True
            graql_attribute_update_query = f"match $i isa Malware, " \
                                           f"has name \"{df['name']}\"; insert $i"
            if df['description'] != 'NA':
                # graql_attribute_delete_query += f" has description $a via $i2; "\
                graql_attribute_update_query += f" has description \"{df['description']}\" "
                if (first_attr_flg) & (len(aliases)>0):
                    graql_attribute_update_query += ","
                update_flg = True
                first_attr_flg = False
            print(len(aliases))
            if len(aliases) > 0:
                s = "|"
                graql_attribute_update_query += f" has alias \"{s.join(aliases).replace(' ','')}\" " 
                if first_attr_flg:
                     graql_attribute_update_query += ","
                update_flg = True
                first_attr_flg = False
            graql_attribute_update_query += ";"
            print(graql_attribute_update_query)
            if update_flg:
                with session.transaction().write() as write_transaction:
                    # make a write transection with the query
                    write_transaction.query(graql_attribute_delete_query)
                    write_transaction.query(graql_attribute_update_query)
                    # remember to commit at the end
                    write_transaction.commit()           
        else:
            # print("Insert intrusion-set...")
            print("Insert: " + df['name'])
            graql_insert_query = f"insert $x isa Malware, " \
                                 f"has internal_id_key \"{df['internal_id_key']}\", " \
                                 f"has stix_id_key \"{df['stix_id_key']}\", " \
                                 f"has stix_label \"{df['stix_label']}\", " \
                                 f"has entity_type \"{df['entity_type']}\", " \
                                 f"has created {df['created']}, " \
                                 f"has revoked \"{df['revoked']}\", "\
                                 f"has created_at {df['created_at']}, " \
                                 f"has created_at_day \"{df['created_at_day']}\", " \
                                 f"has created_at_month \"{df['created_at_month']}\", " \
                                 f"has created_at_year \"{df['created_at_year']}\", "\
                                 f"has updated_at {df['updated_at']}, "\
                                 f"has name \"{df['name']}\" "
                                 
            if df['description'] != 'NA':
                graql_insert_query += f", has description \"{df['description']}\" "
            if len(aliases) > 0:
                s = "|"
                graql_insert_query += f", has alias \"{s.join(aliases)}\" "
            #if f is not None:
            #    graql_insert_query += f", has first_seen {f} "
            #if f_d is not None:
            #    graql_insert_query += f", has first_seen_day \"{f_d}\" "
            #if f_m is not None:
             #   graql_insert_query += f", has first_seen_month \"{f_m}\" "
            #if f_m is not None:
            #    graql_insert_query += f", has first_seen_year \"{df['first_seen_year']}\""
            graql_insert_query += ";"
            #print(graql_insert_query)
            with session.transaction().write() as write_transaction:
                # make a write transection with the query
                write_transaction.query(graql_insert_query)
                # remember to commit at the end
                write_transaction.commit()

# %%
def load_data_into_grakn(session,input_df):
    print("Malware...")
    # using progress_apply instead of apply so we have a progress bar form tqdm
    # input_df.progress_apply(insert_one_intrusion_set, axis=1, session=session)
    print("Malware...")
    for index,row in input_df.iterrows():
        insert_one_malware(df=row,session=session)

# %%
def build_grakn_graph(input_df, keyspace_name):
    with GraknClient(uri="192.168.83.128:48555") as client:
        with client.session(keyspace = keyspace_name) as session:
            load_data_into_grakn(session,input_df)

# %%
build_grakn_graph(input_df=result,keyspace_name='grakn_new')
# Out:
# Malware...
# Malware...
# Insert: Ixeshe
# Insert: Aumlib
# Insert: Threebyte
# Insert: Hightide
# Insert: Waterspout
# Insert: Coblnt
# Insert: More_eggs
# Insert: Carbanak
# Insert:  PetrWrap
# Insert: Finspy
# Insert: Finfisher
# Insert: wingbird
# Insert: ADVSTORESHELL
# Insert: Cannon
# Insert: CHOPSTICK
# Insert: CORESHELL
# Insert: Downdelph
# Insert: Fysbis
# Insert: JHUHUGIT
# Insert: HIDEDRV
# Insert: Komplex
# Insert: LoJax
# Insert: XAgentOSX
# Insert: XTunnel
# Insert: Zebrocy
# Insert: Backspace
# Insert: Flashflood
# Insert: spaceship
# Insert: Neteagle
# Insert: shipspace
